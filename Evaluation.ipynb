# %% [markdown]
# # NLQ to SQL Query Translator: Evaluation
#
# This notebook contains our code to evaluate our Natural Language Query (NLQ) to Structured Query Language (SQL) generator. It requires functions from the nlq2sql and sqlExtract classes. It also assumes spaCy is already installed as spaCy comes pre-installed in the Google Colab environment.
#
# Note: change file paths wherever appropriate to avoid errors.

# %% [markdown]
# # General Setup

# %% [markdown]
# We mount this notebook so that it can access Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# We install dependencies and load the WikiSQL dataset.

# %%
# !pip install datasets
# Out:
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %%
from tqdm import tqdm
from datasets import load_dataset

# %%
dataset = load_dataset('wikisql')
# Out:
# Downloading builder script:   0%|          | 0.00/6.57k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.76k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.80k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/26.2M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/15878 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/8421 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/56355 [00:00<?, ? examples/s]

# %% [markdown]
# The cell below describes the format of the WikiSQL dataset. Each row has an NLQ, the corresponding SQL query, and a set of attributes (column names of the table).

# %%
question = dataset ['train'][0]['question']
sqlQuery = dataset ['train'][0]['sql']['human_readable']
columns = dataset ['train'][0]['table']['header']

print("NLQ:", question)
print("SQL Query:", sqlQuery)
print("Columns/Attributes:", columns)

print('Train length:', len(dataset['train']))
print('Validation length:', len(dataset['validation']))
print('Test length:', len(dataset['test']))
# Out:
# NLQ: Tell me what the notes are for South Australia
# SQL Query: SELECT Notes FROM table WHERE Current slogan = SOUTH AUSTRALIA
# Columns/Attributes: ['State/territory', 'Text/background colour', 'Format', 'Current slogan', 'Current series', 'Notes']
# Train length: 56355
# Validation length: 8421
# Test length: 15878

# %% [markdown]
# We import the nlq2sql class for evaluation and the sqlExtract class functions to extract attributes and values from SQL queries during evaluation.

# %%
# %load_ext autoreload
# %autoreload 2

from nlq2sql import *
from sqlExtract import *

# %% [markdown]
# The cell below shows an example usage of the sqlExtract's fetch where and select attributes functions.

# %%
sqlQuery = "SELECT COUNT Date,temp FROM table WHERE Location = davos AND Time > 45.7"
sqlExtractor = sqlExtract(sqlQuery)
whereAttr, whereAttrValue = sqlExtractor.fetch_where_attr()
print("Where Attributes:", whereAttr)
print("Where Attributes w/ Corresponding Values:", whereAttrValue)
print("Select Attributes:", sqlExtractor.fetch_select_attr())
# Out:
# Where Attributes: ['Location', 'Time']
# Where Attributes w/ Corresponding Values: {'Location': 'davos', 'Time': '45.7'}
# Select Attributes: {'Date': 'COUNT', 'temp': ''}

# %% [markdown]
# # Filter Test Data for Evaluation

# %% [markdown]
# We define filter functions to be those functions that help us filter our dataset to evaluate our model only on a specific subset of queries at a time. These functions also helped us analyze the intricacies of our model to understand its strengths and weaknesses. They also helped us develop our model iteratively so that it can gradually increase its complexity. Each filter function's condition is defined in the function's docstring.

# %%
def is_select_not_present_in_nlq(selectAttr, question):
  """Return true if the select attribute is not explicitly present in the NLQ."""
  # assume all the select attributes are explicitly present in the nlq
  for attr in selectAttr.keys():
    idx = question.lower().find(attr.lower())
    if attr != '*' and idx == -1:
        return True
    endIdx = idx + len(attr.lower()) - 1
    # if part of the select attr was found in the query, the character after
    # it (if exists) would not be a whitespace but would be an alphanum char
    if endIdx + 1 < len(question) and question[endIdx + 1].isalnum():
      return True
  return False

# %%
selectAttr = {'Start': ''}
question = "Where was the starting position when there were 182 laps?"
print(is_select_not_present_in_nlq(selectAttr, question))
# Out:
# True

# %%
def is_invalid_num_select_attr(selectAttr):
  """Return true if more than one attribute has to be selected."""
  return len(selectAttr) > 1

# %%
def is_invalid_constraint(sqlQuery):
  """Return true if an operator other than the = is used."""
  for char in ['<', '>', '>=', '<=', '!=', '<>']:
    if char in sqlQuery:
      return True
  return False

# %%
def is_invalid_num_where_attr(whereAttr):
  """Return true if more than one attribute has a constraint."""
  return len(whereAttr) > 1

# %%
def spaces_in_attr(iterable):
  """Return true if there is a space in the given set of attributes."""
  for attr in iterable:
    if ' ' in attr:
      return True
  return False

# %%
def attr_not_present_in_nlq(whereAttrValue, question):
  """Return true if the given set of attributes are not explicitly present in the NLQ."""
  for attr, value in whereAttrValue.items():
    idx = question.lower().find(attr.lower())
    if idx == -1:
      return True
    endIdx = idx + len(attr.lower()) - 1
    if endIdx + 1 < len(question) and question[endIdx + 1].isalnum():
      return True
  return False

# %% [markdown]
# The is_aggregate filter function filters out queries with aggregate function keywords in SQL. These keywords are always in uppercase in the SQL queries of the WikiSQL dataset due to which the function assumes the same.

# %%
def is_aggregate(sqlQuery):
  """Return true if an aggregate keyword exists in the NLQ."""
  aggr = ['MAX', 'MIN', 'SUM', 'COUNT', 'AVG']
  for agg in aggr:
    if agg in sqlQuery.split():
      return True
  return False

# %% [markdown]
# The filter function below checks if a value is not explicitly present in the NLQ. This is only true for a very few poorly formatted queries (about 20 out of 15,000 in the test set). We apply this filter by default to the test split of WikiSQL.

# %%
def value_not_present_in_nlq(whereAttrValue, question):
  """Return true if the values are not explicity present in the NLQ."""
  for attr, value in whereAttrValue.items():
      if question.lower().find(value.lower()) == -1:
        return True
  return False

# %% [markdown]
# Some NLQs had a thin space instead of a white space in the WikiSQL dataset which negatively affected the accuracy of our named-entity recognition (NER) model, so we are replacing them in the function below.

# %%
def remove_unicode_characters(text):
  # replace thin space with normal space
  return text.replace("\u2009", " ")

# %% [markdown]
# In the cell below, we define a function apply our desired filters and extract a partition of the WikiSQL test split to evaluate our model on.

# %%
def filter_test_data(filters={}):
  validFilters = {'is_select_not_present_in_nlq',
                   'is_invalid_num_select_attr',
                   'is_invalid_constraint',
                   'is_invalid_num_where_attr',
                   'spaces_in_select_attr',
                   'spaces_in_where_attr',
                   'attr_not_present_in_nlq',
                   'is_aggregate'}
  for filter in filters:
    assert filter in validFilters
  tagTestSet= []
  i = 0
  for row in tqdm(dataset['test']):
    question = row['question']
    sqlQuery = row['sql']['human_readable']
    columns = row['table']['header']
    question = remove_unicode_characters(question)
    sqlQuery = remove_unicode_characters(sqlQuery)
    sqlExtractor = sqlExtract(sqlQuery)
    for i in range(len(columns)):
      columns[i] = remove_unicode_characters(columns[i])
    selectAttr = sqlExtractor.fetch_select_attr()
    if 'is_select_not_present_in_nlq' in filters and is_select_not_present_in_nlq(selectAttr, question):
      continue
    if 'is_invalid_num_select_attr' in filters and is_invalid_num_select_attr(selectAttr):
      continue
    if 'is_invalid_constraint' in filters and is_invalid_constraint(sqlQuery):
      continue
    if 'is_aggregate' in filters and is_aggregate(sqlQuery):
      continue
    if 'spaces_in_select_attr' in filters and spaces_in_attr(selectAttr):
      continue
    if 'WHERE' in sqlQuery:
      whereAttr, whereAttrValue = sqlExtractor.fetch_where_attr()
      if 'is_invalid_num_where_attr' in filters and is_invalid_num_where_attr(whereAttr):
        continue
      if 'attr_not_present_in_nlq' in filters and attr_not_present_in_nlq(whereAttrValue, question):
        continue
      if 'spaces_in_where_attr' in filters and spaces_in_attr(whereAttr):
        continue
      if value_not_present_in_nlq(whereAttrValue, question):
        continue
    tagTestSet.append({'question': question, 'sqlQuery': sqlQuery, 'attr': columns})
  print(len(tagTestSet))
  return tagTestSet

# %% [markdown]
# The obtain_aggregate_queries function obtains aggregate queries with some default filters applied: Values and SELECT/WHERE attributes are explicitly present in the NLQ.

# %%
def obtain_aggregate_queries():
  tagTestSet= []
  i = 0
  for row in tqdm(dataset['test']):
    question = row['question']
    sqlQuery = row['sql']['human_readable']
    columns = row['table']['header']
    question = remove_unicode_characters(question)
    sqlQuery = remove_unicode_characters(sqlQuery)
    sqlExtractor = sqlExtract(sqlQuery)
    addedIndicator = False
    for i in range(len(columns)):
      columns[i] = remove_unicode_characters(columns[i])
    selectAttr = sqlExtractor.fetch_select_attr()
    if is_select_not_present_in_nlq(selectAttr, question):
      continue
    if 'WHERE' in sqlQuery:
      whereAttr, whereAttrValue = sqlExtractor.fetch_where_attr()
      if attr_not_present_in_nlq(whereAttrValue, question):
        continue
      if value_not_present_in_nlq(whereAttrValue, question):
        continue
    if is_aggregate(sqlQuery):
      tagTestSet.append({'question': question, 'sqlQuery': sqlQuery, 'attr': columns})
  print(len(tagTestSet))
  return tagTestSet

# %% [markdown]
# The obtain_absent_where_attr_queries function obtains queries whose where attributes are not explicitly present in the NLQ with some default filters applied: Values and SELECT attributes are explicitly present in the NLQ.

# %%
def obtain_absent_where_attr_queries():
  """Obtain queries where WHERE attr isn't present in the NLQ."""
  tagTestSet= []
  i = 0
  for row in tqdm(dataset['test']):
    question = row['question']
    sqlQuery = row['sql']['human_readable']
    columns = row['table']['header']
    question = remove_unicode_characters(question)
    sqlQuery = remove_unicode_characters(sqlQuery)
    sqlExtractor = sqlExtract(sqlQuery)
    for i in range(len(columns)):
      columns[i] = remove_unicode_characters(columns[i])
    selectAttr = sqlExtractor.fetch_select_attr()
    if is_select_not_present_in_nlq(selectAttr, question):
      continue
    if 'WHERE' in sqlQuery:
      whereAttr, whereAttrValue = sqlExtractor.fetch_where_attr()
      if value_not_present_in_nlq(whereAttrValue, question):
        continue
      if attr_not_present_in_nlq(whereAttrValue, question):
        tagTestSet.append({'question': question, 'sqlQuery': sqlQuery, 'attr': columns})
  print(len(tagTestSet))
  return tagTestSet

# %% [markdown]
# # Setup Evaluation Helper Functions

# %% [markdown]
# We install the large spaCy English model to perform tokenization in nlq2sql and the transformers library to perform custom NER.

# %%
import spacy
# !python3 -m spacy download en_core_web_lg
# Out:
# Successfully installed en-core-web-lg-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !pip install spacy-transformers

# %%
def ignore_case_and_order(iterable):
  """Return the iterable in lower case as a set."""
  temp = []
  for item in iterable:
    if item is None:
      print(iterable)
    temp.append(item.lower())
  return set(temp)

# %%
def ignore_case(dictObj):
  """Return a dict with lower case keys and values."""
  temp = {}
  for key, value in dictObj.items():
    temp[key.lower()] = value.lower()
  return temp

# %%
def remove_quotes(sqlQuery):
  """Remove quotes from an SQL query."""
  return sqlQuery.replace('"', '')

# %% [markdown]
# The evaluate_data function defined below calculates accuracy on the filtered tagTestSet and prints statistics. It prints the SELECT accuracy, which is calculated as:
# $$\frac{\text{#queries with correct SELECT attributes}}{\text{#total queries}}$$
# the WHERE accuracy, which is calculated as:
# $$\frac{\text{#queries with correct WHERE attributes}}{\text{#total queries}}$$
# the Value accuracy, which is calculated as:
# $$\frac{\text{#queries with correct Values}}{\text{#total queries}}$$
# the Overall accuracy, which is calculated as:
# $$\frac{\text{#correct queries}}{\text{#total queries}}$$
# Correct queries are those queries with correct SELECT attributes and correct WHERE attributes associated with their correct corresponding values and operators.
#
# It prints a "1" if the SELECT/WHERE attributes and values in the predicted and expected SQL query match. Otherwise, it prints the NLQ, attributes, predicted SQL query, and the expected SQL query. Along with this information, it also prints a progress fraction: $$\frac{\text{#queries completed}}{\text{#total queries}}$$

# %%
import spacy_transformers

def evaluate_data(tagTestSet, nlp_ner, rule, nlp_aggr=None):
  """Calculate accuracy on test data and print statistics."""
  numCorrectOverall = 0
  numCorrectSelect = 0
  numCorrectWhere = 0
  numCorrectValues = 0
  nlp = spacy.load("en_core_web_lg")
  i = 0
  for obj in tagTestSet:
      sqlQuery = remove_quotes(obj['sqlQuery'])
      attributes = obj['attr']
      nlq = obj['question']
      nQueryObj = nlq2sql(nlq, "table", attributes, nlp, nlp_ner, rule)
      isSelect = False
      pred = nQueryObj.get_sql_query()
      sqlExtractor = sqlExtract(sqlQuery)
      correctSelectAttr = sqlExtractor.fetch_select_attr()
      if ignore_case(nQueryObj.selectAttributes) == ignore_case(correctSelectAttr):
          numCorrectSelect += 1
          isSelect = True
      correctWhereAttr, whereAttrVals = sqlExtractor.fetch_where_attr()
      if ignore_case_and_order(nQueryObj.whereAttributes.keys()) == ignore_case_and_order(correctWhereAttr):
          numCorrectWhere += 1
      if ignore_case_and_order(nQueryObj.whereAttributes.values()) == ignore_case_and_order(whereAttrVals.values()):
          numCorrectValues += 1
      if isSelect and ignore_case(nQueryObj.whereAttributes) == ignore_case(whereAttrVals):
          numCorrectOverall += 1
          print(f"{i} / {len(tagTestSet)}", 1)
      else:
        print(f"{i} / {len(tagTestSet)}", obj['question'], obj['attr'], pred, sqlQuery)
      i += 1
  print('Select accuracy', (numCorrectSelect / len(tagTestSet)) * 100)
  print('Where accuracy', (numCorrectWhere / len(tagTestSet)) * 100)
  print('Value accuracy', (numCorrectValues / len(tagTestSet)) * 100)
  print('Overall accuracy', (numCorrectOverall / len(tagTestSet)) * 100)

# %% [markdown]
# # Evaluation
#
# This section consists of our results from evaluating our NLP to SQL Query translator on various cases which represent specific subsets of queries from the WikiSQL dataset. We have analyzed these results in detail in our final report.

# %% [markdown]
# We load 2 models: one that supports tagging SELECT attributes with their corresponding aggregate functions and one that doesn't. The nlp_ner model doesn't support aggregation, that is, it only tags words as "SELECT" or "CONSTRAINT". The nlp_aggr model supports aggregation, that is, it tags words as "COUNT SELECT", "MAX SELECT", "MIN SELECT", "AVG SELECT", "SELECT", and "CONSTRAINT".

# %%
nlp_ner = spacy.load("/content/drive/MyDrive/train_spacy/model-best-no-aggr")

# %%
nlp_aggr = spacy.load("/content/drive/MyDrive/train_spacy/model-best")

# %% [markdown]
# # Case 1: No Aggregation, Attributes Explicitly Present in NLQ, Rule 1
#
# We evaluate accuracy assuming that
#
# *   the SELECT and WHERE attributes are explicitly present in the NLQ
# *   there are no aggregate functions like MAX, MIN, COUNT, or others
# *   nlq2sql uses rule 1 (defined in our report)
#
# We also assume that there are no WHERE clauses with any operator other than '=' but no such queries exist when we also impose the condition that attributes need to be explicitly present in the NLQ.
#
# The ner model used in the evaluation below doesn't support aggregation.

# %%
filters = {'is_select_not_present_in_nlq',
           'is_invalid_constraint',
           'attr_not_present_in_nlq',
           'is_aggregate'}
tagTestSet = filter_test_data(filters)
print(len(tagTestSet))
# Out:
# 100%|██████████| 15878/15878 [00:06<00:00, 2383.87it/s]
# 4855
# 4855

# %%
evaluate_data(tagTestSet, nlp_ner, 'rule1')
# Out:
# 0 / 4855 1
# 1 / 4855 1
# 2 / 4855 1
# 3 / 4855 1
# 4 / 4855 1
# 5 / 4855 1
# 6 / 4855 1
# 7 / 4855 1
# 8 / 4855 1
# 9 / 4855 1
# 10 / 4855 1
# 11 / 4855 1
# 12 / 4855 1
# 13 / 4855 1
# 14 / 4855 If % lunsford is 51.82% what is the % mcconnell in Letcher? ['County', 'Precincts', 'Lunsford', '% Lunsford', 'McConnell', '% McConnell', 'Total'] SELECT % mcconnell FROM table WHERE lunsford = 51.82% SELECT % McConnell FROM table WHERE % Lunsford = 51.82%
# 15 / 4855 1
# 16 / 4855 what's the original air date with title  "hell" ['No. in series', 'No. in season', 'Title', 'Directed by', 'Written by', 'Original air date'] SELECT original air date FROM table WHERE title = "hell" SELECT Original air date FROM table WHERE Title = Hell
# 17 / 4855 1
# 18 / 4855 What is the percentage of the  trance- n himalaya zone that corresponds with the high hill zone is 25%? ['Particulars and Characteristics', 'Shivalik Zone', 'Mid-Hill Zone', 'High hill zone', 'Trance- n Himalaya Zone'] SELECT * FROM table WHERE high hill zone = 25% SELECT Trance- n Himalaya Zone FROM table WHERE High hill zone = 25%
# 19 / 4855 1
# 20 / 4855 1
# 21 / 4855 1
# 22 / 4855 1
# 23 / 4855 1
# 24 / 4855 Which song has picturization by only vijay? ['Track #', 'Song', 'Singers', 'Picturization', 'Length', 'Lyricist'] SELECT song FROM table WHERE picturization = only vijay SELECT Song FROM table WHERE Picturization = Vijay
# 25 / 4855 For which singers was Alangudi Somu the lyricist? ['Track #', 'Song', 'Singers', 'Picturization', 'Length', 'Lyricist'] SELECT * FROM table WHERE singers = Alangudi Somu SELECT Singers FROM table WHERE Lyricist = Alangudi Somu
# 26 / 4855 1
# 27 / 4855 1
# 28 / 4855 What percentage of The Bronx voters occured when Manhattan had 29.9% of voters? ['1953', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT The Bronx FROM table WHERE % = 29.9% SELECT The Bronx FROM table WHERE Manhattan = 29.9%
# 29 / 4855 What number of voters did the Bronx have when the total number was 2054? ['1953', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT * FROM table WHERE the bronx = voters AND total = 2054 SELECT The Bronx FROM table WHERE Total = 2054
# 30 / 4855 1
# 31 / 4855 1
# 32 / 4855 1
# 33 / 4855 Which candidate won 88 votes in Queens in 1921? ['1921', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT * FROM table WHERE queens = 88 SELECT 1921 FROM table WHERE Queens = 88
# 34 / 4855 1
# 35 / 4855 1
# 36 / 4855 1
# 37 / 4855 What are the highest recorded attendance rates of the stadiums with an average attendance of 4752? ['Team', 'Stadium', 'Capacity', 'Lowest', 'Highest', 'Average'] SELECT * FROM table WHERE average = 4752 SELECT Highest FROM table WHERE Average = 4752
# 38 / 4855 What is the catalog number of the title called "super callanetics"? ['Year', 'Title', 'Format', 'Studio', 'Release Date', 'Copyright Information', 'Catalog Number'] SELECT * FROM table WHERE title = "super callanetics" SELECT Catalog Number FROM table WHERE Title = Super Callanetics
# 39 / 4855 1
# 40 / 4855 1
# 41 / 4855 1
# 42 / 4855 1
# 43 / 4855 What is the premiere on the mega channel? ['Country/Region', 'Show Title', 'Languages', 'Host', 'Channel', 'Premiere', 'Seasons', 'Status'] SELECT premiere FROM table WHERE channel = mega SELECT Premiere FROM table WHERE Channel = Mega Channel
# 44 / 4855 1
# 45 / 4855 1
# 46 / 4855 1
# 47 / 4855 1
# 48 / 4855 1
# 49 / 4855 1
# 50 / 4855 1
# 51 / 4855 Who was the winning driver when the pole position was held by Ayrton Senna and the Fastest lap was Michael Schumacher? ['Round', 'Grand Prix', 'Pole Position', 'Fastest Lap', 'Winning Driver', 'Winning Constructor', 'Report'] SELECT winning driver FROM table WHERE fastest lap = Michael Schumacher SELECT Winning Driver FROM table WHERE Pole Position = Ayrton Senna AND Fastest Lap = Michael Schumacher
# 52 / 4855 1
# 53 / 4855 1
# 54 / 4855 1
# 55 / 4855 1
# 56 / 4855 1
# 57 / 4855 1
# 58 / 4855 1
# 59 / 4855 1
# 60 / 4855 1
# 61 / 4855 1
# 62 / 4855 Which model number has a GVM (kg) Technical Capacity of 16000 and a Torque Nm@rpm of 600 @ 1700? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT * FROM table WHERE model = model number AND gvm (kg) technical capacity = 16000 AND torque nm@rpm = 600 @ 1700 SELECT Model FROM table WHERE GVM (kg) Technical Capacity = 16000 AND Torque Nm@rpm = 600 @ 1700
# 63 / 4855 If the model is  15.180e, what is the GVM (kg) Technical Capacity? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT * FROM table WHERE model = Technical Capacity SELECT GVM (kg) Technical Capacity FROM table WHERE Model = 15.180E
# 64 / 4855 When the transmission make/type/speed is eaton fs 5306-a manual synchromesh 6 speed, what is the value of the gcm (kg) technical capacity? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT * FROM table WHERE transmission make/type/speed = technical capacity SELECT GCM (kg) Technical Capacity FROM table WHERE Transmission Make/Type/Speed = Eaton FS 5306-A Manual Synchromesh 6 Speed
# 65 / 4855 Which model possesses a transmission make/type/speed of eaton fs-6306 a manual synchromesh 6 speed? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT model FROM table WHERE transmission make/type/speed = manual synchromesh 6 SELECT Model FROM table WHERE Transmission Make/Type/Speed = Eaton FS-6306 A Manual Synchromesh 6 Speed
# 66 / 4855 For driver Mark Skaife what is the result for race 1? ['Driver', 'No.', 'Team', 'Car', 'Race 1', 'GP 100', 'Race 3', 'Points'] SELECT * FROM table WHERE driver = 1 AND race 1 = result SELECT Race 1 FROM table WHERE Driver = Mark Skaife
# 67 / 4855 1
# 68 / 4855 1
# 69 / 4855 1
# 70 / 4855 1
# 71 / 4855 1
# 72 / 4855 1
# 73 / 4855 1
# 74 / 4855 1
# 75 / 4855 1
# 76 / 4855 1
# 77 / 4855 1
# 78 / 4855 1
# 79 / 4855 1
# 80 / 4855 1
# 81 / 4855 1
# 82 / 4855 1
# 83 / 4855 1
# 84 / 4855  what's the introduced where notes is 9 withdrawn in 1946 after fire ['Number Range', 'Introduced', 'Builder', 'Engine', 'Weight (long tons)', 'Seats', 'Withdrawn', 'Notes'] SELECT introduced FROM table WHERE withdrawn = 9 withdrawn in 1946 after fire SELECT Introduced FROM table WHERE Notes = 9 withdrawn in 1946 after fire
# 85 / 4855 1
# 86 / 4855 1
# 87 / 4855 1
# 88 / 4855 what is the song name for the film name ganga kare insaaf? ['Year', 'Song name', 'Film name', 'Co-singer', 'Music director', 'Lyricist', 'Language'] SELECT * FROM table WHERE film name = ganga kare insaaf SELECT Song name FROM table WHERE Film name = Ganga Kare Insaaf
# 89 / 4855 1
# 90 / 4855  what's the electorate where election date is 16 cannot handle non-empty timestamp argument! ['Member', 'Electorate', 'Province', 'MPs term', 'Election date'] SELECT electorate FROM table WHERE election date = 16 cannot handle non-empty timestamp argument SELECT Electorate FROM table WHERE Election date = 16 Cannot handle non-empty timestamp argument!
# 91 / 4855 1
# 92 / 4855 1
# 93 / 4855 1
# 94 / 4855 1
# 95 / 4855 1
# 96 / 4855 How many integrated allied-related are there? ['Component', 'Integrated', 'Allied-Related', 'Allied-Unrelated', 'Holding'] SELECT * FROM table WHERE integrated = integrated allied-related SELECT Integrated FROM table WHERE Allied-Related = Many
# 97 / 4855 1
# 98 / 4855 what is the integrated in which the holding allied-unrelated is many? ['Component', 'Integrated', 'Allied-Related', 'Allied-Unrelated', 'Holding'] SELECT integrated FROM table WHERE allied-unrelated = many SELECT Holding FROM table WHERE Allied-Unrelated = Many
# 99 / 4855 1
# 100 / 4855 1
# 101 / 4855 1
# 102 / 4855 1
# 103 / 4855 1
# 104 / 4855 1
# 105 / 4855 1
# 106 / 4855 Crockett High School had which number(#)? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT * FROM table WHERE high school = Crockett High School AND # = number SELECT # FROM table WHERE High School = Crockett
# 107 / 4855 Which home town was the high school Catholic University located in? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT home town FROM table WHERE high school = Catholic SELECT Home Town FROM table WHERE High School = Catholic University
# 108 / 4855 What height was the forward position at Crockett High School? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT height FROM table WHERE position = forward AND high school = Crockett High School SELECT Height FROM table WHERE Position = Forward AND High School = Crockett
# 109 / 4855 1
# 110 / 4855 1
# 111 / 4855 1
# 112 / 4855 1
# 113 / 4855 1
# 114 / 4855 1
# 115 / 4855 1
# 116 / 4855 1
# 117 / 4855 1
# 118 / 4855 1
# 119 / 4855 1
# 120 / 4855 1
# 121 / 4855 What is the score for the interview for the state of New York? ['State', 'Preliminaries', 'Interview', 'Swimsuit', 'Evening Gown', 'Average'] SELECT * FROM table WHERE interview = score AND state = New York SELECT Interview FROM table WHERE State = New York
# 122 / 4855 1
# 123 / 4855 1
# 124 / 4855 1
# 125 / 4855 1
# 126 / 4855 1
# 127 / 4855 1
# 128 / 4855 1
# 129 / 4855 1
# 130 / 4855 What is the theme for the episode selection process? ['Episode', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT theme FROM table WHERE episode = selection SELECT Theme FROM table WHERE Episode = Selection Process
# 131 / 4855 What is the song choice when the theme is not aired? ['Episode', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT song choice FROM table WHERE theme = not aired SELECT Theme FROM table WHERE Song choice = Not Aired
# 132 / 4855 What years did Markose Bristow Madhumita Bisht win the mens singles and/or the mixed doubles? ['Season', 'Mens singles', 'Womens singles', 'Mens doubles', 'Womens doubles', 'Mixed doubles'] SELECT * FROM table WHERE mens singles = Markose Bristow Madhumita Bisht SELECT Mens singles FROM table WHERE Mixed doubles = Markose Bristow Madhumita Bisht
# 133 / 4855 What year is Japan the country? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT year FROM table WHERE year = Japan SELECT Year FROM table WHERE Country = Japan
# 134 / 4855 What is the year that Dewi Claire Schreefel is the champion? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT year FROM table WHERE year = Dewi Claire Schreefel SELECT Year FROM table WHERE Champion = Dewi Claire Schreefel
# 135 / 4855 What is the tournament location when Vicky Hurst in the champion? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT tournament location FROM table WHERE tournament location = Vicky Hurst SELECT Tournament location FROM table WHERE Champion = Vicky Hurst
# 136 / 4855 1
# 137 / 4855 1
# 138 / 4855 1
# 139 / 4855 1
# 140 / 4855 Which is the charity that the background of the celebrity is heavyweight champion? ['Celebrity', 'Background', 'Original Team', 'Age', 'Hometown', 'Charity', 'Result', 'Raised'] SELECT charity FROM table WHERE celebrity = heavyweight champion SELECT Charity FROM table WHERE Background = Heavyweight Champion
# 141 / 4855 1
# 142 / 4855 1
# 143 / 4855 1
# 144 / 4855 What is the background of the celebrity who had the result 13 the celebrity apprentice (2008-03-27)? ['Celebrity', 'Background', 'Original Team', 'Age', 'Hometown', 'Charity', 'Result', 'Raised'] SELECT background FROM table WHERE celebrity = celebrity apprentice (2008-03-27) SELECT Background FROM table WHERE Result = 13 The Celebrity Apprentice (2008-03-27)
# 145 / 4855 1
# 146 / 4855 1
# 147 / 4855 1
# 148 / 4855 1
# 149 / 4855 1
# 150 / 4855 1
# 151 / 4855 1
# 152 / 4855 1
# 153 / 4855 1
# 154 / 4855 1
# 155 / 4855 What is the 2007 estimate when the rank (csa) is 4 ['Rank (CSA)', 'Combined Statistical Area (or Metropolitan Statistical Area if noted)', 'State(s)', '2007 Estimate', '2000 Population', 'Percent Change (1990–2000)'] SELECT * FROM table WHERE rank (csa) = 4 SELECT 2007 Estimate FROM table WHERE Rank (CSA) = 4
# 156 / 4855 1
# 157 / 4855 1
# 158 / 4855 1
# 159 / 4855 1
# 160 / 4855 1
# 161 / 4855 1
# 162 / 4855 1
# 163 / 4855 1
# 164 / 4855 1
# 165 / 4855 1
# 166 / 4855 What was the lost with tries for? ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Tries for', 'Tries against', 'Try bonus', 'Losing bonus', 'Points'] SELECT lost FROM table SELECT Lost FROM table WHERE Tries for = Tries for
# 167 / 4855 1
# 168 / 4855 1
# 169 / 4855 1
# 170 / 4855 1
# 171 / 4855 1
# 172 / 4855 What is the type of the printer ports included in the EX Plus3 model number? ['Model number', 'Printer ports', 'Network ports', 'Network protocols', 'Firmware', 'Notes'] SELECT * FROM table WHERE printer ports = type AND model number = EX Plus3 SELECT Printer ports FROM table WHERE Model number = EX Plus3
# 173 / 4855 What is the traditional way to write the name of the district who's area is 2331? ['English Name', 'Simplified', 'Traditional', 'Pinyin', 'Area', 'Population', 'Density'] SELECT * FROM table WHERE area = 2331 SELECT Traditional FROM table WHERE Area = 2331
# 174 / 4855 1
# 175 / 4855 1
# 176 / 4855 1
# 177 / 4855 1
# 178 / 4855 1
# 179 / 4855 1
# 180 / 4855 What was the air date of part 2 of the episode whose part 1 was aired on January 31, 2008? ['Episode #', 'Title', 'Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5', 'Part 6'] SELECT part 2 FROM table WHERE part 2 = air date AND part 1 = January 31, 2008 SELECT Part 2 FROM table WHERE Part 1 = January 31, 2008
# 181 / 4855 What's the air date of part 1 of the episode whose part 2 aired on December 2, 2007? ['Episode #', 'Title', 'Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5', 'Part 6'] SELECT part 1 FROM table WHERE part 1 = air date AND part 2 = December 2, 2007 SELECT Part 1 FROM table WHERE Part 2 = December 2, 2007
# 182 / 4855 1
# 183 / 4855 1
# 184 / 4855 1
# 185 / 4855 1
# 186 / 4855 1
# 187 / 4855 1
# 188 / 4855 1
# 189 / 4855 1
# 190 / 4855 1
# 191 / 4855 1
# 192 / 4855 Who were the candidates when gregory w. meeks was the incumbent ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT candidates FROM table WHERE candidates = gregory w. meeks SELECT Candidates FROM table WHERE Incumbent = Gregory W. Meeks
# 193 / 4855 1
# 194 / 4855 1
# 195 / 4855 1
# 196 / 4855 1
# 197 / 4855 1
# 198 / 4855 1
# 199 / 4855 1
# 200 / 4855 1
# 201 / 4855 1
# 202 / 4855 1
# 203 / 4855 1
# 204 / 4855 1
# 205 / 4855 1
# 206 / 4855 1
# 207 / 4855 1
# 208 / 4855 1
# 209 / 4855 1
# 210 / 4855 1
# 211 / 4855 1
# 212 / 4855 1
# 213 / 4855 1
# 214 / 4855 1
# 215 / 4855 1
# 216 / 4855 1
# 217 / 4855 1
# 218 / 4855 What district is F. Edward Hebert the incumbent in? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = F. Edward Hebert SELECT District FROM table WHERE Incumbent = F. Edward Hebert
# 219 / 4855 1
# 220 / 4855 What's the district that Otto Passman is the incumbent of? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = Otto Passman SELECT District FROM table WHERE Incumbent = Otto Passman
# 221 / 4855 1
# 222 / 4855 1
# 223 / 4855 1
# 224 / 4855 1
# 225 / 4855 1
# 226 / 4855 1
# 227 / 4855 1
# 228 / 4855 1
# 229 / 4855 1
# 230 / 4855 1
# 231 / 4855 1
# 232 / 4855 1
# 233 / 4855 1
# 234 / 4855 What district was Harold Earthman the incumbent in?  ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = Harold Earthman SELECT District FROM table WHERE Incumbent = Harold Earthman
# 235 / 4855 1
# 236 / 4855 1
# 237 / 4855 1
# 238 / 4855 1
# 239 / 4855 1
# 240 / 4855 What year was incumbent william f. stevenson first elected? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT first elected FROM table WHERE first elected = william f. stevenson SELECT First elected FROM table WHERE Incumbent = William F. Stevenson
# 241 / 4855 1
# 242 / 4855 1
# 243 / 4855 1
# 244 / 4855 1
# 245 / 4855 1
# 246 / 4855 1
# 247 / 4855 1
# 248 / 4855 Pink cytoplasm is seen in a test that specifically stains what? ['Stain', 'Common use', 'Nucleus', 'Cytoplasm', 'Red blood cell (RBC)', 'Collagen fibers', 'Specifically stains'] SELECT * FROM table WHERE cytoplasm = Pink cytoplasm SELECT Specifically stains FROM table WHERE Cytoplasm = Pink
# 249 / 4855 The pink cytoplasm will have a nucleus of what color? ['Stain', 'Common use', 'Nucleus', 'Cytoplasm', 'Red blood cell (RBC)', 'Collagen fibers', 'Specifically stains'] SELECT nucleus FROM table WHERE cytoplasm = pink cytoplasm SELECT Nucleus FROM table WHERE Cytoplasm = Pink
# 250 / 4855 where is hte second place winner from united kingdom? ['Year', 'Winner', 'Language', 'Artist', 'Song', 'Points', 'Margin', 'Second place', 'Date', 'Venue', 'Location', 'Participants'] SELECT second place FROM table WHERE winner = united kingdom SELECT Winner FROM table WHERE Second place = United Kingdom
# 251 / 4855 1
# 252 / 4855 1
# 253 / 4855 1
# 254 / 4855 1
# 255 / 4855 1
# 256 / 4855 1
# 257 / 4855 1
# 258 / 4855 1
# 259 / 4855 1
# 260 / 4855 1
# 261 / 4855 what's the byu-uu score with uu-usu score being 44–16 ['Season', 'Winner', 'BYU-UU score', 'BYU-USU score', 'UU-USU score'] SELECT * FROM table WHERE uu-usu score = 44–16 SELECT BYU-UU score FROM table WHERE UU-USU score = 44–16
# 262 / 4855 what's the record with high points being dwyane wade (27) and location attendance being arco arena ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT record FROM table WHERE location attendance = arco arena SELECT Record FROM table WHERE High points = Dwyane Wade (27) AND Location Attendance = ARCO Arena
# 263 / 4855 1
# 264 / 4855 1
# 265 / 4855 1
# 266 / 4855 1
# 267 / 4855 1
# 268 / 4855 1
# 269 / 4855 what's the district with party being republican and elected being 1998 ['District', 'Incumbent', 'Party', 'Elected', 'Status', 'Opponent'] SELECT district FROM table WHERE elected = 1998 SELECT District FROM table WHERE Party = Republican AND Elected = 1998
# 270 / 4855 1
# 271 / 4855 1
# 272 / 4855 1
# 273 / 4855 1
# 274 / 4855 1
# 275 / 4855 1
# 276 / 4855 1
# 277 / 4855 1
# 278 / 4855 what's the result with opponent being at oakland raiders ['Week', 'Date', 'Opponent', 'Result', 'Stadium', 'Record', 'Attendance'] SELECT result FROM table WHERE opponent = oakland raiders SELECT Result FROM table WHERE Opponent = at Oakland Raiders
# 279 / 4855 1
# 280 / 4855 1
# 281 / 4855 The results for gt2 winning team is all lars-erik nielsen allan simonsen richard westbrook.  ['Rnd', 'Circuit', 'LMP1 Winning Team', 'LMP2 Winning Team', 'GT1 Winning Team', 'GT2 Winning Team', 'Results'] SELECT results FROM table WHERE gt2 winning team = all lars-erik nielsen allan simonsen richard westbrook SELECT Results FROM table WHERE GT2 Winning Team = Lars-Erik Nielsen Allan Simonsen Richard Westbrook
# 282 / 4855 1
# 283 / 4855 1
# 284 / 4855 1
# 285 / 4855 1
# 286 / 4855 1
# 287 / 4855 1
# 288 / 4855 1
# 289 / 4855 1
# 290 / 4855 1
# 291 / 4855 1
# 292 / 4855 1
# 293 / 4855 1
# 294 / 4855 picturesque and trekking route is the category what is the height from sea level in meters? ['Name Of Place', 'Height from Sea Level In Meters', 'Nearby Town', 'Trekking Route', 'Category'] SELECT height from sea level in meters FROM table WHERE trekking route = picturesque and trekking route SELECT Height from Sea Level In Meters FROM table WHERE Category = Picturesque and Trekking Route
# 295 / 4855 1
# 296 / 4855 1
# 297 / 4855 1
# 298 / 4855 1
# 299 / 4855 When the total points are 22 how many total touchdowns have been made? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT * FROM table WHERE points = 22 AND touchdowns = total touchdowns SELECT Touchdowns FROM table WHERE Points = 22
# 300 / 4855 1
# 301 / 4855 Who led the points classification when Roman Kreuziger led the young rider classification? ['Stage', 'Winner', 'General classification', 'Points classification', 'Mountains classification', 'Young rider classification', 'Team classification', 'Combativity award'] SELECT points classification FROM table WHERE points classification = Roman Kreuziger SELECT Points classification FROM table WHERE Young rider classification = Roman Kreuziger
# 302 / 4855 Name the hometown for ventrell jenkins ['Position', 'Number', 'Name', 'Height', 'Weight', 'Class', 'Hometown', 'Games↑'] SELECT hometown FROM table WHERE hometown = ventrell jenkins SELECT Hometown FROM table WHERE Name = Ventrell Jenkins
# 303 / 4855 1
# 304 / 4855 1
# 305 / 4855 1
# 306 / 4855 1
# 307 / 4855 What locale has the skip Colleen Jones? ['Locale', 'Skip', 'W', 'L', 'PF', 'PA', 'Ends Won', 'Ends Lost', 'Blank Ends', 'Stolen Ends', 'Shot Pct.'] SELECT locale FROM table WHERE l = Colleen Jones SELECT Locale FROM table WHERE Skip = Colleen Jones
# 308 / 4855 Who plays Overton Moyle in casino theatre 1888 & savoy theatre 1906? ['Role', 'Savoy Theatre 1888', 'Casino Theatre 1888', 'Savoy Theatre 1897', 'Savoy Theatre 1906', 'Savoy Theatre 1909'] SELECT * FROM table WHERE casino theatre 1888 = Overton Moyle AND savoy theatre 1906 = casino theatre 1888 & savoy theatre 1906 SELECT Casino Theatre 1888 FROM table WHERE Savoy Theatre 1906 = Overton Moyle
# 309 / 4855 1
# 310 / 4855 1
# 311 / 4855 what's the result with opponent being at new england patriots ['Week', 'Date', 'Opponent', 'Result', 'Record', 'Game Site', 'Attendance'] SELECT result FROM table WHERE opponent = new england patriots SELECT Result FROM table WHERE Opponent = at New England Patriots
# 312 / 4855 1
# 313 / 4855 1
# 314 / 4855 1
# 315 / 4855 1
# 316 / 4855 1
# 317 / 4855 1
# 318 / 4855 1
# 319 / 4855 Which player's results were T6 in the PGA Ch., T4 in the Masters and T8 at the U.S. Open? ['Nationality', 'Player', 'Year', 'Wins', 'Masters', 'U.S. Open', 'Open Ch.', 'PGA Ch.'] SELECT player FROM table WHERE pga ch. = T4 AND masters = T8 SELECT Player FROM table WHERE PGA Ch. = T6 AND Masters = T4 AND U.S. Open = T8
# 320 / 4855 What is the result at the Masters for the player who finished R16 at the PGA Ch.? ['Nationality', 'Player', 'Year', 'Wins', 'Masters', 'U.S. Open', 'Open Ch.', 'PGA Ch.'] SELECT * FROM table WHERE pga ch. = R16 SELECT Masters FROM table WHERE PGA Ch. = R16
# 321 / 4855 1
# 322 / 4855 1
# 323 / 4855 1
# 324 / 4855 1
# 325 / 4855 1
# 326 / 4855 which electorate is 54787 of the constituency ['Constituency', 'Electorate', 's Spoilt vote', 'Total poll (%)', 'For (%)', 'Against (%)'] SELECT electorate FROM table WHERE electorate = 54787 SELECT Constituency FROM table WHERE Electorate = 54787
# 327 / 4855 1
# 328 / 4855 1
# 329 / 4855 1
# 330 / 4855 Name the solo when name is briggs, diyral ['Name', 'GP', 'Solo', 'Ast', 'Total', 'TFL-Yds', 'No-Yds', 'BrUp', 'QBH', 'No.-Yds', 'Avg', 'TD', 'Rcv-Yds', 'FF', 'Blkd Kick'] SELECT solo FROM table WHERE solo = briggs, diyral SELECT Solo FROM table WHERE Name = Briggs, Diyral
# 331 / 4855 Name the gp for ff being 0 and qbh being 1 ['Name', 'GP', 'Solo', 'Ast', 'Total', 'TFL-Yds', 'No-Yds', 'BrUp', 'QBH', 'No.-Yds', 'Avg', 'TD', 'Rcv-Yds', 'FF', 'Blkd Kick'] SELECT gp FROM table WHERE qbh = 1 SELECT GP FROM table WHERE FF = 0 AND QBH = 1
# 332 / 4855 When the division is Division 2 men what is the champion score? ['Division', 'Champion Score', 'Runner-Up Score', 'Final MVP Team', 'Defensive Player of the Final Team'] SELECT * FROM table WHERE division = champion SELECT Champion Score FROM table WHERE Division = Division 2 Men
# 333 / 4855 1
# 334 / 4855 1
# 335 / 4855 1
# 336 / 4855 1
# 337 / 4855 1
# 338 / 4855 1
# 339 / 4855 1
# 340 / 4855 1
# 341 / 4855 What is the clock multiplier if the voltage range (v) is 3.3 - 3.6; input clock (mhz) is 33 x 3 / 50 x 2; and part number is a80486dx4-100? ['Processor Speed (MHz)', 'Input Clock (MHz)', 'Voltage Center (V)', 'Voltage Range (V)', 'Part Number', 'Clock Multiplier', 'S-Spec Number'] SELECT clock multiplier FROM table WHERE input clock (mhz) = 33 x 3 / 50 x 2 AND part number = a80486dx4-100 SELECT Clock Multiplier FROM table WHERE Voltage Range (V) = 3.3 - 3.6 AND Input Clock (MHz) = 33 X 3 / 50 X 2 AND Part Number = A80486DX4-100
# 342 / 4855 1
# 343 / 4855 1
# 344 / 4855 1
# 345 / 4855 What date was parliament assembled when John rudhale was first member? ['Elected', 'Assembled', 'Dissolved', 'First member', 'Second member'] SELECT * FROM table WHERE first member = John rudhale SELECT Assembled FROM table WHERE First member = John Rudhale
# 346 / 4855 1
# 347 / 4855 1
# 348 / 4855 1
# 349 / 4855 1
# 350 / 4855 1
# 351 / 4855 1
# 352 / 4855 1
# 353 / 4855 1
# 354 / 4855 WHO IS THE PLAYER(S) ON THE ROSTER FROM SCHOOL/CLUB TEAM ARIZONA? ['Player', 'No.', 'Nationality', 'Position', 'Years in Orlando', 'School/Club Team'] SELECT * FROM table WHERE school/club team = ARIZONA SELECT Player FROM table WHERE School/Club Team = Arizona
# 355 / 4855 1
# 356 / 4855 1
# 357 / 4855 1
# 358 / 4855 1
# 359 / 4855 1
# 360 / 4855 1
# 361 / 4855 1
# 362 / 4855 1
# 363 / 4855 1
# 364 / 4855 1
# 365 / 4855 Who is the original artist for the theme "Year they were born?" ['Week #', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT original artist FROM table WHERE theme = "Year they were born?" SELECT Original artist FROM table WHERE Theme = Year They Were Born
# 366 / 4855 What theme name has the original artist of Dolly Parton? ['Week #', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT * FROM table WHERE theme = theme name AND original artist = Dolly Parton SELECT Theme FROM table WHERE Original artist = Dolly Parton
# 367 / 4855 1
# 368 / 4855 1
# 369 / 4855 March 0.41 in July?  ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT July FROM table WHERE march = March 0.41 SELECT July FROM table WHERE March = 0.41
# 370 / 4855 1
# 371 / 4855 January 7.34 where is June ? ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT June FROM table WHERE january = 7.34 SELECT January FROM table WHERE June = 7.34
# 372 / 4855 What December is 8.77 in January  ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT December FROM table WHERE december = 8.77 SELECT December FROM table WHERE January = 8.77
# 373 / 4855 1
# 374 / 4855 1
# 375 / 4855 1
# 376 / 4855 1
# 377 / 4855 1
# 378 / 4855 1
# 379 / 4855 1
# 380 / 4855 1
# 381 / 4855 1
# 382 / 4855 Is the team force india allowed to race? ['Year', 'Event', 'Pole position time', '107% time', 'Driver', 'Team', 'Time', '% of pole', 'Allowed to race?'] SELECT * FROM table WHERE allowed to race? = force india AND team = race SELECT Allowed to race? FROM table WHERE Team = Force India
# 383 / 4855 1
# 384 / 4855 1
# 385 / 4855 What was the home team score when Brisbane lions was the home team? ['Home team', 'Home team score', 'Away team', 'Away team score', 'Ground', 'Crowd', 'Date'] SELECT home team score FROM table WHERE home team score = Brisbane lions SELECT Home team score FROM table WHERE Home team = Brisbane Lions
# 386 / 4855 1
# 387 / 4855 Name the french title for english title of "inventor bunnies" ['Official #', 'TF1 #', 'French title', 'English title', 'Air date (France)', 'Original Beechwood Bunny Tale / Source material'] SELECT french title FROM table WHERE english title = "inventor bunnies" SELECT French title FROM table WHERE English title = Inventor Bunnies
# 388 / 4855 1
# 389 / 4855 What school location had an enrollment of 12400? ['Institution', 'Location', 'Nickname', 'Enrollment', 'Established'] SELECT * FROM table WHERE location = school location AND enrollment = 12400 SELECT Location FROM table WHERE Enrollment = 12400
# 390 / 4855 1
# 391 / 4855 What is the winning song for the artist with a debut album "the winner"? ['Season', 'Winner', 'Winning Song', 'Winning Song (English Title)', 'Debut Album'] SELECT winning song FROM table WHERE winner = "the winner" SELECT Winning Song FROM table WHERE Debut Album = The Winner
# 392 / 4855 What is the winning song for the artist with a debut album "mike"? ['Season', 'Winner', 'Winning Song', 'Winning Song (English Title)', 'Debut Album'] SELECT winning song FROM table WHERE debut album = "mike" SELECT Winning Song FROM table WHERE Debut Album = Mike
# 393 / 4855 1
# 394 / 4855 1
# 395 / 4855 1
# 396 / 4855 1
# 397 / 4855 1
# 398 / 4855 How many bypass boosters are there on the engine with slit exhaust ports and SPI is yes? ['Engine', 'Exhaust Ports', 'Bypass Ports', 'Bypass Boosters', 'SPI', 'Tapered Grind', 'Number on cyl.'] SELECT * FROM table WHERE engine = bypass AND exhaust ports = slit AND spi = yes SELECT Bypass Boosters FROM table WHERE SPI = Yes AND Exhaust Ports = Slit
# 399 / 4855 What is the points for when the total points is 6? ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Points difference', 'Points'] SELECT points for FROM table WHERE points for = 6 SELECT Points for FROM table WHERE Points = 6
# 400 / 4855 What club has 693 points for? ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Points difference', 'Points'] SELECT club FROM table WHERE points = 693 SELECT Club FROM table WHERE Points for = 693
# 401 / 4855 Name the snatch when body weight is 73.7 ['Place', 'Weightlifter', 'Body weight', 'one hand snatch', 'one hand clean & jerk', 'Press', 'Snatch', '1.', '2.', '3.', 'Total'] SELECT snatch FROM table WHERE 3. = 73.7 SELECT Snatch FROM table WHERE Body weight = 73.7
# 402 / 4855 1
# 403 / 4855 1
# 404 / 4855 1
# 405 / 4855 1
# 406 / 4855 1
# 407 / 4855 1
# 408 / 4855 1
# 409 / 4855 1
# 410 / 4855 1
# 411 / 4855 1
# 412 / 4855 Which date did Chris Duhon (13) receive high assists? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT date FROM table WHERE date = Chris Duhon (13) SELECT Date FROM table WHERE High assists = Chris Duhon (13)
# 413 / 4855 1
# 414 / 4855 1
# 415 / 4855 1
# 416 / 4855 What was the record when Canty (5) was the high assists? ['Game', 'Date', 'Opponent', 'Score', 'High points', 'High rebounds', 'High assists', 'Location/Attendance', 'Record'] SELECT record FROM table WHERE record = Canty (5) SELECT Record FROM table WHERE High assists = Canty (5)
# 417 / 4855 On what date did Canty (6) receive high assists? ['Game', 'Date', 'Opponent', 'Score', 'High points', 'High rebounds', 'High assists', 'Location/Attendance', 'Record'] SELECT date FROM table WHERE date = Canty (6) SELECT Date FROM table WHERE High assists = Canty (6)
# 418 / 4855 1
# 419 / 4855 1
# 420 / 4855 1
# 421 / 4855 1
# 422 / 4855 1
# 423 / 4855 When galaxy angel aa was the title was the us release date? ['Series', 'Title', 'Broadcasts (TV) 1', 'Episodes (TV+extra) 2', 'Directors', 'Aired in Japan 3', 'US Release Date'] SELECT * FROM table WHERE title = release date SELECT US Release Date FROM table WHERE Title = Galaxy Angel AA
# 424 / 4855 What's the change over previous year as a whole in the period in which the change over same quarter the previous year was up 2.8%? ['Period', '% trains arriving within 5 mins of scheduled time (over three months)', 'Change over same quarter the previous year', '% trains arriving within 5 mins of scheduled time Moving Annual Average (MAA)', 'Change over previous year as a whole'] SELECT change over previous year as a whole FROM table WHERE change over same quarter the previous year = 2.8% SELECT Change over previous year as a whole FROM table WHERE Change over same quarter the previous year = Up 2.8%
# 425 / 4855 How many open era titles does the team with their first title in 1925 have? ['Country', 'Amateur Era', 'Open Era', 'All-time', 'First title', 'Last title'] SELECT * FROM table WHERE open era = open era titles AND first title = 1925 SELECT Open Era FROM table WHERE First title = 1925
# 426 / 4855 1
# 427 / 4855 1
# 428 / 4855 1
# 429 / 4855 1
# 430 / 4855 1
# 431 / 4855 What was the date when Troy Murphy (15), got high rebounds?  ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT date FROM table WHERE date = Troy Murphy (15) SELECT Date FROM table WHERE High rebounds = Troy Murphy (15)
# 432 / 4855 Who did the High Assists when Kevin Durant (28) took the High Points? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT High Assists FROM table WHERE high assists = Kevin Durant (28) SELECT High assists FROM table WHERE High points = Kevin Durant (28)
# 433 / 4855 1
# 434 / 4855 1
# 435 / 4855 1
# 436 / 4855 what is the largest city where the province is eastern cape? ['Province', 'Provincial capital', 'Largest city', 'Area (km 2 )', 'Population (2013)'] SELECT * FROM table WHERE province = eastern cape SELECT Largest city FROM table WHERE Province = Eastern Cape
# 437 / 4855 What is the IATA of the airport with 3848 traffic in 2010-11? ['Rank', 'Airport', 'Location', 'IATA', '1985–86', '1990–91', '1995–96', '2000–01', '2005–06', '2007–08', '2009–10', '2010-11'] SELECT IATA FROM table WHERE airport = 3848 SELECT IATA FROM table WHERE 2010-11 = 3848
# 438 / 4855 1
# 439 / 4855 What is the name where the type is listed as free agent and  the country is ngr eng? ['N', 'P', 'Name', 'EU', 'Country', 'Age', 'Type', 'Moving from', 'Transfer window', 'Ends', 'Transfer fee', 'Source'] SELECT name FROM table WHERE age = free agent AND n = ngr eng SELECT Name FROM table WHERE Type = Free Agent AND Country = NGR ENG
# 440 / 4855 What is listed in p when the type is listed as free agent 1? ['N', 'P', 'Name', 'EU', 'Country', 'Age', 'Type', 'Moving from', 'Transfer window', 'Ends', 'Transfer fee', 'Source'] SELECT * FROM table WHERE age = free agent 1 SELECT P FROM table WHERE Type = Free Agent 1
# 441 / 4855 1
# 442 / 4855 Name the original title for 6.05 million viewership ['Episode', 'Original title', 'Directed by', 'Written by', 'Original airdate', 'Duration', 'Viewership'] SELECT original title FROM table WHERE original title = 6.05 SELECT Original title FROM table WHERE Viewership = 6.05 million
# 443 / 4855 1
# 444 / 4855 1
# 445 / 4855 1
# 446 / 4855 What is every "directed by" when the title is "One To Go" (part 2)? ['No. in series', 'No. in season', 'Title', 'Directed by', 'Written by', 'Original air date', 'U.S. viewers (millions)'] SELECT directed by FROM table WHERE title = "One To Go" (part 2) SELECT Directed by FROM table WHERE Title = One to Go (Part 2)
# 447 / 4855 1
# 448 / 4855 1
# 449 / 4855 which examples are pronounced et in australian ['Ending', 'American', 'British', 'Australian', 'Examples'] SELECT * FROM table WHERE australian = et SELECT Examples FROM table WHERE Australian = et
# 450 / 4855 What is the location of the church when the church name is Ortnevik Kyrkje? ['Parish (Prestegjeld)', 'Sub-Parish (Sogn)', 'Church Name', 'Year Built', 'Location of the Church'] SELECT * FROM table WHERE church name = Ortnevik Kyrkje SELECT Location of the Church FROM table WHERE Church Name = Ortnevik kyrkje
# 451 / 4855 1
# 452 / 4855 1
# 453 / 4855 When did the club UNAM played the first season in top division? ['Club', 'First season in top division', 'Number of seasons in top division', 'First season of current spell in top division', 'Number of seasons in Liga MX', 'Top division titles'] SELECT * FROM table WHERE club = first season SELECT First season in top division FROM table WHERE Club = UNAM
# 454 / 4855 1
# 455 / 4855 1
# 456 / 4855 which chapter was Transmitted on wednesday if the episode of "363 the hangover part ii" was transmitted on monday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "363 the hangover part ii" SELECT Wednesday FROM table WHERE Monday = 363 The Hangover Part II
# 457 / 4855 which episode was Transmitted on wednesday if the episode of "438 magic: the gathering mini masters tournament" was transmitted on thursday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "438 magic: the gathering mini masters tournament" SELECT Wednesday FROM table WHERE Thursday = 438 Magic: The Gathering Mini Masters Tournament
# 458 / 4855 which episode was Transmitted on friday if the episode of "414 insanely twisted shadow planet" was transmitted on tuesday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT friday FROM table WHERE friday = "414 insanely twisted shadow planet" SELECT Friday FROM table WHERE Tuesday = 414 Insanely Twisted Shadow Planet
# 459 / 4855 which episode was Transmitted on friday if the episode of "515 the adventures of tintin" was transmitted on monday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT friday FROM table WHERE friday = "515 the adventures of tintin" SELECT Friday FROM table WHERE Monday = 515 The Adventures of Tintin
# 460 / 4855 which episode was Transmitted on wednesday if the episode of "307 vs." was transmitted on friday?   ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "307 vs." SELECT Wednesday FROM table WHERE Friday = 307 VS.
# 461 / 4855 1
# 462 / 4855 1
# 463 / 4855 1
# 464 / 4855 1
# 465 / 4855 there are in tobago species name helicops angulatus ['Species', 'Common name', 'Trinidad', 'Tobago', 'Bocas Is.', 'Other'] SELECT * FROM table WHERE species = helicops angulatus SELECT Tobago FROM table WHERE Species = Helicops angulatus
# 466 / 4855 are in tobago species liophis cobellus cobellus? ['Species', 'Common name', 'Trinidad', 'Tobago', 'Bocas Is.', 'Other'] SELECT * FROM table WHERE species = liophis cobellus cobellus SELECT Tobago FROM table WHERE Species = Liophis cobellus cobellus
# 467 / 4855 Which U.S. Acres episode with Garfield episode 1 has a date of disaster? ['Episode', 'Garfield Episode 1', 'U.S. Acres Episode', 'Garfield Episode 2', 'Original Airdate'] SELECT * FROM table WHERE episode = 1 AND garfield episode 1 = disaster SELECT U.S. Acres Episode FROM table WHERE Garfield Episode 1 = Date of Disaster
# 468 / 4855 Which Garfield episode 1 has Garfield episode 2 as the second penelope episode? ['Episode', 'Garfield Episode 1', 'U.S. Acres Episode', 'Garfield Episode 2', 'Original Airdate'] SELECT Garfield episode 1 FROM table WHERE episode = the second penelope episode SELECT Garfield Episode 1 FROM table WHERE Garfield Episode 2 = The Second Penelope Episode
# 469 / 4855 1
# 470 / 4855 1
# 471 / 4855 1
# 472 / 4855 1
# 473 / 4855 1
# 474 / 4855 1
# 475 / 4855 1
# 476 / 4855 1
# 477 / 4855 1
# 478 / 4855 1
# 479 / 4855 1
# 480 / 4855 1
# 481 / 4855 1
# 482 / 4855 1
# 483 / 4855 1
# 484 / 4855 1
# 485 / 4855 1
# 486 / 4855 When batavo is the main sponsor and olympikus is the kit manufacturer who are the minor sponsors? ['Period', 'Kit manufacturer', 'Main sponsor', 'Secondary sponsor', 'Minor sponsors'] SELECT minor sponsors FROM table WHERE main sponsor = olympikus SELECT Minor sponsors FROM table WHERE Kit manufacturer = Olympikus AND Main sponsor = Batavo
# 487 / 4855 1
# 488 / 4855 1
# 489 / 4855 1
# 490 / 4855 1
# 491 / 4855 1
# 492 / 4855 1
# 493 / 4855 1
# 494 / 4855 1
# 495 / 4855 1
# 496 / 4855 What is the rank of london borough in southwark? ['Rank', 'London Borough', 'Black African Population', 'Black Caribbean Population', 'Other Black Population', 'Total Black Population'] SELECT rank FROM table WHERE rank = london AND london borough = southwark SELECT Rank FROM table WHERE London Borough = Southwark
# 497 / 4855 1
# 498 / 4855 What was the team's status in the USISL Pro League playoffs? ['Year', 'Division', 'League', 'Regular Season', 'Playoffs', 'Open Cup'] SELECT * FROM table WHERE league = USISL Pro League SELECT Playoffs FROM table WHERE League = USISL Pro League
# 499 / 4855 1
# 500 / 4855 1
# 501 / 4855 1
# 502 / 4855 1
# 503 / 4855 1
# 504 / 4855 1
# 505 / 4855 1
# 506 / 4855 Who are the opponents of Mike Byron and partner in matches where the score was  6–4, 4–6, 7–6 (7–4)? ['Outcome', 'Year', 'Championship', 'Surface', 'Partner', 'Opponents', 'Score'] SELECT * FROM table WHERE opponents = Mike Byron AND score = 6–4, 4–6, 7–6 (7–4) SELECT Opponents FROM table WHERE Score = 6–4, 4–6, 7–6 (7–4)
# 507 / 4855 1
# 508 / 4855 1
# 509 / 4855 1
# 510 / 4855 1
# 511 / 4855 1
# 512 / 4855 1
# 513 / 4855 1
# 514 / 4855 1
# 515 / 4855 1
# 516 / 4855 1
# 517 / 4855 1
# 518 / 4855 1
# 519 / 4855 What was the result when John Barrow was the incumbent first elected in 2004? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT result FROM table WHERE result = John Barrow AND first elected = 2004 SELECT Result FROM table WHERE First elected = 2004 AND Incumbent = John Barrow
# 520 / 4855 1
# 521 / 4855 1
# 522 / 4855 1
# 523 / 4855 1
# 524 / 4855 What is the intelligence os the one that has 思 sī, "thought"? ['Shekhina:', 'Reason', 'Mind', 'Intelligence', 'Thought', 'Understanding'] SELECT intelligence FROM table WHERE thought = 思 sī SELECT Intelligence FROM table WHERE Thought = 思 sī, thought
# 525 / 4855 1
# 526 / 4855 1
# 527 / 4855 1
# 528 / 4855 1
# 529 / 4855 1
# 530 / 4855 1
# 531 / 4855 1
# 532 / 4855 1
# 533 / 4855 1
# 534 / 4855 What is the playoffs result in years where Open Canada Cup was "N/A" and regular season result was "2nd, New England"? ['Year', 'Division', 'League', 'Regular Season', 'Playoffs', 'Open Canada Cup'] SELECT playoffs FROM table WHERE regular season = 2nd, New England SELECT Playoffs FROM table WHERE Open Canada Cup = N/A AND Regular Season = 2nd, New England
# 535 / 4855 1
# 536 / 4855 1
# 537 / 4855 1
# 538 / 4855 1
# 539 / 4855 1
# 540 / 4855 1
# 541 / 4855 What was the time in part 3 when Heikki Kovalainen was the driver?  ['Pos', 'No', 'Driver', 'Constructor', 'Part 1', 'Part 2', 'Part 3', 'Grid'] SELECT * FROM table WHERE part 3 = Heikki Kovalainen SELECT Part 3 FROM table WHERE Driver = Heikki Kovalainen
# 542 / 4855 What was the time in part 3 when Nick Heidfeld was the driver? ['Pos', 'No', 'Driver', 'Constructor', 'Part 1', 'Part 2', 'Part 3', 'Grid'] SELECT * FROM table WHERE part 3 = Nick Heidfeld SELECT Part 3 FROM table WHERE Driver = Nick Heidfeld
# 543 / 4855 1
# 544 / 4855 1
# 545 / 4855 What's the Sanskrit word for month with Thai name มกราคม? ['English name', 'Thai name', 'Abbr.', 'Transcription', 'Sanskrit word', 'Zodiac sign'] SELECT * FROM table WHERE thai name = มกราคม SELECT Sanskrit word FROM table WHERE Thai name = มกราคม
# 546 / 4855 1
# 547 / 4855 1
# 548 / 4855 1
# 549 / 4855 1
# 550 / 4855 1
# 551 / 4855 1
# 552 / 4855 What was the Obama% when McCain% was 61.2%? ['County', 'Obama%', 'Obama#', 'McCain%', 'McCain#', 'Others%', 'Others#'] SELECT * FROM table WHERE mccain% = 61.2% SELECT Obama% FROM table WHERE McCain% = 61.2%
# 553 / 4855 1
# 554 / 4855 1
# 555 / 4855 when type of work is novel and published in english is 1977, what was published in russian? ['English title', 'Russian title', 'Published in Russian', 'Published in English', 'Type of work'] SELECT * FROM table WHERE type of work = novel AND published in english = russian SELECT Published in Russian FROM table WHERE Type of work = novel AND Published in English = 1977
# 556 / 4855 1
# 557 / 4855 1
# 558 / 4855 1
# 559 / 4855 1
# 560 / 4855 What is the weight for western ontario college? ['Round', 'Choice', 'Player', 'Position', 'Height', 'Weight', 'College'] SELECT weight FROM table WHERE college = western ontario college SELECT Weight FROM table WHERE College = Western Ontario
# 561 / 4855 1
# 562 / 4855 1
# 563 / 4855 1
# 564 / 4855 1
# 565 / 4855 what is the name of the institution of the sparta, wi location? ['Institution', 'Location', 'Year Joined', 'Affiliation', 'Enrollment', 'Mascot', 'Colors'] SELECT * FROM table WHERE institution = name AND location = sparta, wi SELECT Institution FROM table WHERE Location = Sparta, WI
# 566 / 4855 1
# 567 / 4855 1
# 568 / 4855 1
# 569 / 4855 1
# 570 / 4855 1
# 571 / 4855 1
# 572 / 4855 1
# 573 / 4855 What song did Robin perform with a result of 4.0? ['Order', 'Couple', 'Karen', 'Nicky', 'Jason', 'Ruthie', 'Robin', 'Total', 'Scoreboard', 'Song', 'Public Vote %', 'Result'] SELECT song FROM table WHERE result = 4.0 SELECT Song FROM table WHERE Robin = 4.0
# 574 / 4855 1
# 575 / 4855 1
# 576 / 4855 1
# 577 / 4855 1
# 578 / 4855 What date did Adriano Buzaid have the pole position? ['Round', 'Circuit', 'Date', 'Pole Position', 'Fastest Lap', 'Winning Driver', 'Winning Team'] SELECT date FROM table WHERE date = Adriano Buzaid SELECT Date FROM table WHERE Pole Position = Adriano Buzaid
# 579 / 4855 What is the ministries number when duration is 4 years, 4 days (1,465 days)? ['Nº', 'Cabinet (Nickname)', 'Took office', 'Left office', 'Duration', 'Coalition parties', 'ministers', 'ministries', 'President'] SELECT * FROM table WHERE ministries = ministries number AND duration = 4 years, 4 days (1,465 days) SELECT ministries FROM table WHERE Duration = 4 years, 4 days (1,465 days)
# 580 / 4855 1
# 581 / 4855 1
# 582 / 4855 1
# 583 / 4855 1
# 584 / 4855 1
# 585 / 4855 What source gave 26% of the votes to Brian Moran? ['Source', 'Dates Administered', 'Terry McAuliffe', 'Brian Moran', 'Creigh Deeds'] SELECT source FROM table WHERE source = 26% SELECT Source FROM table WHERE Brian Moran = 26%
# 586 / 4855 1
# 587 / 4855 1
# 588 / 4855 What is the maturity date of the ISIN labeled DE000A0BVBN3? ['Issuer', 'Issue Date', 'ISIN', 'Amount Issued [€]', 'Coupon', 'Maturity'] SELECT * FROM table WHERE maturity = maturity date AND isin = DE000A0BVBN3 SELECT Maturity FROM table WHERE ISIN = DE000A0BVBN3
# 589 / 4855 1
# 590 / 4855 1
# 591 / 4855 1
# 592 / 4855 1
# 593 / 4855 1
# 594 / 4855 1
# 595 / 4855 1
# 596 / 4855 1
# 597 / 4855 What was the highest position for the person who performed in 16 races? ['Season', 'Series', 'Team', 'Races', 'Wins', 'Poles', 'F/Laps', 'Podiums', 'Points', 'Position'] SELECT * FROM table WHERE races = 16 SELECT Position FROM table WHERE Races = 16
# 598 / 4855 1
# 599 / 4855 1
# 600 / 4855 1
# 601 / 4855 1
# 602 / 4855 1
# 603 / 4855 1
# 604 / 4855 1
# 605 / 4855 What is the event # when the winner is what is 7x6? ['Dateca', 'Event #', 'Event', 'Winner', 'Prize', 'Entries', 'Prize Pool', 'Elapsed Time'] SELECT event # FROM table WHERE winner = 7x6 SELECT Event # FROM table WHERE Winner = what is 7x6
# 606 / 4855 1
# 607 / 4855 How many games were played in the 1989 season? ['Season', 'Player', 'Nationality', 'Team', 'Points', 'Average', 'Played'] SELECT * FROM table WHERE season = 1989 SELECT Played FROM table WHERE Season = 1989
# 608 / 4855 1
# 609 / 4855 1
# 610 / 4855 1
# 611 / 4855 1
# 612 / 4855 1
# 613 / 4855 1
# 614 / 4855 1
# 615 / 4855 1
# 616 / 4855 1
# 617 / 4855 1
# 618 / 4855 1
# 619 / 4855 1
# 620 / 4855 1
# 621 / 4855 1
# 622 / 4855 1
# 623 / 4855 Which points classification has 4 as the stage? ['Stage', 'Stage winner', 'General classification', 'Points classification', 'Mountains classification', 'Malaysian rider classification', 'Team classification', 'Malaysian team classification'] SELECT points classification FROM table WHERE points classification = 4 SELECT Points classification FROM table WHERE Stage = 4
# 624 / 4855 1
# 625 / 4855 1
# 626 / 4855 Which team classification has taiji nishitani as the stage winner? ['Stage', 'Stage winner', 'General classification', 'Points classification', 'Mountains classification', 'Malaysian rider classification', 'Team classification', 'Malaysian team classification'] SELECT team classification FROM table WHERE team classification = taiji nishitani SELECT Team classification FROM table WHERE Stage winner = Taiji Nishitani
# 627 / 4855 1
# 628 / 4855 Who was the Best Male Artist where Bankie Travolta won the Best Male MC? ['Best Male MC', 'Best Female MC', 'Best Male Artist', 'Best Female Artist', 'Best Male Lyricist', 'Best Female Lyricist', 'Best Male Record'] SELECT Best Male Artist FROM table WHERE best male artist = Bankie Travolta SELECT Best Male Artist FROM table WHERE Best Male MC = Bankie Travolta
# ...
# 4595 / 4855 1
# 4596 / 4855 What Golden point(s) scorer has the Away Sydney Roosters and Home Cronulla Sharks? ['Home', 'Score', 'Away', 'Venue', 'Golden point(s) scorer'] SELECT * FROM table WHERE score = Golden point(s) AND away = Sydney Roosters AND home = Cronulla Sharks SELECT Golden point(s) scorer FROM table WHERE Away = sydney roosters AND Home = cronulla sharks
# 4597 / 4855 What Golden point(s) scorer has the Away Brisbane Broncos and Home South Sydney Rabbitohs? ['Home', 'Score', 'Away', 'Venue', 'Golden point(s) scorer'] SELECT * FROM table WHERE score = Golden point(s) AND away = Brisbane Broncos AND home = South Sydney Rabbitohs SELECT Golden point(s) scorer FROM table WHERE Away = brisbane broncos AND Home = south sydney rabbitohs
# 4598 / 4855 What is the Name of the Special Stage with a 2.40km length and S. Loeb as Winner? ['Stage', 'Time', 'Name', 'Length', 'Winner', 'Rally leader'] SELECT Name FROM table WHERE stage = Special Stage AND length = 2.40km AND winner = S. Loeb SELECT Name FROM table WHERE Length = 2.40km AND Winner = s. loeb
# 4599 / 4855 1
# 4600 / 4855 1
# 4601 / 4855 Bldr of mcw&f, and a Notes of "mv"; converted from steam stock, 1927, and a Year of 1920, and a LT Nos of 9716-9718 has what type? ['LT Nos', 'Year', 'Bldr', 'Type', 'Notes'] SELECT type FROM table WHERE bldr = mcw&f AND notes = mv AND year = 1920 AND lt nos = 9716-9718 SELECT Type FROM table WHERE Bldr = mcw&f AND Notes = mv; converted from steam stock, 1927 AND Year = 1920 AND LT Nos = 9716-9718
# 4602 / 4855 1
# 4603 / 4855 1
# 4604 / 4855 Which event has Philadelphia, PA as the location and 41 days held? ['Wrestler', 'Reigns', 'Days held', 'Location', 'Successful defenses', 'Event'] SELECT event FROM table WHERE event = Philadelphia, PA AND location = 41 days SELECT Event FROM table WHERE Location = philadelphia, pa AND Days held = 41
# 4605 / 4855 1
# 4606 / 4855 1
# 4607 / 4855 What was the double's performance data from the Canada Masters tournament in 2008? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT * FROM table WHERE tournament = Canada Masters SELECT 2008 FROM table WHERE Tournament = canada masters
# 4608 / 4855 What was the double's performance data from the Monte Carlo Masters tournament in 2007? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT * FROM table WHERE tournament = Monte Carlo Masters SELECT 2007 FROM table WHERE Tournament = monte carlo masters
# 4609 / 4855 1
# 4610 / 4855 1
# 4611 / 4855 1
# 4612 / 4855 1
# 4613 / 4855 1
# 4614 / 4855 1
# 4615 / 4855 What is the value in 2009 when 1R is in 2007? ['Tournament', '2007', '2008', '2009', 'Career Win-Loss'] SELECT 2009 FROM table WHERE 2009 = 1R SELECT 2009 FROM table WHERE 2007 = 1r
# 4616 / 4855 1
# 4617 / 4855 what is the tournament with the performance in 2010 and 2011 is 1r? ['Tournament', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE 2011 = 1r SELECT Tournament FROM table WHERE 2010 = 1r AND 2011 = 1r
# 4618 / 4855 1
# 4619 / 4855 1
# 4620 / 4855 1
# 4621 / 4855 Which car won the same award in 2001 that the toyota 1nz-fxe hybrid prius won in 1999? ['category', '1999', '2000', '2001', '2004'] SELECT 2001 FROM table WHERE 2001 = car AND 1999 = toyota 1nz-fxe hybrid prius SELECT 2001 FROM table WHERE 1999 = toyota 1nz-fxe hybrid prius
# 4622 / 4855 1
# 4623 / 4855 Which car won the same award in 2001 that the bmw m67d39 3.9l v8 e38 740d won in 1999? ['category', '1999', '2000', '2001', '2004'] SELECT 2001 FROM table WHERE 2001 = car AND 1999 = bmw m67d39 3.9l v8 e38 740d SELECT 2001 FROM table WHERE 1999 = bmw m67d39 3.9l v8 e38 740d
# 4624 / 4855 What is the surface of the mountain range that contains the Elk Garden Mountain? ['Mountain', 'Elevation', 'Range', 'State(s)', 'Surface'] SELECT surface FROM table WHERE mountain = Elk Garden Mountain SELECT Surface FROM table WHERE Mountain = elk garden
# 4625 / 4855 What is the tournament with A in 2011? ['Tournament', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table SELECT Tournament FROM table WHERE 2011 = a
# 4626 / 4855 What is the 2012 value with A in 2010 at the Tournament of Wimbledon? ['Tournament', '2008', '2009', '2010', '2011', '2012'] SELECT 2012 FROM table WHERE tournament = Wimbledon SELECT 2012 FROM table WHERE 2010 = a AND Tournament = wimbledon
# 4627 / 4855 1
# 4628 / 4855 1
# 4629 / 4855 1
# 4630 / 4855 1
# 4631 / 4855 1
# 4632 / 4855 1
# 4633 / 4855 1
# 4634 / 4855 1
# 4635 / 4855 1
# 4636 / 4855 1
# 4637 / 4855 1
# 4638 / 4855 1
# 4639 / 4855 1
# 4640 / 4855 1
# 4641 / 4855 1
# 4642 / 4855 1
# 4643 / 4855 1
# 4644 / 4855 1
# 4645 / 4855 1
# 4646 / 4855 What Lomavren word has the same meaning as the Hindi word do? ['Hindi', 'Romani', 'Domari', 'Lomavren', 'Persian'] SELECT Lomavren FROM table SELECT Lomavren FROM table WHERE Hindi = do
# 4647 / 4855 1
# 4648 / 4855 1
# 4649 / 4855 1
# 4650 / 4855 1
# 4651 / 4855 1
# 4652 / 4855 1
# 4653 / 4855 1
# 4654 / 4855 Which entrant used the chassis de tomaso 505? ['Year', 'Entrant', 'Chassis', 'Engine', 'Points'] SELECT entrant FROM table WHERE chassis = tomaso 505 SELECT Entrant FROM table WHERE Chassis = de tomaso 505
# 4655 / 4855 1
# 4656 / 4855 1
# 4657 / 4855 1
# 4658 / 4855 1
# 4659 / 4855 1
# 4660 / 4855 1
# 4661 / 4855 1
# 4662 / 4855 1
# 4663 / 4855 1
# 4664 / 4855 1
# 4665 / 4855 1
# 4666 / 4855 Name the 2010 for 2007 of a and 2012 of a ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT 2010 FROM table SELECT 2010 FROM table WHERE 2007 = a AND 2012 = a
# 4667 / 4855 Name the 2008 for 2012 being a and tournament of australian open ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT 2008 FROM table WHERE tournament = australian open SELECT 2008 FROM table WHERE 2012 = a AND Tournament = australian open
# 4668 / 4855 Name the tournament for 2012 grand slam tournaments ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE tournament = grand slam tournaments SELECT Tournament FROM table WHERE 2012 = grand slam tournaments
# 4669 / 4855 1
# 4670 / 4855 1
# 4671 / 4855 1
# 4672 / 4855 1
# 4673 / 4855 1
# 4674 / 4855 1
# 4675 / 4855 1
# 4676 / 4855 1
# 4677 / 4855 1
# 4678 / 4855 1
# 4679 / 4855 What primary sponsor(s) owns ford fusion car(s) and the crew chief is Drew Blickensderfer? ['Team', 'Car(s)', 'Driver(s)', 'Primary Sponsor(s)', 'Owner(s)', 'Crew Chief'] SELECT * FROM table WHERE car(s) = ford fusion car(s) AND crew chief = Drew Blickensderfer SELECT Primary Sponsor(s) FROM table WHERE Car(s) = ford fusion AND Crew Chief = drew blickensderfer
# 4680 / 4855 1
# 4681 / 4855 What tournament was at the 2007 Olympic Games? ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE 2007 = 2007 Olympic Games SELECT Tournament FROM table WHERE 2007 = olympic games
# 4682 / 4855 What tournament was at the 2011 Cincinnati Masters? ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE 2011 = 2011 Cincinnati Masters SELECT 2011 FROM table WHERE Tournament = cincinnati masters
# 4683 / 4855 1
# 4684 / 4855 1
# 4685 / 4855 1
# 4686 / 4855 Name the location of reign 3 ['Championship', 'Current champion(s)', 'Reign', 'Date won', 'Days held', 'Location'] SELECT location FROM table WHERE reign = reign 3 SELECT Location FROM table WHERE Reign = 3
# 4687 / 4855 1
# 4688 / 4855 1
# 4689 / 4855 1
# 4690 / 4855 Which Club has a Not winning editions of 1992, 2003? ['Club', 'Winners', 'Finalists', 'Winning editions', 'Not winning editions'] SELECT Club FROM table WHERE winning editions = 1992, 2003 SELECT Club FROM table WHERE Not winning editions = 1992, 2003
# 4691 / 4855 1
# 4692 / 4855 What is the Finalists that has 2008, 2012, 2013 as Not winning editions ['Club', 'Winners', 'Finalists', 'Winning editions', 'Not winning editions'] SELECT Finalists FROM table SELECT Finalists FROM table WHERE Not winning editions = 2008, 2012, 2013
# 4693 / 4855 1
# 4694 / 4855 1
# 4695 / 4855 What is the score when november 15 is the date? ['Date', 'Visitor', 'Score', 'Home', 'Record', 'Attendance'] SELECT score FROM table WHERE score = november 15 SELECT Score FROM table WHERE Date = november 15
# 4696 / 4855 What record has November 15 as the date? ['Date', 'Visitor', 'Score', 'Home', 'Record', 'Attendance'] SELECT record FROM table WHERE record = November 15 SELECT Record FROM table WHERE Date = november 15
# 4697 / 4855 What tournament what held in Cincinnati in 2009? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT tournament FROM table WHERE 2009 = Cincinnati SELECT 2009 FROM table WHERE Tournament = cincinnati
# 4698 / 4855 1
# 4699 / 4855 1
# 4700 / 4855 1
# 4701 / 4855 1
# 4702 / 4855 1
# 4703 / 4855 1
# 4704 / 4855 1
# 4705 / 4855 1
# 4706 / 4855 Which Representative has a Presentation of Credentials on september 8, 2005? ['Representative', 'Title', 'Presentation of Credentials', 'Termination of Mission', 'Appointed by'] SELECT Representative FROM table WHERE representative = Credentials AND presentation of credentials = september 8, 2005 SELECT Representative FROM table WHERE Presentation of Credentials = september 8, 2005
# 4707 / 4855 Which Termination of Mission has a Presentation of Credentials on October 29, 1981 ['Representative', 'Title', 'Presentation of Credentials', 'Termination of Mission', 'Appointed by'] SELECT Termination of Mission FROM table WHERE termination of mission = Credentials AND presentation of credentials = October 29, 1981 SELECT Termination of Mission FROM table WHERE Presentation of Credentials = october 29, 1981
# 4708 / 4855 1
# 4709 / 4855 1
# 4710 / 4855 Which gold Coast has a Melbourne of yes, a Perth of yes, an Auckland of no, and a Sydney of no? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT gold Coast FROM table WHERE melbourne = yes AND auckland = no SELECT Gold Coast FROM table WHERE Melbourne = yes AND Perth = yes AND Auckland = no AND Sydney = no
# 4711 / 4855 Which Adelaide has an Auckland of no and a Melbourne of no? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Adelaide FROM table WHERE auckland = no SELECT Adelaide FROM table WHERE Auckland = no AND Melbourne = no
# 4712 / 4855 Which Sydney has a Gold Coast of yes, an Adelaide of no, and an Auckland of yes? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Sydney FROM table WHERE gold coast = yes AND adelaide = no SELECT Sydney FROM table WHERE Gold Coast = yes AND Adelaide = no AND Auckland = yes
# 4713 / 4855 Which Sydney has a Perth of no, an Adelaide of yes, and a Gold Coast of no? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Sydney FROM table WHERE perth = no AND adelaide = yes SELECT Sydney FROM table WHERE Perth = no AND Adelaide = yes AND Gold Coast = no
# 4714 / 4855 Which Adelaide has a Sydney of yes, a Perth of no, a Melbourne of yes, and an Auckland of no? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Adelaide FROM table WHERE perth = yes AND melbourne = no SELECT Adelaide FROM table WHERE Sydney = yes AND Perth = no AND Melbourne = yes AND Auckland = no
# 4715 / 4855 Which Melbourne has a Perth of yes, and an Auckland of yes? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Melbourne FROM table WHERE perth = yes SELECT Melbourne FROM table WHERE Perth = yes AND Auckland = yes
# 4716 / 4855 1
# 4717 / 4855 1
# 4718 / 4855 1
# 4719 / 4855 1
# 4720 / 4855 1
# 4721 / 4855 1
# 4722 / 4855 1
# 4723 / 4855 1
# 4724 / 4855 1
# 4725 / 4855 1
# 4726 / 4855 1
# 4727 / 4855 1
# 4728 / 4855 1
# 4729 / 4855 1
# 4730 / 4855 1
# 4731 / 4855 1
# 4732 / 4855 1
# 4733 / 4855 What is the name of the party called name? ['Name', 'Entered Office', 'Left Office', 'Party', 'First Minister'] SELECT party FROM table SELECT Party FROM table WHERE Name = name
# 4734 / 4855 1
# 4735 / 4855 1
# 4736 / 4855 1
# 4737 / 4855 1
# 4738 / 4855 1
# 4739 / 4855 1
# 4740 / 4855 1
# 4741 / 4855 1
# 4742 / 4855 1
# 4743 / 4855 1
# 4744 / 4855 1
# 4745 / 4855 1
# 4746 / 4855 1
# 4747 / 4855 1
# 4748 / 4855 1
# 4749 / 4855 1
# 4750 / 4855 1
# 4751 / 4855 1
# 4752 / 4855 1
# 4753 / 4855 1
# 4754 / 4855 1
# 4755 / 4855 1
# 4756 / 4855 1
# 4757 / 4855 1
# 4758 / 4855 1
# 4759 / 4855 1
# 4760 / 4855 1
# 4761 / 4855 1
# 4762 / 4855 1
# 4763 / 4855 1
# 4764 / 4855 1
# 4765 / 4855 What character did Katie Rowley Jones play in the Original West End Cast? ['Character', 'Original West End Cast', 'Original Broadway Cast', 'First UK Tour Cast', 'First US Tour Cast'] SELECT character FROM table WHERE character = Original West End SELECT Character FROM table WHERE Original West End Cast = katie rowley jones
# 4766 / 4855 1
# 4767 / 4855 1
# 4768 / 4855 1
# 4769 / 4855 1
# 4770 / 4855 1
# 4771 / 4855 1
# 4772 / 4855 Which player has 68 as the score and canada as the country? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT player FROM table WHERE player = 68 AND score = canada SELECT Player FROM table WHERE Score = 68 AND Country = canada
# 4773 / 4855 What place has Canada as the country? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT place FROM table WHERE place = Canada SELECT Place FROM table WHERE Country = canada
# 4774 / 4855 Which player has 69 as the score? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT player FROM table WHERE player = 69 SELECT Player FROM table WHERE Score = 69
# 4775 / 4855 1
# 4776 / 4855 1
# 4777 / 4855 1
# 4778 / 4855 1
# 4779 / 4855 1
# 4780 / 4855 1
# 4781 / 4855 1
# 4782 / 4855 1
# 4783 / 4855 1
# 4784 / 4855 1
# 4785 / 4855 1
# 4786 / 4855 Which year has brm v12 as the engine? ['Year', 'Entrant', 'Chassis', 'Engine', 'Pts.'] SELECT year FROM table WHERE year = brm v12 SELECT Year FROM table WHERE Engine = brm v12
# 4787 / 4855 1
# 4788 / 4855 1
# 4789 / 4855 1
# 4790 / 4855 1
# 4791 / 4855 1
# 4792 / 4855 1
# 4793 / 4855 1
# 4794 / 4855 1
# 4795 / 4855 1
# 4796 / 4855 1
# 4797 / 4855 1
# 4798 / 4855 1
# 4799 / 4855 1
# 4800 / 4855 1
# 4801 / 4855 1
# 4802 / 4855 1
# 4803 / 4855 1
# 4804 / 4855 1
# 4805 / 4855 1
# 4806 / 4855 1
# 4807 / 4855 1
# 4808 / 4855 1
# 4809 / 4855 1
# 4810 / 4855 1
# 4811 / 4855 1
# 4812 / 4855 1
# 4813 / 4855 1
# 4814 / 4855 1
# 4815 / 4855 1
# 4816 / 4855 1
# 4817 / 4855 1
# 4818 / 4855 1
# 4819 / 4855 1
# 4820 / 4855 1
# 4821 / 4855 1
# 4822 / 4855 1
# 4823 / 4855 What Best Bowl is it that has 151 Matches and 1 100s? ['Matches', 'Runs', 'Bat Ave', 'High Score', '100s', 'Wickets', 'Bowl Ave', 'Best Bowl'] SELECT Best Bowl FROM table WHERE matches = 151 SELECT Best Bowl FROM table WHERE 100s = 1 AND Matches = 151
# 4824 / 4855 1
# 4825 / 4855 1
# 4826 / 4855 1
# 4827 / 4855 1
# 4828 / 4855 What is the diameter of the Archery Reverse coin? ['Year', 'Denomination', 'Alloy', 'Reverse', 'Diameter', 'Weight', 'Obverse', 'Mintage', 'Series'] SELECT diameter FROM table WHERE reverse = Archery Reverse SELECT Diameter FROM table WHERE Reverse = archery
# 4829 / 4855 1
# 4830 / 4855 1
# 4831 / 4855 1
# 4832 / 4855 1
# 4833 / 4855 1
# 4834 / 4855 1
# 4835 / 4855 1
# 4836 / 4855 1
# 4837 / 4855 What year did Lonneke Janssen win the Women's singles? ['Year', "Men's singles", "Women's singles", "Men's doubles", "Women's doubles", 'Mixed doubles'] SELECT year FROM table WHERE year = Lonneke Janssen SELECT Year FROM table WHERE Women's singles = lonneke janssen
# 4838 / 4855 1
# 4839 / 4855 1
# 4840 / 4855 1
# 4841 / 4855 1
# 4842 / 4855 1
# 4843 / 4855 1
# 4844 / 4855 1
# 4845 / 4855 Which main cast seasons were portrayed by Joe Jonas? ['Character', 'Portrayed by', 'Main cast seasons', 'Recurring cast seasons', '# of episodes'] SELECT * FROM table WHERE portrayed by = Joe Jonas SELECT Main cast seasons FROM table WHERE Portrayed by = joe jonas
# 4846 / 4855 1
# 4847 / 4855 1
# 4848 / 4855 1
# 4849 / 4855 1
# 4850 / 4855 1
# 4851 / 4855 1
# 4852 / 4855 1
# 4853 / 4855 1
# 4854 / 4855 1
# Select accuracy 95.42739443872297
# Where accuracy 85.80844490216272
# Value accuracy 90.93717816683831
# Overall accuracy 80.86508753861999

# %% [markdown]
# Our accuracy statistics for this case is as follows.
#
# *   Select accuracy: 95.43%
# *   Where accuracy: 85.81%
# *   Value accuracy: 90.94%
# *   Overall accuracy 80.86%

# %% [markdown]
# # Case 2: No Aggregation, Attributes Explicitly Present in NLQ, Rule 2
#
# We evaluate accuracy with the same conditions as before, but nlq2sql uses rule 2 instead (defined in our report).

# %%
evaluate_data(tagTestSet, nlp_ner, 'rule2')
# Out:
# 0 / 4855 1
# 1 / 4855 1
# 2 / 4855 1
# 3 / 4855 1
# 4 / 4855 1
# 5 / 4855 1
# 6 / 4855 1
# 7 / 4855 1
# 8 / 4855 1
# 9 / 4855 1
# 10 / 4855 1
# 11 / 4855 1
# 12 / 4855 1
# 13 / 4855 1
# 14 / 4855 1
# 15 / 4855 1
# 16 / 4855 what's the original air date with title  "hell" ['No. in series', 'No. in season', 'Title', 'Directed by', 'Written by', 'Original air date'] SELECT original air date FROM table WHERE original air date = "hell" SELECT Original air date FROM table WHERE Title = Hell
# 17 / 4855 1
# 18 / 4855 What is the percentage of the  trance- n himalaya zone that corresponds with the high hill zone is 25%? ['Particulars and Characteristics', 'Shivalik Zone', 'Mid-Hill Zone', 'High hill zone', 'Trance- n Himalaya Zone'] SELECT * FROM table WHERE trance- n himalaya zone = trance- n himalaya AND high hill zone = 25% SELECT Trance- n Himalaya Zone FROM table WHERE High hill zone = 25%
# 19 / 4855 1
# 20 / 4855 1
# 21 / 4855 1
# 22 / 4855 1
# 23 / 4855 1
# 24 / 4855 Which song has picturization by only vijay? ['Track #', 'Song', 'Singers', 'Picturization', 'Length', 'Lyricist'] SELECT song FROM table WHERE picturization = only vijay SELECT Song FROM table WHERE Picturization = Vijay
# 25 / 4855 For which singers was Alangudi Somu the lyricist? ['Track #', 'Song', 'Singers', 'Picturization', 'Length', 'Lyricist'] SELECT * FROM table WHERE singers = Alangudi Somu SELECT Singers FROM table WHERE Lyricist = Alangudi Somu
# 26 / 4855 1
# 27 / 4855 1
# 28 / 4855 What percentage of The Bronx voters occured when Manhattan had 29.9% of voters? ['1953', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT The Bronx FROM table WHERE % = 29.9% SELECT The Bronx FROM table WHERE Manhattan = 29.9%
# 29 / 4855 What number of voters did the Bronx have when the total number was 2054? ['1953', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT * FROM table WHERE the bronx = Bronx AND total = 2054 SELECT The Bronx FROM table WHERE Total = 2054
# 30 / 4855 1
# 31 / 4855 1
# 32 / 4855 1
# 33 / 4855 Which candidate won 88 votes in Queens in 1921? ['1921', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT * FROM table WHERE queens = 88 SELECT 1921 FROM table WHERE Queens = 88
# 34 / 4855 1
# 35 / 4855 1
# 36 / 4855 1
# 37 / 4855 What are the highest recorded attendance rates of the stadiums with an average attendance of 4752? ['Team', 'Stadium', 'Capacity', 'Lowest', 'Highest', 'Average'] SELECT * FROM table WHERE average = 4752 SELECT Highest FROM table WHERE Average = 4752
# 38 / 4855 What is the catalog number of the title called "super callanetics"? ['Year', 'Title', 'Format', 'Studio', 'Release Date', 'Copyright Information', 'Catalog Number'] SELECT * FROM table WHERE catalog number = "super callanetics" SELECT Catalog Number FROM table WHERE Title = Super Callanetics
# 39 / 4855 1
# 40 / 4855 1
# 41 / 4855 1
# 42 / 4855 1
# 43 / 4855 What is the premiere on the mega channel? ['Country/Region', 'Show Title', 'Languages', 'Host', 'Channel', 'Premiere', 'Seasons', 'Status'] SELECT premiere FROM table WHERE channel = mega SELECT Premiere FROM table WHERE Channel = Mega Channel
# 44 / 4855 1
# 45 / 4855 1
# 46 / 4855 1
# 47 / 4855 1
# 48 / 4855 1
# 49 / 4855 1
# 50 / 4855 1
# 51 / 4855 Who was the winning driver when the pole position was held by Ayrton Senna and the Fastest lap was Michael Schumacher? ['Round', 'Grand Prix', 'Pole Position', 'Fastest Lap', 'Winning Driver', 'Winning Constructor', 'Report'] SELECT winning driver FROM table WHERE fastest lap = Michael Schumacher SELECT Winning Driver FROM table WHERE Pole Position = Ayrton Senna AND Fastest Lap = Michael Schumacher
# 52 / 4855 1
# 53 / 4855 1
# 54 / 4855 1
# 55 / 4855 1
# 56 / 4855 1
# 57 / 4855 1
# 58 / 4855 1
# 59 / 4855 1
# 60 / 4855 1
# 61 / 4855 1
# 62 / 4855 Which model number has a GVM (kg) Technical Capacity of 16000 and a Torque Nm@rpm of 600 @ 1700? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT * FROM table WHERE model = model number AND gvm (kg) technical capacity = 16000 AND torque nm@rpm = 600 @ 1700 SELECT Model FROM table WHERE GVM (kg) Technical Capacity = 16000 AND Torque Nm@rpm = 600 @ 1700
# 63 / 4855 If the model is  15.180e, what is the GVM (kg) Technical Capacity? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT * FROM table WHERE model = Technical Capacity SELECT GVM (kg) Technical Capacity FROM table WHERE Model = 15.180E
# 64 / 4855 When the transmission make/type/speed is eaton fs 5306-a manual synchromesh 6 speed, what is the value of the gcm (kg) technical capacity? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT * FROM table WHERE transmission make/type/speed = technical capacity SELECT GCM (kg) Technical Capacity FROM table WHERE Transmission Make/Type/Speed = Eaton FS 5306-A Manual Synchromesh 6 Speed
# 65 / 4855 Which model possesses a transmission make/type/speed of eaton fs-6306 a manual synchromesh 6 speed? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT model FROM table WHERE transmission make/type/speed = manual synchromesh 6 SELECT Model FROM table WHERE Transmission Make/Type/Speed = Eaton FS-6306 A Manual Synchromesh 6 Speed
# 66 / 4855 For driver Mark Skaife what is the result for race 1? ['Driver', 'No.', 'Team', 'Car', 'Race 1', 'GP 100', 'Race 3', 'Points'] SELECT * FROM table WHERE driver = 1 AND race 1 = result SELECT Race 1 FROM table WHERE Driver = Mark Skaife
# 67 / 4855 1
# 68 / 4855 1
# 69 / 4855 1
# 70 / 4855 1
# 71 / 4855 1
# 72 / 4855 1
# 73 / 4855 1
# 74 / 4855 1
# 75 / 4855 1
# 76 / 4855 1
# 77 / 4855 1
# 78 / 4855 1
# 79 / 4855 1
# 80 / 4855 1
# 81 / 4855 1
# 82 / 4855 1
# 83 / 4855 1
# 84 / 4855  what's the introduced where notes is 9 withdrawn in 1946 after fire ['Number Range', 'Introduced', 'Builder', 'Engine', 'Weight (long tons)', 'Seats', 'Withdrawn', 'Notes'] SELECT introduced FROM table WHERE withdrawn = 9 withdrawn in 1946 after fire SELECT Introduced FROM table WHERE Notes = 9 withdrawn in 1946 after fire
# 85 / 4855 1
# 86 / 4855 1
# 87 / 4855 1
# 88 / 4855 what is the song name for the film name ganga kare insaaf? ['Year', 'Song name', 'Film name', 'Co-singer', 'Music director', 'Lyricist', 'Language'] SELECT * FROM table WHERE song name = song AND film name = ganga kare insaaf SELECT Song name FROM table WHERE Film name = Ganga Kare Insaaf
# 89 / 4855 1
# 90 / 4855  what's the electorate where election date is 16 cannot handle non-empty timestamp argument! ['Member', 'Electorate', 'Province', 'MPs term', 'Election date'] SELECT electorate FROM table WHERE electorate = 16 cannot handle non-empty timestamp argument SELECT Electorate FROM table WHERE Election date = 16 Cannot handle non-empty timestamp argument!
# 91 / 4855 1
# 92 / 4855 1
# 93 / 4855 1
# 94 / 4855 1
# 95 / 4855 1
# 96 / 4855 How many integrated allied-related are there? ['Component', 'Integrated', 'Allied-Related', 'Allied-Unrelated', 'Holding'] SELECT * FROM table WHERE integrated = integrated allied-related SELECT Integrated FROM table WHERE Allied-Related = Many
# 97 / 4855 1
# 98 / 4855 what is the integrated in which the holding allied-unrelated is many? ['Component', 'Integrated', 'Allied-Related', 'Allied-Unrelated', 'Holding'] SELECT integrated FROM table WHERE allied-unrelated = many SELECT Holding FROM table WHERE Allied-Unrelated = Many
# 99 / 4855 1
# 100 / 4855 1
# 101 / 4855 1
# 102 / 4855 1
# 103 / 4855 1
# 104 / 4855 1
# 105 / 4855 1
# 106 / 4855 Crockett High School had which number(#)? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT * FROM table WHERE high school = Crockett High School AND # = number SELECT # FROM table WHERE High School = Crockett
# 107 / 4855 Which home town was the high school Catholic University located in? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT home town FROM table WHERE high school = Catholic SELECT Home Town FROM table WHERE High School = Catholic University
# 108 / 4855 What height was the forward position at Crockett High School? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT height FROM table WHERE position = forward AND high school = Crockett High School SELECT Height FROM table WHERE Position = Forward AND High School = Crockett
# 109 / 4855 1
# 110 / 4855 1
# 111 / 4855 1
# 112 / 4855 1
# 113 / 4855 1
# 114 / 4855 1
# 115 / 4855 1
# 116 / 4855 1
# 117 / 4855 1
# 118 / 4855 1
# 119 / 4855 1
# 120 / 4855 1
# 121 / 4855 What is the score for the interview for the state of New York? ['State', 'Preliminaries', 'Interview', 'Swimsuit', 'Evening Gown', 'Average'] SELECT * FROM table WHERE interview = score AND state = New York SELECT Interview FROM table WHERE State = New York
# 122 / 4855 1
# 123 / 4855 1
# 124 / 4855 1
# 125 / 4855 1
# 126 / 4855 1
# 127 / 4855 1
# 128 / 4855 1
# 129 / 4855 1
# 130 / 4855 What is the theme for the episode selection process? ['Episode', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT theme FROM table WHERE episode = selection SELECT Theme FROM table WHERE Episode = Selection Process
# 131 / 4855 What is the song choice when the theme is not aired? ['Episode', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT song choice FROM table WHERE theme = not aired SELECT Theme FROM table WHERE Song choice = Not Aired
# 132 / 4855 What years did Markose Bristow Madhumita Bisht win the mens singles and/or the mixed doubles? ['Season', 'Mens singles', 'Womens singles', 'Mens doubles', 'Womens doubles', 'Mixed doubles'] SELECT * FROM table WHERE mens singles = Markose Bristow Madhumita Bisht SELECT Mens singles FROM table WHERE Mixed doubles = Markose Bristow Madhumita Bisht
# 133 / 4855 What year is Japan the country? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT year FROM table WHERE year = Japan SELECT Year FROM table WHERE Country = Japan
# 134 / 4855 What is the year that Dewi Claire Schreefel is the champion? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT year FROM table WHERE year = Dewi Claire Schreefel SELECT Year FROM table WHERE Champion = Dewi Claire Schreefel
# 135 / 4855 What is the tournament location when Vicky Hurst in the champion? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT tournament location FROM table WHERE tournament location = Vicky Hurst SELECT Tournament location FROM table WHERE Champion = Vicky Hurst
# 136 / 4855 1
# 137 / 4855 1
# 138 / 4855 1
# 139 / 4855 1
# 140 / 4855 Which is the charity that the background of the celebrity is heavyweight champion? ['Celebrity', 'Background', 'Original Team', 'Age', 'Hometown', 'Charity', 'Result', 'Raised'] SELECT charity FROM table WHERE celebrity = heavyweight champion SELECT Charity FROM table WHERE Background = Heavyweight Champion
# 141 / 4855 1
# 142 / 4855 1
# 143 / 4855 1
# 144 / 4855 What is the background of the celebrity who had the result 13 the celebrity apprentice (2008-03-27)? ['Celebrity', 'Background', 'Original Team', 'Age', 'Hometown', 'Charity', 'Result', 'Raised'] SELECT background FROM table WHERE celebrity = celebrity apprentice (2008-03-27) SELECT Background FROM table WHERE Result = 13 The Celebrity Apprentice (2008-03-27)
# 145 / 4855 1
# 146 / 4855 1
# 147 / 4855 1
# 148 / 4855 1
# 149 / 4855 1
# 150 / 4855 1
# 151 / 4855 1
# 152 / 4855 1
# 153 / 4855 1
# 154 / 4855 1
# 155 / 4855 What is the 2007 estimate when the rank (csa) is 4 ['Rank (CSA)', 'Combined Statistical Area (or Metropolitan Statistical Area if noted)', 'State(s)', '2007 Estimate', '2000 Population', 'Percent Change (1990–2000)'] SELECT * FROM table WHERE 2007 estimate = 2007 AND rank (csa) = 4 SELECT 2007 Estimate FROM table WHERE Rank (CSA) = 4
# 156 / 4855 1
# 157 / 4855 1
# 158 / 4855 1
# 159 / 4855 1
# 160 / 4855 1
# 161 / 4855 1
# 162 / 4855 1
# 163 / 4855 1
# 164 / 4855 1
# 165 / 4855 1
# 166 / 4855 What was the lost with tries for? ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Tries for', 'Tries against', 'Try bonus', 'Losing bonus', 'Points'] SELECT lost FROM table SELECT Lost FROM table WHERE Tries for = Tries for
# 167 / 4855 1
# 168 / 4855 1
# 169 / 4855 1
# 170 / 4855 1
# 171 / 4855 1
# 172 / 4855 What is the type of the printer ports included in the EX Plus3 model number? ['Model number', 'Printer ports', 'Network ports', 'Network protocols', 'Firmware', 'Notes'] SELECT * FROM table WHERE printer ports = ports AND model number = EX Plus3 SELECT Printer ports FROM table WHERE Model number = EX Plus3
# 173 / 4855 What is the traditional way to write the name of the district who's area is 2331? ['English Name', 'Simplified', 'Traditional', 'Pinyin', 'Area', 'Population', 'Density'] SELECT * FROM table WHERE area = 2331 SELECT Traditional FROM table WHERE Area = 2331
# 174 / 4855 1
# 175 / 4855 1
# 176 / 4855 1
# 177 / 4855 1
# 178 / 4855 1
# 179 / 4855 1
# 180 / 4855 What was the air date of part 2 of the episode whose part 1 was aired on January 31, 2008? ['Episode #', 'Title', 'Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5', 'Part 6'] SELECT part 2 FROM table WHERE part 2 = air date AND part 1 = January 31, 2008 SELECT Part 2 FROM table WHERE Part 1 = January 31, 2008
# 181 / 4855 What's the air date of part 1 of the episode whose part 2 aired on December 2, 2007? ['Episode #', 'Title', 'Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5', 'Part 6'] SELECT part 1 FROM table WHERE part 1 = air date AND part 2 = December 2, 2007 SELECT Part 1 FROM table WHERE Part 2 = December 2, 2007
# 182 / 4855 1
# 183 / 4855 1
# 184 / 4855 who is the the office with incumbent being ramon r. jimenez, jr. ['Department', 'Acronym', 'Office', 'Incumbent', 'in Office since'] SELECT office FROM table WHERE office = ramon r. jimenez, jr. SELECT Office FROM table WHERE Incumbent = Ramon R. Jimenez, Jr.
# 185 / 4855 1
# 186 / 4855 1
# 187 / 4855 1
# 188 / 4855 1
# 189 / 4855 1
# 190 / 4855 1
# 191 / 4855 1
# 192 / 4855 Who were the candidates when gregory w. meeks was the incumbent ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT candidates FROM table WHERE candidates = gregory w. meeks SELECT Candidates FROM table WHERE Incumbent = Gregory W. Meeks
# 193 / 4855 1
# 194 / 4855 1
# 195 / 4855 1
# 196 / 4855 1
# 197 / 4855 In which district is the incumbent Marcia C. Kaptur?  ['District', 'Incumbent', 'Party', 'First elected', 'Results', 'Candidates'] SELECT district FROM table WHERE district = Marcia C. Kaptur SELECT District FROM table WHERE Incumbent = Marcia C. Kaptur
# 198 / 4855 1
# 199 / 4855 1
# 200 / 4855 1
# 201 / 4855 1
# 202 / 4855 what's the first elected with opponent being ralph regula (r) 75.0% j. michael finn (d) 25.0% ['District', 'Incumbent', 'Party', 'First elected', 'Status', 'Opponent'] SELECT first elected FROM table WHERE first elected = ralph regula (r) 75.0% j. michael finn (d) 25.0% SELECT First elected FROM table WHERE Opponent = Ralph Regula (R) 75.0% J. Michael Finn (D) 25.0%
# 203 / 4855 1
# 204 / 4855 1
# 205 / 4855 1
# 206 / 4855 what's party with result being retired to run for u. s. senate republican hold ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT party FROM table WHERE party = retired to run for u. s. senate republican hold SELECT Party FROM table WHERE Result = Retired to run for U. S. Senate Republican hold
# 207 / 4855 1
# 208 / 4855 what's district with candidates being lawrence j. smith (d) 69.4% joseph smith (r) 30.6% ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = lawrence j. smith (d) 69.4% joseph smith (r) 30.6% SELECT District FROM table WHERE Candidates = Lawrence J. Smith (D) 69.4% Joseph Smith (R) 30.6%
# 209 / 4855 1
# 210 / 4855 1
# 211 / 4855 1
# 212 / 4855 1
# 213 / 4855 1
# 214 / 4855 1
# 215 / 4855 who are the candidates where the incumbent is sam m. gibbons? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT candidates FROM table WHERE candidates = sam m. gibbons SELECT Candidates FROM table WHERE Incumbent = Sam M. Gibbons
# 216 / 4855 what was the result where the candidates are sam m. gibbons (d) unopposed? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT result FROM table WHERE result = sam m. gibbons (d) unopposed SELECT Result FROM table WHERE Candidates = Sam M. Gibbons (D) Unopposed
# 217 / 4855 1
# 218 / 4855 What district is F. Edward Hebert the incumbent in? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = F. Edward Hebert SELECT District FROM table WHERE Incumbent = F. Edward Hebert
# 219 / 4855 1
# 220 / 4855 What's the district that Otto Passman is the incumbent of? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = Otto Passman SELECT District FROM table WHERE Incumbent = Otto Passman
# 221 / 4855 What party is incumbent thomas j. lane from? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT party FROM table WHERE party = thomas j. lane SELECT Party FROM table WHERE Incumbent = Thomas J. Lane
# 222 / 4855 1
# 223 / 4855 1
# 224 / 4855 what's the district with incumbent being lawrence h. fountain ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = lawrence h. fountain SELECT District FROM table WHERE Incumbent = Lawrence H. Fountain
# 225 / 4855 1
# 226 / 4855 1
# 227 / 4855 What was the result of the election of the incumbent harry r. sheppard? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT result FROM table WHERE result = harry r. sheppard SELECT Result FROM table WHERE Incumbent = Harry R. Sheppard
# 228 / 4855 What district did incumbent Ralph A. Gamble represent? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = Ralph A. Gamble SELECT District FROM table WHERE Incumbent = Ralph A. Gamble
# 229 / 4855 1
# 230 / 4855 1
# 231 / 4855 What district does  incumbent  james c. davis represent? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = james c. davis SELECT District FROM table WHERE Incumbent = James C. Davis
# 232 / 4855 1
# 233 / 4855 1
# 234 / 4855 What district was Harold Earthman the incumbent in?  ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = Harold Earthman SELECT District FROM table WHERE Incumbent = Harold Earthman
# 235 / 4855 Who were the candidates when Noble Jones Gregory was incumbent? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT candidates FROM table WHERE candidates = Noble Jones Gregory SELECT Candidates FROM table WHERE Incumbent = Noble Jones Gregory
# 236 / 4855 1
# 237 / 4855 1
# 238 / 4855 1
# 239 / 4855 1
# 240 / 4855 1
# 241 / 4855 1
# 242 / 4855 What was the winning party when the incumbent was richard s. whaley? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT party FROM table WHERE party = richard s. whaley SELECT Party FROM table WHERE Incumbent = Richard S. Whaley
# 243 / 4855 1
# 244 / 4855 1
# 245 / 4855 1
# 246 / 4855 1
# 247 / 4855 1
# 248 / 4855 Pink cytoplasm is seen in a test that specifically stains what? ['Stain', 'Common use', 'Nucleus', 'Cytoplasm', 'Red blood cell (RBC)', 'Collagen fibers', 'Specifically stains'] SELECT * FROM table WHERE cytoplasm = Pink cytoplasm SELECT Specifically stains FROM table WHERE Cytoplasm = Pink
# 249 / 4855 The pink cytoplasm will have a nucleus of what color? ['Stain', 'Common use', 'Nucleus', 'Cytoplasm', 'Red blood cell (RBC)', 'Collagen fibers', 'Specifically stains'] SELECT nucleus FROM table WHERE cytoplasm = pink cytoplasm SELECT Nucleus FROM table WHERE Cytoplasm = Pink
# 250 / 4855 where is hte second place winner from united kingdom? ['Year', 'Winner', 'Language', 'Artist', 'Song', 'Points', 'Margin', 'Second place', 'Date', 'Venue', 'Location', 'Participants'] SELECT second place FROM table WHERE winner = united kingdom SELECT Winner FROM table WHERE Second place = United Kingdom
# 251 / 4855 1
# 252 / 4855 1
# 253 / 4855 1
# 254 / 4855 1
# 255 / 4855 1
# 256 / 4855 1
# 257 / 4855 1
# 258 / 4855 1
# 259 / 4855 1
# 260 / 4855 1
# 261 / 4855 what's the byu-uu score with uu-usu score being 44–16 ['Season', 'Winner', 'BYU-UU score', 'BYU-USU score', 'UU-USU score'] SELECT * FROM table WHERE uu-usu score = 44–16 SELECT BYU-UU score FROM table WHERE UU-USU score = 44–16
# 262 / 4855 1
# 263 / 4855 1
# 264 / 4855 1
# 265 / 4855 1
# 266 / 4855 1
# 267 / 4855 who is the the incumbent with opponent being anthony weiner (d) unopposed ['District', 'Incumbent', 'Party', 'Elected', 'Status', 'Opponent'] SELECT incumbent FROM table WHERE incumbent = anthony weiner (d) unopposed SELECT Incumbent FROM table WHERE Opponent = Anthony Weiner (D) unopposed
# 268 / 4855 1
# 269 / 4855 1
# 270 / 4855 1
# 271 / 4855 1
# 272 / 4855 1
# 273 / 4855 1
# 274 / 4855 1
# 275 / 4855 1
# 276 / 4855 1
# 277 / 4855 1
# 278 / 4855 what's the result with opponent being at oakland raiders ['Week', 'Date', 'Opponent', 'Result', 'Stadium', 'Record', 'Attendance'] SELECT result FROM table WHERE opponent = oakland raiders SELECT Result FROM table WHERE Opponent = at Oakland Raiders
# 279 / 4855 1
# 280 / 4855 1
# 281 / 4855 The results for gt2 winning team is all lars-erik nielsen allan simonsen richard westbrook.  ['Rnd', 'Circuit', 'LMP1 Winning Team', 'LMP2 Winning Team', 'GT1 Winning Team', 'GT2 Winning Team', 'Results'] SELECT results FROM table WHERE gt2 winning team = all lars-erik nielsen allan simonsen richard westbrook SELECT Results FROM table WHERE GT2 Winning Team = Lars-Erik Nielsen Allan Simonsen Richard Westbrook
# 282 / 4855 1
# 283 / 4855 1
# 284 / 4855 1
# 285 / 4855 1
# 286 / 4855 1
# 287 / 4855 1
# 288 / 4855 1
# 289 / 4855 1
# 290 / 4855 1
# 291 / 4855 1
# 292 / 4855 1
# 293 / 4855 1
# 294 / 4855 picturesque and trekking route is the category what is the height from sea level in meters? ['Name Of Place', 'Height from Sea Level In Meters', 'Nearby Town', 'Trekking Route', 'Category'] SELECT height from sea level in meters FROM table WHERE trekking route = picturesque and trekking route SELECT Height from Sea Level In Meters FROM table WHERE Category = Picturesque and Trekking Route
# 295 / 4855 1
# 296 / 4855 1
# 297 / 4855 1
# 298 / 4855 1
# 299 / 4855 When the total points are 22 how many total touchdowns have been made? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT * FROM table WHERE points = 22 AND touchdowns = total touchdowns SELECT Touchdowns FROM table WHERE Points = 22
# 300 / 4855 1
# 301 / 4855 Who led the points classification when Roman Kreuziger led the young rider classification? ['Stage', 'Winner', 'General classification', 'Points classification', 'Mountains classification', 'Young rider classification', 'Team classification', 'Combativity award'] SELECT points classification FROM table WHERE points classification = Roman Kreuziger SELECT Points classification FROM table WHERE Young rider classification = Roman Kreuziger
# 302 / 4855 Name the hometown for ventrell jenkins ['Position', 'Number', 'Name', 'Height', 'Weight', 'Class', 'Hometown', 'Games↑'] SELECT hometown FROM table WHERE hometown = ventrell jenkins SELECT Hometown FROM table WHERE Name = Ventrell Jenkins
# 303 / 4855 1
# 304 / 4855 1
# 305 / 4855 1
# 306 / 4855 What locale has Suzanne Gaudet as skip? ['Locale', 'Skip', 'W', 'L', 'PF', 'PA', 'Ends Won', 'Ends Lost', 'Blank Ends', 'Stolen Ends', 'Shot Pct.'] SELECT locale FROM table WHERE locale = Suzanne Gaudet SELECT Locale FROM table WHERE Skip = Suzanne Gaudet
# 307 / 4855 What locale has the skip Colleen Jones? ['Locale', 'Skip', 'W', 'L', 'PF', 'PA', 'Ends Won', 'Ends Lost', 'Blank Ends', 'Stolen Ends', 'Shot Pct.'] SELECT locale FROM table WHERE l = Colleen Jones SELECT Locale FROM table WHERE Skip = Colleen Jones
# 308 / 4855 Who plays Overton Moyle in casino theatre 1888 & savoy theatre 1906? ['Role', 'Savoy Theatre 1888', 'Casino Theatre 1888', 'Savoy Theatre 1897', 'Savoy Theatre 1906', 'Savoy Theatre 1909'] SELECT * FROM table WHERE casino theatre 1888 = Overton Moyle AND savoy theatre 1906 = casino theatre 1888 & savoy theatre 1906 SELECT Casino Theatre 1888 FROM table WHERE Savoy Theatre 1906 = Overton Moyle
# 309 / 4855 1
# 310 / 4855 1
# 311 / 4855 what's the result with opponent being at new england patriots ['Week', 'Date', 'Opponent', 'Result', 'Record', 'Game Site', 'Attendance'] SELECT result FROM table WHERE opponent = new england patriots SELECT Result FROM table WHERE Opponent = at New England Patriots
# 312 / 4855 1
# 313 / 4855 1
# 314 / 4855 1
# 315 / 4855 1
# 316 / 4855 1
# 317 / 4855 1
# 318 / 4855 1
# 319 / 4855 Which player's results were T6 in the PGA Ch., T4 in the Masters and T8 at the U.S. Open? ['Nationality', 'Player', 'Year', 'Wins', 'Masters', 'U.S. Open', 'Open Ch.', 'PGA Ch.'] SELECT player FROM table WHERE pga ch. = T4 AND masters = T8 SELECT Player FROM table WHERE PGA Ch. = T6 AND Masters = T4 AND U.S. Open = T8
# 320 / 4855 What is the result at the Masters for the player who finished R16 at the PGA Ch.? ['Nationality', 'Player', 'Year', 'Wins', 'Masters', 'U.S. Open', 'Open Ch.', 'PGA Ch.'] SELECT * FROM table WHERE player = R16 SELECT Masters FROM table WHERE PGA Ch. = R16
# 321 / 4855 1
# 322 / 4855 1
# 323 / 4855 1
# 324 / 4855 1
# 325 / 4855 1
# 326 / 4855 which electorate is 54787 of the constituency ['Constituency', 'Electorate', 's Spoilt vote', 'Total poll (%)', 'For (%)', 'Against (%)'] SELECT electorate FROM table WHERE electorate = 54787 SELECT Constituency FROM table WHERE Electorate = 54787
# 327 / 4855 1
# 328 / 4855 1
# 329 / 4855 1
# 330 / 4855 1
# 331 / 4855 1
# 332 / 4855 When the division is Division 2 men what is the champion score? ['Division', 'Champion Score', 'Runner-Up Score', 'Final MVP Team', 'Defensive Player of the Final Team'] SELECT * FROM table WHERE division = champion SELECT Champion Score FROM table WHERE Division = Division 2 Men
# 333 / 4855 1
# 334 / 4855 1
# 335 / 4855 1
# 336 / 4855 When marshmallow cookies is segment b what episode is it on netflix? ['Series Ep.', 'Episode', 'Netflix', 'Segment A', 'Segment B', 'Segment C', 'Segment D'] SELECT netflix FROM table WHERE episode = marshmallow cookies SELECT Netflix FROM table WHERE Segment B = Marshmallow Cookies
# 337 / 4855 1
# 338 / 4855 1
# 339 / 4855 1
# 340 / 4855 1
# 341 / 4855 What is the clock multiplier if the voltage range (v) is 3.3 - 3.6; input clock (mhz) is 33 x 3 / 50 x 2; and part number is a80486dx4-100? ['Processor Speed (MHz)', 'Input Clock (MHz)', 'Voltage Center (V)', 'Voltage Range (V)', 'Part Number', 'Clock Multiplier', 'S-Spec Number'] SELECT clock multiplier FROM table WHERE input clock (mhz) = 33 x 3 / 50 x 2 AND part number = a80486dx4-100 SELECT Clock Multiplier FROM table WHERE Voltage Range (V) = 3.3 - 3.6 AND Input Clock (MHz) = 33 X 3 / 50 X 2 AND Part Number = A80486DX4-100
# 342 / 4855 1
# 343 / 4855 1
# 344 / 4855 1
# 345 / 4855 What date was parliament assembled when John rudhale was first member? ['Elected', 'Assembled', 'Dissolved', 'First member', 'Second member'] SELECT * FROM table WHERE assembled = John rudhale SELECT Assembled FROM table WHERE First member = John Rudhale
# 346 / 4855 1
# 347 / 4855 1
# 348 / 4855 1
# 349 / 4855 1
# 350 / 4855 1
# 351 / 4855 1
# 352 / 4855 1
# 353 / 4855 List all years in Orlando where Jeryl Sasser was a player. ['Player', 'No.', 'Nationality', 'Position', 'Years in Orlando', 'School/Club Team'] SELECT years in Orlando FROM table WHERE years in orlando = Jeryl Sasser SELECT Years in Orlando FROM table WHERE Player = Jeryl Sasser
# 354 / 4855 WHO IS THE PLAYER(S) ON THE ROSTER FROM SCHOOL/CLUB TEAM ARIZONA? ['Player', 'No.', 'Nationality', 'Position', 'Years in Orlando', 'School/Club Team'] SELECT * FROM table WHERE school/club team = ARIZONA SELECT Player FROM table WHERE School/Club Team = Arizona
# 355 / 4855 1
# 356 / 4855 1
# 357 / 4855 1
# 358 / 4855 1
# 359 / 4855 Which date contained Aubrey O'Day as the cover model? ['Date', 'Cover model', 'Centerfold model', 'Interview subject', '20 Questions', 'Pictorials'] SELECT date FROM table WHERE date = Aubrey O'Day SELECT Date FROM table WHERE Cover model = Aubrey O'Day
# 360 / 4855 1
# 361 / 4855 1
# 362 / 4855 1
# 363 / 4855 1
# 364 / 4855 1
# 365 / 4855 Who is the original artist for the theme "Year they were born?" ['Week #', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT original artist FROM table WHERE original artist = "Year they were born?" SELECT Original artist FROM table WHERE Theme = Year They Were Born
# 366 / 4855 What theme name has the original artist of Dolly Parton? ['Week #', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT * FROM table WHERE theme = theme name AND original artist = Dolly Parton SELECT Theme FROM table WHERE Original artist = Dolly Parton
# 367 / 4855 1
# 368 / 4855 1
# 369 / 4855 March 0.41 in July?  ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT July FROM table WHERE march = March 0.41 SELECT July FROM table WHERE March = 0.41
# 370 / 4855 What september has 10.35 in November?  ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT september FROM table WHERE september = 10.35 SELECT September FROM table WHERE November = 10.35
# 371 / 4855 January 7.34 where is June ? ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT June FROM table WHERE january = 7.34 SELECT January FROM table WHERE June = 7.34
# 372 / 4855 What December is 8.77 in January  ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT December FROM table WHERE december = 8.77 SELECT December FROM table WHERE January = 8.77
# 373 / 4855 1
# 374 / 4855 1
# 375 / 4855 1
# 376 / 4855 1
# 377 / 4855 1
# 378 / 4855 1
# 379 / 4855 1
# 380 / 4855 1
# 381 / 4855 1
# 382 / 4855 Is the team force india allowed to race? ['Year', 'Event', 'Pole position time', '107% time', 'Driver', 'Team', 'Time', '% of pole', 'Allowed to race?'] SELECT * FROM table WHERE team = race SELECT Allowed to race? FROM table WHERE Team = Force India
# 383 / 4855 1
# 384 / 4855 1
# 385 / 4855 What was the home team score when Brisbane lions was the home team? ['Home team', 'Home team score', 'Away team', 'Away team score', 'Ground', 'Crowd', 'Date'] SELECT home team score FROM table WHERE home team score = Brisbane lions SELECT Home team score FROM table WHERE Home team = Brisbane Lions
# 386 / 4855 1
# 387 / 4855 Name the french title for english title of "inventor bunnies" ['Official #', 'TF1 #', 'French title', 'English title', 'Air date (France)', 'Original Beechwood Bunny Tale / Source material'] SELECT french title FROM table WHERE english title = "inventor bunnies" SELECT French title FROM table WHERE English title = Inventor Bunnies
# 388 / 4855 1
# 389 / 4855 What school location had an enrollment of 12400? ['Institution', 'Location', 'Nickname', 'Enrollment', 'Established'] SELECT * FROM table WHERE location = school location AND enrollment = 12400 SELECT Location FROM table WHERE Enrollment = 12400
# 390 / 4855 1
# 391 / 4855 What is the winning song for the artist with a debut album "the winner"? ['Season', 'Winner', 'Winning Song', 'Winning Song (English Title)', 'Debut Album'] SELECT winning song FROM table WHERE winner = "the winner" SELECT Winning Song FROM table WHERE Debut Album = The Winner
# 392 / 4855 What is the winning song for the artist with a debut album "mike"? ['Season', 'Winner', 'Winning Song', 'Winning Song (English Title)', 'Debut Album'] SELECT winning song FROM table WHERE debut album = "mike" SELECT Winning Song FROM table WHERE Debut Album = Mike
# 393 / 4855 1
# 394 / 4855 1
# 395 / 4855 1
# 396 / 4855 1
# 397 / 4855 1
# 398 / 4855 How many bypass boosters are there on the engine with slit exhaust ports and SPI is yes? ['Engine', 'Exhaust Ports', 'Bypass Ports', 'Bypass Boosters', 'SPI', 'Tapered Grind', 'Number on cyl.'] SELECT * FROM table WHERE bypass boosters = bypass AND exhaust ports = slit AND spi = yes SELECT Bypass Boosters FROM table WHERE SPI = Yes AND Exhaust Ports = Slit
# 399 / 4855 1
# 400 / 4855 1
# 401 / 4855 Name the snatch when body weight is 73.7 ['Place', 'Weightlifter', 'Body weight', 'one hand snatch', 'one hand clean & jerk', 'Press', 'Snatch', '1.', '2.', '3.', 'Total'] SELECT snatch FROM table WHERE 3. = 73.7 SELECT Snatch FROM table WHERE Body weight = 73.7
# 402 / 4855 1
# 403 / 4855 1
# 404 / 4855 1
# 405 / 4855 1
# 406 / 4855 1
# 407 / 4855 1
# 408 / 4855 1
# 409 / 4855 1
# 410 / 4855 1
# 411 / 4855 1
# 412 / 4855 Which date did Chris Duhon (13) receive high assists? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT date FROM table WHERE date = Chris Duhon (13) SELECT Date FROM table WHERE High assists = Chris Duhon (13)
# 413 / 4855 1
# 414 / 4855 1
# 415 / 4855 1
# 416 / 4855 What was the record when Canty (5) was the high assists? ['Game', 'Date', 'Opponent', 'Score', 'High points', 'High rebounds', 'High assists', 'Location/Attendance', 'Record'] SELECT record FROM table WHERE record = Canty (5) SELECT Record FROM table WHERE High assists = Canty (5)
# 417 / 4855 On what date did Canty (6) receive high assists? ['Game', 'Date', 'Opponent', 'Score', 'High points', 'High rebounds', 'High assists', 'Location/Attendance', 'Record'] SELECT date FROM table WHERE date = Canty (6) SELECT Date FROM table WHERE High assists = Canty (6)
# 418 / 4855 1
# 419 / 4855 1
# 420 / 4855 1
# 421 / 4855 1
# 422 / 4855 1
# 423 / 4855 When galaxy angel aa was the title was the us release date? ['Series', 'Title', 'Broadcasts (TV) 1', 'Episodes (TV+extra) 2', 'Directors', 'Aired in Japan 3', 'US Release Date'] SELECT * FROM table WHERE title = release date SELECT US Release Date FROM table WHERE Title = Galaxy Angel AA
# 424 / 4855 What's the change over previous year as a whole in the period in which the change over same quarter the previous year was up 2.8%? ['Period', '% trains arriving within 5 mins of scheduled time (over three months)', 'Change over same quarter the previous year', '% trains arriving within 5 mins of scheduled time Moving Annual Average (MAA)', 'Change over previous year as a whole'] SELECT change over previous year as a whole FROM table WHERE change over same quarter the previous year = 2.8% SELECT Change over previous year as a whole FROM table WHERE Change over same quarter the previous year = Up 2.8%
# 425 / 4855 How many open era titles does the team with their first title in 1925 have? ['Country', 'Amateur Era', 'Open Era', 'All-time', 'First title', 'Last title'] SELECT * FROM table WHERE open era = open era titles AND first title = 1925 SELECT Open Era FROM table WHERE First title = 1925
# 426 / 4855 1
# 427 / 4855 1
# 428 / 4855 1
# 429 / 4855 1
# 430 / 4855 1
# 431 / 4855 What was the date when Troy Murphy (15), got high rebounds?  ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT date FROM table WHERE date = Troy Murphy (15) SELECT Date FROM table WHERE High rebounds = Troy Murphy (15)
# 432 / 4855 Who did the High Assists when Kevin Durant (28) took the High Points? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT High Assists FROM table WHERE high assists = Kevin Durant (28) SELECT High assists FROM table WHERE High points = Kevin Durant (28)
# 433 / 4855 1
# 434 / 4855 1
# 435 / 4855 1
# 436 / 4855 what is the largest city where the province is eastern cape? ['Province', 'Provincial capital', 'Largest city', 'Area (km 2 )', 'Population (2013)'] SELECT * FROM table WHERE largest city = city AND province = eastern cape SELECT Largest city FROM table WHERE Province = Eastern Cape
# 437 / 4855 What is the IATA of the airport with 3848 traffic in 2010-11? ['Rank', 'Airport', 'Location', 'IATA', '1985–86', '1990–91', '1995–96', '2000–01', '2005–06', '2007–08', '2009–10', '2010-11'] SELECT IATA FROM table WHERE airport = 3848 SELECT IATA FROM table WHERE 2010-11 = 3848
# 438 / 4855 1
# 439 / 4855 What is the name where the type is listed as free agent and  the country is ngr eng? ['N', 'P', 'Name', 'EU', 'Country', 'Age', 'Type', 'Moving from', 'Transfer window', 'Ends', 'Transfer fee', 'Source'] SELECT name FROM table WHERE age = free agent AND n = ngr eng SELECT Name FROM table WHERE Type = Free Agent AND Country = NGR ENG
# 440 / 4855 What is listed in p when the type is listed as free agent 1? ['N', 'P', 'Name', 'EU', 'Country', 'Age', 'Type', 'Moving from', 'Transfer window', 'Ends', 'Transfer fee', 'Source'] SELECT * FROM table WHERE age = free agent 1 SELECT P FROM table WHERE Type = Free Agent 1
# 441 / 4855 1
# 442 / 4855 Name the original title for 6.05 million viewership ['Episode', 'Original title', 'Directed by', 'Written by', 'Original airdate', 'Duration', 'Viewership'] SELECT original title FROM table WHERE original title = 6.05 SELECT Original title FROM table WHERE Viewership = 6.05 million
# 443 / 4855 1
# 444 / 4855 1
# 445 / 4855 1
# 446 / 4855 What is every "directed by" when the title is "One To Go" (part 2)? ['No. in series', 'No. in season', 'Title', 'Directed by', 'Written by', 'Original air date', 'U.S. viewers (millions)'] SELECT directed by FROM table WHERE directed by = "One To Go" (part 2) SELECT Directed by FROM table WHERE Title = One to Go (Part 2)
# 447 / 4855 1
# 448 / 4855 1
# 449 / 4855 which examples are pronounced et in australian ['Ending', 'American', 'British', 'Australian', 'Examples'] SELECT * FROM table WHERE australian = et SELECT Examples FROM table WHERE Australian = et
# 450 / 4855 What is the location of the church when the church name is Ortnevik Kyrkje? ['Parish (Prestegjeld)', 'Sub-Parish (Sogn)', 'Church Name', 'Year Built', 'Location of the Church'] SELECT * FROM table WHERE location of the church = location AND church name = Ortnevik Kyrkje SELECT Location of the Church FROM table WHERE Church Name = Ortnevik kyrkje
# 451 / 4855 1
# 452 / 4855 1
# 453 / 4855 When did the club UNAM played the first season in top division? ['Club', 'First season in top division', 'Number of seasons in top division', 'First season of current spell in top division', 'Number of seasons in Liga MX', 'Top division titles'] SELECT * FROM table WHERE club = first season SELECT First season in top division FROM table WHERE Club = UNAM
# 454 / 4855 1
# 455 / 4855 1
# 456 / 4855 which chapter was Transmitted on wednesday if the episode of "363 the hangover part ii" was transmitted on monday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "363 the hangover part ii" SELECT Wednesday FROM table WHERE Monday = 363 The Hangover Part II
# 457 / 4855 which episode was Transmitted on wednesday if the episode of "438 magic: the gathering mini masters tournament" was transmitted on thursday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "438 magic: the gathering mini masters tournament" SELECT Wednesday FROM table WHERE Thursday = 438 Magic: The Gathering Mini Masters Tournament
# 458 / 4855 which episode was Transmitted on friday if the episode of "414 insanely twisted shadow planet" was transmitted on tuesday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT friday FROM table WHERE friday = "414 insanely twisted shadow planet" SELECT Friday FROM table WHERE Tuesday = 414 Insanely Twisted Shadow Planet
# 459 / 4855 which episode was Transmitted on friday if the episode of "515 the adventures of tintin" was transmitted on monday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT friday FROM table WHERE friday = "515 the adventures of tintin" SELECT Friday FROM table WHERE Monday = 515 The Adventures of Tintin
# 460 / 4855 which episode was Transmitted on wednesday if the episode of "307 vs." was transmitted on friday?   ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "307 vs." SELECT Wednesday FROM table WHERE Friday = 307 VS.
# 461 / 4855 1
# 462 / 4855 1
# 463 / 4855 1
# 464 / 4855 1
# 465 / 4855 there are in tobago species name helicops angulatus ['Species', 'Common name', 'Trinidad', 'Tobago', 'Bocas Is.', 'Other'] SELECT * FROM table WHERE species = helicops angulatus SELECT Tobago FROM table WHERE Species = Helicops angulatus
# 466 / 4855 are in tobago species liophis cobellus cobellus? ['Species', 'Common name', 'Trinidad', 'Tobago', 'Bocas Is.', 'Other'] SELECT * FROM table WHERE species = liophis cobellus cobellus SELECT Tobago FROM table WHERE Species = Liophis cobellus cobellus
# 467 / 4855 Which U.S. Acres episode with Garfield episode 1 has a date of disaster? ['Episode', 'Garfield Episode 1', 'U.S. Acres Episode', 'Garfield Episode 2', 'Original Airdate'] SELECT * FROM table WHERE u.s. acres episode = 1 AND garfield episode 1 = disaster SELECT U.S. Acres Episode FROM table WHERE Garfield Episode 1 = Date of Disaster
# 468 / 4855 Which Garfield episode 1 has Garfield episode 2 as the second penelope episode? ['Episode', 'Garfield Episode 1', 'U.S. Acres Episode', 'Garfield Episode 2', 'Original Airdate'] SELECT Garfield episode 1 FROM table WHERE episode = the second penelope episode SELECT Garfield Episode 1 FROM table WHERE Garfield Episode 2 = The Second Penelope Episode
# 469 / 4855 1
# 470 / 4855 1
# 471 / 4855 1
# 472 / 4855 1
# 473 / 4855 1
# 474 / 4855 What township is located at longitude -99.287270? ['Township', 'County', 'Pop. (2010)', 'Land ( sqmi )', 'Water (sqmi)', 'Latitude', 'Longitude', 'GEO ID', 'ANSI code'] SELECT township FROM table WHERE township = -99.287270 SELECT Township FROM table WHERE Longitude = -99.287270
# 475 / 4855 1
# 476 / 4855 1
# 477 / 4855 1
# 478 / 4855 1
# 479 / 4855 1
# 480 / 4855 1
# 481 / 4855 1
# 482 / 4855 1
# 483 / 4855 1
# 484 / 4855 1
# 485 / 4855 1
# 486 / 4855 When batavo is the main sponsor and olympikus is the kit manufacturer who are the minor sponsors? ['Period', 'Kit manufacturer', 'Main sponsor', 'Secondary sponsor', 'Minor sponsors'] SELECT minor sponsors FROM table WHERE main sponsor = olympikus SELECT Minor sponsors FROM table WHERE Kit manufacturer = Olympikus AND Main sponsor = Batavo
# 487 / 4855 1
# 488 / 4855 1
# 489 / 4855 1
# 490 / 4855 1
# 491 / 4855 1
# 492 / 4855 1
# 493 / 4855 1
# 494 / 4855 1
# 495 / 4855 1
# 496 / 4855 What is the rank of london borough in southwark? ['Rank', 'London Borough', 'Black African Population', 'Black Caribbean Population', 'Other Black Population', 'Total Black Population'] SELECT rank FROM table WHERE rank = london AND london borough = southwark SELECT Rank FROM table WHERE London Borough = Southwark
# 497 / 4855 1
# 498 / 4855 What was the team's status in the USISL Pro League playoffs? ['Year', 'Division', 'League', 'Regular Season', 'Playoffs', 'Open Cup'] SELECT * FROM table WHERE league = USISL Pro League SELECT Playoffs FROM table WHERE League = USISL Pro League
# 499 / 4855 1
# 500 / 4855 1
# 501 / 4855 1
# 502 / 4855 1
# 503 / 4855 1
# 504 / 4855 1
# 505 / 4855 1
# 506 / 4855 Who are the opponents of Mike Byron and partner in matches where the score was  6–4, 4–6, 7–6 (7–4)? ['Outcome', 'Year', 'Championship', 'Surface', 'Partner', 'Opponents', 'Score'] SELECT * FROM table WHERE opponents = Mike Byron AND score = 6–4, 4–6, 7–6 (7–4) SELECT Opponents FROM table WHERE Score = 6–4, 4–6, 7–6 (7–4)
# 507 / 4855 1
# 508 / 4855 1
# 509 / 4855 1
# 510 / 4855 1
# 511 / 4855 1
# 512 / 4855 1
# 513 / 4855 1
# 514 / 4855 1
# 515 / 4855 1
# 516 / 4855 1
# 517 / 4855 1
# 518 / 4855 1
# 519 / 4855 What was the result when John Barrow was the incumbent first elected in 2004? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT result FROM table WHERE result = John Barrow AND first elected = 2004 SELECT Result FROM table WHERE First elected = 2004 AND Incumbent = John Barrow
# 520 / 4855 1
# 521 / 4855 1
# 522 / 4855 1
# 523 / 4855 1
# 524 / 4855 What is the intelligence os the one that has 思 sī, "thought"? ['Shekhina:', 'Reason', 'Mind', 'Intelligence', 'Thought', 'Understanding'] SELECT intelligence FROM table WHERE thought = 思 sī SELECT Intelligence FROM table WHERE Thought = 思 sī, thought
# 525 / 4855 1
# 526 / 4855 1
# 527 / 4855 1
# 528 / 4855 1
# 529 / 4855 1
# 530 / 4855 1
# 531 / 4855 1
# 532 / 4855 1
# 533 / 4855 1
# 534 / 4855 1
# 535 / 4855 1
# 536 / 4855 1
# 537 / 4855 1
# 538 / 4855 1
# 539 / 4855 1
# 540 / 4855 1
# 541 / 4855 What was the time in part 3 when Heikki Kovalainen was the driver?  ['Pos', 'No', 'Driver', 'Constructor', 'Part 1', 'Part 2', 'Part 3', 'Grid'] SELECT * FROM table WHERE part 3 = Heikki Kovalainen SELECT Part 3 FROM table WHERE Driver = Heikki Kovalainen
# 542 / 4855 What was the time in part 3 when Nick Heidfeld was the driver? ['Pos', 'No', 'Driver', 'Constructor', 'Part 1', 'Part 2', 'Part 3', 'Grid'] SELECT * FROM table WHERE part 3 = Nick Heidfeld SELECT Part 3 FROM table WHERE Driver = Nick Heidfeld
# 543 / 4855 1
# 544 / 4855 1
# 545 / 4855 What's the Sanskrit word for month with Thai name มกราคม? ['English name', 'Thai name', 'Abbr.', 'Transcription', 'Sanskrit word', 'Zodiac sign'] SELECT * FROM table WHERE sanskrit word = Sanskrit AND thai name = มกราคม SELECT Sanskrit word FROM table WHERE Thai name = มกราคม
# 546 / 4855 1
# 547 / 4855 1
# 548 / 4855 1
# 549 / 4855 1
# 550 / 4855 1
# 551 / 4855 1
# 552 / 4855 What was the Obama% when McCain% was 61.2%? ['County', 'Obama%', 'Obama#', 'McCain%', 'McCain#', 'Others%', 'Others#'] SELECT * FROM table WHERE mccain% = 61.2% SELECT Obama% FROM table WHERE McCain% = 61.2%
# 553 / 4855 1
# 554 / 4855 1
# 555 / 4855 when type of work is novel and published in english is 1977, what was published in russian? ['English title', 'Russian title', 'Published in Russian', 'Published in English', 'Type of work'] SELECT * FROM table WHERE type of work = russian AND published in english = 1977 SELECT Published in Russian FROM table WHERE Type of work = novel AND Published in English = 1977
# 556 / 4855 1
# 557 / 4855 1
# 558 / 4855 1
# 559 / 4855 1
# 560 / 4855 What is the weight for western ontario college? ['Round', 'Choice', 'Player', 'Position', 'Height', 'Weight', 'College'] SELECT weight FROM table WHERE college = western ontario college SELECT Weight FROM table WHERE College = Western Ontario
# 561 / 4855 Which position has 225lb as weight? ['Round', 'Choice', 'Player', 'Position', 'Height', 'Weight', 'College'] SELECT position FROM table WHERE position = 225lb SELECT Position FROM table WHERE Weight = 225lb
# 562 / 4855 1
# 563 / 4855 1
# 564 / 4855 1
# 565 / 4855 what is the name of the institution of the sparta, wi location? ['Institution', 'Location', 'Year Joined', 'Affiliation', 'Enrollment', 'Mascot', 'Colors'] SELECT * FROM table WHERE institution = name AND location = sparta, wi SELECT Institution FROM table WHERE Location = Sparta, WI
# 566 / 4855 1
# 567 / 4855 1
# 568 / 4855 1
# 569 / 4855 1
# 570 / 4855 1
# 571 / 4855 1
# 572 / 4855 1
# ...
# 4603 / 4855 1
# 4604 / 4855 Which event has Philadelphia, PA as the location and 41 days held? ['Wrestler', 'Reigns', 'Days held', 'Location', 'Successful defenses', 'Event'] SELECT event FROM table WHERE event = Philadelphia, PA AND location = 41 days SELECT Event FROM table WHERE Location = philadelphia, pa AND Days held = 41
# 4605 / 4855 1
# 4606 / 4855 1
# 4607 / 4855 What was the double's performance data from the Canada Masters tournament in 2008? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT * FROM table WHERE tournament = Canada Masters SELECT 2008 FROM table WHERE Tournament = canada masters
# 4608 / 4855 What was the double's performance data from the Monte Carlo Masters tournament in 2007? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT * FROM table WHERE tournament = Monte Carlo Masters SELECT 2007 FROM table WHERE Tournament = monte carlo masters
# 4609 / 4855 1
# 4610 / 4855 1
# 4611 / 4855 1
# 4612 / 4855 1
# 4613 / 4855 1
# 4614 / 4855 1
# 4615 / 4855 What is the value in 2009 when 1R is in 2007? ['Tournament', '2007', '2008', '2009', 'Career Win-Loss'] SELECT 2009 FROM table WHERE 2009 = 1R SELECT 2009 FROM table WHERE 2007 = 1r
# 4616 / 4855 1
# 4617 / 4855 what is the tournament with the performance in 2010 and 2011 is 1r? ['Tournament', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE 2011 = 1r SELECT Tournament FROM table WHERE 2010 = 1r AND 2011 = 1r
# 4618 / 4855 1
# 4619 / 4855 1
# 4620 / 4855 1
# 4621 / 4855 Which car won the same award in 2001 that the toyota 1nz-fxe hybrid prius won in 1999? ['category', '1999', '2000', '2001', '2004'] SELECT 2001 FROM table WHERE 2001 = toyota 1nz-fxe hybrid prius SELECT 2001 FROM table WHERE 1999 = toyota 1nz-fxe hybrid prius
# 4622 / 4855 Which car won the same award in 2000 that the ferrari f133 5.5l v12 456 / 550 won in 2001? ['category', '1999', '2000', '2001', '2004'] SELECT 2000 FROM table WHERE 2000 = ferrari f133 5.5l v12 456 / 550 SELECT 2000 FROM table WHERE 2001 = ferrari f133 5.5l v12 456 / 550
# 4623 / 4855 Which car won the same award in 2001 that the bmw m67d39 3.9l v8 e38 740d won in 1999? ['category', '1999', '2000', '2001', '2004'] SELECT 2001 FROM table WHERE 2001 = bmw m67d39 3.9l v8 e38 740d SELECT 2001 FROM table WHERE 1999 = bmw m67d39 3.9l v8 e38 740d
# 4624 / 4855 What is the surface of the mountain range that contains the Elk Garden Mountain? ['Mountain', 'Elevation', 'Range', 'State(s)', 'Surface'] SELECT surface FROM table WHERE mountain = Elk Garden Mountain SELECT Surface FROM table WHERE Mountain = elk garden
# 4625 / 4855 What is the tournament with A in 2011? ['Tournament', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table SELECT Tournament FROM table WHERE 2011 = a
# 4626 / 4855 What is the 2012 value with A in 2010 at the Tournament of Wimbledon? ['Tournament', '2008', '2009', '2010', '2011', '2012'] SELECT 2012 FROM table WHERE tournament = Wimbledon SELECT 2012 FROM table WHERE 2010 = a AND Tournament = wimbledon
# 4627 / 4855 1
# 4628 / 4855 1
# 4629 / 4855 1
# 4630 / 4855 1
# 4631 / 4855 1
# 4632 / 4855 1
# 4633 / 4855 1
# 4634 / 4855 1
# 4635 / 4855 1
# 4636 / 4855 1
# 4637 / 4855 What Division III has Bishop Brady in Division V and Hanover in Division IV? ['Year', 'Division I', 'Division II', 'Division III', 'Division IV', 'Division V'] SELECT Division III FROM table WHERE division iii = Bishop Brady AND division v = Hanover SELECT Division III FROM table WHERE Division V = bishop brady AND Division IV = hanover
# 4638 / 4855 What is the Home Captain which has Waca Ground as a Venue ['Date', 'Home captain', 'Away captain', 'Venue', 'Result'] SELECT Home Captain FROM table WHERE home captain = Waca Ground SELECT Home captain FROM table WHERE Venue = waca ground
# 4639 / 4855 1
# 4640 / 4855 1
# 4641 / 4855 1
# 4642 / 4855 1
# 4643 / 4855 1
# 4644 / 4855 1
# 4645 / 4855 1
# 4646 / 4855 What Lomavren word has the same meaning as the Hindi word do? ['Hindi', 'Romani', 'Domari', 'Lomavren', 'Persian'] SELECT Lomavren FROM table SELECT Lomavren FROM table WHERE Hindi = do
# 4647 / 4855 Which type of surface do Amer Delic Robert Kendrick's opponents have? ['Outcome', 'Date', 'Tournament', 'Surface', 'Partner', 'Opponents', 'Score'] SELECT surface FROM table WHERE surface = Amer Delic Robert Kendrick SELECT Surface FROM table WHERE Opponents = amer delic robert kendrick
# 4648 / 4855 1
# 4649 / 4855 1
# 4650 / 4855 1
# 4651 / 4855 1
# 4652 / 4855 1
# 4653 / 4855 1
# 4654 / 4855 Which entrant used the chassis de tomaso 505? ['Year', 'Entrant', 'Chassis', 'Engine', 'Points'] SELECT entrant FROM table WHERE chassis = tomaso 505 SELECT Entrant FROM table WHERE Chassis = de tomaso 505
# 4655 / 4855 1
# 4656 / 4855 1
# 4657 / 4855 What is the Termination of Mission with a Title of Ambassador Extraordinary and Plenipotentiary with a Representative of Reynold E. Carlson? ['Representative', 'Title', 'Presentation of Credentials', 'Termination of Mission', 'Appointed by'] SELECT Termination of Mission FROM table WHERE title = Ambassador Extraordinary and Plenipotentiary AND termination of mission = Reynold E. Carlson SELECT Termination of Mission FROM table WHERE Title = ambassador extraordinary and plenipotentiary AND Representative = reynold e. carlson
# 4658 / 4855 1
# 4659 / 4855 1
# 4660 / 4855 1
# 4661 / 4855 1
# 4662 / 4855 1
# 4663 / 4855 1
# 4664 / 4855 1
# 4665 / 4855 1
# 4666 / 4855 Name the 2010 for 2007 of a and 2012 of a ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT 2010 FROM table SELECT 2010 FROM table WHERE 2007 = a AND 2012 = a
# 4667 / 4855 Name the 2008 for 2012 being a and tournament of australian open ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT 2008 FROM table WHERE tournament = australian open SELECT 2008 FROM table WHERE 2012 = a AND Tournament = australian open
# 4668 / 4855 Name the tournament for 2012 grand slam tournaments ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE tournament = grand slam tournaments SELECT Tournament FROM table WHERE 2012 = grand slam tournaments
# 4669 / 4855 1
# 4670 / 4855 1
# 4671 / 4855 1
# 4672 / 4855 1
# 4673 / 4855 1
# 4674 / 4855 1
# 4675 / 4855 1
# 4676 / 4855 1
# 4677 / 4855 1
# 4678 / 4855 1
# 4679 / 4855 What primary sponsor(s) owns ford fusion car(s) and the crew chief is Drew Blickensderfer? ['Team', 'Car(s)', 'Driver(s)', 'Primary Sponsor(s)', 'Owner(s)', 'Crew Chief'] SELECT * FROM table WHERE primary sponsor(s) = primary AND car(s) = ford fusion car(s) AND crew chief = Drew Blickensderfer SELECT Primary Sponsor(s) FROM table WHERE Car(s) = ford fusion AND Crew Chief = drew blickensderfer
# 4680 / 4855 1
# 4681 / 4855 What tournament was at the 2007 Olympic Games? ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE 2007 = 2007 Olympic Games SELECT Tournament FROM table WHERE 2007 = olympic games
# 4682 / 4855 What tournament was at the 2011 Cincinnati Masters? ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE 2011 = 2011 Cincinnati Masters SELECT 2011 FROM table WHERE Tournament = cincinnati masters
# 4683 / 4855 1
# 4684 / 4855 1
# 4685 / 4855 1
# 4686 / 4855 Name the location of reign 3 ['Championship', 'Current champion(s)', 'Reign', 'Date won', 'Days held', 'Location'] SELECT location FROM table WHERE reign = reign 3 SELECT Location FROM table WHERE Reign = 3
# 4687 / 4855 1
# 4688 / 4855 1
# 4689 / 4855 1
# 4690 / 4855 1
# 4691 / 4855 1
# 4692 / 4855 What is the Finalists that has 2008, 2012, 2013 as Not winning editions ['Club', 'Winners', 'Finalists', 'Winning editions', 'Not winning editions'] SELECT Finalists FROM table SELECT Finalists FROM table WHERE Not winning editions = 2008, 2012, 2013
# 4693 / 4855 1
# 4694 / 4855 1
# 4695 / 4855 What is the score when november 15 is the date? ['Date', 'Visitor', 'Score', 'Home', 'Record', 'Attendance'] SELECT score FROM table WHERE score = november 15 SELECT Score FROM table WHERE Date = november 15
# 4696 / 4855 What record has November 15 as the date? ['Date', 'Visitor', 'Score', 'Home', 'Record', 'Attendance'] SELECT record FROM table WHERE record = November 15 SELECT Record FROM table WHERE Date = november 15
# 4697 / 4855 What tournament what held in Cincinnati in 2009? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT tournament FROM table WHERE 2009 = Cincinnati SELECT 2009 FROM table WHERE Tournament = cincinnati
# 4698 / 4855 1
# 4699 / 4855 1
# 4700 / 4855 1
# 4701 / 4855 1
# 4702 / 4855 1
# 4703 / 4855 1
# 4704 / 4855 1
# 4705 / 4855 1
# 4706 / 4855 Which Representative has a Presentation of Credentials on september 8, 2005? ['Representative', 'Title', 'Presentation of Credentials', 'Termination of Mission', 'Appointed by'] SELECT Representative FROM table WHERE representative = Credentials AND presentation of credentials = september 8, 2005 SELECT Representative FROM table WHERE Presentation of Credentials = september 8, 2005
# 4707 / 4855 Which Termination of Mission has a Presentation of Credentials on October 29, 1981 ['Representative', 'Title', 'Presentation of Credentials', 'Termination of Mission', 'Appointed by'] SELECT Termination of Mission FROM table WHERE termination of mission = Credentials AND presentation of credentials = October 29, 1981 SELECT Termination of Mission FROM table WHERE Presentation of Credentials = october 29, 1981
# 4708 / 4855 1
# 4709 / 4855 1
# 4710 / 4855 Which gold Coast has a Melbourne of yes, a Perth of yes, an Auckland of no, and a Sydney of no? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT gold Coast FROM table WHERE perth = yes AND sydney = no SELECT Gold Coast FROM table WHERE Melbourne = yes AND Perth = yes AND Auckland = no AND Sydney = no
# 4711 / 4855 Which Adelaide has an Auckland of no and a Melbourne of no? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Adelaide FROM table WHERE melbourne = no SELECT Adelaide FROM table WHERE Auckland = no AND Melbourne = no
# 4712 / 4855 Which Sydney has a Gold Coast of yes, an Adelaide of no, and an Auckland of yes? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Sydney FROM table WHERE auckland = yes AND adelaide = no SELECT Sydney FROM table WHERE Gold Coast = yes AND Adelaide = no AND Auckland = yes
# 4713 / 4855 Which Sydney has a Perth of no, an Adelaide of yes, and a Gold Coast of no? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Sydney FROM table WHERE gold coast = no AND adelaide = yes SELECT Sydney FROM table WHERE Perth = no AND Adelaide = yes AND Gold Coast = no
# 4714 / 4855 Which Adelaide has a Sydney of yes, a Perth of no, a Melbourne of yes, and an Auckland of no? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Adelaide FROM table WHERE melbourne = yes AND auckland = no SELECT Adelaide FROM table WHERE Sydney = yes AND Perth = no AND Melbourne = yes AND Auckland = no
# 4715 / 4855 Which Melbourne has a Perth of yes, and an Auckland of yes? ['Sydney', 'Melbourne', 'Perth', 'Adelaide', 'Gold Coast', 'Auckland'] SELECT Melbourne FROM table WHERE auckland = yes SELECT Melbourne FROM table WHERE Perth = yes AND Auckland = yes
# 4716 / 4855 1
# 4717 / 4855 1
# 4718 / 4855 1
# 4719 / 4855 1
# 4720 / 4855 1
# 4721 / 4855 1
# 4722 / 4855 1
# 4723 / 4855 1
# 4724 / 4855 What is the to par that has bill collins as the player? ['Place', 'Player', 'Country', 'Score', 'To par', 'Money ( $ )'] SELECT to par FROM table WHERE to par = bill collins SELECT To par FROM table WHERE Player = bill collins
# 4725 / 4855 1
# 4726 / 4855 1
# 4727 / 4855 1
# 4728 / 4855 1
# 4729 / 4855 1
# 4730 / 4855 1
# 4731 / 4855 1
# 4732 / 4855 1
# 4733 / 4855 What is the name of the party called name? ['Name', 'Entered Office', 'Left Office', 'Party', 'First Minister'] SELECT party FROM table SELECT Party FROM table WHERE Name = name
# 4734 / 4855 1
# 4735 / 4855 1
# 4736 / 4855 1
# 4737 / 4855 1
# 4738 / 4855 1
# 4739 / 4855 1
# 4740 / 4855 1
# 4741 / 4855 1
# 4742 / 4855 1
# 4743 / 4855 1
# 4744 / 4855 1
# 4745 / 4855 1
# 4746 / 4855 1
# 4747 / 4855 1
# 4748 / 4855 1
# 4749 / 4855 1
# 4750 / 4855 1
# 4751 / 4855 1
# 4752 / 4855 1
# 4753 / 4855 1
# 4754 / 4855 1
# 4755 / 4855 1
# 4756 / 4855 1
# 4757 / 4855 1
# 4758 / 4855 1
# 4759 / 4855 1
# 4760 / 4855 1
# 4761 / 4855 1
# 4762 / 4855 1
# 4763 / 4855 1
# 4764 / 4855 1
# 4765 / 4855 What character did Katie Rowley Jones play in the Original West End Cast? ['Character', 'Original West End Cast', 'Original Broadway Cast', 'First UK Tour Cast', 'First US Tour Cast'] SELECT character FROM table WHERE character = Original West End SELECT Character FROM table WHERE Original West End Cast = katie rowley jones
# 4766 / 4855 1
# 4767 / 4855 1
# 4768 / 4855 1
# 4769 / 4855 1
# 4770 / 4855 1
# 4771 / 4855 1
# 4772 / 4855 Which player has 68 as the score and canada as the country? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT player FROM table WHERE player = 68 AND score = canada SELECT Player FROM table WHERE Score = 68 AND Country = canada
# 4773 / 4855 What place has Canada as the country? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT place FROM table WHERE place = Canada SELECT Place FROM table WHERE Country = canada
# 4774 / 4855 Which player has 69 as the score? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT player FROM table WHERE player = 69 SELECT Player FROM table WHERE Score = 69
# 4775 / 4855 1
# 4776 / 4855 1
# 4777 / 4855 1
# 4778 / 4855 1
# 4779 / 4855 1
# 4780 / 4855 1
# 4781 / 4855 1
# 4782 / 4855 1
# 4783 / 4855 1
# 4784 / 4855 1
# 4785 / 4855 1
# 4786 / 4855 Which year has brm v12 as the engine? ['Year', 'Entrant', 'Chassis', 'Engine', 'Pts.'] SELECT year FROM table WHERE year = brm v12 SELECT Year FROM table WHERE Engine = brm v12
# 4787 / 4855 1
# 4788 / 4855 1
# 4789 / 4855 1
# 4790 / 4855 1
# 4791 / 4855 1
# 4792 / 4855 1
# 4793 / 4855 1
# 4794 / 4855 1
# 4795 / 4855 1
# 4796 / 4855 1
# 4797 / 4855 1
# 4798 / 4855 1
# 4799 / 4855 1
# 4800 / 4855 1
# 4801 / 4855 1
# 4802 / 4855 1
# 4803 / 4855 1
# 4804 / 4855 What award was Hannah Gal the recipient of? ['Film', 'Director(s)', 'Producer(s)', 'Recipient', 'Date', 'Award'] SELECT award FROM table WHERE award = Hannah Gal SELECT Award FROM table WHERE Recipient = hannah gal
# 4805 / 4855 1
# 4806 / 4855 1
# 4807 / 4855 1
# 4808 / 4855 1
# 4809 / 4855 1
# 4810 / 4855 1
# 4811 / 4855 1
# 4812 / 4855 1
# 4813 / 4855 1
# 4814 / 4855 1
# 4815 / 4855 1
# 4816 / 4855 1
# 4817 / 4855 1
# 4818 / 4855 1
# 4819 / 4855 1
# 4820 / 4855 1
# 4821 / 4855 1
# 4822 / 4855 1
# 4823 / 4855 What Best Bowl is it that has 151 Matches and 1 100s? ['Matches', 'Runs', 'Bat Ave', 'High Score', '100s', 'Wickets', 'Bowl Ave', 'Best Bowl'] SELECT Best Bowl FROM table WHERE matches = 151 SELECT Best Bowl FROM table WHERE 100s = 1 AND Matches = 151
# 4824 / 4855 1
# 4825 / 4855 1
# 4826 / 4855 1
# 4827 / 4855 1
# 4828 / 4855 What is the diameter of the Archery Reverse coin? ['Year', 'Denomination', 'Alloy', 'Reverse', 'Diameter', 'Weight', 'Obverse', 'Mintage', 'Series'] SELECT diameter FROM table WHERE reverse = Archery Reverse SELECT Diameter FROM table WHERE Reverse = archery
# 4829 / 4855 1
# 4830 / 4855 1
# 4831 / 4855 1
# 4832 / 4855 1
# 4833 / 4855 1
# 4834 / 4855 1
# 4835 / 4855 1
# 4836 / 4855 1
# 4837 / 4855 What year did Lonneke Janssen win the Women's singles? ['Year', "Men's singles", "Women's singles", "Men's doubles", "Women's doubles", 'Mixed doubles'] SELECT year FROM table WHERE year = Lonneke Janssen SELECT Year FROM table WHERE Women's singles = lonneke janssen
# 4838 / 4855 1
# 4839 / 4855 1
# 4840 / 4855 1
# 4841 / 4855 1
# 4842 / 4855 1
# 4843 / 4855 1
# 4844 / 4855 1
# 4845 / 4855 Which main cast seasons were portrayed by Joe Jonas? ['Character', 'Portrayed by', 'Main cast seasons', 'Recurring cast seasons', '# of episodes'] SELECT * FROM table WHERE main cast seasons = main cast AND portrayed by = Joe Jonas SELECT Main cast seasons FROM table WHERE Portrayed by = joe jonas
# 4846 / 4855 1
# 4847 / 4855 1
# 4848 / 4855 1
# 4849 / 4855 1
# 4850 / 4855 1
# 4851 / 4855 1
# 4852 / 4855 1
# 4853 / 4855 1
# 4854 / 4855 1
# Select accuracy 95.42739443872297
# Where accuracy 82.3480947476828
# Value accuracy 90.25746652935118
# Overall accuracy 78.4140061791967

# %% [markdown]
# Our accuracy statistics for this case is as follows.
#
#
# *   Select accuracy: 95.43%
# *   Where accuracy: 82.35%
# *   Value accuracy: 90.26%
# *   Overall accuracy 78.41%

# %% [markdown]
# # Case 4: No Aggregation, Attributes Explicitly Present in NLQ, Only One WHERE and SELECT Attribute
#
# We evaluate accuracy assuming that
#
# *   the SELECT and WHERE attributes are explicitly present in the NLQ
# *   there are no aggregate functions like MAX, MIN, COUNT, or others
# *   nlq2sql uses rule 1 (defined in our report)
# *   only one SELECT and WHERE attribute exist
#
# We also assume that there are no WHERE clauses with any operator other than '=' but no such queries exist when we also impose the condition that attributes need to be explicitly present in the NLQ.
#
# The ner model we used in the evaluation below doesn't support aggregation.

# %%
filters = {'is_select_not_present_in_nlq',
           'is_invalid_constraint',
           'is_invalid_num_select_attr',
           'is_invalid_num_where_attr',
           'attr_not_present_in_nlq',
           'is_aggregate'}
tagTestSet = filter_test_data(filters)
print(len(tagTestSet))
# Out:
# 100%|██████████| 15878/15878 [00:06<00:00, 2435.85it/s]
# 3932
# 3932

# %%
evaluate_data(tagTestSet, nlp_ner, 'rule1')
# Out:
# 0 / 3932 1
# 1 / 3932 1
# 2 / 3932 1
# 3 / 3932 1
# 4 / 3932 1
# 5 / 3932 1
# 6 / 3932 1
# 7 / 3932 1
# 8 / 3932 1
# 9 / 3932 1
# 10 / 3932 1
# 11 / 3932 1
# 12 / 3932 1
# 13 / 3932 1
# 14 / 3932 1
# 15 / 3932 1
# 16 / 3932 what's the original air date with title  "hell" ['No. in series', 'No. in season', 'Title', 'Directed by', 'Written by', 'Original air date'] SELECT original air date FROM table WHERE title = "hell" SELECT Original air date FROM table WHERE Title = Hell
# 17 / 3932 1
# 18 / 3932 What is the percentage of the  trance- n himalaya zone that corresponds with the high hill zone is 25%? ['Particulars and Characteristics', 'Shivalik Zone', 'Mid-Hill Zone', 'High hill zone', 'Trance- n Himalaya Zone'] SELECT * FROM table WHERE high hill zone = 25% SELECT Trance- n Himalaya Zone FROM table WHERE High hill zone = 25%
# 19 / 3932 1
# 20 / 3932 1
# 21 / 3932 1
# 22 / 3932 1
# 23 / 3932 Which song has picturization by only vijay? ['Track #', 'Song', 'Singers', 'Picturization', 'Length', 'Lyricist'] SELECT song FROM table WHERE picturization = only vijay SELECT Song FROM table WHERE Picturization = Vijay
# 24 / 3932 For which singers was Alangudi Somu the lyricist? ['Track #', 'Song', 'Singers', 'Picturization', 'Length', 'Lyricist'] SELECT * FROM table WHERE singers = Alangudi Somu SELECT Singers FROM table WHERE Lyricist = Alangudi Somu
# 25 / 3932 1
# 26 / 3932 1
# 27 / 3932 What percentage of The Bronx voters occured when Manhattan had 29.9% of voters? ['1953', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT The Bronx FROM table WHERE % = 29.9% SELECT The Bronx FROM table WHERE Manhattan = 29.9%
# 28 / 3932 What number of voters did the Bronx have when the total number was 2054? ['1953', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT * FROM table WHERE the bronx = voters AND total = 2054 SELECT The Bronx FROM table WHERE Total = 2054
# 29 / 3932 1
# 30 / 3932 1
# 31 / 3932 1
# 32 / 3932 Which candidate won 88 votes in Queens in 1921? ['1921', 'party', 'Manhattan', 'The Bronx', 'Brooklyn', 'Queens', 'Richmond [Staten Is.]', 'Total', '%'] SELECT * FROM table WHERE queens = 88 SELECT 1921 FROM table WHERE Queens = 88
# 33 / 3932 1
# 34 / 3932 1
# 35 / 3932 1
# 36 / 3932 What are the highest recorded attendance rates of the stadiums with an average attendance of 4752? ['Team', 'Stadium', 'Capacity', 'Lowest', 'Highest', 'Average'] SELECT * FROM table WHERE average = 4752 SELECT Highest FROM table WHERE Average = 4752
# 37 / 3932 What is the catalog number of the title called "super callanetics"? ['Year', 'Title', 'Format', 'Studio', 'Release Date', 'Copyright Information', 'Catalog Number'] SELECT * FROM table WHERE title = "super callanetics" SELECT Catalog Number FROM table WHERE Title = Super Callanetics
# 38 / 3932 1
# 39 / 3932 1
# 40 / 3932 1
# 41 / 3932 1
# 42 / 3932 What is the premiere on the mega channel? ['Country/Region', 'Show Title', 'Languages', 'Host', 'Channel', 'Premiere', 'Seasons', 'Status'] SELECT premiere FROM table WHERE channel = mega SELECT Premiere FROM table WHERE Channel = Mega Channel
# 43 / 3932 1
# 44 / 3932 1
# 45 / 3932 1
# 46 / 3932 1
# 47 / 3932 1
# 48 / 3932 1
# 49 / 3932 1
# 50 / 3932 1
# 51 / 3932 1
# 52 / 3932 1
# 53 / 3932 1
# 54 / 3932 1
# 55 / 3932 1
# 56 / 3932 1
# 57 / 3932 If the model is  15.180e, what is the GVM (kg) Technical Capacity? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT * FROM table WHERE model = Technical Capacity SELECT GVM (kg) Technical Capacity FROM table WHERE Model = 15.180E
# 58 / 3932 When the transmission make/type/speed is eaton fs 5306-a manual synchromesh 6 speed, what is the value of the gcm (kg) technical capacity? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT * FROM table WHERE transmission make/type/speed = technical capacity SELECT GCM (kg) Technical Capacity FROM table WHERE Transmission Make/Type/Speed = Eaton FS 5306-A Manual Synchromesh 6 Speed
# 59 / 3932 Which model possesses a transmission make/type/speed of eaton fs-6306 a manual synchromesh 6 speed? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT model FROM table WHERE transmission make/type/speed = manual synchromesh 6 SELECT Model FROM table WHERE Transmission Make/Type/Speed = Eaton FS-6306 A Manual Synchromesh 6 Speed
# 60 / 3932 For driver Mark Skaife what is the result for race 1? ['Driver', 'No.', 'Team', 'Car', 'Race 1', 'GP 100', 'Race 3', 'Points'] SELECT * FROM table WHERE driver = 1 AND race 1 = result SELECT Race 1 FROM table WHERE Driver = Mark Skaife
# 61 / 3932 1
# 62 / 3932 1
# 63 / 3932 1
# 64 / 3932 1
# 65 / 3932 1
# 66 / 3932 1
# 67 / 3932 1
# 68 / 3932 1
# 69 / 3932 1
# 70 / 3932 1
# 71 / 3932 1
# 72 / 3932 1
# 73 / 3932 1
# 74 / 3932 1
# 75 / 3932 1
# 76 / 3932 1
# 77 / 3932  what's the introduced where notes is 9 withdrawn in 1946 after fire ['Number Range', 'Introduced', 'Builder', 'Engine', 'Weight (long tons)', 'Seats', 'Withdrawn', 'Notes'] SELECT introduced FROM table WHERE withdrawn = 9 withdrawn in 1946 after fire SELECT Introduced FROM table WHERE Notes = 9 withdrawn in 1946 after fire
# 78 / 3932 1
# 79 / 3932 1
# 80 / 3932 1
# 81 / 3932 what is the song name for the film name ganga kare insaaf? ['Year', 'Song name', 'Film name', 'Co-singer', 'Music director', 'Lyricist', 'Language'] SELECT * FROM table WHERE film name = ganga kare insaaf SELECT Song name FROM table WHERE Film name = Ganga Kare Insaaf
# 82 / 3932 1
# 83 / 3932  what's the electorate where election date is 16 cannot handle non-empty timestamp argument! ['Member', 'Electorate', 'Province', 'MPs term', 'Election date'] SELECT electorate FROM table WHERE election date = 16 cannot handle non-empty timestamp argument SELECT Electorate FROM table WHERE Election date = 16 Cannot handle non-empty timestamp argument!
# 84 / 3932 1
# 85 / 3932 1
# 86 / 3932 1
# 87 / 3932 1
# 88 / 3932 1
# 89 / 3932 How many integrated allied-related are there? ['Component', 'Integrated', 'Allied-Related', 'Allied-Unrelated', 'Holding'] SELECT * FROM table WHERE integrated = integrated allied-related SELECT Integrated FROM table WHERE Allied-Related = Many
# 90 / 3932 1
# 91 / 3932 what is the integrated in which the holding allied-unrelated is many? ['Component', 'Integrated', 'Allied-Related', 'Allied-Unrelated', 'Holding'] SELECT integrated FROM table WHERE allied-unrelated = many SELECT Holding FROM table WHERE Allied-Unrelated = Many
# 92 / 3932 1
# 93 / 3932 1
# 94 / 3932 1
# 95 / 3932 1
# 96 / 3932 1
# 97 / 3932 1
# 98 / 3932 Crockett High School had which number(#)? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT * FROM table WHERE high school = Crockett High School AND # = number SELECT # FROM table WHERE High School = Crockett
# 99 / 3932 Which home town was the high school Catholic University located in? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT home town FROM table WHERE high school = Catholic SELECT Home Town FROM table WHERE High School = Catholic University
# 100 / 3932 1
# 101 / 3932 1
# 102 / 3932 1
# 103 / 3932 1
# 104 / 3932 1
# 105 / 3932 1
# 106 / 3932 1
# 107 / 3932 1
# 108 / 3932 1
# 109 / 3932 1
# 110 / 3932 1
# 111 / 3932 1
# 112 / 3932 What is the score for the interview for the state of New York? ['State', 'Preliminaries', 'Interview', 'Swimsuit', 'Evening Gown', 'Average'] SELECT * FROM table WHERE interview = score AND state = New York SELECT Interview FROM table WHERE State = New York
# 113 / 3932 1
# 114 / 3932 1
# 115 / 3932 1
# 116 / 3932 1
# 117 / 3932 1
# 118 / 3932 1
# 119 / 3932 1
# 120 / 3932 1
# 121 / 3932 What is the theme for the episode selection process? ['Episode', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT theme FROM table WHERE episode = selection SELECT Theme FROM table WHERE Episode = Selection Process
# 122 / 3932 What is the song choice when the theme is not aired? ['Episode', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT song choice FROM table WHERE theme = not aired SELECT Theme FROM table WHERE Song choice = Not Aired
# 123 / 3932 What years did Markose Bristow Madhumita Bisht win the mens singles and/or the mixed doubles? ['Season', 'Mens singles', 'Womens singles', 'Mens doubles', 'Womens doubles', 'Mixed doubles'] SELECT * FROM table WHERE mens singles = Markose Bristow Madhumita Bisht SELECT Mens singles FROM table WHERE Mixed doubles = Markose Bristow Madhumita Bisht
# 124 / 3932 What year is Japan the country? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT year FROM table WHERE year = Japan SELECT Year FROM table WHERE Country = Japan
# 125 / 3932 What is the year that Dewi Claire Schreefel is the champion? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT year FROM table WHERE year = Dewi Claire Schreefel SELECT Year FROM table WHERE Champion = Dewi Claire Schreefel
# 126 / 3932 What is the tournament location when Vicky Hurst in the champion? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT tournament location FROM table WHERE tournament location = Vicky Hurst SELECT Tournament location FROM table WHERE Champion = Vicky Hurst
# 127 / 3932 1
# 128 / 3932 1
# 129 / 3932 1
# 130 / 3932 1
# 131 / 3932 Which is the charity that the background of the celebrity is heavyweight champion? ['Celebrity', 'Background', 'Original Team', 'Age', 'Hometown', 'Charity', 'Result', 'Raised'] SELECT charity FROM table WHERE celebrity = heavyweight champion SELECT Charity FROM table WHERE Background = Heavyweight Champion
# 132 / 3932 1
# 133 / 3932 1
# 134 / 3932 1
# 135 / 3932 What is the background of the celebrity who had the result 13 the celebrity apprentice (2008-03-27)? ['Celebrity', 'Background', 'Original Team', 'Age', 'Hometown', 'Charity', 'Result', 'Raised'] SELECT background FROM table WHERE celebrity = celebrity apprentice (2008-03-27) SELECT Background FROM table WHERE Result = 13 The Celebrity Apprentice (2008-03-27)
# 136 / 3932 1
# 137 / 3932 1
# 138 / 3932 1
# 139 / 3932 1
# 140 / 3932 1
# 141 / 3932 1
# 142 / 3932 1
# 143 / 3932 1
# 144 / 3932 What is the 2007 estimate when the rank (csa) is 4 ['Rank (CSA)', 'Combined Statistical Area (or Metropolitan Statistical Area if noted)', 'State(s)', '2007 Estimate', '2000 Population', 'Percent Change (1990–2000)'] SELECT * FROM table WHERE rank (csa) = 4 SELECT 2007 Estimate FROM table WHERE Rank (CSA) = 4
# 145 / 3932 1
# 146 / 3932 1
# 147 / 3932 1
# 148 / 3932 1
# 149 / 3932 1
# 150 / 3932 1
# 151 / 3932 1
# 152 / 3932 1
# 153 / 3932 1
# 154 / 3932 What was the lost with tries for? ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Tries for', 'Tries against', 'Try bonus', 'Losing bonus', 'Points'] SELECT lost FROM table SELECT Lost FROM table WHERE Tries for = Tries for
# 155 / 3932 1
# 156 / 3932 1
# 157 / 3932 1
# 158 / 3932 1
# 159 / 3932 What is the type of the printer ports included in the EX Plus3 model number? ['Model number', 'Printer ports', 'Network ports', 'Network protocols', 'Firmware', 'Notes'] SELECT * FROM table WHERE printer ports = type AND model number = EX Plus3 SELECT Printer ports FROM table WHERE Model number = EX Plus3
# 160 / 3932 What is the traditional way to write the name of the district who's area is 2331? ['English Name', 'Simplified', 'Traditional', 'Pinyin', 'Area', 'Population', 'Density'] SELECT * FROM table WHERE area = 2331 SELECT Traditional FROM table WHERE Area = 2331
# 161 / 3932 1
# 162 / 3932 1
# 163 / 3932 1
# 164 / 3932 1
# 165 / 3932 1
# 166 / 3932 What was the air date of part 2 of the episode whose part 1 was aired on January 31, 2008? ['Episode #', 'Title', 'Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5', 'Part 6'] SELECT part 2 FROM table WHERE part 2 = air date AND part 1 = January 31, 2008 SELECT Part 2 FROM table WHERE Part 1 = January 31, 2008
# 167 / 3932 What's the air date of part 1 of the episode whose part 2 aired on December 2, 2007? ['Episode #', 'Title', 'Part 1', 'Part 2', 'Part 3', 'Part 4', 'Part 5', 'Part 6'] SELECT part 1 FROM table WHERE part 1 = air date AND part 2 = December 2, 2007 SELECT Part 1 FROM table WHERE Part 2 = December 2, 2007
# 168 / 3932 1
# 169 / 3932 1
# 170 / 3932 1
# 171 / 3932 1
# 172 / 3932 1
# 173 / 3932 1
# 174 / 3932 1
# 175 / 3932 1
# 176 / 3932 1
# 177 / 3932 1
# 178 / 3932 Who were the candidates when gregory w. meeks was the incumbent ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT candidates FROM table WHERE candidates = gregory w. meeks SELECT Candidates FROM table WHERE Incumbent = Gregory W. Meeks
# 179 / 3932 1
# 180 / 3932 1
# 181 / 3932 1
# 182 / 3932 1
# 183 / 3932 1
# 184 / 3932 1
# 185 / 3932 1
# 186 / 3932 1
# 187 / 3932 1
# 188 / 3932 1
# 189 / 3932 1
# 190 / 3932 1
# 191 / 3932 1
# 192 / 3932 1
# 193 / 3932 1
# 194 / 3932 1
# 195 / 3932 1
# 196 / 3932 1
# 197 / 3932 1
# 198 / 3932 1
# 199 / 3932 1
# 200 / 3932 1
# 201 / 3932 1
# 202 / 3932 1
# 203 / 3932 What district is F. Edward Hebert the incumbent in? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = F. Edward Hebert SELECT District FROM table WHERE Incumbent = F. Edward Hebert
# 204 / 3932 1
# 205 / 3932 What's the district that Otto Passman is the incumbent of? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = Otto Passman SELECT District FROM table WHERE Incumbent = Otto Passman
# 206 / 3932 1
# 207 / 3932 1
# 208 / 3932 1
# 209 / 3932 1
# 210 / 3932 1
# 211 / 3932 1
# 212 / 3932 1
# 213 / 3932 1
# 214 / 3932 1
# 215 / 3932 1
# 216 / 3932 1
# 217 / 3932 1
# 218 / 3932 1
# 219 / 3932 What district was Harold Earthman the incumbent in?  ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT district FROM table WHERE district = Harold Earthman SELECT District FROM table WHERE Incumbent = Harold Earthman
# 220 / 3932 1
# 221 / 3932 1
# 222 / 3932 1
# 223 / 3932 1
# 224 / 3932 1
# 225 / 3932 1
# 226 / 3932 1
# 227 / 3932 1
# 228 / 3932 1
# 229 / 3932 1
# 230 / 3932 1
# 231 / 3932 1
# 232 / 3932 1
# 233 / 3932 Pink cytoplasm is seen in a test that specifically stains what? ['Stain', 'Common use', 'Nucleus', 'Cytoplasm', 'Red blood cell (RBC)', 'Collagen fibers', 'Specifically stains'] SELECT * FROM table WHERE cytoplasm = Pink cytoplasm SELECT Specifically stains FROM table WHERE Cytoplasm = Pink
# 234 / 3932 The pink cytoplasm will have a nucleus of what color? ['Stain', 'Common use', 'Nucleus', 'Cytoplasm', 'Red blood cell (RBC)', 'Collagen fibers', 'Specifically stains'] SELECT nucleus FROM table WHERE cytoplasm = pink cytoplasm SELECT Nucleus FROM table WHERE Cytoplasm = Pink
# 235 / 3932 where is hte second place winner from united kingdom? ['Year', 'Winner', 'Language', 'Artist', 'Song', 'Points', 'Margin', 'Second place', 'Date', 'Venue', 'Location', 'Participants'] SELECT second place FROM table WHERE winner = united kingdom SELECT Winner FROM table WHERE Second place = United Kingdom
# 236 / 3932 1
# 237 / 3932 1
# 238 / 3932 1
# 239 / 3932 1
# 240 / 3932 1
# 241 / 3932 1
# 242 / 3932 1
# 243 / 3932 1
# 244 / 3932 1
# 245 / 3932 1
# 246 / 3932 what's the byu-uu score with uu-usu score being 44–16 ['Season', 'Winner', 'BYU-UU score', 'BYU-USU score', 'UU-USU score'] SELECT * FROM table WHERE uu-usu score = 44–16 SELECT BYU-UU score FROM table WHERE UU-USU score = 44–16
# 247 / 3932 1
# 248 / 3932 1
# 249 / 3932 1
# 250 / 3932 1
# 251 / 3932 1
# 252 / 3932 1
# 253 / 3932 1
# 254 / 3932 1
# 255 / 3932 1
# 256 / 3932 1
# 257 / 3932 1
# 258 / 3932 1
# 259 / 3932 1
# 260 / 3932 1
# 261 / 3932 what's the result with opponent being at oakland raiders ['Week', 'Date', 'Opponent', 'Result', 'Stadium', 'Record', 'Attendance'] SELECT result FROM table WHERE opponent = oakland raiders SELECT Result FROM table WHERE Opponent = at Oakland Raiders
# 262 / 3932 1
# 263 / 3932 1
# 264 / 3932 The results for gt2 winning team is all lars-erik nielsen allan simonsen richard westbrook.  ['Rnd', 'Circuit', 'LMP1 Winning Team', 'LMP2 Winning Team', 'GT1 Winning Team', 'GT2 Winning Team', 'Results'] SELECT results FROM table WHERE gt2 winning team = all lars-erik nielsen allan simonsen richard westbrook SELECT Results FROM table WHERE GT2 Winning Team = Lars-Erik Nielsen Allan Simonsen Richard Westbrook
# 265 / 3932 1
# 266 / 3932 1
# 267 / 3932 1
# 268 / 3932 1
# 269 / 3932 1
# 270 / 3932 1
# 271 / 3932 1
# 272 / 3932 1
# 273 / 3932 1
# 274 / 3932 1
# 275 / 3932 1
# 276 / 3932 1
# 277 / 3932 picturesque and trekking route is the category what is the height from sea level in meters? ['Name Of Place', 'Height from Sea Level In Meters', 'Nearby Town', 'Trekking Route', 'Category'] SELECT height from sea level in meters FROM table WHERE trekking route = picturesque and trekking route SELECT Height from Sea Level In Meters FROM table WHERE Category = Picturesque and Trekking Route
# 278 / 3932 1
# 279 / 3932 1
# 280 / 3932 1
# 281 / 3932 1
# 282 / 3932 When the total points are 22 how many total touchdowns have been made? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT * FROM table WHERE points = 22 AND touchdowns = total touchdowns SELECT Touchdowns FROM table WHERE Points = 22
# 283 / 3932 1
# 284 / 3932 Who led the points classification when Roman Kreuziger led the young rider classification? ['Stage', 'Winner', 'General classification', 'Points classification', 'Mountains classification', 'Young rider classification', 'Team classification', 'Combativity award'] SELECT points classification FROM table WHERE points classification = Roman Kreuziger SELECT Points classification FROM table WHERE Young rider classification = Roman Kreuziger
# 285 / 3932 Name the hometown for ventrell jenkins ['Position', 'Number', 'Name', 'Height', 'Weight', 'Class', 'Hometown', 'Games↑'] SELECT hometown FROM table WHERE hometown = ventrell jenkins SELECT Hometown FROM table WHERE Name = Ventrell Jenkins
# 286 / 3932 1
# 287 / 3932 1
# 288 / 3932 1
# 289 / 3932 1
# 290 / 3932 What locale has the skip Colleen Jones? ['Locale', 'Skip', 'W', 'L', 'PF', 'PA', 'Ends Won', 'Ends Lost', 'Blank Ends', 'Stolen Ends', 'Shot Pct.'] SELECT locale FROM table WHERE l = Colleen Jones SELECT Locale FROM table WHERE Skip = Colleen Jones
# 291 / 3932 Who plays Overton Moyle in casino theatre 1888 & savoy theatre 1906? ['Role', 'Savoy Theatre 1888', 'Casino Theatre 1888', 'Savoy Theatre 1897', 'Savoy Theatre 1906', 'Savoy Theatre 1909'] SELECT * FROM table WHERE casino theatre 1888 = Overton Moyle AND savoy theatre 1906 = casino theatre 1888 & savoy theatre 1906 SELECT Casino Theatre 1888 FROM table WHERE Savoy Theatre 1906 = Overton Moyle
# 292 / 3932 1
# 293 / 3932 1
# 294 / 3932 what's the result with opponent being at new england patriots ['Week', 'Date', 'Opponent', 'Result', 'Record', 'Game Site', 'Attendance'] SELECT result FROM table WHERE opponent = new england patriots SELECT Result FROM table WHERE Opponent = at New England Patriots
# 295 / 3932 1
# 296 / 3932 1
# 297 / 3932 1
# 298 / 3932 1
# 299 / 3932 1
# 300 / 3932 1
# 301 / 3932 1
# 302 / 3932 What is the result at the Masters for the player who finished R16 at the PGA Ch.? ['Nationality', 'Player', 'Year', 'Wins', 'Masters', 'U.S. Open', 'Open Ch.', 'PGA Ch.'] SELECT * FROM table WHERE pga ch. = R16 SELECT Masters FROM table WHERE PGA Ch. = R16
# 303 / 3932 1
# 304 / 3932 1
# 305 / 3932 1
# 306 / 3932 1
# 307 / 3932 1
# 308 / 3932 which electorate is 54787 of the constituency ['Constituency', 'Electorate', 's Spoilt vote', 'Total poll (%)', 'For (%)', 'Against (%)'] SELECT electorate FROM table WHERE electorate = 54787 SELECT Constituency FROM table WHERE Electorate = 54787
# 309 / 3932 1
# 310 / 3932 1
# 311 / 3932 1
# 312 / 3932 Name the solo when name is briggs, diyral ['Name', 'GP', 'Solo', 'Ast', 'Total', 'TFL-Yds', 'No-Yds', 'BrUp', 'QBH', 'No.-Yds', 'Avg', 'TD', 'Rcv-Yds', 'FF', 'Blkd Kick'] SELECT solo FROM table WHERE solo = briggs, diyral SELECT Solo FROM table WHERE Name = Briggs, Diyral
# 313 / 3932 When the division is Division 2 men what is the champion score? ['Division', 'Champion Score', 'Runner-Up Score', 'Final MVP Team', 'Defensive Player of the Final Team'] SELECT * FROM table WHERE division = champion SELECT Champion Score FROM table WHERE Division = Division 2 Men
# 314 / 3932 1
# 315 / 3932 1
# 316 / 3932 1
# 317 / 3932 1
# 318 / 3932 1
# 319 / 3932 1
# 320 / 3932 1
# 321 / 3932 1
# 322 / 3932 1
# 323 / 3932 1
# 324 / 3932 1
# 325 / 3932 What date was parliament assembled when John rudhale was first member? ['Elected', 'Assembled', 'Dissolved', 'First member', 'Second member'] SELECT * FROM table WHERE first member = John rudhale SELECT Assembled FROM table WHERE First member = John Rudhale
# 326 / 3932 1
# 327 / 3932 1
# 328 / 3932 1
# 329 / 3932 1
# 330 / 3932 1
# 331 / 3932 1
# 332 / 3932 1
# 333 / 3932 List all years in Orlando where Jeryl Sasser was a player. ['Player', 'No.', 'Nationality', 'Position', 'Years in Orlando', 'School/Club Team'] SELECT years in Orlando FROM table WHERE years in orlando = Jeryl Sasser SELECT Years in Orlando FROM table WHERE Player = Jeryl Sasser
# 334 / 3932 WHO IS THE PLAYER(S) ON THE ROSTER FROM SCHOOL/CLUB TEAM ARIZONA? ['Player', 'No.', 'Nationality', 'Position', 'Years in Orlando', 'School/Club Team'] SELECT * FROM table WHERE school/club team = ARIZONA SELECT Player FROM table WHERE School/Club Team = Arizona
# 335 / 3932 1
# 336 / 3932 1
# 337 / 3932 1
# 338 / 3932 1
# 339 / 3932 1
# 340 / 3932 1
# 341 / 3932 1
# 342 / 3932 1
# 343 / 3932 1
# 344 / 3932 1
# 345 / 3932 Who is the original artist for the theme "Year they were born?" ['Week #', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT original artist FROM table WHERE theme = "Year they were born?" SELECT Original artist FROM table WHERE Theme = Year They Were Born
# 346 / 3932 What theme name has the original artist of Dolly Parton? ['Week #', 'Theme', 'Song choice', 'Original artist', 'Order #', 'Result'] SELECT * FROM table WHERE theme = theme name AND original artist = Dolly Parton SELECT Theme FROM table WHERE Original artist = Dolly Parton
# 347 / 3932 1
# 348 / 3932 1
# 349 / 3932 March 0.41 in July?  ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT July FROM table WHERE march = March 0.41 SELECT July FROM table WHERE March = 0.41
# 350 / 3932 1
# 351 / 3932 January 7.34 where is June ? ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT June FROM table WHERE january = 7.34 SELECT January FROM table WHERE June = 7.34
# 352 / 3932 What December is 8.77 in January  ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Annual Additions(in millions)', 'Average Monthly Additions(in millions)'] SELECT December FROM table WHERE december = 8.77 SELECT December FROM table WHERE January = 8.77
# 353 / 3932 1
# 354 / 3932 1
# 355 / 3932 1
# 356 / 3932 1
# 357 / 3932 1
# 358 / 3932 1
# 359 / 3932 1
# 360 / 3932 1
# 361 / 3932 1
# 362 / 3932 Is the team force india allowed to race? ['Year', 'Event', 'Pole position time', '107% time', 'Driver', 'Team', 'Time', '% of pole', 'Allowed to race?'] SELECT * FROM table WHERE team = race SELECT Allowed to race? FROM table WHERE Team = Force India
# 363 / 3932 1
# 364 / 3932 1
# 365 / 3932 What was the home team score when Brisbane lions was the home team? ['Home team', 'Home team score', 'Away team', 'Away team score', 'Ground', 'Crowd', 'Date'] SELECT home team score FROM table WHERE home team score = Brisbane lions SELECT Home team score FROM table WHERE Home team = Brisbane Lions
# 366 / 3932 1
# 367 / 3932 Name the french title for english title of "inventor bunnies" ['Official #', 'TF1 #', 'French title', 'English title', 'Air date (France)', 'Original Beechwood Bunny Tale / Source material'] SELECT french title FROM table WHERE english title = "inventor bunnies" SELECT French title FROM table WHERE English title = Inventor Bunnies
# 368 / 3932 1
# 369 / 3932 What school location had an enrollment of 12400? ['Institution', 'Location', 'Nickname', 'Enrollment', 'Established'] SELECT * FROM table WHERE location = school location AND enrollment = 12400 SELECT Location FROM table WHERE Enrollment = 12400
# 370 / 3932 1
# 371 / 3932 What is the winning song for the artist with a debut album "the winner"? ['Season', 'Winner', 'Winning Song', 'Winning Song (English Title)', 'Debut Album'] SELECT winning song FROM table WHERE winner = "the winner" SELECT Winning Song FROM table WHERE Debut Album = The Winner
# 372 / 3932 What is the winning song for the artist with a debut album "mike"? ['Season', 'Winner', 'Winning Song', 'Winning Song (English Title)', 'Debut Album'] SELECT winning song FROM table WHERE debut album = "mike" SELECT Winning Song FROM table WHERE Debut Album = Mike
# 373 / 3932 1
# 374 / 3932 1
# 375 / 3932 1
# 376 / 3932 1
# 377 / 3932 What is the points for when the total points is 6? ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Points difference', 'Points'] SELECT points for FROM table WHERE points for = 6 SELECT Points for FROM table WHERE Points = 6
# 378 / 3932 What club has 693 points for? ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Points difference', 'Points'] SELECT club FROM table WHERE points = 693 SELECT Club FROM table WHERE Points for = 693
# 379 / 3932 Name the snatch when body weight is 73.7 ['Place', 'Weightlifter', 'Body weight', 'one hand snatch', 'one hand clean & jerk', 'Press', 'Snatch', '1.', '2.', '3.', 'Total'] SELECT snatch FROM table WHERE 3. = 73.7 SELECT Snatch FROM table WHERE Body weight = 73.7
# 380 / 3932 1
# 381 / 3932 1
# 382 / 3932 1
# 383 / 3932 1
# 384 / 3932 1
# 385 / 3932 1
# 386 / 3932 1
# 387 / 3932 1
# 388 / 3932 1
# 389 / 3932 Which date did Chris Duhon (13) receive high assists? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT date FROM table WHERE date = Chris Duhon (13) SELECT Date FROM table WHERE High assists = Chris Duhon (13)
# 390 / 3932 1
# 391 / 3932 1
# 392 / 3932 1
# 393 / 3932 What was the record when Canty (5) was the high assists? ['Game', 'Date', 'Opponent', 'Score', 'High points', 'High rebounds', 'High assists', 'Location/Attendance', 'Record'] SELECT record FROM table WHERE record = Canty (5) SELECT Record FROM table WHERE High assists = Canty (5)
# 394 / 3932 On what date did Canty (6) receive high assists? ['Game', 'Date', 'Opponent', 'Score', 'High points', 'High rebounds', 'High assists', 'Location/Attendance', 'Record'] SELECT date FROM table WHERE date = Canty (6) SELECT Date FROM table WHERE High assists = Canty (6)
# 395 / 3932 1
# 396 / 3932 1
# 397 / 3932 1
# 398 / 3932 1
# 399 / 3932 1
# 400 / 3932 When galaxy angel aa was the title was the us release date? ['Series', 'Title', 'Broadcasts (TV) 1', 'Episodes (TV+extra) 2', 'Directors', 'Aired in Japan 3', 'US Release Date'] SELECT * FROM table WHERE title = release date SELECT US Release Date FROM table WHERE Title = Galaxy Angel AA
# 401 / 3932 What's the change over previous year as a whole in the period in which the change over same quarter the previous year was up 2.8%? ['Period', '% trains arriving within 5 mins of scheduled time (over three months)', 'Change over same quarter the previous year', '% trains arriving within 5 mins of scheduled time Moving Annual Average (MAA)', 'Change over previous year as a whole'] SELECT change over previous year as a whole FROM table WHERE change over same quarter the previous year = 2.8% SELECT Change over previous year as a whole FROM table WHERE Change over same quarter the previous year = Up 2.8%
# 402 / 3932 How many open era titles does the team with their first title in 1925 have? ['Country', 'Amateur Era', 'Open Era', 'All-time', 'First title', 'Last title'] SELECT * FROM table WHERE open era = open era titles AND first title = 1925 SELECT Open Era FROM table WHERE First title = 1925
# 403 / 3932 1
# 404 / 3932 1
# 405 / 3932 1
# 406 / 3932 1
# 407 / 3932 1
# 408 / 3932 What was the date when Troy Murphy (15), got high rebounds?  ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT date FROM table WHERE date = Troy Murphy (15) SELECT Date FROM table WHERE High rebounds = Troy Murphy (15)
# 409 / 3932 Who did the High Assists when Kevin Durant (28) took the High Points? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT High Assists FROM table WHERE high assists = Kevin Durant (28) SELECT High assists FROM table WHERE High points = Kevin Durant (28)
# 410 / 3932 1
# 411 / 3932 1
# 412 / 3932 1
# 413 / 3932 what is the largest city where the province is eastern cape? ['Province', 'Provincial capital', 'Largest city', 'Area (km 2 )', 'Population (2013)'] SELECT * FROM table WHERE province = eastern cape SELECT Largest city FROM table WHERE Province = Eastern Cape
# 414 / 3932 What is the IATA of the airport with 3848 traffic in 2010-11? ['Rank', 'Airport', 'Location', 'IATA', '1985–86', '1990–91', '1995–96', '2000–01', '2005–06', '2007–08', '2009–10', '2010-11'] SELECT IATA FROM table WHERE airport = 3848 SELECT IATA FROM table WHERE 2010-11 = 3848
# 415 / 3932 1
# 416 / 3932 What is listed in p when the type is listed as free agent 1? ['N', 'P', 'Name', 'EU', 'Country', 'Age', 'Type', 'Moving from', 'Transfer window', 'Ends', 'Transfer fee', 'Source'] SELECT * FROM table WHERE age = free agent 1 SELECT P FROM table WHERE Type = Free Agent 1
# 417 / 3932 1
# 418 / 3932 Name the original title for 6.05 million viewership ['Episode', 'Original title', 'Directed by', 'Written by', 'Original airdate', 'Duration', 'Viewership'] SELECT original title FROM table WHERE original title = 6.05 SELECT Original title FROM table WHERE Viewership = 6.05 million
# 419 / 3932 1
# 420 / 3932 1
# 421 / 3932 1
# 422 / 3932 What is every "directed by" when the title is "One To Go" (part 2)? ['No. in series', 'No. in season', 'Title', 'Directed by', 'Written by', 'Original air date', 'U.S. viewers (millions)'] SELECT directed by FROM table WHERE title = "One To Go" (part 2) SELECT Directed by FROM table WHERE Title = One to Go (Part 2)
# 423 / 3932 The opponent was the New York Jets on what week?  ['Week', 'Date', 'Opponent', 'Result', 'Game site', 'Record', 'Attendance'] SELECT week FROM table WHERE week = New York Jets SELECT Week FROM table WHERE Opponent = New York Jets
# 424 / 3932 1
# 425 / 3932 which examples are pronounced et in australian ['Ending', 'American', 'British', 'Australian', 'Examples'] SELECT * FROM table WHERE australian = et SELECT Examples FROM table WHERE Australian = et
# 426 / 3932 What is the location of the church when the church name is Ortnevik Kyrkje? ['Parish (Prestegjeld)', 'Sub-Parish (Sogn)', 'Church Name', 'Year Built', 'Location of the Church'] SELECT * FROM table WHERE church name = Ortnevik Kyrkje SELECT Location of the Church FROM table WHERE Church Name = Ortnevik kyrkje
# 427 / 3932 1
# 428 / 3932 1
# 429 / 3932 When did the club UNAM played the first season in top division? ['Club', 'First season in top division', 'Number of seasons in top division', 'First season of current spell in top division', 'Number of seasons in Liga MX', 'Top division titles'] SELECT * FROM table WHERE club = first season SELECT First season in top division FROM table WHERE Club = UNAM
# 430 / 3932 1
# 431 / 3932 1
# 432 / 3932 which chapter was Transmitted on wednesday if the episode of "363 the hangover part ii" was transmitted on monday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "363 the hangover part ii" SELECT Wednesday FROM table WHERE Monday = 363 The Hangover Part II
# 433 / 3932 which episode was Transmitted on wednesday if the episode of "438 magic: the gathering mini masters tournament" was transmitted on thursday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "438 magic: the gathering mini masters tournament" SELECT Wednesday FROM table WHERE Thursday = 438 Magic: The Gathering Mini Masters Tournament
# 434 / 3932 which episode was Transmitted on friday if the episode of "414 insanely twisted shadow planet" was transmitted on tuesday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT friday FROM table WHERE friday = "414 insanely twisted shadow planet" SELECT Friday FROM table WHERE Tuesday = 414 Insanely Twisted Shadow Planet
# 435 / 3932 which episode was Transmitted on friday if the episode of "515 the adventures of tintin" was transmitted on monday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT friday FROM table WHERE friday = "515 the adventures of tintin" SELECT Friday FROM table WHERE Monday = 515 The Adventures of Tintin
# 436 / 3932 which episode was Transmitted on wednesday if the episode of "307 vs." was transmitted on friday?   ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "307 vs." SELECT Wednesday FROM table WHERE Friday = 307 VS.
# 437 / 3932 1
# 438 / 3932 1
# 439 / 3932 1
# 440 / 3932 1
# 441 / 3932 there are in tobago species name helicops angulatus ['Species', 'Common name', 'Trinidad', 'Tobago', 'Bocas Is.', 'Other'] SELECT * FROM table WHERE species = helicops angulatus SELECT Tobago FROM table WHERE Species = Helicops angulatus
# 442 / 3932 are in tobago species liophis cobellus cobellus? ['Species', 'Common name', 'Trinidad', 'Tobago', 'Bocas Is.', 'Other'] SELECT * FROM table WHERE species = liophis cobellus cobellus SELECT Tobago FROM table WHERE Species = Liophis cobellus cobellus
# 443 / 3932 Which U.S. Acres episode with Garfield episode 1 has a date of disaster? ['Episode', 'Garfield Episode 1', 'U.S. Acres Episode', 'Garfield Episode 2', 'Original Airdate'] SELECT * FROM table WHERE episode = U.S. Acres AND u.s. acres episode = 1 AND garfield episode 1 = disaster SELECT U.S. Acres Episode FROM table WHERE Garfield Episode 1 = Date of Disaster
# 444 / 3932 Which Garfield episode 1 has Garfield episode 2 as the second penelope episode? ['Episode', 'Garfield Episode 1', 'U.S. Acres Episode', 'Garfield Episode 2', 'Original Airdate'] SELECT Garfield episode 1 FROM table WHERE episode = the second penelope episode SELECT Garfield Episode 1 FROM table WHERE Garfield Episode 2 = The Second Penelope Episode
# 445 / 3932 1
# 446 / 3932 1
# 447 / 3932 1
# 448 / 3932 1
# 449 / 3932 1
# 450 / 3932 1
# 451 / 3932 1
# 452 / 3932 1
# 453 / 3932 1
# 454 / 3932 1
# 455 / 3932 1
# 456 / 3932 1
# 457 / 3932 1
# 458 / 3932 1
# 459 / 3932 1
# 460 / 3932 1
# 461 / 3932 1
# 462 / 3932 1
# 463 / 3932 1
# 464 / 3932 1
# 465 / 3932 1
# 466 / 3932 1
# 467 / 3932 1
# 468 / 3932 1
# 469 / 3932 1
# 470 / 3932 1
# 471 / 3932 What is the rank of london borough in southwark? ['Rank', 'London Borough', 'Black African Population', 'Black Caribbean Population', 'Other Black Population', 'Total Black Population'] SELECT rank FROM table WHERE rank = london AND london borough = southwark SELECT Rank FROM table WHERE London Borough = Southwark
# 472 / 3932 when q1 pos is 8 what is the q1+q2 time? ['Pos', 'No', 'Driver', 'Constructor', 'Q1 order', 'Q1 time', 'Q1 pos', 'Q1+Q2 time'] SELECT q1+q2 time FROM table WHERE pos = 8 SELECT Q1+Q2 time FROM table WHERE Q1 pos = 8
# 473 / 3932 What was the team's status in the USISL Pro League playoffs? ['Year', 'Division', 'League', 'Regular Season', 'Playoffs', 'Open Cup'] SELECT * FROM table WHERE league = USISL Pro League SELECT Playoffs FROM table WHERE League = USISL Pro League
# 474 / 3932 1
# 475 / 3932 1
# 476 / 3932 1
# 477 / 3932 1
# 478 / 3932 1
# 479 / 3932 1
# 480 / 3932 1
# 481 / 3932 Who are the opponents of Mike Byron and partner in matches where the score was  6–4, 4–6, 7–6 (7–4)? ['Outcome', 'Year', 'Championship', 'Surface', 'Partner', 'Opponents', 'Score'] SELECT * FROM table WHERE opponents = Mike Byron AND score = 6–4, 4–6, 7–6 (7–4) SELECT Opponents FROM table WHERE Score = 6–4, 4–6, 7–6 (7–4)
# 482 / 3932 1
# 483 / 3932 1
# 484 / 3932 1
# 485 / 3932 1
# 486 / 3932 1
# 487 / 3932 1
# 488 / 3932 1
# 489 / 3932 1
# 490 / 3932 1
# 491 / 3932 1
# 492 / 3932 1
# 493 / 3932 1
# 494 / 3932 1
# 495 / 3932 1
# 496 / 3932 1
# 497 / 3932 1
# 498 / 3932 What is the intelligence os the one that has 思 sī, "thought"? ['Shekhina:', 'Reason', 'Mind', 'Intelligence', 'Thought', 'Understanding'] SELECT intelligence FROM table WHERE thought = 思 sī SELECT Intelligence FROM table WHERE Thought = 思 sī, thought
# 499 / 3932 1
# 500 / 3932 1
# 501 / 3932 1
# 502 / 3932 1
# 503 / 3932 1
# 504 / 3932 1
# 505 / 3932 state all spokesperson for the channel where dual commentator was elena batinova ['Year(s)', 'Commentator', 'Dual Commentator', 'Spokesperson', 'Channel'] SELECT spokesperson FROM table WHERE commentator = elena batinova SELECT Spokesperson FROM table WHERE Dual Commentator = Elena Batinova
# 506 / 3932 1
# 507 / 3932 1
# 508 / 3932 1
# 509 / 3932 1
# 510 / 3932 1
# 511 / 3932 1
# 512 / 3932 1
# 513 / 3932 1
# 514 / 3932 What was the time in part 3 when Heikki Kovalainen was the driver?  ['Pos', 'No', 'Driver', 'Constructor', 'Part 1', 'Part 2', 'Part 3', 'Grid'] SELECT * FROM table WHERE part 3 = Heikki Kovalainen SELECT Part 3 FROM table WHERE Driver = Heikki Kovalainen
# 515 / 3932 What was the time in part 3 when Nick Heidfeld was the driver? ['Pos', 'No', 'Driver', 'Constructor', 'Part 1', 'Part 2', 'Part 3', 'Grid'] SELECT * FROM table WHERE part 3 = Nick Heidfeld SELECT Part 3 FROM table WHERE Driver = Nick Heidfeld
# 516 / 3932 1
# 517 / 3932 1
# 518 / 3932 What's the Sanskrit word for month with Thai name มกราคม? ['English name', 'Thai name', 'Abbr.', 'Transcription', 'Sanskrit word', 'Zodiac sign'] SELECT * FROM table WHERE thai name = มกราคม SELECT Sanskrit word FROM table WHERE Thai name = มกราคม
# 519 / 3932 1
# 520 / 3932 1
# 521 / 3932 1
# 522 / 3932 1
# 523 / 3932 1
# 524 / 3932 1
# 525 / 3932 What was the Obama% when McCain% was 61.2%? ['County', 'Obama%', 'Obama#', 'McCain%', 'McCain#', 'Others%', 'Others#'] SELECT * FROM table WHERE mccain% = 61.2% SELECT Obama% FROM table WHERE McCain% = 61.2%
# 526 / 3932 1
# 527 / 3932 1
# 528 / 3932 1
# 529 / 3932 1
# 530 / 3932 1
# 531 / 3932 What is the weight for western ontario college? ['Round', 'Choice', 'Player', 'Position', 'Height', 'Weight', 'College'] SELECT weight FROM table WHERE college = western ontario college SELECT Weight FROM table WHERE College = Western Ontario
# 532 / 3932 1
# 533 / 3932 1
# 534 / 3932 1
# 535 / 3932 1
# 536 / 3932 what is the name of the institution of the sparta, wi location? ['Institution', 'Location', 'Year Joined', 'Affiliation', 'Enrollment', 'Mascot', 'Colors'] SELECT * FROM table WHERE institution = name AND location = sparta, wi SELECT Institution FROM table WHERE Location = Sparta, WI
# 537 / 3932 1
# 538 / 3932 1
# 539 / 3932 1
# 540 / 3932 1
# 541 / 3932 1
# 542 / 3932 1
# 543 / 3932 1
# 544 / 3932 What song did Robin perform with a result of 4.0? ['Order', 'Couple', 'Karen', 'Nicky', 'Jason', 'Ruthie', 'Robin', 'Total', 'Scoreboard', 'Song', 'Public Vote %', 'Result'] SELECT song FROM table WHERE result = 4.0 SELECT Song FROM table WHERE Robin = 4.0
# 545 / 3932 1
# 546 / 3932 1
# 547 / 3932 1
# 548 / 3932 1
# 549 / 3932 What date did Adriano Buzaid have the pole position? ['Round', 'Circuit', 'Date', 'Pole Position', 'Fastest Lap', 'Winning Driver', 'Winning Team'] SELECT date FROM table WHERE date = Adriano Buzaid SELECT Date FROM table WHERE Pole Position = Adriano Buzaid
# 550 / 3932 What is the ministries number when duration is 4 years, 4 days (1,465 days)? ['Nº', 'Cabinet (Nickname)', 'Took office', 'Left office', 'Duration', 'Coalition parties', 'ministers', 'ministries', 'President'] SELECT * FROM table WHERE ministries = ministries number AND duration = 4 years, 4 days (1,465 days) SELECT ministries FROM table WHERE Duration = 4 years, 4 days (1,465 days)
# 551 / 3932 1
# 552 / 3932 1
# 553 / 3932 1
# 554 / 3932 1
# 555 / 3932 1
# 556 / 3932 What source gave 26% of the votes to Brian Moran? ['Source', 'Dates Administered', 'Terry McAuliffe', 'Brian Moran', 'Creigh Deeds'] SELECT source FROM table WHERE source = 26% SELECT Source FROM table WHERE Brian Moran = 26%
# 557 / 3932 1
# 558 / 3932 1
# 559 / 3932 What is the maturity date of the ISIN labeled DE000A0BVBN3? ['Issuer', 'Issue Date', 'ISIN', 'Amount Issued [€]', 'Coupon', 'Maturity'] SELECT * FROM table WHERE maturity = maturity date AND isin = DE000A0BVBN3 SELECT Maturity FROM table WHERE ISIN = DE000A0BVBN3
# 560 / 3932 1
# 561 / 3932 1
# 562 / 3932 1
# 563 / 3932 1
# 564 / 3932 1
# 565 / 3932 1
# 566 / 3932 1
# 567 / 3932 1
# 568 / 3932 What was the highest position for the person who performed in 16 races? ['Season', 'Series', 'Team', 'Races', 'Wins', 'Poles', 'F/Laps', 'Podiums', 'Points', 'Position'] SELECT * FROM table WHERE races = 16 SELECT Position FROM table WHERE Races = 16
# 569 / 3932 1
# 570 / 3932 1
# 571 / 3932 1
# 572 / 3932 1
# 573 / 3932 1
# 574 / 3932 1
# 575 / 3932 What is the event # when the winner is what is 7x6? ['Dateca', 'Event #', 'Event', 'Winner', 'Prize', 'Entries', 'Prize Pool', 'Elapsed Time'] SELECT event # FROM table WHERE winner = 7x6 SELECT Event # FROM table WHERE Winner = what is 7x6
# 576 / 3932 1
# 577 / 3932 How many games were played in the 1989 season? ['Season', 'Player', 'Nationality', 'Team', 'Points', 'Average', 'Played'] SELECT * FROM table WHERE season = 1989 SELECT Played FROM table WHERE Season = 1989
# 578 / 3932 1
# 579 / 3932 1
# 580 / 3932 1
# 581 / 3932 1
# 582 / 3932 1
# 583 / 3932 1
# 584 / 3932 1
# 585 / 3932 1
# 586 / 3932 1
# 587 / 3932 1
# 588 / 3932 1
# 589 / 3932 1
# 590 / 3932 1
# 591 / 3932 1
# 592 / 3932 1
# 593 / 3932 Which points classification has 4 as the stage? ['Stage', 'Stage winner', 'General classification', 'Points classification', 'Mountains classification', 'Malaysian rider classification', 'Team classification', 'Malaysian team classification'] SELECT points classification FROM table WHERE points classification = 4 SELECT Points classification FROM table WHERE Stage = 4
# 594 / 3932 1
# 595 / 3932 1
# 596 / 3932 Which team classification has taiji nishitani as the stage winner? ['Stage', 'Stage winner', 'General classification', 'Points classification', 'Mountains classification', 'Malaysian rider classification', 'Team classification', 'Malaysian team classification'] SELECT team classification FROM table WHERE team classification = taiji nishitani SELECT Team classification FROM table WHERE Stage winner = Taiji Nishitani
# 597 / 3932 1
# 598 / 3932 Who was the Best Male Artist where Bankie Travolta won the Best Male MC? ['Best Male MC', 'Best Female MC', 'Best Male Artist', 'Best Female Artist', 'Best Male Lyricist', 'Best Female Lyricist', 'Best Male Record'] SELECT Best Male Artist FROM table WHERE best male artist = Bankie Travolta SELECT Best Male Artist FROM table WHERE Best Male MC = Bankie Travolta
# 599 / 3932 Who was the Best Male MC if Best Album won the Best Male Lyricist? ['Best Male MC', 'Best Female MC', 'Best Male Artist', 'Best Female Artist', 'Best Male Lyricist', 'Best Female Lyricist', 'Best Male Record'] SELECT Best Male MC FROM table WHERE best male mc = Best Album SELECT Best Male MC FROM table WHERE Best Male Lyricist = Best Album
# 600 / 3932 Who was the Best Male Lyricist if Neshia Nee won the Best Male Record? ['Best Male MC', 'Best Female MC', 'Best Male Artist', 'Best Female Artist', 'Best Male Lyricist', 'Best Female Lyricist', 'Best Male Record'] SELECT Best Male Lyricist FROM table WHERE best male lyricist = Neshia Nee SELECT Best Male Lyricist FROM table WHERE Best Male Record = Neshia Nee
# 601 / 3932 Who won the Best Female Artist where Best R&B Contributor won the Best Male Lyricist? ['Best Male MC', 'Best Female MC', 'Best Male Artist', 'Best Female Artist', 'Best Male Lyricist', 'Best Female Lyricist', 'Best Male Record'] SELECT Best Female Artist FROM table WHERE best female artist = Best R&B Contributor SELECT Best Female Artist FROM table WHERE Best Male Lyricist = Best R&B Contributor
# 602 / 3932 What won the Best Female Artist if Best Lyrical Record won the Best Male Artist? ['Best Male MC', 'Best Female MC', 'Best Male Artist', 'Best Female Artist', 'Best Male Lyricist', 'Best Female Lyricist', 'Best Male Record'] SELECT Best Female Artist FROM table WHERE best female artist = Best Lyrical Record SELECT Best Female Artist FROM table WHERE Best Male Artist = Best Lyrical Record
# 603 / 3932 What won the Best Female Artist if People's Male MC won the Best Female Lyricist? ['Best Male MC', 'Best Female MC', 'Best Male Artist', 'Best Female Artist', 'Best Male Lyricist', 'Best Female Lyricist', 'Best Male Record'] SELECT Best Female Artist FROM table WHERE best female artist = People's Male MC SELECT Best Female Artist FROM table WHERE Best Female Lyricist = People's Male MC
# 604 / 3932 1
# 605 / 3932 1
# 606 / 3932 1
# 607 / 3932 What is every performance comparison if the value of 81 St. Regis is 114.7? ['Performance comparison', '78 Fury', '78 Monaco', '79 St. Regis', '80 St. Regis', '81 St. Regis'] SELECT * FROM table WHERE 81 st. regis = 114.7 SELECT Performance comparison FROM table WHERE 81 St. Regis = 114.7
# 608 / 3932 1
# 609 / 3932 1
# 610 / 3932 1
# 611 / 3932 1
# 612 / 3932 Name the country for gerrard ['N', 'P', 'Name', 'EU', 'Country', 'Age', 'Type', 'Moving from', 'Transfer window', 'Ends', 'Transfer fee', 'Source'] SELECT country FROM table WHERE country = gerrard SELECT Country FROM table WHERE Name = Gerrard
# 613 / 3932 1
# 614 / 3932 1
# 615 / 3932 1
# 616 / 3932 1
# 617 / 3932 1
# 618 / 3932 1
# 619 / 3932 1
# 620 / 3932 1
# 621 / 3932 1
# 622 / 3932 1
# 623 / 3932 1
# 624 / 3932 What's the overall record of the team with 4-3 road record? ['Team', 'SEC Wins', 'SEC Losses', 'Percentage', 'Home Record', 'Road Record', 'Overall Record'] SELECT * FROM table WHERE team = overall AND road record = 4-3 SELECT Overall Record FROM table WHERE Road Record = 4-3
# 625 / 3932 1
# 626 / 3932 1
# 627 / 3932 1
# 628 / 3932 Who were the comedians on episode 1x03? ['Episode', 'Location', 'Headliner', 'Comedians', 'Airdate'] SELECT * FROM table WHERE episode = 1x03 SELECT Comedians FROM table WHERE Episode = 1x03
# 629 / 3932 1
# 630 / 3932 1
# 631 / 3932 1
# 632 / 3932 1
# 633 / 3932 1
# 634 / 3932 1
# 635 / 3932 1
# 636 / 3932 1
# 637 / 3932 1
# 638 / 3932 1
# 639 / 3932 Who has the high points when 53-27 is the record? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT high points FROM table WHERE high points = 53-27 SELECT High points FROM table WHERE Record = 53-27
# 640 / 3932 1
# 641 / 3932 1
# 642 / 3932 Who has the high assists when 50-26 is the record? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT high assists FROM table WHERE high assists = 50-26 SELECT High assists FROM table WHERE Record = 50-26
# 643 / 3932 Who has high points when 50-26 is the record? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT high points FROM table WHERE high points = 50-26 SELECT High points FROM table WHERE Record = 50-26
# 644 / 3932 1
# 645 / 3932 1
# 646 / 3932 1
# 647 / 3932 What is the score when 36-33 is the record? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT score FROM table WHERE score = 36-33 SELECT Score FROM table WHERE Record = 36-33
# 648 / 3932 Who has the high assists when April 26 is the date? ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Series'] SELECT high assists FROM table WHERE high assists = April 26 SELECT High assists FROM table WHERE Date = April 26
# ...
# 3605 / 3932 1
# 3606 / 3932 1
# 3607 / 3932 Which home team has an Away of (2-1)? ['Opponent', 'OVERALL', 'HOME', 'AWAY', 'PLYFF'] SELECT * FROM table WHERE home = home team AND away = (2-1) SELECT HOME FROM table WHERE AWAY = (2-1)
# 3608 / 3932 1
# 3609 / 3932 1
# 3610 / 3932 1
# 3611 / 3932 1
# 3612 / 3932 1
# 3613 / 3932 1
# 3614 / 3932 Who was the host team when the Miami Dolphins were the visiting team? ['Week', 'Date', 'Visiting team', 'Final score', 'Host team', 'Stadium'] SELECT host team FROM table WHERE host team = Miami Dolphins SELECT Host team FROM table WHERE Visiting team = miami dolphins
# 3615 / 3932 1
# 3616 / 3932 1
# 3617 / 3932 1
# 3618 / 3932 1
# 3619 / 3932 1
# 3620 / 3932 1
# 3621 / 3932 1
# 3622 / 3932 1
# 3623 / 3932 1
# 3624 / 3932 1
# 3625 / 3932 1
# 3626 / 3932 Which tournament has a value of a for 2009? ['Tournament', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'] SELECT tournament FROM table SELECT Tournament FROM table WHERE 2009 = a
# 3627 / 3932 1
# 3628 / 3932 1
# 3629 / 3932 The year the Women's singles was won by Christine Magnusson who was the winner of the Men's singles? ['Year', "Men's singles", "Women's singles", "Men's doubles", "Women's doubles", 'Mixed doubles'] SELECT * FROM table WHERE men's singles = Christine Magnusson SELECT Men's singles FROM table WHERE Women's singles = christine magnusson
# 3630 / 3932 1
# 3631 / 3932 1
# 3632 / 3932 1
# 3633 / 3932 1
# 3634 / 3932 1
# 3635 / 3932 1
# 3636 / 3932 When completing 182 laps, what was the qual.? ['Year', 'Start', 'Qual', 'Rank', 'Finish', 'Laps'] SELECT * FROM table WHERE laps = 182 AND qual = qual. SELECT Qual FROM table WHERE Laps = 182
# 3637 / 3932 1
# 3638 / 3932 1
# 3639 / 3932 What is the score with lost as the result? ['Date', 'Venue', 'Score', 'Result', 'Competition'] SELECT score FROM table WHERE score = lost SELECT Score FROM table WHERE Result = lost
# 3640 / 3932 Which date has china as the venue? ['Date', 'Venue', 'Score', 'Result', 'Competition'] SELECT date FROM table WHERE date = china SELECT Date FROM table WHERE Venue = china
# 3641 / 3932 Which competition has 4-0 as the score? ['Date', 'Venue', 'Score', 'Result', 'Competition'] SELECT competition FROM table WHERE competition = 4-0 SELECT Competition FROM table WHERE Score = 4-0
# 3642 / 3932 What score has october 16, 2000 as the date? ['Date', 'Venue', 'Score', 'Result', 'Competition'] SELECT score FROM table WHERE score = october 16, 2000 SELECT Score FROM table WHERE Date = october 16, 2000
# 3643 / 3932 1
# 3644 / 3932 What is the category for the premios lo nuestro award? ['Year', 'Award', 'Category', 'Motive', 'Result'] SELECT category FROM table WHERE award = premios lo nuestro award SELECT Category FROM table WHERE Award = premios lo nuestro
# 3645 / 3932 1
# 3646 / 3932 1
# 3647 / 3932 1
# 3648 / 3932 1
# 3649 / 3932 1
# 3650 / 3932 1
# 3651 / 3932 What score has january 15, 2005 as the date? ['Date', 'Venue', 'Score', 'Result', 'Competition'] SELECT score FROM table WHERE score = january 15, 2005 SELECT Score FROM table WHERE Date = january 15, 2005
# 3652 / 3932 What score has january 3, 2005 as the date? ['Date', 'Venue', 'Score', 'Result', 'Competition'] SELECT score FROM table WHERE score = january 3, 2005 SELECT Score FROM table WHERE Date = january 3, 2005
# 3653 / 3932 What competition has may 5, 2001 as the date? ['Date', 'Venue', 'Score', 'Result', 'Competition'] SELECT competition FROM table WHERE competition = may 5, 2001 SELECT Competition FROM table WHERE Date = may 5, 2001
# 3654 / 3932 1
# 3655 / 3932 1
# 3656 / 3932 1
# 3657 / 3932 1
# 3658 / 3932 1
# 3659 / 3932 1
# 3660 / 3932 1
# 3661 / 3932 1
# 3662 / 3932 What Willingshain is Kirchheim 1,126? ['Gersdorf', 'Gershausen', 'Heddersdorf', 'Kemmerode', 'Kirchheim', 'Reckerode ****', 'Reimboldsh.', 'Rotterterode', 'Willingshain'] SELECT Willingshain FROM table WHERE kirchheim = Kirchheim 1,126 SELECT Willingshain FROM table WHERE Kirchheim = 1,126
# 3663 / 3932 1
# 3664 / 3932 1
# 3665 / 3932 1
# 3666 / 3932 1
# 3667 / 3932 1
# 3668 / 3932 1
# 3669 / 3932 1
# 3670 / 3932 1
# 3671 / 3932 1
# 3672 / 3932 1
# 3673 / 3932 what college has paul seiler as a player? ['Overall Pick #', 'AFL Team', 'Player', 'Position', 'College'] SELECT college FROM table WHERE college = paul seiler SELECT College FROM table WHERE Player = paul seiler
# 3674 / 3932 1
# 3675 / 3932 1
# 3676 / 3932 1
# 3677 / 3932 1
# 3678 / 3932 1
# 3679 / 3932 1
# 3680 / 3932 1
# 3681 / 3932 Which Language Director of nagisa oshima use in his film? ['Country', 'Film title used in nomination', 'Language', 'Original name', 'Director'] SELECT * FROM table WHERE language = Language Director AND director = nagisa oshima SELECT Language FROM table WHERE Director = nagisa oshima
# 3682 / 3932 1
# 3683 / 3932 1
# 3684 / 3932 1
# 3685 / 3932 1
# 3686 / 3932 1
# 3687 / 3932 1
# 3688 / 3932 1
# 3689 / 3932 1
# 3690 / 3932 1
# 3691 / 3932 1
# 3692 / 3932 What Race 3 is Round 5? ['Round', 'Track', 'Race 1', 'Race 2', 'Race 3'] SELECT Race 3 FROM table WHERE round = 5 SELECT Race 3 FROM table WHERE Round = round 5
# 3693 / 3932 What Round has the Track Clipsal 500 Support? ['Round', 'Track', 'Race 1', 'Race 2', 'Race 3'] SELECT Round FROM table WHERE track = Clipsal 500 SELECT Round FROM table WHERE Track = clipsal 500 support
# 3694 / 3932 1
# 3695 / 3932 What is the Race 2 result of Round 2? ['Round', 'Track', 'Race 1', 'Race 2', 'Race 3'] SELECT * FROM table WHERE round = 2 SELECT Race 2 FROM table WHERE Round = round 2
# 3696 / 3932 What is the Race 1 result of Round 2? ['Round', 'Track', 'Race 1', 'Race 2', 'Race 3'] SELECT Race 1 FROM table WHERE round = 2 SELECT Race 1 FROM table WHERE Round = round 2
# 3697 / 3932 Which women's doubles had Tine Rasmussen on the women's singles? ['Year', "Men's singles", "Women's singles", "Men's doubles", "Women's doubles", 'Mixed doubles'] SELECT women's doubles FROM table WHERE women's doubles = Tine Rasmussen SELECT Women's doubles FROM table WHERE Women's singles = tine rasmussen
# 3698 / 3932 1
# 3699 / 3932 1
# 3700 / 3932 1
# 3701 / 3932 1
# 3702 / 3932 1
# 3703 / 3932 1
# 3704 / 3932 1
# 3705 / 3932 1
# 3706 / 3932 1
# 3707 / 3932 1
# 3708 / 3932 1
# 3709 / 3932 1
# 3710 / 3932 1
# 3711 / 3932 1
# 3712 / 3932 1
# 3713 / 3932 1
# 3714 / 3932 1
# 3715 / 3932 1
# 3716 / 3932 1
# 3717 / 3932 1
# 3718 / 3932 1
# 3719 / 3932 1
# 3720 / 3932 1
# 3721 / 3932 1
# 3722 / 3932 1
# 3723 / 3932 1
# 3724 / 3932 What was the double's performance data from the Canada Masters tournament in 2008? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT * FROM table WHERE tournament = Canada Masters SELECT 2008 FROM table WHERE Tournament = canada masters
# 3725 / 3932 What was the double's performance data from the Monte Carlo Masters tournament in 2007? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT * FROM table WHERE tournament = Monte Carlo Masters SELECT 2007 FROM table WHERE Tournament = monte carlo masters
# 3726 / 3932 1
# 3727 / 3932 1
# 3728 / 3932 1
# 3729 / 3932 1
# 3730 / 3932 1
# 3731 / 3932 What is the value in 2009 when 1R is in 2007? ['Tournament', '2007', '2008', '2009', 'Career Win-Loss'] SELECT 2009 FROM table WHERE 2009 = 1R SELECT 2009 FROM table WHERE 2007 = 1r
# 3732 / 3932 1
# 3733 / 3932 Which car won the same award in 2001 that the toyota 1nz-fxe hybrid prius won in 1999? ['category', '1999', '2000', '2001', '2004'] SELECT 2001 FROM table WHERE 2001 = car AND 1999 = toyota 1nz-fxe hybrid prius SELECT 2001 FROM table WHERE 1999 = toyota 1nz-fxe hybrid prius
# 3734 / 3932 1
# 3735 / 3932 Which car won the same award in 2001 that the bmw m67d39 3.9l v8 e38 740d won in 1999? ['category', '1999', '2000', '2001', '2004'] SELECT 2001 FROM table WHERE 2001 = car AND 1999 = bmw m67d39 3.9l v8 e38 740d SELECT 2001 FROM table WHERE 1999 = bmw m67d39 3.9l v8 e38 740d
# 3736 / 3932 What is the surface of the mountain range that contains the Elk Garden Mountain? ['Mountain', 'Elevation', 'Range', 'State(s)', 'Surface'] SELECT surface FROM table WHERE mountain = Elk Garden Mountain SELECT Surface FROM table WHERE Mountain = elk garden
# 3737 / 3932 What is the tournament with A in 2011? ['Tournament', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table SELECT Tournament FROM table WHERE 2011 = a
# 3738 / 3932 1
# 3739 / 3932 1
# 3740 / 3932 1
# 3741 / 3932 1
# 3742 / 3932 1
# 3743 / 3932 1
# 3744 / 3932 1
# 3745 / 3932 1
# 3746 / 3932 1
# 3747 / 3932 1
# 3748 / 3932 1
# 3749 / 3932 1
# 3750 / 3932 1
# 3751 / 3932 1
# 3752 / 3932 1
# 3753 / 3932 1
# 3754 / 3932 1
# 3755 / 3932 1
# 3756 / 3932 What Lomavren word has the same meaning as the Hindi word do? ['Hindi', 'Romani', 'Domari', 'Lomavren', 'Persian'] SELECT Lomavren FROM table SELECT Lomavren FROM table WHERE Hindi = do
# 3757 / 3932 1
# 3758 / 3932 1
# 3759 / 3932 1
# 3760 / 3932 1
# 3761 / 3932 1
# 3762 / 3932 1
# 3763 / 3932 Which entrant used the chassis de tomaso 505? ['Year', 'Entrant', 'Chassis', 'Engine', 'Points'] SELECT entrant FROM table WHERE chassis = tomaso 505 SELECT Entrant FROM table WHERE Chassis = de tomaso 505
# 3764 / 3932 1
# 3765 / 3932 1
# 3766 / 3932 1
# 3767 / 3932 1
# 3768 / 3932 1
# 3769 / 3932 1
# 3770 / 3932 1
# 3771 / 3932 1
# 3772 / 3932 1
# 3773 / 3932 Name the tournament for 2012 grand slam tournaments ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE tournament = grand slam tournaments SELECT Tournament FROM table WHERE 2012 = grand slam tournaments
# 3774 / 3932 1
# 3775 / 3932 1
# 3776 / 3932 1
# 3777 / 3932 1
# 3778 / 3932 1
# 3779 / 3932 1
# 3780 / 3932 What tournament was at the 2007 Olympic Games? ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE 2007 = 2007 Olympic Games SELECT Tournament FROM table WHERE 2007 = olympic games
# 3781 / 3932 What tournament was at the 2011 Cincinnati Masters? ['Tournament', '2007', '2008', '2009', '2010', '2011', '2012'] SELECT tournament FROM table WHERE 2011 = 2011 Cincinnati Masters SELECT 2011 FROM table WHERE Tournament = cincinnati masters
# 3782 / 3932 1
# 3783 / 3932 1
# 3784 / 3932 Name the location of reign 3 ['Championship', 'Current champion(s)', 'Reign', 'Date won', 'Days held', 'Location'] SELECT location FROM table WHERE reign = reign 3 SELECT Location FROM table WHERE Reign = 3
# 3785 / 3932 1
# 3786 / 3932 1
# 3787 / 3932 1
# 3788 / 3932 1
# 3789 / 3932 What is the Finalists that has 2008, 2012, 2013 as Not winning editions ['Club', 'Winners', 'Finalists', 'Winning editions', 'Not winning editions'] SELECT Finalists FROM table SELECT Finalists FROM table WHERE Not winning editions = 2008, 2012, 2013
# 3790 / 3932 1
# 3791 / 3932 1
# 3792 / 3932 What is the score when november 15 is the date? ['Date', 'Visitor', 'Score', 'Home', 'Record', 'Attendance'] SELECT score FROM table WHERE score = november 15 SELECT Score FROM table WHERE Date = november 15
# 3793 / 3932 What record has November 15 as the date? ['Date', 'Visitor', 'Score', 'Home', 'Record', 'Attendance'] SELECT record FROM table WHERE record = November 15 SELECT Record FROM table WHERE Date = november 15
# 3794 / 3932 What tournament what held in Cincinnati in 2009? ['Tournament', '2007', '2008', '2009', '2010', '2011'] SELECT tournament FROM table WHERE 2009 = Cincinnati SELECT 2009 FROM table WHERE Tournament = cincinnati
# 3795 / 3932 1
# 3796 / 3932 1
# 3797 / 3932 1
# 3798 / 3932 1
# 3799 / 3932 1
# 3800 / 3932 1
# 3801 / 3932 1
# 3802 / 3932 Which Representative has a Presentation of Credentials on september 8, 2005? ['Representative', 'Title', 'Presentation of Credentials', 'Termination of Mission', 'Appointed by'] SELECT Representative FROM table WHERE representative = Credentials AND presentation of credentials = september 8, 2005 SELECT Representative FROM table WHERE Presentation of Credentials = september 8, 2005
# 3803 / 3932 Which Termination of Mission has a Presentation of Credentials on October 29, 1981 ['Representative', 'Title', 'Presentation of Credentials', 'Termination of Mission', 'Appointed by'] SELECT Termination of Mission FROM table WHERE termination of mission = Credentials AND presentation of credentials = October 29, 1981 SELECT Termination of Mission FROM table WHERE Presentation of Credentials = october 29, 1981
# 3804 / 3932 1
# 3805 / 3932 1
# 3806 / 3932 1
# 3807 / 3932 1
# 3808 / 3932 1
# 3809 / 3932 1
# 3810 / 3932 1
# 3811 / 3932 1
# 3812 / 3932 1
# 3813 / 3932 1
# 3814 / 3932 1
# 3815 / 3932 1
# 3816 / 3932 1
# 3817 / 3932 1
# 3818 / 3932 1
# 3819 / 3932 1
# 3820 / 3932 1
# 3821 / 3932 1
# 3822 / 3932 What is the name of the party called name? ['Name', 'Entered Office', 'Left Office', 'Party', 'First Minister'] SELECT party FROM table SELECT Party FROM table WHERE Name = name
# 3823 / 3932 1
# 3824 / 3932 1
# 3825 / 3932 1
# 3826 / 3932 1
# 3827 / 3932 1
# 3828 / 3932 1
# 3829 / 3932 1
# 3830 / 3932 1
# 3831 / 3932 1
# 3832 / 3932 1
# 3833 / 3932 1
# 3834 / 3932 1
# 3835 / 3932 1
# 3836 / 3932 1
# 3837 / 3932 1
# 3838 / 3932 1
# 3839 / 3932 1
# 3840 / 3932 1
# 3841 / 3932 1
# 3842 / 3932 1
# 3843 / 3932 1
# 3844 / 3932 1
# 3845 / 3932 1
# 3846 / 3932 1
# 3847 / 3932 1
# 3848 / 3932 1
# 3849 / 3932 1
# 3850 / 3932 1
# 3851 / 3932 1
# 3852 / 3932 What character did Katie Rowley Jones play in the Original West End Cast? ['Character', 'Original West End Cast', 'Original Broadway Cast', 'First UK Tour Cast', 'First US Tour Cast'] SELECT character FROM table WHERE character = Original West End SELECT Character FROM table WHERE Original West End Cast = katie rowley jones
# 3853 / 3932 1
# 3854 / 3932 1
# 3855 / 3932 1
# 3856 / 3932 1
# 3857 / 3932 1
# 3858 / 3932 1
# 3859 / 3932 What place has Canada as the country? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT place FROM table WHERE place = Canada SELECT Place FROM table WHERE Country = canada
# 3860 / 3932 Which player has 69 as the score? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT player FROM table WHERE player = 69 SELECT Player FROM table WHERE Score = 69
# 3861 / 3932 1
# 3862 / 3932 1
# 3863 / 3932 1
# 3864 / 3932 1
# 3865 / 3932 1
# 3866 / 3932 1
# 3867 / 3932 1
# 3868 / 3932 1
# 3869 / 3932 1
# 3870 / 3932 Which year has brm v12 as the engine? ['Year', 'Entrant', 'Chassis', 'Engine', 'Pts.'] SELECT year FROM table WHERE year = brm v12 SELECT Year FROM table WHERE Engine = brm v12
# 3871 / 3932 1
# 3872 / 3932 1
# 3873 / 3932 1
# 3874 / 3932 1
# 3875 / 3932 1
# 3876 / 3932 1
# 3877 / 3932 1
# 3878 / 3932 1
# 3879 / 3932 1
# 3880 / 3932 1
# 3881 / 3932 1
# 3882 / 3932 1
# 3883 / 3932 1
# 3884 / 3932 1
# 3885 / 3932 1
# 3886 / 3932 1
# 3887 / 3932 What award was Hannah Gal the recipient of? ['Film', 'Director(s)', 'Producer(s)', 'Recipient', 'Date', 'Award'] SELECT award FROM table WHERE award = Hannah Gal SELECT Award FROM table WHERE Recipient = hannah gal
# 3888 / 3932 1
# 3889 / 3932 1
# 3890 / 3932 1
# 3891 / 3932 1
# 3892 / 3932 1
# 3893 / 3932 1
# 3894 / 3932 1
# 3895 / 3932 1
# 3896 / 3932 1
# 3897 / 3932 1
# 3898 / 3932 1
# 3899 / 3932 1
# 3900 / 3932 1
# 3901 / 3932 1
# 3902 / 3932 1
# 3903 / 3932 1
# 3904 / 3932 1
# 3905 / 3932 1
# 3906 / 3932 1
# 3907 / 3932 1
# 3908 / 3932 1
# 3909 / 3932 What is the diameter of the Archery Reverse coin? ['Year', 'Denomination', 'Alloy', 'Reverse', 'Diameter', 'Weight', 'Obverse', 'Mintage', 'Series'] SELECT diameter FROM table WHERE reverse = Archery Reverse SELECT Diameter FROM table WHERE Reverse = archery
# 3910 / 3932 1
# 3911 / 3932 1
# 3912 / 3932 1
# 3913 / 3932 1
# 3914 / 3932 1
# 3915 / 3932 1
# 3916 / 3932 What year did Lonneke Janssen win the Women's singles? ['Year', "Men's singles", "Women's singles", "Men's doubles", "Women's doubles", 'Mixed doubles'] SELECT year FROM table WHERE year = Lonneke Janssen SELECT Year FROM table WHERE Women's singles = lonneke janssen
# 3917 / 3932 1
# 3918 / 3932 1
# 3919 / 3932 1
# 3920 / 3932 1
# 3921 / 3932 1
# 3922 / 3932 1
# 3923 / 3932 Which main cast seasons were portrayed by Joe Jonas? ['Character', 'Portrayed by', 'Main cast seasons', 'Recurring cast seasons', '# of episodes'] SELECT * FROM table WHERE portrayed by = Joe Jonas SELECT Main cast seasons FROM table WHERE Portrayed by = joe jonas
# 3924 / 3932 1
# 3925 / 3932 1
# 3926 / 3932 1
# 3927 / 3932 1
# 3928 / 3932 1
# 3929 / 3932 1
# 3930 / 3932 1
# 3931 / 3932 1
# Select accuracy 95.37131230925738
# Where accuracy 88.73346897253306
# Value accuracy 93.54018311291964
# Overall accuracy 83.62156663275687

# %% [markdown]
# Our accuracy statistics for this case is as follows.
#
# *   Select accuracy: 95.37%
# *   Where accuracy: 88.73%
# *   Value accuracy: 93.54%
# *   Overall accuracy 83.62%

# %% [markdown]
# #Case 5: Only Aggregate Function Queries, Attributes Explicitly Present in NLQ, Rule 3
# We evaluate accuracy assuming that
#
# *   the SELECT and WHERE attributes are explicitly present in the NLQ
# *   there are ONLY aggregate functions like MAX, MIN, COUNT, or others.
# *   nlq2sql uses rule 3 (defined in our report)
#
# We also assume that there are no WHERE clauses with any operator other than '=' but no such queries exist when we also impose the condition that attributes need to be explicitly present in the NLQ.
#
# The ner model we used in the evaluation below supports aggregation.

# %%
tagTestSet = obtain_aggregate_queries()
print(len(tagTestSet))
# Out:
# 100%|██████████| 15878/15878 [00:04<00:00, 3592.94it/s]
# 2027
# 2027

# %%
evaluate_data(tagTestSet, nlp_aggr, 'rule3')
# Out:
# 0 / 2027 what is the total number of total w–l where doubles w–l is 11–11 ['Player', 'Total W–L', 'Singles W–L', 'Doubles W–L', 'Ties played', 'Debut', 'Years played'] SELECT * FROM table WHERE doubles w–l = 11–11 SELECT COUNT Total W–L FROM table WHERE Doubles W–L = 11–11
# 1 / 2027 what is the total number of singles w–l where doubles w–l is 11–14 ['Player', 'Total W–L', 'Singles W–L', 'Doubles W–L', 'Ties played', 'Debut', 'Years played'] SELECT * FROM table WHERE doubles w–l = 11–14 SELECT COUNT Singles W–L FROM table WHERE Doubles W–L = 11–14
# 2 / 2027 1
# 3 / 2027 1
# 4 / 2027 What is the Frequency at the Market/Rank of Burlington - Plattsburgh , Vermont - New York /143? ['Calls', 'Frequency', 'Branding', 'Format', 'Market/Rank', 'Timeslot', 'Group owner'] SELECT Frequency FROM table WHERE market/rank = Burlington - Plattsburgh , Vermont - New York /143 SELECT COUNT Frequency FROM table WHERE Market/Rank = Burlington - Plattsburgh , Vermont - New York /143
# 5 / 2027 Of the years that had exactly 17096 departures, what is the greatest number of aircraft kilometers flown? ['Year', 'Aircraft kilometers', 'Departures', 'Flying hours', 'Passengers', 'Seat factor', 'Employees', 'Profit/loss'] SELECT * FROM table WHERE departures = 17096 AND aircraft kilometers = aircraft kilometers flown SELECT MAX Aircraft kilometers FROM table WHERE Departures = 17096
# 6 / 2027 what's the minimum total with crop (kilotonnes) being s lupin ['Crop (kilotonnes)', 'New South Wales', 'Victoria', 'Queensland', 'Western Australia', 'South Australia', 'Tasmania', 'Total'] SELECT * FROM table WHERE crop (kilotonnes) = s lupin SELECT MIN Total FROM table WHERE Crop (kilotonnes) = s Lupin
# 7 / 2027 1
# 8 / 2027 what's the minimum tasmania value ['Crop (kilotonnes)', 'New South Wales', 'Victoria', 'Queensland', 'Western Australia', 'South Australia', 'Tasmania', 'Total'] SELECT * FROM table SELECT MIN Tasmania FROM table
# 9 / 2027 what's the total number of tasmania with new south wales crop of 190 kilotonnes ['Crop (kilotonnes)', 'New South Wales', 'Victoria', 'Queensland', 'Western Australia', 'South Australia', 'Tasmania', 'Total'] SELECT COUNT tasmania FROM table WHERE new south wales = 190 kilotonnes SELECT COUNT Tasmania FROM table WHERE New South Wales = 190
# 10 / 2027 In what group stage were 177.2 points awarded? ['Rank', 'Member Association', 'Points', 'Group stage', 'Play-off', 'AFC Cup'] SELECT group stage FROM table WHERE points = 177.2 SELECT COUNT Group stage FROM table WHERE Points = 177.2
# 11 / 2027 If % mcconnell is 47.17% what is the total number of mcconnell ? ['County', 'Precincts', 'Lunsford', '% Lunsford', 'McConnell', '% McConnell', 'Total'] SELECT COUNT mcconnell FROM table WHERE mcconnell = 47.17% SELECT COUNT McConnell FROM table WHERE % McConnell = 47.17%
# 12 / 2027 1
# 13 / 2027 What's the standard of the country who won its first title in 1992? ['Country', 'Players', 'Standard', 'Minor', 'First title', 'Last title'] SELECT standard FROM table WHERE first title = 1992 SELECT MAX Standard FROM table WHERE First title = 1992
# 14 / 2027 What's the smallest number of players? ['Country', 'Players', 'Standard', 'Minor', 'First title', 'Last title'] SELECT * FROM table WHERE players = number of players SELECT MIN Players FROM table
# 15 / 2027 In what year was the last last title received, by any of the countries? ['Country', 'Players', 'Standard', 'Minor', 'First title', 'Last title'] SELECT * FROM table WHERE last title = last last title SELECT MAX Last title FROM table
# 16 / 2027 1
# 17 / 2027 What was the highest amount of people that attended the elgin city team? ['Team', 'Stadium', 'Capacity', 'Highest', 'Lowest', 'Average'] SELECT MAX highest FROM table WHERE team = elgin city SELECT COUNT Highest FROM table WHERE Team = Elgin City
# 18 / 2027 The firs park stadium had the lowest average attendence of what? ['Team', 'Stadium', 'Capacity', 'Highest', 'Lowest', 'Average'] SELECT * FROM table WHERE stadium = firs park stadium AND average = average attendence SELECT MIN Average FROM table WHERE Stadium = Firs Park
# 19 / 2027 What was the lowest highest attendance for the dumbarton team? ['Team', 'Stadium', 'Capacity', 'Highest', 'Lowest', 'Average'] SELECT * FROM table WHERE highest = attendance AND team = dumbarton SELECT MIN Highest FROM table WHERE Team = Dumbarton
# 20 / 2027 The gayfield park stadium had a highest attendance of what? ['Team', 'Stadium', 'Capacity', 'Highest', 'Lowest', 'Average'] SELECT * FROM table WHERE stadium = gayfield park stadium AND highest = attendance SELECT MAX Highest FROM table WHERE Stadium = Gayfield Park
# 21 / 2027 The stenhousemuir team had how many highest attendances? ['Team', 'Stadium', 'Capacity', 'Highest', 'Lowest', 'Average'] SELECT * FROM table WHERE team = stenhousemuir SELECT COUNT Highest FROM table WHERE Team = Stenhousemuir
# 22 / 2027 what is the minimum rank ['Rank', 'English title', 'Chinese title', 'Average', 'Peak', 'Premiere', 'Finale', 'HK viewers'] SELECT * FROM table SELECT MIN Rank FROM table
# 23 / 2027 What is Pittodrie Stadium's maximum capacity? ['Team', 'Stadium', 'Capacity', 'Lowest', 'Highest', 'Average'] SELECT MAX capacity FROM table WHERE stadium = Pittodrie Stadium SELECT MAX Capacity FROM table WHERE Stadium = Pittodrie
# 24 / 2027 What is the highest number of ties? ['Player', 'W-L (Total)', 'W-L ( Singles )', 'W-L ( Doubles )', 'Ties', 'Debut', 'Years Played'] SELECT MAX ties FROM table SELECT MAX Ties FROM table
# 25 / 2027 What was the # for the episode "the birthday present"? ['#', 'Episode', 'Air Date', 'Timeslot (EST)', 'Rating', 'Share', '18–49 Rating', 'Viewers (millions)', 'Rank'] SELECT MAX # FROM table WHERE episode = "the birthday present" SELECT MAX # FROM table WHERE Episode = The Birthday Present
# 26 / 2027 What was the # for the episode "the wedding"? ['#', 'Episode', 'Air Date', 'Timeslot (EST)', 'Rating', 'Share', '18–49 Rating', 'Viewers (millions)', 'Rank'] SELECT MAX # FROM table WHERE episode = "the wedding" SELECT MAX # FROM table WHERE Episode = The Wedding
# 27 / 2027 1
# 28 / 2027 1
# 29 / 2027 what is the total number of kickoff [a ] where week is week ['Week', 'Date', 'Opponent', 'Result', 'Kickoff [a ]', 'Game site', 'TV', 'Attendance', 'Record'] SELECT COUNT kickoff [a ] FROM table SELECT COUNT Kickoff [a ] FROM table WHERE Week = Week
# 30 / 2027 What is the power kw@RPM of the 13.180 model? ['Model', 'Engine make/Capacity', 'Power kW@rpm', 'Torque Nm@rpm', 'Transmission Make/Type/Speed', 'GVM (kg) Technical Capacity', 'GCM (kg) Technical Capacity'] SELECT power kw@RPM FROM table WHERE model = 13.180 SELECT COUNT Power kW@rpm FROM table WHERE Model = 13.180
# 31 / 2027 1
# 32 / 2027 What is the area (square km) where the arrondissement is millau? ['Dep.', 'Chief town', 'Arrondissement', 'Population (1999)', 'Area (Square km)', 'Pop density', 'Cantons', 'Communes'] SELECT area (square km) FROM table WHERE arrondissement = millau SELECT MIN Area (Square km) FROM table WHERE Arrondissement = Millau
# 33 / 2027 1
# 34 / 2027 How many communes when the arrondissement is cosne-cours-sur-loire? ['Dep.', 'Chief town', 'Arrondissement', 'Population (1999)', 'Area (Square km)', 'Pop density', 'Cantons', 'Communes'] SELECT communes FROM table WHERE arrondissement = cosne-cours-sur-loire SELECT MIN Communes FROM table WHERE Arrondissement = Cosne-Cours-sur-Loire
# 35 / 2027 1
# 36 / 2027 1
# 37 / 2027 What number (#) is associated with the Name Ron Baxter? ['Name', '#', 'Position', 'Height', 'Weight', 'Year', 'Home Town', 'High School'] SELECT * FROM table WHERE name = Ron Baxter SELECT COUNT # FROM table WHERE Name = Ron Baxter
# 38 / 2027 what is the minimum voted no where percent no is 56.6 ['Jurisdiction', 'Voted Yes', 'Percent Yes', 'Voted No', 'Percent No'] SELECT * FROM table WHERE percent no = 56.6 SELECT MIN Voted No FROM table WHERE Percent No = 56.6
# 39 / 2027 what is the minimum voted yes where percent no is 68.2 ['Jurisdiction', 'Voted Yes', 'Percent Yes', 'Voted No', 'Percent No'] SELECT * FROM table WHERE percent no = 68.2 SELECT MIN Voted Yes FROM table WHERE Percent No = 68.2
# 40 / 2027 1
# 41 / 2027 The earliest year is 1996. ['Year', 'Product', 'Production', 'Consumption', 'Import', 'Export'] SELECT * FROM table WHERE year = 1996 SELECT MIN Year FROM table
# 42 / 2027 1
# 43 / 2027 1
# 44 / 2027 1
# 45 / 2027 1
# 46 / 2027 What is the winners Share ($) in the year 2004? ['Year', 'Champion', 'Country', 'Score', 'Tournament location', 'Purse ($)', 'Winners share ($)'] SELECT * FROM table WHERE winners share ($) = winners Share ($) in AND year = 2004 SELECT MIN Winners share ($) FROM table WHERE Year = 2004
# 47 / 2027 What is the general classification with the winner being evgeni berzin? ['Stage', 'Winner', 'General classification', 'Points classification', 'Mountains classification', 'Intergiro classification', 'Trofeo Fast Team'] SELECT general classification FROM table WHERE winner = evgeni berzin SELECT COUNT General classification FROM table WHERE Winner = Evgeni Berzin
# 48 / 2027 How many season did sportfreunde siegen win best supported club? ['Season', 'Overall Spectators', 'Per game', 'Best supported Club', 'Spectators /game', 'Top goal scorer', 'Goals'] SELECT COUNT season FROM table WHERE season = sportfreunde siegen SELECT COUNT Season FROM table WHERE Best supported Club = Sportfreunde Siegen
# 49 / 2027 what is the minimum production code ['Season #', 'Series #', 'Title', 'Canadian airdate', 'U.S. airdate', 'Production code'] SELECT * FROM table SELECT MIN Production code FROM table
# 50 / 2027 When was the institution of Kansas city Kansas community college founded? ['Institution', 'Main Campus Location', 'Founded', 'Mascot', 'School Colors'] SELECT MAX founded FROM table WHERE founded = Kansas city Kansas community college SELECT COUNT Founded FROM table WHERE Institution = Kansas City Kansas Community College
# 51 / 2027 1
# 52 / 2027 1
# 53 / 2027 What is the number of the original airdate with the production code 208. ['Series Ep #', 'Season 2 Ep #', 'Title', 'Director', 'Writer(s)', 'Original Airdate', 'Production Code'] SELECT original airdate FROM table WHERE production code = 208 SELECT COUNT Original Airdate FROM table WHERE Production Code = 208
# 54 / 2027 What is the largest number of rounds for the team that hired Donnie Wingo as crew chief? ['Team', 'Car(s)', '#', 'Driver(s)', 'Primary Sponsor(s)', 'Owner(s)', 'Crew Chief', 'Rounds'] SELECT * FROM table WHERE crew chief = Donnie Wingo SELECT MAX Rounds FROM table WHERE Crew Chief = Donnie Wingo
# 55 / 2027 1
# 56 / 2027 How many tries for are for 473 points for? ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Tries for', 'Tries against', 'Try bonus', 'Losing bonus', 'Points'] SELECT tries for FROM table WHERE points = 473 SELECT COUNT Tries for FROM table WHERE Points for = 473
# 57 / 2027 1
# 58 / 2027 WHat is the number for the player whose height is 2.01? ['No', 'Player', 'Height', 'Position', 'Year born', 'Current Club'] SELECT * FROM table WHERE player = number AND height = 2.01 SELECT COUNT Player FROM table WHERE Height = 2.01
# 59 / 2027 What No is the player Zoran Erceg ['No', 'Player', 'Height', 'Position', 'Year born', 'Current Club'] SELECT No FROM table WHERE player = Zoran Erceg SELECT MIN No FROM table WHERE Player = Zoran Erceg
# 60 / 2027 What's the smallest number of bronze medals that any one if the ensembles has?  ['Ensemble', 'Gold Medals', 'Silver Medals', 'Bronze Medals', 'Total Medals'] SELECT * FROM table WHERE ensemble = bronze SELECT MIN Bronze Medals FROM table
# 61 / 2027 1
# 62 / 2027 1
# 63 / 2027 1
# 64 / 2027 1
# 65 / 2027 What year was incumbent jim ramstad first elected? ['District', 'Incumbent', 'Party', 'First elected', 'Results', 'Candidatess'] SELECT first elected FROM table WHERE first elected = jim ramstad SELECT MIN First elected FROM table WHERE Incumbent = Jim Ramstad
# 66 / 2027 When was the incumbent Sherrod Brown first elected?  ['District', 'Incumbent', 'Party', 'First elected', 'Results', 'Candidates'] SELECT first elected FROM table WHERE first elected = Sherrod Brown SELECT MAX First elected FROM table WHERE Incumbent = Sherrod Brown
# 67 / 2027 1
# 68 / 2027 What is the last year that someone is first elected in this table? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT MAX first elected FROM table SELECT MAX First elected FROM table
# 69 / 2027 1
# 70 / 2027 1
# 71 / 2027 1
# 72 / 2027 When was the Tennessee 3 district incumbent first elected?  ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT first elected FROM table WHERE district = Tennessee 3 SELECT MAX First elected FROM table WHERE District = Tennessee 3
# 73 / 2027 1
# 74 / 2027 1
# 75 / 2027 What is the last year on this list someone was first elected? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT MAX first elected FROM table SELECT MAX First elected FROM table
# 76 / 2027 1
# 77 / 2027 1
# 78 / 2027 When was incumbent John N. Tillman first elected? ['District', 'Incumbent', 'Party', 'First elected', 'Result', 'Candidates'] SELECT first elected FROM table WHERE first elected = John N. Tillman SELECT MIN First elected FROM table WHERE Incumbent = John N. Tillman
# 79 / 2027 what is the minimum total with kerry % being 16.71% ['County', 'Bush #', 'Bush %', 'Kerry #', 'Kerry %', 'Others #', 'Others %', 'Total'] SELECT * FROM table WHERE kerry % = 16.71% SELECT MIN Total FROM table WHERE Kerry % = 16.71%
# 80 / 2027 what is the minimum kerry # with bush % being 78.40% ['County', 'Bush #', 'Bush %', 'Kerry #', 'Kerry %', 'Others #', 'Others %', 'Total'] SELECT * FROM table WHERE bush % = 78.40% SELECT MIN Kerry # FROM table WHERE Bush % = 78.40%
# 81 / 2027 1
# 82 / 2027 what is the minimum bush # with kerry # being 3938 ['County', 'Bush #', 'Bush %', 'Kerry #', 'Kerry %', 'Others #', 'Others %', 'Total'] SELECT * FROM table WHERE kerry # = 3938 SELECT MIN Bush # FROM table WHERE Kerry # = 3938
# 83 / 2027 1
# 84 / 2027 How many different results came out of the round in which #98 All American Racers became the GTU winning team?  ['Rnd', 'Circuit', 'GTP Winning Team', 'GTO Winning Team', 'GTU Winning Team', 'Results'] SELECT * FROM table WHERE gtu winning team = #98 All American Racers SELECT COUNT Results FROM table WHERE GTU Winning Team = #98 All American Racers
# 85 / 2027 1
# 86 / 2027 1
# 87 / 2027 1
# 88 / 2027 1
# 89 / 2027 what is the minimum district with incumbent being tom reynolds ['District', 'Incumbent', 'Party', 'Elected', 'Status', 'Opponent'] SELECT * FROM table WHERE incumbent = tom reynolds SELECT MIN District FROM table WHERE Incumbent = Tom Reynolds
# 90 / 2027 what is the minimum average with highest being 2363 ['Team', 'Stadium', 'Capacity', 'Highest', 'Lowest', 'Average'] SELECT * FROM table WHERE highest = 2363 SELECT MIN Average FROM table WHERE Highest = 2363
# 91 / 2027 what is the minimum lowest with highest being 2363 ['Team', 'Stadium', 'Capacity', 'Highest', 'Lowest', 'Average'] SELECT * FROM table WHERE highest = 2363 SELECT MIN Lowest FROM table WHERE Highest = 2363
# 92 / 2027 What's the tries against count of the team with 396 points against?  ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Tries for', 'Tries against', 'Try bonus', 'Losing bonus', 'Points'] SELECT tries against FROM table WHERE points against = 396 SELECT COUNT Tries against FROM table WHERE Points against = 396
# 93 / 2027 How many home losses occured when PF 13? ['Num', 'Team', 'W', 'L', 'PCT', 'PF', 'PA', 'Last appearance', 'Last championship', 'HOME games', 'Home wins', 'Home losses', 'Home Win Pct.', 'ROAD games', 'Road wins', 'Road losses', 'Road Win Pct.'] SELECT * FROM table WHERE l = home AND pf = PF 13 SELECT COUNT Home losses FROM table WHERE PF = 13
# 94 / 2027 what is the minimum attendance with stadium being cotton bowl ['Week', 'Date', 'Opponent', 'Result', 'Stadium', 'Record', 'Attendance'] SELECT * FROM table WHERE stadium = cotton bowl SELECT MIN Attendance FROM table WHERE Stadium = Cotton Bowl
# 95 / 2027 1
# 96 / 2027 what is the minimum attendance with record being 4–6 ['Week', 'Date', 'Opponent', 'Result', 'Stadium', 'Record', 'Attendance'] SELECT * FROM table WHERE record = 4–6 SELECT MIN Attendance FROM table WHERE Record = 4–6
# 97 / 2027 1
# 98 / 2027 what is the minimum population with canton being redange ['Map Key', 'Commune', 'Canton', 'District', 'Population'] SELECT * FROM table WHERE canton = redange SELECT MIN Population FROM table WHERE Canton = Redange
# 99 / 2027 1
# 100 / 2027 When the % of boundary by water is 63% what is the overall number of zip code prefix(es)? ['IN No.', 'County Name', 'Establishment Date (SW Indiana) (History) (Statehood)', 'County Seat', 'Time Zone', 'Population (2010) (Rank)', 'Area sq mi (km 2 ) (Rank)', 'Twps', 'ZIP code Prefix(es)', '% of Boundary by water'] SELECT * FROM table WHERE % of boundary by water = zip code SELECT COUNT ZIP code Prefix(es) FROM table WHERE % of Boundary by water = 63%
# 101 / 2027 1
# 102 / 2027 How many total smartphones were shipped during the quarter 2012 Q1? ['Quarter', 'Android', 'iOS', 'Symbian', 'BlackBerry OS', 'Linux', 'Windows Phone', 'Other', 'Total'] SELECT * FROM table WHERE quarter = 2012 Q1 SELECT COUNT Total FROM table WHERE Quarter = 2012 Q1
# 103 / 2027 How man "other" millions of smartphones were shipped when 181.1 million total were shipped? ['Quarter', 'Android', 'iOS', 'Symbian', 'BlackBerry OS', 'Linux', 'Windows Phone', 'Other', 'Total'] SELECT other FROM table WHERE total = 181.1 SELECT COUNT Other FROM table WHERE Total = 181.1
# 104 / 2027 What was the most extra points? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT MAX extra points FROM table SELECT MAX Extra points FROM table
# 105 / 2027 1
# 106 / 2027 1
# 107 / 2027 What is the least amount of field goals made by a player? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT * FROM table SELECT MIN Field goals FROM table
# 108 / 2027 What is the least amount of extra points made in by a player? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT * FROM table SELECT MIN Extra points FROM table
# 109 / 2027 what is the maximum number of points? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT MAX points FROM table SELECT MAX Points FROM table
# 110 / 2027 What is the highest number of extra points? ['Player', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT MAX extra points FROM table SELECT MAX Extra points FROM table
# 111 / 2027 How many field goals were made by someone playing position of right end? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT MAX field goals FROM table WHERE position = right end SELECT COUNT Field goals FROM table WHERE Position = Right end
# 112 / 2027 How many points were scored by someone who's position was right tackle? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT points FROM table WHERE position = right tackle SELECT COUNT Points FROM table WHERE Position = Right tackle
# 113 / 2027 What is the least amount of touchdowns scored on the chart? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT * FROM table SELECT MIN Touchdowns FROM table
# 114 / 2027 How many touchdowns were scored by players who scored more than 5.0 extra points? ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT SUM touchdowns FROM table WHERE extra points = 5.0 SELECT COUNT Touchdowns FROM table WHERE Extra points > 5.0
# 115 / 2027 What is the lowest amount of field goals on the chart?  ['Player', 'Position', 'Starter', 'Touchdowns', 'Extra points', 'Field goals', 'Points'] SELECT * FROM table SELECT MIN Field goals FROM table
# 116 / 2027 Name the total number of date of vacancy for manner of departure being resigned and outgoing manager is geninho ['Team', 'Outgoing manager', 'Manner of departure', 'Date of vacancy', 'Last match', 'Replaced by'] SELECT COUNT date of vacancy FROM table WHERE outgoing manager = geninho SELECT COUNT Date of vacancy FROM table WHERE Manner of departure = Resigned AND Outgoing manager = Geninho
# 117 / 2027 1
# 118 / 2027 What is the data point for s hindu where the buddhist data point is 73.0%? ['Composition', 's Hindu', 's Muslim', 'Christians', 's Sikh', 'Buddhist', 's Jain', 'Others'] SELECT s hindu FROM table WHERE s hindu = data point AND buddhist = 73.0% SELECT COUNT s Hindu FROM table WHERE Buddhist = 73.0%
# 119 / 2027 What is the highest score of round 1 where they also shot 90 in round 2 ['Place', 'Shooter', 'Total', 'Round 1', 'Round 2', 'Round 3', 'Round 4', 'Round 5', 'Round 6'] SELECT * FROM table WHERE round 2 = 90 SELECT MAX Round 1 FROM table WHERE Round 2 = 90
# 120 / 2027 At maximum, what are our goals? ['Season', 'Champions (Premier League titles)', 'Runners-up', 'Third place', 'Player(s) (Club)', 'Goals'] SELECT MAX goals FROM table SELECT MAX Goals FROM table
# 121 / 2027 What is the minimum stolen ends for the locale Alberta? ['Locale', 'Skip', 'W', 'L', 'PF', 'PA', 'Ends Won', 'Ends Lost', 'Blank Ends', 'Stolen Ends', 'Shot Pct.'] SELECT * FROM table WHERE l = Alberta SELECT MIN Stolen Ends FROM table WHERE Locale = Alberta
# 122 / 2027 1
# 123 / 2027 1
# 124 / 2027 1
# 125 / 2027 Name the least spirou ['Title (pages)', 'Spirou', 'Writer / Artist', '1st publication, Belgium', 'Integrale'] SELECT * FROM table SELECT MIN Spirou FROM table
# 126 / 2027 Name the least attendance ['Tie No.', 'Home team', 'Score', 'Away team', 'Report', 'Attendance'] SELECT * FROM table SELECT MIN Attendance FROM table
# 127 / 2027 What is the voltage range (v) if the clock multiplier is 3x or 2x mode and part number is a80486dx4wb-100? ['Processor Speed (MHz)', 'Input Clock (MHz)', 'Voltage Center (V)', 'Voltage Range (V)', 'Part Number', 'Clock Multiplier', 'S-Spec Number'] SELECT voltage range (v) FROM table WHERE clock multiplier = 3x or 2x mode AND part number = a80486dx4wb-100 SELECT COUNT Voltage Range (V) FROM table WHERE Clock Multiplier = 3X or 2X mode AND Part Number = A80486DX4WB-100
# 128 / 2027 What is the processor speed (mhz) for part number a80486dx4-75? ['Processor Speed (MHz)', 'Input Clock (MHz)', 'Voltage Center (V)', 'Voltage Range (V)', 'Part Number', 'Clock Multiplier', 'S-Spec Number'] SELECT processor speed (mhz) FROM table WHERE part number = a80486dx4-75 SELECT COUNT Processor Speed (MHz) FROM table WHERE Part Number = A80486DX4-75
# 129 / 2027 What is the least amount of league of communists where municipality is mojkovac ['Municipality', 'League of Communists', 'Peoples Party', 'Union of Reform Forces', 'Democratic Coalition', 'DSSP', 'Total seats'] SELECT * FROM table WHERE municipality = mojkovac SELECT MIN League of Communists FROM table WHERE Municipality = Mojkovac
# 130 / 2027 1
# 131 / 2027 Name the most wins ['Year', 'Class', 'Team name', 'Bike', 'Riders', 'Races', 'Wins', 'Podiums', 'Poles', 'F.laps', 'Points', 'Pos.'] SELECT * FROM table SELECT MIN Wins FROM table
# 132 / 2027 What's the biggest zone? ['Station', 'Year opened', 'Metropolitan borough [c ]', 'Zone', 'Servedby Route maps:- [ dead link ] [ dead link ]', 'Station users 2006–07', 'Station users 2007–08'] SELECT MAX zone FROM table SELECT MAX Zone FROM table
# 133 / 2027 What is the minimum number of wins? ['Year', 'Events played', 'Cuts made', 'Wins', '2nds', 'Top 10s', 'Best finish', 'Earnings ($)', 'Rank', 'Scoring average', 'Scoring rank'] SELECT * FROM table SELECT MIN Wins FROM table
# 134 / 2027 Name the points for where lost is 4 ['Club', 'Played', 'Won', 'Drawn', 'Lost', 'Points for', 'Points against', 'Tries For', 'Tries Against', 'Try Bonus', 'Losing Bonus', 'Points'] SELECT points for FROM table WHERE lost = 4 SELECT COUNT Points for FROM table WHERE Lost = 4
# 135 / 2027 Name the most number of s eva ['Mission name', 'Lunar lander', 'Lunar landing date', 'Lunar blastoff date', 'Lunar landing site', 'Duration on lunar surface', 'Crew', 'Number of s EVA', 'Total EVA Time (HH:MM)'] SELECT * FROM table SELECT MAX Number of s EVA FROM table
# 136 / 2027 Name the most number of s eva ['Mission name', 'Lunar lander', 'Lunar landing date', 'Lunar blastoff date', 'Lunar landing site', 'Duration on lunar surface', 'Crew', 'Number of s EVA', 'Total EVA Time (HH:MM)'] SELECT * FROM table SELECT MAX Number of s EVA FROM table
# 137 / 2027 What is the fleet size of the airline which has a callsign of cool red? ['Airline', 'ICAO', 'IATA', 'Callsign', 'Commenced operations', 'Fleet size', 'Headquarters'] SELECT fleet size FROM table WHERE callsign = cool red SELECT MIN Fleet size FROM table WHERE Callsign = COOL RED
# 138 / 2027 How large is the fleet size of the airline with the IATA code of 5j? ['Airline', 'ICAO', 'IATA', 'Callsign', 'Commenced operations', 'Fleet size', 'Headquarters'] SELECT fleet size FROM table WHERE iata = 5j SELECT COUNT Fleet size FROM table WHERE IATA = 5J
# 139 / 2027 Name the msot episode that was adapted by leon griffiths ['Episode', 'Title', 'Story', 'Adapted by', 'Director', 'Airdate', 'Exists?'] SELECT * FROM table WHERE episode = msot episode AND adapted by = leon griffiths SELECT MAX Episode FROM table WHERE Adapted by = Leon Griffiths
# 140 / 2027 Name the least road wins ['Num', 'Team', 'W', 'L', 'PCT', 'PF', 'PA', 'Last appearance', 'Last championship', 'HOME games', 'Home wins', 'Home losses', 'Home Win Pct.', 'ROAD games', 'Road wins', 'Road losses', 'Road Win Pct.'] SELECT * FROM table SELECT MIN Road wins FROM table
# 141 / 2027 Name the road wins ['Num', 'Team', 'W', 'L', 'PCT', 'PF', 'PA', 'Last appearance', 'Last championship', 'HOME games', 'Home wins', 'Home losses', 'Home Win Pct.', 'ROAD games', 'Road wins', 'Road losses', 'Road Win Pct.'] SELECT road wins FROM table SELECT MIN Road wins FROM table
# 142 / 2027 1
# 143 / 2027 1
# 144 / 2027 How many stations are transmitted on frequency 7 uhf? ['Television Station', 'Frequency', 'Site', 'Transmitted', 'Network', 'Status', 'Country of Region'] SELECT * FROM table WHERE frequency = 7 uhf SELECT COUNT Transmitted FROM table WHERE Frequency = 7 UHF
# 145 / 2027 What is the fewest number of games played? ['Position', 'Club', 'Games played', 'Wins', 'Draws', 'Loses', 'Goals scored', 'Goals conceded', 'Points'] SELECT * FROM table SELECT MIN Games played FROM table
# 146 / 2027 How many times was the incumbent elected in Washington 4 district? ['District', 'Incumbent', 'Party', 'Elected', 'Status', '2008 Candidates', 'Results'] SELECT * FROM table WHERE district = Washington 4 SELECT COUNT Elected FROM table WHERE District = Washington 4
# 147 / 2027 What is the highest number of Counties carries? ['Candidate', 'State Delegate', 'Percentage', 'Delegates', 'Counties Carries'] SELECT MAX Counties carries FROM table SELECT MAX Counties Carries FROM table
# 148 / 2027 Name the least established ['University', 'Location', 'Established', 'Endowment as of 2008', 'Campus Area (acres)', 'Kiplingers Top 100 Values', 'Enrollment as of 2008'] SELECT * FROM table SELECT MIN Established FROM table
# 149 / 2027 1
# 150 / 2027 If 65 to 69 is 2417, what is the minimum of 25 to 29? ['C/W 15+', 'Oblast\\Age', '15 to 17', '18 to 19', '20 to 24', '25 to 29', '30 to 34', '35 to 39', '40 to 44', '45 to 49', '50 to 54', '55 to 59', '60 to 64', '65 to 69', '70+'] SELECT * FROM table WHERE 65 to 69 = 2417 SELECT MIN 25 to 29 FROM table WHERE 65 to 69 = 2417
# 151 / 2027 What is the minimum of 25 to 29? ['C/W 15+', 'Oblast\\Age', '15 to 17', '18 to 19', '20 to 24', '25 to 29', '30 to 34', '35 to 39', '40 to 44', '45 to 49', '50 to 54', '55 to 59', '60 to 64', '65 to 69', '70+'] SELECT * FROM table SELECT MIN 25 to 29 FROM table
# 152 / 2027 What is the minimum if 40 to 44? ['C/W 15+', 'Oblast\\Age', '15 to 17', '18 to 19', '20 to 24', '25 to 29', '30 to 34', '35 to 39', '40 to 44', '45 to 49', '50 to 54', '55 to 59', '60 to 64', '65 to 69', '70+'] SELECT * FROM table SELECT MIN 40 to 44 FROM table
# 153 / 2027 1
# 154 / 2027 How many numbers were recorde under 50s when there was 2 matches? ['Player', 'Team', 'Matches', 'Innings', 'Runs', 'Average', 'Highest Score', '100s', '50s'] SELECT * FROM table WHERE matches = 2 SELECT COUNT 50s FROM table WHERE Matches = 2
# 155 / 2027 What is the highest number of matches? ['Player', 'Team', 'Matches', 'Innings', 'Runs', 'Average', 'Highest Score', '100s', '50s'] SELECT MAX matches FROM table SELECT MAX Matches FROM table
# 156 / 2027 1
# 157 / 2027 1
# 158 / 2027 At 1:48.16 what was the number of track time? ['Finish', 'Race', 'Distance', 'Jockey', 'Time', 'Victory Margin (in lengths)', 'Runner up', 'Track', 'Surface', 'Date'] SELECT * FROM table WHERE track = track time SELECT COUNT Track FROM table WHERE Time = 1:48.16
# 159 / 2027 what is the attendance where the game site is kingdome? ['Week', 'Date', 'Opponent', 'Result', 'Game site', 'Record', 'Attendance'] SELECT attendance FROM table WHERE game site = kingdome SELECT MIN Attendance FROM table WHERE Game site = Kingdome
# 160 / 2027 1
# 161 / 2027 What is the minimum number of bypass ports listed? ['Engine', 'Exhaust Ports', 'Bypass Ports', 'Bypass Boosters', 'SPI', 'Tapered Grind', 'Number on cyl.'] SELECT * FROM table SELECT MIN Bypass Ports FROM table
# 162 / 2027 How many points were made in game 70? ['Game', 'Date', 'Opponent', 'Score', 'Location', 'Attendance', 'Record', 'Points'] SELECT * FROM table WHERE game = 70 SELECT COUNT Points FROM table WHERE Game = 70
# 163 / 2027 1
# 164 / 2027 Name the least votes for percent yes for 57.2 ['Constituency', 'Electorate', 'Votes', 'Turnout', 'Yes', 'No', 'Spoilt', 'Percent Yes'] SELECT * FROM table WHERE percent yes = 57.2 SELECT MIN Votes FROM table WHERE Percent Yes = 57.2
# 165 / 2027 1
# 166 / 2027 Name the most poles ['Year', 'Starts', 'Wins', 'Top 5', 'Top 10', 'Poles', 'Avg. Start', 'Avg. Finish', 'Winnings', 'Position', 'Team(s)'] SELECT MAX poles FROM table SELECT MIN Poles FROM table
# 167 / 2027 At census ranking 1,184 of 5,008, what was the minimum population? ['Official Name', 'Status', 'Area km 2', 'Population', 'Census Ranking'] SELECT * FROM table WHERE census ranking = 1,184 of 5,008 SELECT MIN Population FROM table WHERE Census Ranking = 1,184 of 5,008
# 168 / 2027 1
# 169 / 2027 Which game number had a location/attendance of US Airways Center 7,311 respectively? ['Game', 'Date', 'Opponent', 'Score', 'High points', 'High rebounds', 'High assists', 'Location/Attendance', 'Record'] SELECT * FROM table WHERE location/attendance = US Airways Center 7,311 SELECT MAX Game FROM table WHERE Location/Attendance = US Airways Center 7,311
# 170 / 2027 1
# 171 / 2027 1
# 172 / 2027 1
# 173 / 2027 What is the lowest game number when the team is Houston?  ['Game', 'Date', 'Team', 'Score', 'High points', 'High rebounds', 'High assists', 'Location Attendance', 'Record'] SELECT * FROM table WHERE team = Houston SELECT MIN Game FROM table WHERE Team = Houston
# 174 / 2027 1
# 175 / 2027 1
# 176 / 2027 What is the airport with the IATA MEL? ['Rank', 'Airport', 'Location', 'IATA', '1985–86', '1990–91', '1995–96', '2000–01', '2005–06', '2007–08', '2009–10', '2010-11'] SELECT airport FROM table WHERE iata = MEL SELECT COUNT Airport FROM table WHERE IATA = MEL
# 177 / 2027 If two years is 159, what is the amount for one year? ['Year', 'Total', 'Less than a year', 'One year', 'Two years', 'Three years', 'Four years', '5–9 years', '10–14 years', '15–19 years', '20–24 years', '25 and more', 'Unknown'] SELECT one year FROM table WHERE two years = 159 SELECT MIN One year FROM table WHERE Two years = 159
# 178 / 2027 What is the largest number of holding companies? ['COMPANY NAME', 'Holding Companies', 'Subsidiaries', 'Description of activities', 'Parent (holding) company'] SELECT * FROM table WHERE holding companies = number of holding companies SELECT MAX Holding Companies FROM table
# 179 / 2027 Name the total number of league for 5 ['Player', 'League', 'Scottish Cup', 'League Cup', 'Challenge Cup', 'Total'] SELECT COUNT league FROM table WHERE league = 5 SELECT COUNT League FROM table WHERE Total = 5
# 180 / 2027 Name the number of duration for viewership of 5.46 million ['Episode', 'Original title', 'Directed by', 'Written by', 'Original airdate', 'Duration', 'Viewership'] SELECT COUNT duration FROM table WHERE viewership = 5.46 SELECT COUNT Duration FROM table WHERE Viewership = 5.46 million
# 181 / 2027 1
# 182 / 2027 What is the lowest no. in series? ['No. in series', 'No. in season', 'Title', 'Directed by', 'Written by', 'Original air date', 'U.S. viewers (millions)'] SELECT * FROM table SELECT MIN No. in series FROM table
# 183 / 2027 1
# 184 / 2027 How many 'number of seasons in top division' were played if the 'first season in top division' games is in 1990-91? ['Club', 'First season in top division', 'Number of seasons in top division', 'First season of current spell in top division', 'Number of seasons in Liga MX', 'Top division titles'] SELECT COUNT number of seasons in top division FROM table WHERE first season in top division = 1990-91 SELECT MAX Number of seasons in top division FROM table WHERE First season in top division = 1990-91
# 185 / 2027 which episode was Transmitted on wednesday if the episode of "319 sucker punch" was transmitted on tuesday?  ['Episodes', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] SELECT wednesday FROM table WHERE wednesday = "319 sucker punch" SELECT COUNT Wednesday FROM table WHERE Tuesday = 319 Sucker Punch
# 186 / 2027 1
# 187 / 2027 When koki mizuno is the player what is the lowest league cup? ['P', 'Player', 'Position', 'SPL', 'League Cup', 'Scottish Cup', 'UEFA Champions League', 'Total'] SELECT * FROM table WHERE player = koki mizuno SELECT MIN League Cup FROM table WHERE Player = Koki Mizuno
# 188 / 2027 When "to live and die in brentwood" is the title what is the largest production code? ['No. in series', 'No. in season', 'Title', 'Directed by', 'Written by', 'Original air date', 'Production code'] SELECT MAX production code FROM table WHERE title = "to live and die in brentwood" SELECT MAX Production code FROM table WHERE Title = To Live and Die in Brentwood
# 189 / 2027 Name the most ending with ['Sl no', 'Name of the prabandham', 'Starting from', 'Ending with', 'Number of pasurams', 'Sung by'] SELECT * FROM table SELECT MAX Ending with FROM table
# 190 / 2027 When the ability to compromise is 13, what is background? ['Seq.', 'Name', 'Background', 'Party Leadership', 'Communication Ability', 'Relations with Congress', 'Court Appointments', 'Handling of Economy', 'Luck', 'Ability to Compromise', 'Willing to take Risks', 'Executive Appointments', 'Overall Ability', 'Imagination', 'Domestic Accomplishments', 'Integrity', 'Executive Ability', 'Foreign Policy Accomplishments', 'Leadership Ability', 'Intelligence', 'Avoid Crucial Mistakes', 'Experts View', 'Overall'] SELECT background FROM table WHERE ability to compromise = 13 SELECT MAX Background FROM table WHERE Ability to Compromise = 13
# 191 / 2027 When 25 are willing to take risks, what is the experts view? ['Seq.', 'Name', 'Background', 'Party Leadership', 'Communication Ability', 'Relations with Congress', 'Court Appointments', 'Handling of Economy', 'Luck', 'Ability to Compromise', 'Willing to take Risks', 'Executive Appointments', 'Overall Ability', 'Imagination', 'Domestic Accomplishments', 'Integrity', 'Executive Ability', 'Foreign Policy Accomplishments', 'Leadership Ability', 'Intelligence', 'Avoid Crucial Mistakes', 'Experts View', 'Overall'] SELECT experts view FROM table WHERE willing to take risks = 25 SELECT MIN Experts View FROM table WHERE Willing to take Risks = 25
# 192 / 2027 What was the position of the Atl. Colegiales team? ['Position', 'Team', 'Played', 'Wins', 'Draws', 'Losses', 'Scored', 'Conceded', 'Points'] SELECT position FROM table WHERE team = Atl. Colegiales SELECT MAX Position FROM table WHERE Team = Atl. Colegiales
# 193 / 2027 What was the position where the team scored 9 points? ['Position', 'Team', 'Played', 'Wins', 'Draws', 'Losses', 'Scored', 'Conceded', 'Points'] SELECT AVG position FROM table WHERE points = 9 SELECT COUNT Position FROM table WHERE Points = 9
# 194 / 2027 If the longitude is -97.473110, what is the minimum geo id? ['Township', 'County', 'Pop. (2010)', 'Land ( sqmi )', 'Water (sqmi)', 'Latitude', 'Longitude', 'GEO ID', 'ANSI code'] SELECT * FROM table WHERE longitude = -97.473110 SELECT MIN GEO ID FROM table WHERE Longitude = -97.473110
# 195 / 2027 1
# 196 / 2027 When 2011 is the period and olympikus is the kit manufacturer how many minor sponsors are there? ['Period', 'Kit manufacturer', 'Main sponsor', 'Secondary sponsor', 'Minor sponsors'] SELECT COUNT minor sponsors FROM table WHERE period = olympikus SELECT COUNT Minor sponsors FROM table WHERE Kit manufacturer = Olympikus AND Period = 2011
# 197 / 2027 What was the minimum score for r2? ['Player', 'Country', 'Year(s) won', 'R1', 'R2', 'R3', 'R4', 'Total', 'To par', 'Finish'] SELECT * FROM table WHERE r2 = score SELECT MIN R2 FROM table
# 198 / 2027 If the PCT is 0.514, what was the minimum OTL? ['Season', 'League', 'Division', 'GP', 'W', 'L', 'T', 'OTL', 'SOL', 'Pts', 'PCT', 'GF', 'GA', 'PIM', 'Coach(es)', 'Result'] SELECT * FROM table WHERE w = 0.514 SELECT MIN OTL FROM table WHERE PCT = 0.514
# 199 / 2027 What was the minimum OTL amount? ['Season', 'League', 'Division', 'GP', 'W', 'L', 'T', 'OTL', 'SOL', 'Pts', 'PCT', 'GF', 'GA', 'PIM', 'Coach(es)', 'Result'] SELECT * FROM table SELECT MIN OTL FROM table
# 200 / 2027 Name the number of events for reset points being 98625 ['#', 'Player', 'Country', 'Points', 'Events', 'Reset Points'] SELECT COUNT events FROM table WHERE points = 98625 SELECT COUNT Events FROM table WHERE Reset Points = 98625
# 201 / 2027 What is the used (kb) when the graphics mode is 4? ['Graphics mode', 'Char cells', 'Pixels', 'Hardware colours', 'used (KB)', 'map', 'Type'] SELECT used (kb) FROM table WHERE graphics mode = 4 SELECT MIN used (KB) FROM table WHERE Graphics mode = 4
# 202 / 2027 What is the smallest converted value at number 19? ['Number', 'Previous Number(s)', 'Previous Class', 'Converted', 'Use', 'Withdrawn', 'Disposal'] SELECT * FROM table WHERE number = 19 SELECT MIN Converted FROM table WHERE Number = 19
# 203 / 2027 How much is the other black population when the black African population is 37811? ['Rank', 'London Borough', 'Black African Population', 'Black Caribbean Population', 'Other Black Population', 'Total Black Population'] SELECT * FROM table WHERE black african population = 37811 SELECT MIN Other Black Population FROM table WHERE Black African Population = 37811
# 204 / 2027 What is the black caribbean population when the other black population is 2243? ['Rank', 'London Borough', 'Black African Population', 'Black Caribbean Population', 'Other Black Population', 'Total Black Population'] SELECT * FROM table WHERE other black population = 2243 SELECT MAX Black Caribbean Population FROM table WHERE Other Black Population = 2243
# 205 / 2027 What is the black caribbean population when the black African population is less than 10552.0? ['Rank', 'London Borough', 'Black African Population', 'Black Caribbean Population', 'Other Black Population', 'Total Black Population'] SELECT * FROM table WHERE black african population = 10552.0 SELECT MIN Black Caribbean Population FROM table WHERE Black African Population < 10552.0
# 206 / 2027 What is the highest no.? ['Pos', 'No', 'Driver', 'Constructor', 'Q1 order', 'Q1 time', 'Q1 pos', 'Q1+Q2 time'] SELECT * FROM table WHERE no = no. SELECT MAX No FROM table
# 207 / 2027 1
# 208 / 2027 1
# 209 / 2027 What is the smallest 8-car sets if 4-car sets is 47? ['Fiscal year', '2-car sets', '4-car sets', '6-car sets', '8-car sets', 'Total vehicles'] SELECT * FROM table WHERE 4-car sets = 47 SELECT MIN 8-car sets FROM table WHERE 4-car sets = 47
# 210 / 2027 What is the lowest fiscal year if total vehicles is 490? ['Fiscal year', '2-car sets', '4-car sets', '6-car sets', '8-car sets', 'Total vehicles'] SELECT * FROM table WHERE total vehicles = 490 SELECT MIN Fiscal year FROM table WHERE Total vehicles = 490
# 211 / 2027 Name the least recognised seats ['Discipline', 'Degree/Diploma', 'Total Seats', 'Recognised Seats', 'Permitted Seats'] SELECT * FROM table SELECT MIN Recognised Seats FROM table
# 212 / 2027 What is the smallest number of fastest laps listed? ['Name', 'Nation', 'Seasons', 'Championship Titles', 'Race Starts', 'Poles', 'Wins', 'Podiums', 'Fastest Laps'] SELECT * FROM table SELECT MIN Fastest Laps FROM table
# 213 / 2027 1
# 214 / 2027 What is the province amount if the % 2011 is 0.0% ['Province', 'Arabs 2001', '% 2001', 'Arabs 2011', '% 2011'] SELECT province FROM table WHERE % 2011 = 0.0% SELECT COUNT Province FROM table WHERE % 2011 = 0.0%
# 215 / 2027 1
# 216 / 2027 How many afc titles were there when there were 2 super bowl wins? ['Teams With Division Titles', 'Division Championships', 'Playoff Berths', 'AFC Titles', 'Super Bowl Wins'] SELECT afc titles FROM table WHERE super bowl wins = 2 SELECT MAX AFC Titles FROM table WHERE Super Bowl Wins = 2
# 217 / 2027 1
# 218 / 2027 How many different actors from the Second national tour year 2 played the character played by Oliver Tompsett from the original West End cast? ['Role', 'Original Broadway Cast', 'Current Broadway Cast', 'Original Toronto Cast', 'First National Tour Cast', 'Original Australian Cast', 'Original West End Cast', 'Current West End Cast', 'Second National Tour Cast', 'Second National Tour Year 2'] SELECT * FROM table WHERE original west end cast = Oliver Tompsett SELECT COUNT Second National Tour Year 2 FROM table WHERE Original West End Cast = Oliver Tompsett
# 219 / 2027 What is the highest overall number one(s)? ['Number One(s)', 'Artist(s)', 'Song(s) — Weeks', 'Issue Years', 'Whole Weeks'] SELECT MAX number one(s) FROM table WHERE number one(s) = overall SELECT MAX Number One(s) FROM table
# 220 / 2027 What is the latest founded year? ['Institution', 'Location', 'Founded', 'Type', 'Enrollment', 'Nickname', 'Joined', 'Left', 'Current Conference'] SELECT MAX founded FROM table SELECT MAX Founded FROM table
# 221 / 2027 What is the smallest enrollment for institutions founded in exactly 1880? ['Institution', 'Location', 'Nickname', 'Founded', 'Type', 'Enrollment', 'Joined', 'Current Conference'] SELECT * FROM table WHERE founded = 1880 SELECT MIN Enrollment FROM table WHERE Founded = 1880
# 222 / 2027 What is the lowest rank? ['Rank', 'Couple', 'Judges', 'Public', 'Total', 'Vote percentage', 'Result'] SELECT * FROM table SELECT MIN Rank FROM table
# 223 / 2027 Name the most # of seats won ['Election', '# of candidates nominated', '# of seats won', '# of total votes', '% of popular vote', 'result'] SELECT MAX # of seats won FROM table SELECT MAX # of seats won FROM table
# 224 / 2027 When was the Australian open? ['#', 'Player', 'Age', 'Australian Open', 'French Open', 'Wimbledon', 'US Open'] SELECT Australian open FROM table SELECT MAX Australian Open FROM table
# 225 / 2027 When is the French Open when serena williams is the player? ['#', 'Player', 'Age', 'Australian Open', 'French Open', 'Wimbledon', 'US Open'] SELECT French Open FROM table WHERE french open = serena williams SELECT MIN French Open FROM table WHERE Player = Serena Williams
# 226 / 2027 how many dismissals in a game with 191 innings ['Rank', 'Dismissals', 'Player', 'Caught', 'Stumped', 'Matches', 'Innings'] SELECT dismissals FROM table WHERE innings = 191 SELECT COUNT Dismissals FROM table WHERE Innings = 191
# 227 / 2027 What is the highest value for map number? ['Map number', 'English name', 'Finnish name', 'Swedish name', 'Residence city', 'Dates of existence', 'Notes'] SELECT MAX map number FROM table SELECT MAX Map number FROM table
# 228 / 2027 1
# 229 / 2027 What's the highest division number through the years? ['Year', 'Division', 'League', 'Regular Season', 'Playoffs', 'Open Cup'] SELECT MAX division FROM table SELECT MAX Division FROM table
# 230 / 2027 What is the earliest year where playoffs was "did not qualify," regular season was "2nd, New England," and Open Canada Cup is "N/A"? ['Year', 'Division', 'League', 'Regular Season', 'Playoffs', 'Open Canada Cup'] SELECT * FROM table WHERE regular season = 2nd, New England AND open canada cup = N/A SELECT MIN Year FROM table WHERE Playoffs = Did not qualify AND Regular Season = 2nd, New England AND Open Canada Cup = N/A
# 231 / 2027 1
# 232 / 2027 where stanier, 2 cylinder is 43, what is the stanier, 3 cylinder ['Year', 'Fowler', 'Stanier, 3 cylinder', 'Stanier, 2 cylinder', 'Fairburn', 'BR Standard', 'Total'] SELECT * FROM table WHERE stanier, 2 cylinder = 3 cylinder AND stanier, 3 cylinder = stanier SELECT COUNT Stanier, 3 cylinder FROM table WHERE Stanier, 2 cylinder = 43
# 233 / 2027 1
# 234 / 2027 How many poles had 78 points? ['Season', 'Series', 'Team', 'Races', 'Wins', 'Poles', 'F/Laps', 'Podiums', 'Points', 'Position'] SELECT * FROM table WHERE points = 78 SELECT COUNT Poles FROM table WHERE Points = 78
# 235 / 2027 How many poles had 72 points? ['Season', 'Series', 'Team', 'Races', 'Wins', 'Poles', 'F/Laps', 'Podiums', 'Points', 'Position'] SELECT * FROM table WHERE points = 72 SELECT COUNT Poles FROM table WHERE Points = 72
# 236 / 2027 What is the Obama# when McCain% is 64.4%? ['County', 'Obama%', 'Obama#', 'McCain%', 'McCain#', 'Others%', 'Others#'] SELECT * FROM table WHERE mccain% = 64.4% SELECT MAX Obama# FROM table WHERE McCain% = 64.4%
# 237 / 2027 1
# 238 / 2027 What is the round? ['Round', 'Choice', 'Player', 'Position', 'Height', 'Weight', 'College'] SELECT COUNT round FROM table SELECT MIN Round FROM table
# 239 / 2027 What is the height of the cornerback position? ['Round', 'Choice', 'Player', 'Position', 'Height', 'Weight', 'College'] SELECT height FROM table WHERE position = cornerback SELECT COUNT Height FROM table WHERE Position = Cornerback
# 240 / 2027 What is the most recent year joined? ['Institution', 'Location', 'Year Joined', 'Affiliation', 'Enrollment', 'Mascot', 'Colors'] SELECT MAX year joined FROM table SELECT MAX Year Joined FROM table
# 241 / 2027 what is the lowest value under the column series no.? ['Episode No.', 'Series No.', 'Title', 'Directed by', 'Written by', 'Viewers (millions)', 'Original airdate'] SELECT * FROM table SELECT MIN Series No. FROM table
# 242 / 2027 1
# 243 / 2027 1
# 244 / 2027 1
# 245 / 2027 period between 1985 - 1990 have minimum infant mortality rate of what. ['Period', 'Births', 'Deaths', 'Difference', 'Crude Birth Rate', 'Crude Death Rate', 'Natural Increase', 'Total Fertility Rate', 'Infant Mortality Rate'] SELECT * FROM table WHERE period = 1985 - 1990 SELECT MIN Infant Mortality Rate FROM table WHERE Period = 1985 - 1990
# 246 / 2027 Name the most households ['Barangay', 'Area (km 2 )', 'Population ( 2007 census )', 'Households', 'Barangay Captain ( 2010 - 2013)'] SELECT MAX households FROM table SELECT MAX Households FROM table
# 247 / 2027 1
# 248 / 2027 What is the most amount of ministries? ['Nº', 'Cabinet (Nickname)', 'Took office', 'Left office', 'Duration', 'Coalition parties', 'ministers', 'ministries', 'King'] SELECT MAX ministries FROM table SELECT MAX ministries FROM table
# 249 / 2027 How many insurgents have 602 as the total per period? ['Period', 'Civilians', 'Security forces', 'Insurgents', 'Total per period'] SELECT insurgents FROM table WHERE insurgents = 602 SELECT MAX Insurgents FROM table WHERE Total per period = 602
# 250 / 2027 How many security forces? ['Period', 'Civilians', 'Security forces', 'Insurgents', 'Total per period'] SELECT COUNT security forces FROM table SELECT MAX Security forces FROM table
# 251 / 2027 How many insurgents have 2003 as a period? ['Period', 'Civilians', 'Security forces', 'Insurgents', 'Total per period'] SELECT COUNT insurgents FROM table WHERE insurgents = 2003 SELECT COUNT Insurgents FROM table WHERE Period = 2003
# 252 / 2027 1
# ...
# 1944 / 2027 1
# 1945 / 2027 Name the least total when bronze is less than 2 and rank is more than 2 with silver less than 1 ['Rank', 'Nation', 'Gold', 'Silver', 'Bronze', 'Total'] SELECT * FROM table WHERE rank = 2 AND silver = 1 SELECT MIN Total FROM table WHERE Bronze < 2 AND Rank > 2 AND Silver < 1
# 1946 / 2027 What is the largest gold with a Total of 2, and a Rank smaller than 2? ['Rank', 'Nation', 'Gold', 'Silver', 'Bronze', 'Total'] SELECT MAX gold FROM table WHERE total = 2 SELECT MAX Gold FROM table WHERE Total = 2 AND Rank < 2
# 1947 / 2027 1
# 1948 / 2027 What is the smallest rank with a Total smaller than 1? ['Rank', 'Nation', 'Gold', 'Silver', 'Bronze', 'Total'] SELECT * FROM table WHERE total = 1 SELECT MIN Rank FROM table WHERE Total < 1
# 1949 / 2027 What year was the (Barcaldine) larger than 1,868 and the (Aramac) lower than 1,592? ['Year', 'Population (Total)', '(Barcaldine)', '(Aramac)', '(Jericho)'] SELECT AVG year FROM table WHERE (aramac) = 1,592 SELECT AVG Year FROM table WHERE (Barcaldine) > 1,868 AND (Aramac) < 1,592
# 1950 / 2027 1
# 1951 / 2027 What is the earliest year that has a Bristol engine? ['Year', 'Entrant', 'Chassis', 'Engine', 'Points'] SELECT * FROM table WHERE engine = Bristol SELECT MIN Year FROM table WHERE Engine = bristol
# 1952 / 2027 Record of 18–15–6 belongs to what lowest attendance? ['Date', 'Visitor', 'Score', 'Home', 'Decision', 'Attendance', 'Record'] SELECT * FROM table WHERE record = 18–15–6 SELECT MIN Attendance FROM table WHERE Record = 18–15–6
# 1953 / 2027 1
# 1954 / 2027 In what heat did the swimmer in Lane 6 rank higher than 7 with a time of 4:08.27? ['Rank', 'Heat', 'Lane', 'Nation', 'Time'] SELECT MAX heat FROM table WHERE lane = 6 AND time = 4:08.27 SELECT SUM Heat FROM table WHERE Lane = 6 AND Time = 4:08.27 AND Rank > 7
# 1955 / 2027 Which year averaged less than 9 points? ['Year', 'Entrant', 'Chassis', 'Engine', 'Points'] SELECT year FROM table WHERE points = 9 SELECT AVG Year FROM table WHERE Points < 9
# 1956 / 2027 What is the total points of teams using a ligier js11/15 chassis? ['Year', 'Entrant', 'Chassis', 'Engine', 'Points'] SELECT SUM points FROM table WHERE chassis = ligier js11/15 SELECT COUNT Points FROM table WHERE Chassis = ligier js11/15
# 1957 / 2027 What is the rank of the town with a population of 258? ['Rank', 'Population', 'Name', 'Former Name', 'Municipality'] SELECT * FROM table WHERE population = 258 SELECT COUNT Rank FROM table WHERE Population = 258
# 1958 / 2027 1
# 1959 / 2027 Position of defensive back, and an Overall smaller than 69 is what lowest pick #? ['Round', 'Pick #', 'Overall', 'Name', 'Position', 'College'] SELECT * FROM table WHERE position = defensive back AND overall = 69 SELECT MIN Pick # FROM table WHERE Position = defensive back AND Overall < 69
# 1960 / 2027 1
# 1961 / 2027 When was the earliest first game with 11 played and 12 games lost? ['First game', 'Played', 'Drawn', 'Lost', 'Percentage'] SELECT * FROM table WHERE played = 12 SELECT MIN First game FROM table WHERE Played > 11 AND Lost = 12
# 1962 / 2027 What is the average number of games played associated with a first game in 1997 and over 0 games drawn? ['First game', 'Played', 'Drawn', 'Lost', 'Percentage'] SELECT AVG played FROM table WHERE first game = 1997 SELECT AVG Played FROM table WHERE First game = 1997 AND Drawn > 0
# 1963 / 2027 1
# 1964 / 2027 In which year was Angélica Rivera a nominee? ['Year', 'Ceremony', 'Category', 'Nominee', 'Result'] SELECT year FROM table WHERE nominee = Angélica Rivera SELECT AVG Year FROM table WHERE Nominee = angélica rivera
# 1965 / 2027 What is the smallest area (sq mi) that has 160 as it rank? ['Rank', 'Island', 'Area (km²)', 'Area (sq mi)', 'Country/Countries/Region'] SELECT * FROM table WHERE rank = 160 SELECT MIN Area (sq mi) FROM table WHERE Rank = 160
# 1966 / 2027 1
# 1967 / 2027 with release date of february 9, 2011, what is the api level? ['Version', 'Code name', 'Release date', 'API level', 'Distribution'] SELECT api level FROM table WHERE release date = february 9, 2011 SELECT AVG API level FROM table WHERE Release date = february 9, 2011
# 1968 / 2027 Which gc37-01 v10 engine has the fewest points? ['Year', 'Entrant', 'Chassis', 'Engine', 'Tyres', 'Points'] SELECT * FROM table WHERE engine = gc37-01 v10 SELECT MIN Points FROM table WHERE Engine = gc37-01 v10
# 1969 / 2027 Name the sum of goals conceded when lost is more than 7 and points less than 26 ['Place', 'Team', 'Played', 'Draw', 'Lost', 'Goals Scored', 'Goals Conceded', 'Points'] SELECT SUM goals conceded FROM table WHERE points = 26 SELECT SUM Goals Conceded FROM table WHERE Lost > 7 AND Points < 26
# 1970 / 2027 Name the most place for goals scored more than 28 and played less than 18 ['Place', 'Team', 'Played', 'Draw', 'Lost', 'Goals Scored', 'Goals Conceded', 'Points'] SELECT MAX place FROM table WHERE played = 18 SELECT MAX Place FROM table WHERE Goals Scored > 28 AND Played < 18
# 1971 / 2027 What place is associated with under 28 points, under 11 games lost, and under 18 games played? ['Place', 'Team', 'Played', 'Draw', 'Lost', 'Goals Scored', 'Goals Conceded', 'Points'] SELECT AVG place FROM table WHERE points = 28 AND lost = 11 AND played = 18 SELECT SUM Place FROM table WHERE Points < 28 AND Lost < 11 AND Played < 18
# 1972 / 2027 Name the lowest league for play-offs more than 0 and total of 25 ['Name', 'League', 'Play-offs', 'FA Cup', 'League Cup', 'Total'] SELECT * FROM table WHERE total = 25 SELECT MIN League FROM table WHERE Play-offs > 0 AND Total = 25
# 1973 / 2027 What camera has the highest Mpix with an aspect ratio of 2:1, a height less than 1536, and a width smaller than 2048? ['Frame size', 'Width', 'Height', 'Mpix', 'Aspect Ratio', 'max. fps', 'lowest possible REDCODE at 24 fps'] SELECT MAX Mpix FROM table WHERE height = 2:1 AND width = 2048 SELECT MAX Mpix FROM table WHERE Aspect Ratio = 2:1 AND Height < 1536 AND Width < 2048
# 1974 / 2027 1
# 1975 / 2027 Name the most games for standing of 5th, lebel and goals against larger than 220 with lost more than 52 ['Season', 'Games', 'Lost', 'Tied', 'Points', 'Goals for', 'Goals against', 'Standing'] SELECT MAX games FROM table WHERE standing = 5th, lebel AND lost = 52 SELECT MAX Games FROM table WHERE Standing = 5th, lebel AND Goals against > 220 AND Lost > 52
# 1976 / 2027 Name the least tied with games more than 70 and goals for less than 310 with points of 98 ['Season', 'Games', 'Lost', 'Tied', 'Points', 'Goals for', 'Goals against', 'Standing'] SELECT * FROM table WHERE goals for = 70 AND points = 98 SELECT MIN Tied FROM table WHERE Games > 70 AND Goals for < 310 AND Points = 98
# 1977 / 2027 1
# 1978 / 2027 1
# 1979 / 2027 What is the latest year for a Emeryson 1006 chassis with more than 0 points? ['Year', 'Entrant', 'Chassis', 'Engine', 'Points'] SELECT MAX year FROM table WHERE chassis = Emeryson 1006 SELECT MAX Year FROM table WHERE Chassis = emeryson 1006 AND Points > 0
# 1980 / 2027 with more than 32 laps and sylvain guintoli as rider, what's the lowest grid ? ['Rider', 'Manufacturer', 'Laps', 'Time/Retired', 'Grid'] SELECT * FROM table WHERE laps = 32 AND rider = sylvain guintoli SELECT MIN Grid FROM table WHERE Rider = sylvain guintoli AND Laps > 32
# 1981 / 2027 What year did the Cosworth v8 engine participate in? ['Year', 'Team', 'Chassis', 'Engine', 'Points'] SELECT year FROM table WHERE engine = Cosworth v8 SELECT AVG Year FROM table WHERE Engine = cosworth v8
# 1982 / 2027 Which year did the team receive more than 0 points? ['Year', 'Team', 'Chassis', 'Engine', 'Points'] SELECT year FROM table WHERE points = 0 SELECT AVG Year FROM table WHERE Points > 0
# 1983 / 2027 1
# 1984 / 2027 What is the average score with lee westwood as the player? ['Place', 'Player', 'Country', 'Score', 'To par'] SELECT AVG score FROM table WHERE score = lee westwood SELECT AVG Score FROM table WHERE Player = lee westwood
# 1985 / 2027 Name the average gold medals when the bronze medals was less than 1, silver medals being 0 and total medals more than 1 ['Ensemble', 'Gold Medals', 'Silver Medals', 'Bronze Medals', 'Total Medals'] SELECT * FROM table WHERE bronze medals = gold AND silver medals = 1 AND total medals = 0 SELECT AVG Gold Medals FROM table WHERE Bronze Medals < 1 AND Silver Medals = 0 AND Total Medals > 1
# 1986 / 2027 Name the total number of bronze medals when gold medals was 2, total medals more than 4 and silver medals less than 5 ['Ensemble', 'Gold Medals', 'Silver Medals', 'Bronze Medals', 'Total Medals'] SELECT * FROM table WHERE gold medals = bronze AND total medals = 2 AND silver medals = 5 SELECT COUNT Bronze Medals FROM table WHERE Gold Medals = 2 AND Total Medals > 4 AND Silver Medals < 5
# 1987 / 2027 Name the average total medals with ensemble of goshen hs ['Ensemble', 'Gold Medals', 'Silver Medals', 'Bronze Medals', 'Total Medals'] SELECT * FROM table WHERE ensemble = goshen hs SELECT AVG Total Medals FROM table WHERE Ensemble = goshen hs
# 1988 / 2027 What is the average value for Top-5, when the value for Top-25 is 0, and the value for Wins is less than 0? ['Tournament', 'Wins', 'Top-5', 'Top-10', 'Top-25', 'Events', 'Cuts made'] SELECT AVG Top-5 FROM table WHERE top-25 = 0 SELECT AVG Top-5 FROM table WHERE Top-25 = 0 AND Wins < 0
# 1989 / 2027 1
# 1990 / 2027 What is the lowest value for Events, when the value for Top-5 is greater than 1? ['Tournament', 'Wins', 'Top-5', 'Top-10', 'Top-25', 'Events', 'Cuts made'] SELECT * FROM table WHERE top-5 = 1 SELECT MIN Events FROM table WHERE Top-5 > 1
# 1991 / 2027 1
# 1992 / 2027 What is the range for the 1980s that correspond to a grid 1910s of 1912, and a 1940s before 1942 ['1910s', '1920s', '1930s', '1940s', '1950s', '1960s', '1970s', '1980s', '1990s', '2000s'] SELECT * FROM table WHERE 1910s = 1912 AND 1940s = 1942 SELECT AVG 1980s FROM table WHERE 1910s = 1912 AND 1940s < 1942
# 1993 / 2027 what is the lowest year in the 1910s that would be in the row were the 1950s are no larger than 1952, and the 1980s are no smaller than 1981? ['1910s', '1920s', '1930s', '1940s', '1950s', '1960s', '1970s', '1980s', '1990s', '2000s'] SELECT * FROM table WHERE 1980s = 1981 SELECT MIN 1910s FROM table WHERE 1950s < 1952 AND 1980s > 1981
# 1994 / 2027 Which is the highest Gold that has a total smaller than 4 and a silver of 1, and a bronze smaller than 2, and a rank of 13? ['Rank', 'Nation', 'Gold', 'Silver', 'Bronze', 'Total'] SELECT MAX Gold FROM table WHERE silver = 1 AND rank = 13 SELECT MAX Gold FROM table WHERE Total < 4 AND Silver = 1 AND Bronze < 2 AND Rank = 13
# 1995 / 2027 Name the sum of attendance for round 3 ['Date', 'Round', 'Opponents', 'Result F–A', 'Attendance'] SELECT SUM attendance FROM table WHERE round = 3 SELECT SUM Attendance FROM table WHERE Round = round 3
# 1996 / 2027 1
# 1997 / 2027 1
# 1998 / 2027 1
# 1999 / 2027 1
# 2000 / 2027 1
# 2001 / 2027 What were the total number of points when there was a lost larger than 6, when the team was Once Municipal, and when the number of goals scored was less than 8? ['Place', 'Team', 'Played', 'Draw', 'Lost', 'Goals Scored', 'Goals Conceded', 'Points'] SELECT COUNT points FROM table WHERE team = Once Municipal AND goals scored = 8 SELECT COUNT Points FROM table WHERE Lost > 6 AND Team = once municipal AND Goals Scored < 8
# 2002 / 2027 1
# 2003 / 2027 What is the lowest rank with poland as the nationality and a time greater than 55.34? ['Rank', 'Lane', 'Name', 'Nationality', 'Time'] SELECT * FROM table WHERE rank = poland AND time = 55.34 SELECT MIN Rank FROM table WHERE Nationality = poland AND Time > 55.34
# 2004 / 2027 Which average lane has 54.95 as a time? ['Rank', 'Lane', 'Name', 'Nationality', 'Time'] SELECT AVG lane FROM table WHERE lane = 54.95 SELECT AVG Lane FROM table WHERE Time = 54.95
# 2005 / 2027 Which average time has eithan urbach as a name with a lane bigger than 2? ['Rank', 'Lane', 'Name', 'Nationality', 'Time'] SELECT AVG time FROM table WHERE time = eithan urbach AND lane = 2 SELECT AVG Time FROM table WHERE Name = eithan urbach AND Lane > 2
# 2006 / 2027 What year was the brabham bt46 bt48 bt49 Chassis common? ['Year', 'Entrant', 'Chassis', 'Engine', 'Tyres', 'Points'] SELECT year FROM table WHERE chassis = brabham bt46 bt48 bt49 SELECT AVG Year FROM table WHERE Chassis = brabham bt46 bt48 bt49
# 2007 / 2027 1
# 2008 / 2027 Name the average total with league cup more than 0 and other more than 0 ['Name', 'League', 'FA Cup', 'League Cup', 'Other', 'Total'] SELECT AVG total FROM table WHERE other = 0 SELECT AVG Total FROM table WHERE League Cup > 0 AND Other > 0
# 2009 / 2027 Name the least other for league cup less than 0, FA cup more than 0 and league of 2 with total less than 14 ['Name', 'League', 'FA Cup', 'League Cup', 'Other', 'Total'] SELECT * FROM table WHERE fa cup = 0 AND total = 14 SELECT MIN Other FROM table WHERE Total < 14 AND League = 2 AND FA Cup > 0 AND League Cup < 0
# 2010 / 2027 1
# 2011 / 2027 1
# 2012 / 2027 1
# 2013 / 2027 What is the Challenge Cup total with a League of 1, Player Simon Storey, and a Total greater than 1? ['Player', 'League', 'Scottish Cup', 'League Cup', 'Challenge Cup', 'Total'] SELECT COUNT Challenge Cup FROM table WHERE player = Simon Storey SELECT SUM Challenge Cup FROM table WHERE League = 1 AND Player = simon storey AND Total > 1
# 2014 / 2027 1
# 2015 / 2027 What is the least for Scottish Cup with a Challenge Cup greater than 0, Player Paul Keegan, and League Cup greater than 0? ['Player', 'League', 'Scottish Cup', 'League Cup', 'Challenge Cup', 'Total'] SELECT * FROM table WHERE player = Paul Keegan SELECT MIN Scottish Cup FROM table WHERE Challenge Cup > 0 AND Player = paul keegan AND League Cup > 0
# 2016 / 2027 What is the greatest Challenge Cup with a League smaller than 2, Total greater than 2, and a League Cup greater than 1? ['Player', 'League', 'Scottish Cup', 'League Cup', 'Challenge Cup', 'Total'] SELECT MAX Challenge Cup FROM table WHERE total = 2 AND league cup = 1 SELECT MAX Challenge Cup FROM table WHERE League < 2 AND Total > 2 AND League Cup > 1
# 2017 / 2027 What is the highest Total with a League Cup greater than 0, Player Gary Harkins, and Scottish Cup greater than 0? ['Player', 'League', 'Scottish Cup', 'League Cup', 'Challenge Cup', 'Total'] SELECT MAX Total FROM table WHERE player = Gary Harkins SELECT MAX Total FROM table WHERE League Cup > 0 AND Player = gary harkins AND Scottish Cup > 0
# 2018 / 2027 Name the most draws when goals against is more than 56 and wins is more than 14 ['Position', 'Club', 'Played', 'Points', 'Wins', 'Draws', 'Losses', 'Goals for', 'Goals against', 'Goal Difference'] SELECT MAX draws FROM table WHERE wins = 14 SELECT MAX Draws FROM table WHERE Goals against > 56 AND Wins > 14
# 2019 / 2027 Which week did the Seattle Seahawks have a record of 6-6? ['Week', 'Date', 'Opponent', 'Result', 'Game site', 'Record', 'Attendance'] SELECT week FROM table WHERE record = 6-6 SELECT AVG Week FROM table WHERE Record = 6-6
# 2020 / 2027 1
# 2021 / 2027 What is the least amount of lecturers in the accounting department with less than 5 full professors? ['Department', 'Head', 'Full professors', 'Honorary professors', 'Lecturers'] SELECT * FROM table WHERE department = accounting department AND full professors = 5 SELECT MIN Lecturers FROM table WHERE Department = accounting AND Full professors < 5
# 2022 / 2027 1
# 2023 / 2027 1
# 2024 / 2027 what is the lowest top-25 when the events is less than 17 and top-5 is more than 0? ['Tournament', 'Wins', 'Top-5', 'Top-25', 'Events', 'Cuts made'] SELECT * FROM table WHERE top-5 = 0 SELECT MIN Top-25 FROM table WHERE Events < 17 AND Top-5 > 0
# 2025 / 2027 1
# 2026 / 2027 what is the highest top-5 when the top-25 is less than 4, cuts made is more than 3 and wins is 0? ['Tournament', 'Wins', 'Top-5', 'Top-25', 'Events', 'Cuts made'] SELECT MAX top-5 FROM table WHERE cuts made = 4 AND wins = 0 SELECT MAX Top-5 FROM table WHERE Top-25 < 4 AND Cuts made > 3 AND Wins < 0
# Select accuracy 51.25801677355698
# Where accuracy 69.4622594967933
# Value accuracy 74.54366058214109
# Overall accuracy 36.16181549087321

# %% [markdown]
# Our accuracy statistics for this case are as follows.
#
# *   Select accuracy: 51.26%
# *   Where accuracy: 69.46%
# *   Value accuracy: 74.54%
# *   Overall accuracy 36.16%

# %% [markdown]
# #Case 6: Operator Accuracy Evaluation
# We evaluate the accuracy of our rule-based determine operator function which identifies which operator ('<', '>', '=') goes with which attribute-value pair in the WHERE clauses. We evaluate accuracy on the entire WikiSQL dataset below. Note that we are only evaluating the accuracy of operators here assuming that the WHERE attributes have already been identified correctly so we don't use any of our pre-defined rules or our NER model. We calculate accuracy using the following formula:
#
# $$\frac{\text{#queries with correctly predicted operators in the WHERE clause}}{\text{#total queries}}$$
#
#
# Because of a quirk in the WikiSQL dataset, about 50 queries have WHERE values that contain operators ("=", "<" and/or ">") in them. Therefore, the filter_invalid_operator_queries function ensures that those queries are ignored.

# %%
def filter_invalid_operator_queries():
  """Remove queries with values that have operators in them from the dataset."""
  validQueries = []
  for row in dataset['test']:
    question = row['question']
    sqlQuery = row['sql']['human_readable']
    columns = row['table']['header']

    question = remove_unicode_characters(question)
    sqlQuery = remove_unicode_characters(sqlQuery)
    sqlQuery = remove_quotes(sqlQuery)

    sqlExtractor = sqlExtract(sqlQuery)
    whereAttr, whereAttrValue = sqlExtractor.fetch_where_attr()

    flag = False
    allOperators = ['=', '>', '<']

    for operator in allOperators:
      for attr, value in whereAttrValue.items():
        if operator in attr or operator in value:
          flag = True
    if flag:
      continue

    validQueries.append({'question': question, 'sqlQuery': sqlQuery, 'attr': columns})
  return validQueries

# %%
validQueries = filter_invalid_operator_queries()
numQueries = len(validQueries)
print(numQueries)
# Out:
# 15734

# %%
numCorrect = 0
count = 0
nlp = spacy.load("en_core_web_lg")

for query in validQueries:
  nlq = query['question']
  sqlQuery = query['sqlQuery']
  attributes = query['attr']

  sqlExtractor = sqlExtract(sqlQuery)

  whereIdx = sqlQuery.find('WHERE')
  if whereIdx == -1:
    whereAttrValue = {}
  else:
    whereAttr, whereAttrValue = sqlExtractor.fetch_where_attr()

  trueCompOperators = sqlExtractor.fetch_comparison_operator()

  nQueryObj = nlq2sql(question, "table", columns, nlp, nlp_ner, "rule1")
  nQueryObj.determine_operator(whereAttrValue)
  predictedCompOperators = nQueryObj.comparisonOperators

  if trueCompOperators != predictedCompOperators:
    print(f"{count} / {numQueries} {sqlQuery} {predictedCompOperators}")
  else:
    print(f"{count} / {numQueries} 1")
    numCorrect += 1

  count += 1

print('Operator accuracy', (numCorrect / numQueries) * 100)
# Out:
# Streaming output truncated to the last 5000 lines.
# 10735 / 15734 SELECT MIN Long FROM table WHERE Player = santana moss AND Att. > 1 ['=', '=']
# 10736 / 15734 1
# 10737 / 15734 SELECT SUM Yards FROM table WHERE Player = jason campbell AND Long < 23 ['=', '=']
# 10738 / 15734 1
# 10739 / 15734 1
# 10740 / 15734 1
# 10741 / 15734 1
# 10742 / 15734 1
# 10743 / 15734 1
# 10744 / 15734 1
# 10745 / 15734 1
# 10746 / 15734 1
# 10747 / 15734 1
# 10748 / 15734 1
# 10749 / 15734 SELECT Title FROM table WHERE Rating > 9.3 AND 18-49 < 5.5 AND Airdate = january 11, 2007 ['=', '=', '=']
# 10750 / 15734 SELECT SUM Viewers FROM table WHERE Rating > 7.8 AND Airdate = october 26, 2006 AND Share > 14 ['=', '=', '=']
# 10751 / 15734 SELECT MIN Viewers FROM table WHERE Episode = 2 AND 18-49 > 4.9 ['=', '=']
# 10752 / 15734 1
# 10753 / 15734 SELECT Mintage FROM table WHERE Artist = royal canadian mint engravers AND Year < 2008 AND Issue Price = $102.95 ['=', '=', '=']
# 10754 / 15734 SELECT Theme FROM table WHERE Year < 2006 AND Issue Price = $25.22 ['=', '=']
# 10755 / 15734 1
# 10756 / 15734 1
# 10757 / 15734 1
# 10758 / 15734 1
# 10759 / 15734 1
# 10760 / 15734 1
# 10761 / 15734 1
# 10762 / 15734 1
# 10763 / 15734 SELECT Venue FROM table WHERE Crowd > 25,000 AND Away team = carlton ['=', '=']
# 10764 / 15734 1
# 10765 / 15734 1
# 10766 / 15734 1
# 10767 / 15734 SELECT Free Agent Class FROM table WHERE Pick < 38 ['=']
# 10768 / 15734 1
# 10769 / 15734 1
# 10770 / 15734 SELECT Artist FROM table WHERE Issue Price (BU)[ clarification needed ] = n/a AND Year > 2004 AND Mintage (Proof) = 25,000 ['=', '=', '=']
# 10771 / 15734 1
# 10772 / 15734 SELECT Issue Price (BU)[ clarification needed ] FROM table WHERE Year > 2002 AND Mintage (Proof) = 50,000 ['=', '=']
# 10773 / 15734 1
# 10774 / 15734 1
# 10775 / 15734 SELECT AVG Total FROM table WHERE Tournament > 2 AND Regular Season = 1 ['=', '=']
# 10776 / 15734 SELECT COUNT Tournament FROM table WHERE Total > 0 AND Team = texas ['=', '=']
# 10777 / 15734 SELECT Season FROM table WHERE Tournament > 2 AND Regular Season = 13 ['=', '=']
# 10778 / 15734 1
# 10779 / 15734 1
# 10780 / 15734 1
# 10781 / 15734 1
# 10782 / 15734 1
# 10783 / 15734 1
# 10784 / 15734 SELECT COUNT Rank FROM table WHERE Swing to gain < 6.92 AND Constituency = caerphilly ['=', '=']
# 10785 / 15734 SELECT SUM Swing to gain FROM table WHERE Winning party 2007 = conservative AND Rank < 5 ['=', '=']
# 10786 / 15734 SELECT Director FROM table WHERE Year < 1949 AND Leading Lady = linda darnell AND Role = jonathan kent ['=', '=', '=']
# 10787 / 15734 1
# 10788 / 15734 SELECT Title FROM table WHERE Director = rouben mamoulian AND Year > 1940 AND Leading Lady = linda darnell ['=', '=', '=']
# 10789 / 15734 SELECT Director FROM table WHERE Year < 1948 AND Leading Lady = linda darnell AND Title = blood and sand ['=', '=', '=']
# 10790 / 15734 SELECT Driver FROM table WHERE Laps = 3 AND Grid < 15 ['=', '=']
# 10791 / 15734 SELECT Time/Retired FROM table WHERE Grid < 22 AND Laps < 33 AND Driver = john surtees ['=', '=', '=']
# 10792 / 15734 1
# 10793 / 15734 1
# 10794 / 15734 1
# 10795 / 15734 1
# 10796 / 15734 1
# 10797 / 15734 SELECT Super G FROM table WHERE Slalom < 5 AND Giant Slalom = 1 ['=', '=']
# 10798 / 15734 1
# 10799 / 15734 1
# 10800 / 15734 1
# 10801 / 15734 1
# 10802 / 15734 1
# 10803 / 15734 1
# 10804 / 15734 1
# 10805 / 15734 SELECT MIN Attendance FROM table WHERE Date = october 13, 1968 AND Week > 5 ['=', '=']
# 10806 / 15734 1
# 10807 / 15734 SELECT COUNT Attendance FROM table WHERE Date = november 3, 1968 AND Week < 8 ['=', '=']
# 10808 / 15734 1
# 10809 / 15734 1
# 10810 / 15734 1
# 10811 / 15734 1
# 10812 / 15734 1
# 10813 / 15734 1
# 10814 / 15734 1
# 10815 / 15734 1
# 10816 / 15734 1
# 10817 / 15734 SELECT Chassis FROM table WHERE Year > 1989 ['=']
# 10818 / 15734 1
# 10819 / 15734 1
# 10820 / 15734 1
# 10821 / 15734 SELECT Opponent FROM table WHERE Attendance > 59,000 ['=']
# 10822 / 15734 1
# 10823 / 15734 SELECT SUM Appearances FROM table WHERE Team = psv eindhoven AND Rank < 11 ['=', '=']
# 10824 / 15734 1
# 10825 / 15734 1
# 10826 / 15734 1
# 10827 / 15734 SELECT Opponent FROM table WHERE Round > 4 AND Event = draka v ['=', '=']
# 10828 / 15734 1
# 10829 / 15734 1
# 10830 / 15734 1
# 10831 / 15734 1
# 10832 / 15734 1
# 10833 / 15734 SELECT AVG Games FROM table WHERE Lost > 27 AND Points < 78 AND Goals against < 300 ['=', '=', '=']
# 10834 / 15734 SELECT COUNT Games FROM table WHERE Tied < 15 AND Goals against < 186 ['=', '=']
# 10835 / 15734 SELECT MIN Goals for FROM table WHERE Tied > 15 ['=']
# 10836 / 15734 1
# 10837 / 15734 SELECT MIN Gold FROM table WHERE Rank < 5 AND Silver = 1 AND Nation = poland AND Total > 1 ['=', '=', '=', '=']
# 10838 / 15734 SELECT COUNT Silver FROM table WHERE Gold = 3 AND Rank > 1 ['=', '=']
# 10839 / 15734 SELECT AVG Gold FROM table WHERE Bronze > 1 ['=']
# 10840 / 15734 SELECT AVG Silver FROM table WHERE Rank = 2 AND Bronze > 1 ['=', '=']
# 10841 / 15734 1
# 10842 / 15734 1
# 10843 / 15734 SELECT Winner FROM table WHERE Majority > 6,181 AND Runner up = j w andrews ['=', '=']
# 10844 / 15734 1
# 10845 / 15734 1
# 10846 / 15734 1
# 10847 / 15734 1
# 10848 / 15734 SELECT Asts FROM table WHERE Rebs > 1,189 ['=']
# 10849 / 15734 1
# 10850 / 15734 1
# 10851 / 15734 1
# 10852 / 15734 1
# 10853 / 15734 1
# 10854 / 15734 SELECT Rank FROM table WHERE Year < 2000 AND Bike = bsl ['=', '=']
# 10855 / 15734 1
# 10856 / 15734 1
# 10857 / 15734 1
# 10858 / 15734 1
# 10859 / 15734 1
# 10860 / 15734 SELECT MIN Not Outs FROM table WHERE Average < 31.25 AND Matches < 13 AND Runs < 327 ['=', '=', '=']
# 10861 / 15734 SELECT COUNT Runs FROM table WHERE Average > 31.25 AND Innings < 24 ['=', '=']
# 10862 / 15734 SELECT MIN Not Outs FROM table WHERE Innings > 25 ['=']
# 10863 / 15734 SELECT Not Outs FROM table WHERE Runs > 327 AND Innings > 24 AND Average = 29.54 ['=', '=', '=']
# 10864 / 15734 SELECT COUNT Runs FROM table WHERE Average < 27.22 ['=']
# 10865 / 15734 1
# 10866 / 15734 1
# 10867 / 15734 1
# 10868 / 15734 1
# 10869 / 15734 1
# 10870 / 15734 1
# 10871 / 15734 1
# 10872 / 15734 1
# 10873 / 15734 1
# 10874 / 15734 1
# 10875 / 15734 1
# 10876 / 15734 1
# 10877 / 15734 1
# 10878 / 15734 1
# 10879 / 15734 SELECT Result FROM table WHERE Scored > 1 ['=']
# 10880 / 15734 1
# 10881 / 15734 1
# 10882 / 15734 1
# 10883 / 15734 1
# 10884 / 15734 1
# 10885 / 15734 1
# 10886 / 15734 1
# 10887 / 15734 1
# 10888 / 15734 1
# 10889 / 15734 1
# 10890 / 15734 1
# 10891 / 15734 1
# 10892 / 15734 1
# 10893 / 15734 1
# 10894 / 15734 1
# 10895 / 15734 1
# 10896 / 15734 1
# 10897 / 15734 1
# 10898 / 15734 1
# 10899 / 15734 1
# 10900 / 15734 SELECT Result FROM table WHERE Year < 2010 AND Tournament = hypo-meeting ['=', '=']
# 10901 / 15734 SELECT Venue FROM table WHERE Result = 12th AND Year < 2012 ['=', '=']
# 10902 / 15734 1
# 10903 / 15734 1
# 10904 / 15734 1
# 10905 / 15734 1
# 10906 / 15734 1
# 10907 / 15734 SELECT Category FROM table WHERE Character = jacqui mcqueen AND Year < 2011 ['=', '=']
# 10908 / 15734 1
# 10909 / 15734 1
# 10910 / 15734 1
# 10911 / 15734 1
# 10912 / 15734 1
# 10913 / 15734 1
# 10914 / 15734 1
# 10915 / 15734 1
# 10916 / 15734 1
# 10917 / 15734 1
# 10918 / 15734 1
# 10919 / 15734 1
# 10920 / 15734 1
# 10921 / 15734 1
# 10922 / 15734 1
# 10923 / 15734 1
# 10924 / 15734 1
# 10925 / 15734 1
# 10926 / 15734 1
# 10927 / 15734 SELECT Home team FROM table WHERE Crowd > 22,449 ['=']
# 10928 / 15734 1
# 10929 / 15734 1
# 10930 / 15734 1
# 10931 / 15734 1
# 10932 / 15734 SELECT MIN Utility PV FROM table WHERE Hydro > 289.25 AND Renewable Total > 520.07 ['=', '=']
# 10933 / 15734 1
# 10934 / 15734 1
# 10935 / 15734 1
# 10936 / 15734 SELECT LNER class FROM table WHERE Passed to LNER > 3 AND Date introduced = 1895–98 ['=', '=']
# 10937 / 15734 1
# 10938 / 15734 1
# 10939 / 15734 1
# 10940 / 15734 1
# 10941 / 15734 1
# 10942 / 15734 1
# 10943 / 15734 1
# 10944 / 15734 1
# 10945 / 15734 SELECT MIN 1960 FROM table WHERE 1940 = 1,115 AND 1990 < 928 ['=', '=']
# 10946 / 15734 SELECT MAX 1920 FROM table WHERE 2000 = 5,030 AND 1960 > 4,228 ['=', '=']
# 10947 / 15734 SELECT SUM 1970 FROM table WHERE 1960 < 4,228 AND 1920 < 106,021,568 AND 1980 > 949 ['=', '=', '=']
# 10948 / 15734 SELECT MIN 1930 FROM table WHERE 1990 = 6,883 AND 1920 > 6,215 ['=', '=']
# 10949 / 15734 SELECT AVG 1940 FROM table WHERE 1970 > 11,070 AND 1950 < 150,844,547 ['=', '=']
# 10950 / 15734 SELECT AVG Fumbles FROM table WHERE Avg. > 5.4 AND Yards < 164 ['=', '=']
# 10951 / 15734 SELECT MAX Fumbles FROM table WHERE Yards > 44 AND Att. = 32 ['=', '=']
# 10952 / 15734 SELECT Entrant FROM table WHERE Year > 1981 AND Chassis = osella fa1c ['=', '=']
# 10953 / 15734 1
# 10954 / 15734 1
# 10955 / 15734 1
# 10956 / 15734 1
# 10957 / 15734 1
# 10958 / 15734 1
# 10959 / 15734 1
# 10960 / 15734 1
# 10961 / 15734 SELECT Time/Retired FROM table WHERE Laps < 52 AND Grid = 19 ['=', '=']
# 10962 / 15734 SELECT Driver FROM table WHERE Laps > 39 AND Grid = 15 ['=', '=']
# 10963 / 15734 SELECT SUM Grid FROM table WHERE Driver = johnny herbert AND Laps > 52 ['=', '=']
# 10964 / 15734 1
# 10965 / 15734 1
# 10966 / 15734 1
# 10967 / 15734 1
# 10968 / 15734 1
# 10969 / 15734 1
# 10970 / 15734 1
# 10971 / 15734 1
# 10972 / 15734 1
# 10973 / 15734 1
# 10974 / 15734 1
# 10975 / 15734 1
# 10976 / 15734 1
# 10977 / 15734 SELECT MIN Class Position FROM table WHERE Drivers = les palmer, terry morris AND Position > 23 ['=', '=']
# 10978 / 15734 SELECT Class FROM table WHERE Laps > 193 AND Class Position = 1 AND Position = 13 ['=', '=', '=']
# 10979 / 15734 1
# 10980 / 15734 1
# 10981 / 15734 1
# 10982 / 15734 1
# 10983 / 15734 SELECT MAX Region FROM table WHERE Name = saint-simon-les-mines AND Population < 458 ['=', '=']
# 10984 / 15734 SELECT SUM Region FROM table WHERE Name = saint-agapit AND Code < 33045 ['=', '=']
# 10985 / 15734 SELECT AVG Area (km 2 ) FROM table WHERE Code > 19025 AND Region < 12 ['=', '=']
# 10986 / 15734 SELECT MAX Region FROM table WHERE Name = saint-flavien AND Area (km 2 ) > 67.56 ['=', '=']
# 10987 / 15734 1
# 10988 / 15734 1
# 10989 / 15734 1
# 10990 / 15734 1
# 10991 / 15734 1
# 10992 / 15734 SELECT MAX Region FROM table WHERE Population < 4,797 AND Name = l'ascension-de-notre-seigneur AND Area (km 2 ) > 131.83 ['=', '=', '=']
# 10993 / 15734 SELECT AVG Population FROM table WHERE Regional County Municipality = le domaine-du-roy AND Type = m AND Region < 2 ['=', '=', '=']
# 10994 / 15734 SELECT Regional County Municipality FROM table WHERE Type = m AND Code < 91015 ['=', '=']
# 10995 / 15734 1
# 10996 / 15734 1
# 10997 / 15734 1
# 10998 / 15734 1
# 10999 / 15734 1
# 11000 / 15734 1
# 11001 / 15734 1
# 11002 / 15734 SELECT Away team FROM table WHERE Crowd > 25,000 ['=']
# 11003 / 15734 1
# 11004 / 15734 1
# 11005 / 15734 1
# 11006 / 15734 1
# 11007 / 15734 1
# 11008 / 15734 SELECT MAX Clean & jerk FROM table WHERE Snatch < 150 AND Bodyweight > 93.13 ['=', '=']
# 11009 / 15734 SELECT Name FROM table WHERE Bodyweight > 89.64 AND Total (kg) > 310 AND Clean & jerk < 207.5 AND Snatch > 165 ['=', '=', '=', '=']
# 11010 / 15734 1
# 11011 / 15734 1
# 11012 / 15734 1
# 11013 / 15734 1
# 11014 / 15734 SELECT Country of origin* FROM table WHERE Pick < 26 AND PBA team = shell turbo chargers ['=', '=']
# 11015 / 15734 1
# 11016 / 15734 1
# 11017 / 15734 1
# 11018 / 15734 1
# 11019 / 15734 1
# 11020 / 15734 1
# 11021 / 15734 1
# 11022 / 15734 1
# 11023 / 15734 1
# 11024 / 15734 1
# 11025 / 15734 1
# 11026 / 15734 1
# 11027 / 15734 1
# 11028 / 15734 1
# 11029 / 15734 1
# 11030 / 15734 1
# 11031 / 15734 1
# 11032 / 15734 SELECT COUNT Laps FROM table WHERE Driver = ukyo katayama AND Grid < 16 ['=', '=']
# 11033 / 15734 1
# 11034 / 15734 1
# 11035 / 15734 1
# 11036 / 15734 1
# 11037 / 15734 1
# 11038 / 15734 1
# 11039 / 15734 1
# 11040 / 15734 1
# 11041 / 15734 1
# 11042 / 15734 1
# 11043 / 15734 1
# 11044 / 15734 1
# 11045 / 15734 1
# 11046 / 15734 1
# 11047 / 15734 SELECT Away team score FROM table WHERE Crowd > 22,283 AND Home team score = 23.13 (151) ['=', '=']
# 11048 / 15734 1
# 11049 / 15734 1
# 11050 / 15734 1
# 11051 / 15734 SELECT SUM Area (km²) FROM table WHERE Median age (in 2006) = 38 years AND Population (in 2008) = 2,444 AND Date first settled as a suburb < 1965 ['=', '=', '=']
# 11052 / 15734 1
# 11053 / 15734 1
# 11054 / 15734 1
# 11055 / 15734 1
# 11056 / 15734 1
# 11057 / 15734 SELECT COUNT Percent Yes FROM table WHERE Voted Yes > 2,410,119 AND Jurisdiction = nova scotia AND Percent No < 51.3 ['=', '=', '=']
# 11058 / 15734 SELECT COUNT Percent Yes FROM table WHERE Jurisdiction = alberta AND Percent No > 60.2 ['=', '=']
# 11059 / 15734 SELECT COUNT Voted Yes FROM table WHERE Jurisdiction = newfoundland AND Voted No < 77,881 ['=', '=']
# 11060 / 15734 SELECT MAX Percent Yes FROM table WHERE Jurisdiction = alberta AND Percent No < 60.2 ['=', '=']
# 11061 / 15734 SELECT MAX Percent Yes FROM table WHERE Voted Yes < 5,354 AND Jurisdiction = alberta AND Voted No < 731,975 ['=', '=', '=']
# 11062 / 15734 1
# 11063 / 15734 1
# 11064 / 15734 SELECT Date FROM table WHERE Crowd > 16,000 AND Home team = carlton ['=', '=']
# 11065 / 15734 1
# 11066 / 15734 1
# 11067 / 15734 1
# 11068 / 15734 1
# 11069 / 15734 1
# 11070 / 15734 1
# 11071 / 15734 1
# 11072 / 15734 1
# 11073 / 15734 1
# 11074 / 15734 1
# 11075 / 15734 1
# 11076 / 15734 1
# 11077 / 15734 1
# 11078 / 15734 1
# 11079 / 15734 SELECT Opponent FROM table WHERE Week < 12 AND Attendance = 65,569 ['=', '=']
# 11080 / 15734 1
# 11081 / 15734 1
# 11082 / 15734 1
# 11083 / 15734 1
# 11084 / 15734 1
# 11085 / 15734 SELECT Composition FROM table WHERE Mintage > 999 AND Artist = jody broomfield AND Year > 2008 ['=', '=', '=']
# 11086 / 15734 SELECT Theme FROM table WHERE Year < 2006 ['=']
# 11087 / 15734 1
# 11088 / 15734 1
# 11089 / 15734 1
# 11090 / 15734 1
# 11091 / 15734 SELECT Originally aired FROM table WHERE Season < 5 AND Season Premiere = october 3, 2001 ['=', '=']
# 11092 / 15734 1
# 11093 / 15734 SELECT MIN Lost FROM table WHERE Drawn < 1 AND % Won = 50% AND Against = netherlands AND Played > 2 ['=', '=', '=', '=']
# 11094 / 15734 1
# 11095 / 15734 1
# 11096 / 15734 SELECT AVG Interview FROM table WHERE Average > 9.233 AND Swimsuit = 9.473 AND Evening Gown > 9.671 ['=', '=', '=']
# 11097 / 15734 SELECT MIN Evening Gown FROM table WHERE Interview > 9.164 AND Swimsuit < 9.35 AND Average < 9.233 ['=', '=', '=']
# 11098 / 15734 SELECT MAX Average FROM table WHERE Swimsuit = 9.4 AND Evening Gown < 9.486 ['=', '=']
# 11099 / 15734 SELECT SUM Interview FROM table WHERE Evening Gown = 9.543 AND Average > 9.521 ['=', '=']
# 11100 / 15734 SELECT AVG Average FROM table WHERE Evening Gown > 9.35 AND State = south carolina AND Swimsuit > 9.4 ['=', '=', '=']
# 11101 / 15734 SELECT SUM Draws FROM table WHERE Goals against = 52 AND Losses < 15 ['=', '=']
# 11102 / 15734 SELECT MAX Losses FROM table WHERE Club = cd toledo AND Points > 56 ['=', '=']
# 11103 / 15734 SELECT MIN Wins FROM table WHERE Goals for > 72 ['=']
# 11104 / 15734 1
# 11105 / 15734 SELECT Name FROM table WHERE Snatch > 140 AND Bodyweight < 84.55 AND Clean & jerk = 192.5 ['=', '=', '=']
# 11106 / 15734 1
# 11107 / 15734 1
# 11108 / 15734 SELECT MIN +1d12 (6) FROM table WHERE Difficulty Value = competent (dv 8) AND 1d10 Resolution (+5) > 13 ['=', '=']
# 11109 / 15734 SELECT MAX 3d6 or 1d20 Resolution (+10) FROM table WHERE 1d10 Resolution (+5) = 5 AND +1d12 (6) < 6 ['=', '=']
# 11110 / 15734 SELECT MAX +1d12 (6) FROM table WHERE 3d6 or 1d20 Resolution (+10) > 10 AND +1d6-1d6 or +1d10-1d10 (+0) = 4 AND 1d10 Resolution (+5) > 9 ['=', '=', '=']
# 11111 / 15734 1
# 11112 / 15734 1
# 11113 / 15734 1
# 11114 / 15734 1
# 11115 / 15734 1
# 11116 / 15734 1
# 11117 / 15734 1
# 11118 / 15734 SELECT Club team FROM table WHERE Overall < 283 AND Player = derrick byfuglien ['=', '=']
# 11119 / 15734 1
# 11120 / 15734 1
# 11121 / 15734 1
# 11122 / 15734 1
# 11123 / 15734 1
# 11124 / 15734 1
# 11125 / 15734 SELECT Date FROM table WHERE Crowd > 23,000 ['=']
# 11126 / 15734 1
# 11127 / 15734 1
# 11128 / 15734 1
# 11129 / 15734 1
# 11130 / 15734 SELECT AVG Stories FROM table WHERE Completed > 2003 AND Rank = 16 ['=', '=']
# 11131 / 15734 1
# 11132 / 15734 SELECT SUM Stories FROM table WHERE City = guadalajara AND Completed > 2007 ['=', '=']
# 11133 / 15734 SELECT State FROM table WHERE Council votes < 4 ['=']
# 11134 / 15734 1
# 11135 / 15734 1
# 11136 / 15734 1
# 11137 / 15734 1
# 11138 / 15734 SELECT COUNT Grid FROM table WHERE Laps > 54 ['=']
# 11139 / 15734 1
# 11140 / 15734 SELECT Constructor FROM table WHERE Grid > 8 AND Time/Retired = +1:17.124 ['=', '=']
# 11141 / 15734 1
# 11142 / 15734 SELECT Engine FROM table WHERE Year < 1996 AND Points = 5 ['=', '=']
# 11143 / 15734 SELECT COUNT Year FROM table WHERE Entrant = red bull sauber petronas AND Points > 6 ['=', '=']
# 11144 / 15734 1
# 11145 / 15734 1
# 11146 / 15734 1
# 11147 / 15734 SELECT Date FROM table WHERE Crowd > 17,259 AND Away team = melbourne ['=', '=']
# 11148 / 15734 1
# 11149 / 15734 1
# 11150 / 15734 1
# 11151 / 15734 1
# 11152 / 15734 1
# 11153 / 15734 1
# 11154 / 15734 1
# 11155 / 15734 1
# 11156 / 15734 SELECT Pos. FROM table WHERE Asts > 11 AND Rebs = 219 ['=', '=']
# 11157 / 15734 1
# 11158 / 15734 1
# 11159 / 15734 1
# 11160 / 15734 1
# 11161 / 15734 1
# 11162 / 15734 1
# 11163 / 15734 1
# 11164 / 15734 1
# 11165 / 15734 1
# 11166 / 15734 1
# 11167 / 15734 SELECT MAX Population Estimate 2005 FROM table WHERE Area (km 2 ) > 1,775.65 AND Name = mamasa regency AND Population Census 2010 < 139,962 ['=', '=', '=']
# 11168 / 15734 1
# 11169 / 15734 SELECT MAX Area (km 2 ) FROM table WHERE Population Estimate 2005 < 93,116 AND Name = polewali mandar regency ['=', '=']
# 11170 / 15734 1
# 11171 / 15734 SELECT COUNT Population Estimate 2005 FROM table WHERE Area (km 2 ) > 8,023.74 ['=']
# 11172 / 15734 1
# 11173 / 15734 SELECT Leading scorer FROM table WHERE Attendance > 12,107 AND Date = 4 april 2008 ['=', '=']
# 11174 / 15734 SELECT Home team score FROM table WHERE Crowd > 18,000 AND Venue = victoria park ['=', '=']
# 11175 / 15734 1
# 11176 / 15734 SELECT MIN Season FROM table WHERE TV Season = 2010-2011 AND Viewers (in millions) < 3.6 ['=', '=']
# 11177 / 15734 1
# 11178 / 15734 1
# 11179 / 15734 SELECT Rank FROM table WHERE Viewers (in millions) < 6.2 AND TV Season = 2009-2010 ['=', '=']
# 11180 / 15734 1
# 11181 / 15734 1
# 11182 / 15734 1
# 11183 / 15734 1
# 11184 / 15734 1
# 11185 / 15734 1
# 11186 / 15734 1
# 11187 / 15734 SELECT Genre FROM table WHERE Number of episodes > 20 AND English title (Chinese title) = wong fei hung - master of kung fu 我師傅係黃飛鴻 ['=', '=']
# 11188 / 15734 1
# 11189 / 15734 1
# 11190 / 15734 1
# 11191 / 15734 1
# 11192 / 15734 1
# 11193 / 15734 1
# 11194 / 15734 1
# 11195 / 15734 1
# 11196 / 15734 1
# 11197 / 15734 1
# 11198 / 15734 1
# 11199 / 15734 1
# 11200 / 15734 1
# 11201 / 15734 1
# 11202 / 15734 1
# 11203 / 15734 1
# 11204 / 15734 1
# 11205 / 15734 1
# 11206 / 15734 1
# 11207 / 15734 1
# 11208 / 15734 1
# 11209 / 15734 1
# 11210 / 15734 1
# 11211 / 15734 1
# 11212 / 15734 1
# 11213 / 15734 1
# 11214 / 15734 1
# 11215 / 15734 1
# 11216 / 15734 1
# 11217 / 15734 SELECT SUM Draw FROM table WHERE Artist = hari mata hari AND Points < 70 ['=', '=']
# 11218 / 15734 SELECT MAX Points FROM table WHERE Draw < 7 AND Song = budi tu ['=', '=']
# 11219 / 15734 1
# 11220 / 15734 SELECT MIN Place FROM table WHERE Song = starac i more AND Draw > 13 ['=', '=']
# 11221 / 15734 1
# 11222 / 15734 1
# 11223 / 15734 1
# 11224 / 15734 1
# 11225 / 15734 1
# 11226 / 15734 1
# 11227 / 15734 1
# 11228 / 15734 1
# 11229 / 15734 1
# 11230 / 15734 1
# 11231 / 15734 1
# 11232 / 15734 SELECT Constructor FROM table WHERE Grid < 18 AND Driver = mika häkkinen ['=', '=']
# 11233 / 15734 SELECT AVG Laps FROM table WHERE Driver = damon hill AND Grid < 1 ['=', '=']
# 11234 / 15734 1
# 11235 / 15734 SELECT AVG Games Played FROM table WHERE Team = ottawa hockey club AND Wins > 5 ['=', '=']
# 11236 / 15734 SELECT AVG Goals Against FROM table WHERE Games Played < 8 ['=']
# 11237 / 15734 SELECT COUNT Wins FROM table WHERE Goals For > 35 AND Team = montreal hockey club AND Losses < 2 ['=', '=', '=']
# 11238 / 15734 1
# 11239 / 15734 SELECT COUNT Week FROM table WHERE Date = december 9, 1961 AND Attendance > 41,268 ['=', '=']
# 11240 / 15734 SELECT COUNT Seats 2001 FROM table WHERE % 2006 < 8.6 ['=']
# 11241 / 15734 SELECT SUM Seats 2001 FROM table WHERE Seats 2006 = 2 AND % 2001 > 7.6 ['=', '=']
# 11242 / 15734 SELECT Date FROM table WHERE Attendance > 20,737 AND Loss = dawley (2-3) ['=', '=']
# 11243 / 15734 1
# 11244 / 15734 SELECT Format FROM table WHERE Year > 1991 AND Catalog Number = 81868 ['=', '=']
# 11245 / 15734 1
# 11246 / 15734 1
# 11247 / 15734 SELECT COUNT Laps FROM table WHERE Time/Retired = received outside assistance AND Grid < 19 ['=', '=']
# 11248 / 15734 1
# 11249 / 15734 1
# 11250 / 15734 SELECT AVG Tries FROM table WHERE Player = mike forshaw AND Points < 28 ['=', '=']
# 11251 / 15734 1
# 11252 / 15734 1
# 11253 / 15734 1
# 11254 / 15734 1
# 11255 / 15734 1
# 11256 / 15734 SELECT Date FROM table WHERE Crowd > 35,151 ['=']
# 11257 / 15734 SELECT COUNT Laps FROM table WHERE Qual > 142.81 AND Grid = 12 ['=', '=']
# 11258 / 15734 SELECT COUNT Qual FROM table WHERE Laps > 93 AND Rank = 32 AND Grid < 32 ['=', '=', '=']
# 11259 / 15734 1
# 11260 / 15734 1
# 11261 / 15734 1
# 11262 / 15734 1
# 11263 / 15734 1
# 11264 / 15734 1
# 11265 / 15734 1
# 11266 / 15734 1
# 11267 / 15734 1
# 11268 / 15734 1
# 11269 / 15734 SELECT MIN Events FROM table WHERE Cuts made > 5 AND Top-25 < 13 ['=', '=']
# 11270 / 15734 SELECT MAX Top-10 FROM table WHERE Cuts made = 16 AND Top-25 < 13 ['=', '=']
# 11271 / 15734 SELECT SUM Top-25 FROM table WHERE Tournament = u.s. open AND Events < 7 ['=', '=']
# 11272 / 15734 SELECT SUM Events FROM table WHERE Top-10 = 2 AND Cuts made > 5 ['=', '=']
# 11273 / 15734 1
# 11274 / 15734 1
# 11275 / 15734 1
# 11276 / 15734 1
# 11277 / 15734 1
# 11278 / 15734 1
# 11279 / 15734 1
# 11280 / 15734 1
# 11281 / 15734 1
# 11282 / 15734 1
# 11283 / 15734 1
# 11284 / 15734 1
# 11285 / 15734 1
# 11286 / 15734 1
# 11287 / 15734 1
# 11288 / 15734 1
# 11289 / 15734 1
# 11290 / 15734 SELECT COUNT Earnings ( $ ) FROM table WHERE Events < 28 AND Rank < 3 ['=', '=']
# 11291 / 15734 SELECT MIN Wins FROM table WHERE Rank > 4 ['=']
# 11292 / 15734 1
# 11293 / 15734 1
# 11294 / 15734 1
# 11295 / 15734 1
# 11296 / 15734 1
# 11297 / 15734 1
# 11298 / 15734 1
# 11299 / 15734 SELECT TD's FROM table WHERE Long < 7 AND Yards < 4 ['=', '=']
# 11300 / 15734 1
# 11301 / 15734 SELECT MAX Season FROM table WHERE Attendance/G = 9,153 AND Pos. > 11 ['=', '=']
# 11302 / 15734 1
# 11303 / 15734 1
# 11304 / 15734 1
# 11305 / 15734 1
# 11306 / 15734 1
# 11307 / 15734 1
# 11308 / 15734 1
# 11309 / 15734 1
# 11310 / 15734 1
# 11311 / 15734 SELECT Object type FROM table WHERE NGC number > 6638 AND Right ascension ( J2000 ) = 18h25m37.8s ['=', '=']
# 11312 / 15734 1
# 11313 / 15734 SELECT COUNT Since FROM table WHERE Goals > 6 AND Name = deco ['=', '=']
# 11314 / 15734 1
# 11315 / 15734 SELECT SUM Ends FROM table WHERE Name = abidal AND Since > 2007 ['=', '=']
# 11316 / 15734 1
# 11317 / 15734 1
# 11318 / 15734 1
# 11319 / 15734 1
# 11320 / 15734 1
# 11321 / 15734 SELECT Constructor FROM table WHERE Grid > 14 AND Laps > 93 AND Rank > 25 ['=', '=', '=']
# 11322 / 15734 SELECT Qual FROM table WHERE Rank > 28 AND Grid > 23 ['=', '=']
# 11323 / 15734 1
# 11324 / 15734 1
# 11325 / 15734 1
# 11326 / 15734 1
# 11327 / 15734 1
# 11328 / 15734 1
# 11329 / 15734 1
# 11330 / 15734 1
# 11331 / 15734 1
# 11332 / 15734 1
# 11333 / 15734 SELECT Result FROM table WHERE Year > 2006 AND Nominated work = the king and i ['=', '=']
# 11334 / 15734 1
# 11335 / 15734 SELECT Additional major sponsor(s) FROM table WHERE Main colour(s) = red AND Year > 1991 ['=', '=']
# 11336 / 15734 1
# 11337 / 15734 1
# 11338 / 15734 1
# 11339 / 15734 1
# 11340 / 15734 SELECT MIN Swimsuit FROM table WHERE Interview < 8.574 AND Average > 8.532 ['=', '=']
# 11341 / 15734 SELECT MIN Interview FROM table WHERE Swimsuit < 9.322 AND Evening Gown > 9.259 AND Average = 9.321 ['=', '=', '=']
# 11342 / 15734 SELECT MAX Average FROM table WHERE State = texas AND Swimsuit > 8.839 ['=', '=']
# 11343 / 15734 1
# 11344 / 15734 SELECT COUNT Evening Gown FROM table WHERE State = new jersey AND Interview < 9.344 ['=', '=']
# 11345 / 15734 1
# 11346 / 15734 1
# 11347 / 15734 1
# 11348 / 15734 1
# 11349 / 15734 SELECT AVG Attendance FROM table WHERE Location = veterans stadium AND Game > 3 AND Time = 2:21 ['=', '=', '=']
# 11350 / 15734 1
# 11351 / 15734 1
# 11352 / 15734 SELECT SUM Attendance FROM table WHERE Date = october 16 AND Game > 5 ['=', '=']
# 11353 / 15734 1
# 11354 / 15734 1
# 11355 / 15734 SELECT Away team score FROM table WHERE Crowd > 27,455 AND Venue = princes park ['=', '=']
# 11356 / 15734 SELECT COUNT Laps FROM table WHERE Time/Retired = + 4 laps AND Grid > 20 ['=', '=']
# 11357 / 15734 1
# 11358 / 15734 SELECT SUM Works number FROM table WHERE Type = 0-6-4t AND Date > 1875 ['=', '=']
# 11359 / 15734 SELECT SUM Works number FROM table WHERE Date > 1875 AND Name = gowrie ['=', '=']
# 11360 / 15734 1
# 11361 / 15734 SELECT COUNT Works number FROM table WHERE Type = 0-6-4t AND Name = gowrie AND Date > 1908 ['=', '=', '=']
# 11362 / 15734 1
# 11363 / 15734 1
# 11364 / 15734 SELECT MIN Bodyweight FROM table WHERE Snatch < 55 ['=']
# 11365 / 15734 1
# 11366 / 15734 1
# 11367 / 15734 1
# 11368 / 15734 1
# 11369 / 15734 1
# 11370 / 15734 1
# 11371 / 15734 1
# 11372 / 15734 1
# 11373 / 15734 1
# 11374 / 15734 1
# 11375 / 15734 SELECT MIN Live births FROM table WHERE Crude birth rate (per 1000) > 22.1 AND Crude death rate (per 1000) < 5.5 AND Average population (x 1000) = 2,401 AND Natural change > 45,272 ['=', '=', '=', '=']
# 11376 / 15734 SELECT SUM Crude birth rate (per 1000) FROM table WHERE Natural change (per 1000) > 31.6 AND Average population (x 1000) < 1,802 ['=', '=']
# 11377 / 15734 SELECT AVG Crude death rate (per 1000) FROM table WHERE Live births < 72,400 AND Crude birth rate (per 1000) > 10 AND Average population (x 1000) = 2,518 ['=', '=', '=']
# 11378 / 15734 SELECT SUM Crude birth rate (per 1000) FROM table WHERE Crude death rate (per 1000) < 6.2 AND Average population (x 1000) > 2,770 AND Natural change (per 1000) = 17.2 ['=', '=', '=']
# 11379 / 15734 SELECT Casualties FROM table WHERE Tonnage > 5,136 AND Name = mckeesport ['=', '=']
# 11380 / 15734 1
# 11381 / 15734 1
# 11382 / 15734 SELECT Nationality FROM table WHERE Tonnage > 5,507 AND Sunk by… = u-584 ['=', '=']
# 11383 / 15734 1
# 11384 / 15734 1
# 11385 / 15734 1
# 11386 / 15734 1
# 11387 / 15734 SELECT Right ascension ( J2000 ) FROM table WHERE NGC number < 6995 AND Object type = diffuse nebula AND Declination ( J2000 ) = °42′30″ ['=', '=', '=']
# 11388 / 15734 SELECT Object type FROM table WHERE NGC number > 6995 AND Right ascension ( J2000 ) = 21h01m37.7s ['=', '=']
# 11389 / 15734 1
# 11390 / 15734 1
# 11391 / 15734 1
# 11392 / 15734 1
# 11393 / 15734 1
# 11394 / 15734 SELECT COUNT Peak FROM table WHERE HK viewers = 1.97 million AND Finale > 33 ['=', '=']
# 11395 / 15734 1
# 11396 / 15734 1
# 11397 / 15734 1
# 11398 / 15734 1
# 11399 / 15734 1
# 11400 / 15734 1
# 11401 / 15734 1
# 11402 / 15734 1
# 11403 / 15734 1
# 11404 / 15734 1
# 11405 / 15734 1
# 11406 / 15734 1
# 11407 / 15734 1
# 11408 / 15734 1
# 11409 / 15734 1
# 11410 / 15734 1
# 11411 / 15734 1
# 11412 / 15734 1
# 11413 / 15734 1
# 11414 / 15734 1
# 11415 / 15734 1
# 11416 / 15734 1
# 11417 / 15734 1
# 11418 / 15734 1
# 11419 / 15734 1
# 11420 / 15734 1
# 11421 / 15734 1
# 11422 / 15734 1
# 11423 / 15734 1
# 11424 / 15734 1
# 11425 / 15734 1
# 11426 / 15734 1
# 11427 / 15734 1
# 11428 / 15734 1
# 11429 / 15734 1
# 11430 / 15734 SELECT Title FROM table WHERE Track < 7 AND Translation = an island ['=', '=']
# 11431 / 15734 1
# 11432 / 15734 1
# 11433 / 15734 1
# 11434 / 15734 1
# 11435 / 15734 1
# 11436 / 15734 1
# 11437 / 15734 1
# 11438 / 15734 1
# 11439 / 15734 1
# 11440 / 15734 1
# 11441 / 15734 1
# 11442 / 15734 1
# 11443 / 15734 1
# 11444 / 15734 1
# 11445 / 15734 1
# 11446 / 15734 1
# 11447 / 15734 1
# 11448 / 15734 SELECT AVG Earnings ( $ ) FROM table WHERE Country = united states AND Wins < 2 AND Rank > 3 ['=', '=', '=']
# 11449 / 15734 SELECT AVG Events FROM table WHERE Player = al geiberger AND Wins < 1 ['=', '=']
# 11450 / 15734 1
# 11451 / 15734 SELECT COUNT Events FROM table WHERE Player = al geiberger AND Earnings ( $ ) > 527,033 ['=', '=']
# 11452 / 15734 SELECT AVG Events FROM table WHERE Rank < 2 AND Wins < 5 ['=', '=']
# 11453 / 15734 1
# 11454 / 15734 1
# 11455 / 15734 1
# 11456 / 15734 SELECT School FROM table WHERE Round > 3 AND Player = jason odom ['=', '=']
# 11457 / 15734 SELECT MIN Evening gown FROM table WHERE Swimsuit = 7.24 AND Interview > 7.97 ['=', '=']
# 11458 / 15734 1
# 11459 / 15734 1
# 11460 / 15734 1
# 11461 / 15734 1
# 11462 / 15734 SELECT Away team FROM table WHERE Crowd > 11,327 AND Home team score = 13.17 (95) ['=', '=']
# 11463 / 15734 1
# 11464 / 15734 1
# 11465 / 15734 1
# 11466 / 15734 1
# 11467 / 15734 SELECT Home city FROM table WHERE Capacity < 18060 AND 2011-12 season = prima divisione/a play-off winners ['=', '=']
# 11468 / 15734 1
# 11469 / 15734 1
# 11470 / 15734 1
# 11471 / 15734 1
# 11472 / 15734 1
# 11473 / 15734 SELECT SUM Number of seasons in top division FROM table WHERE Position in 2012–13 = 009 9th AND Number of seasons in the Premier League < 3 ['=', '=']
# 11474 / 15734 1
# 11475 / 15734 1
# 11476 / 15734 1
# 11477 / 15734 1
# 11478 / 15734 1
# 11479 / 15734 1
# 11480 / 15734 1
# 11481 / 15734 1
# 11482 / 15734 1
# 11483 / 15734 SELECT SUM Interview FROM table WHERE State = new york AND Swimsuit < 9.394 ['=', '=']
# 11484 / 15734 SELECT MAX Interview FROM table WHERE Swimsuit < 8.838 ['=']
# 11485 / 15734 SELECT MIN Average FROM table WHERE Swimsuit < 8.966 AND State = west virginia AND Evening Gown < 8.711 ['=', '=', '=']
# 11486 / 15734 SELECT MIN Swimsuit FROM table WHERE Evening Gown > 8.794 AND State = illinois ['=', '=']
# 11487 / 15734 1
# 11488 / 15734 SELECT Date FROM table WHERE Result = win AND Score = 2-1 AND Year < 2012 ['=', '=', '=']
# 11489 / 15734 1
# 11490 / 15734 1
# 11491 / 15734 1
# 11492 / 15734 SELECT SUM Bronze FROM table WHERE Gold = 2 AND Rank > 2 ['=', '=']
# 11493 / 15734 SELECT Visitor FROM table WHERE Attendance > 17,019 AND Home = toronto ['=', '=']
# 11494 / 15734 1
# 11495 / 15734 1
# 11496 / 15734 1
# 11497 / 15734 1
# 11498 / 15734 SELECT Club team FROM table WHERE Nationality = united states AND Overall < 142 ['=', '=']
# 11499 / 15734 SELECT Object type FROM table WHERE NGC number > 6357 AND Declination ( J2000 ) = °45′34″ ['=', '=']
# 11500 / 15734 1
# 11501 / 15734 SELECT MIN Year FROM table WHERE Theme = red maple AND Mintage > 15,000 ['=', '=']
# 11502 / 15734 SELECT Issue Price FROM table WHERE Year < 2006 AND Theme = voyageur ['=', '=']
# 11503 / 15734 1
# 11504 / 15734 1
# 11505 / 15734 1
# 11506 / 15734 1
# 11507 / 15734 SELECT HDD Capacity FROM table WHERE # FDD > 0 AND FDD Capacity (each) = 710kb ['=', '=']
# 11508 / 15734 1
# 11509 / 15734 SELECT Command Set FROM table WHERE FDD Capacity (each) = 270kb AND Sides = ds AND # FDD > 1 ['=', '=', '=']
# 11510 / 15734 1
# 11511 / 15734 SELECT Total viewers FROM table WHERE Share < 8 ['=']
# 11512 / 15734 1
# 11513 / 15734 SELECT Home team FROM table WHERE Crowd > 25,000 ['=']
# 11514 / 15734 1
# 11515 / 15734 SELECT Driver FROM table WHERE Grid < 10 AND Laps < 70 ['=', '=']
# 11516 / 15734 1
# 11517 / 15734 1
# 11518 / 15734 1
# 11519 / 15734 1
# 11520 / 15734 1
# 11521 / 15734 SELECT Loss FROM table WHERE Attendance > 42,607 AND Date = july 20 ['=', '=']
# 11522 / 15734 1
# 11523 / 15734 1
# 11524 / 15734 1
# 11525 / 15734 1
# 11526 / 15734 1
# 11527 / 15734 1
# 11528 / 15734 1
# 11529 / 15734 SELECT Birth State FROM table WHERE Election Year < 1848 ['=']
# 11530 / 15734 1
# 11531 / 15734 1
# 11532 / 15734 1
# 11533 / 15734 1
# 11534 / 15734 1
# 11535 / 15734 1
# 11536 / 15734 1
# 11537 / 15734 1
# 11538 / 15734 1
# 11539 / 15734 1
# 11540 / 15734 1
# 11541 / 15734 SELECT COUNT Goals for FROM table WHERE Games played > 1 AND Drawn* > 1 AND Lost < 19 AND Goals against > 3 ['=', '=', '=', '=']
# 11542 / 15734 1
# 11543 / 15734 1
# 11544 / 15734 1
# 11545 / 15734 1
# 11546 / 15734 1
# 11547 / 15734 1
# 11548 / 15734 SELECT Country of origin* FROM table WHERE Pick > 1 AND College = far eastern / psba ['=', '=']
# 11549 / 15734 1
# 11550 / 15734 1
# 11551 / 15734 1
# 11552 / 15734 1
# 11553 / 15734 1
# 11554 / 15734 1
# 11555 / 15734 1
# 11556 / 15734 1
# 11557 / 15734 1
# 11558 / 15734 1
# 11559 / 15734 1
# 11560 / 15734 SELECT COUNT Opening Weekend Net Gross FROM table WHERE Year > 2012 AND Rank = 1 ['=', '=']
# 11561 / 15734 1
# 11562 / 15734 1
# 11563 / 15734 SELECT COUNT Year FROM table WHERE Rank < 7 AND Studio(s) = red chillies entertainment AND Opening Weekend Net Gross = 52,93,00,000 ['=', '=', '=']
# 11564 / 15734 SELECT SUM Evening Gown FROM table WHERE State = kansas AND Interview < 9.357 ['=', '=']
# 11565 / 15734 SELECT State FROM table WHERE Swimsuit < 8.874 AND Evening Gown < 9.257 AND Interview < 9.121 ['=', '=', '=']
# 11566 / 15734 SELECT Swimsuit FROM table WHERE Interview < 8.808 ['=']
# 11567 / 15734 SELECT SUM Swimsuit FROM table WHERE Evening Gown > 9.257 AND Interview = 9.357 ['=', '=']
# 11568 / 15734 SELECT MAX Evening Gown FROM table WHERE State = north carolina AND Interview < 9.214 ['=', '=']
# 11569 / 15734 1
# 11570 / 15734 1
# 11571 / 15734 1
# 11572 / 15734 1
# 11573 / 15734 1
# 11574 / 15734 1
# 11575 / 15734 1
# 11576 / 15734 1
# 11577 / 15734 1
# 11578 / 15734 1
# 11579 / 15734 1
# 11580 / 15734 1
# 11581 / 15734 1
# 11582 / 15734 1
# 11583 / 15734 1
# 11584 / 15734 1
# 11585 / 15734 1
# 11586 / 15734 1
# 11587 / 15734 1
# 11588 / 15734 1
# 11589 / 15734 1
# 11590 / 15734 1
# 11591 / 15734 SELECT MAX Bronze FROM table WHERE Gold > 1 ['=']
# 11592 / 15734 SELECT COUNT Bronze FROM table WHERE Rank < 2 AND Gold < 1 ['=', '=']
# 11593 / 15734 SELECT MAX Rank FROM table WHERE Bronze < 1 AND Silver = 1 AND Total > 1 ['=', '=', '=']
# 11594 / 15734 SELECT SUM Average FROM table WHERE State = south carolina AND Interview < 9.626 ['=', '=']
# 11595 / 15734 SELECT MAX Interview FROM table WHERE Average > 9.324 AND State = louisiana ['=', '=']
# 11596 / 15734 1
# 11597 / 15734 1
# 11598 / 15734 1
# 11599 / 15734 1
# 11600 / 15734 1
# 11601 / 15734 SELECT Original air date FROM table WHERE Series # > 78 AND Written by = jenee v. giles ['=', '=']
# 11602 / 15734 SELECT COUNT Gold FROM table WHERE Sport = tennis AND Bronze < 2 ['=', '=']
# 11603 / 15734 1
# 11604 / 15734 SELECT COUNT Bronze FROM table WHERE Total > 2 AND Gold = 0 AND Sport = athletics ['=', '=', '=']
# 11605 / 15734 SELECT MAX Game FROM table WHERE Attendance > 65,042 ['=']
# 11606 / 15734 SELECT Name FROM table WHERE Order < 997 AND Goals > 5 AND Games = 215 ['=', '=', '=']
# 11607 / 15734 SELECT SUM Games FROM table WHERE Order = 1006 AND Goals > 192 ['=', '=']
# 11608 / 15734 SELECT Games FROM table WHERE Order > 975 AND Seasons = 2005 – 2007 AND Goals = 46 ['=', '=', '=']
# 11609 / 15734 1
# 11610 / 15734 1
# 11611 / 15734 1
# 11612 / 15734 1
# 11613 / 15734 1
# 11614 / 15734 SELECT Time/Retired FROM table WHERE Laps < 23 AND Grid > 23 ['=', '=']
# 11615 / 15734 SELECT SUM Laps FROM table WHERE Manufacturer = aprilia AND Rider = jorge lorenzo AND Grid > 1 ['=', '=', '=']
# 11616 / 15734 1
# 11617 / 15734 1
# 11618 / 15734 1
# 11619 / 15734 1
# 11620 / 15734 SELECT AVG Top-10 FROM table WHERE Wins < 1 AND Top-25 = 5 AND Cuts made < 10 ['=', '=', '=']
# 11621 / 15734 1
# 11622 / 15734 1
# 11623 / 15734 SELECT Time/Retired FROM table WHERE Laps < 77 AND Grid = 16 ['=', '=']
# 11624 / 15734 SELECT Constructor FROM table WHERE Grid < 24 AND Laps > 77 AND Driver = jean-pierre beltoise ['=', '=', '=']
# 11625 / 15734 1
# 11626 / 15734 SELECT Driver FROM table WHERE Constructor = maserati AND Laps < 18 AND Grid < 14 AND Time/Retired = oil leak ['=', '=', '=', '=']
# 11627 / 15734 1
# 11628 / 15734 1
# 11629 / 15734 1
# 11630 / 15734 1
# 11631 / 15734 1
# 11632 / 15734 1
# 11633 / 15734 1
# 11634 / 15734 1
# 11635 / 15734 1
# 11636 / 15734 1
# 11637 / 15734 1
# 11638 / 15734 1
# 11639 / 15734 1
# 11640 / 15734 1
# 11641 / 15734 1
# 11642 / 15734 1
# 11643 / 15734 1
# 11644 / 15734 1
# 11645 / 15734 1
# 11646 / 15734 1
# 11647 / 15734 1
# 11648 / 15734 1
# 11649 / 15734 1
# 11650 / 15734 1
# 11651 / 15734 1
# 11652 / 15734 1
# 11653 / 15734 1
# 11654 / 15734 1
# 11655 / 15734 1
# 11656 / 15734 1
# 11657 / 15734 1
# 11658 / 15734 1
# 11659 / 15734 1
# 11660 / 15734 1
# 11661 / 15734 1
# 11662 / 15734 1
# 11663 / 15734 1
# 11664 / 15734 1
# 11665 / 15734 1
# 11666 / 15734 1
# 11667 / 15734 SELECT Venue FROM table WHERE Competition = european indoor championships AND Year > 1979 ['=', '=']
# 11668 / 15734 SELECT Position FROM table WHERE Competition = european indoor championships AND Year < 1979 ['=', '=']
# 11669 / 15734 SELECT Player FROM table WHERE Pick # < 2 ['=']
# 11670 / 15734 1
# 11671 / 15734 1
# 11672 / 15734 1
# 11673 / 15734 1
# 11674 / 15734 1
# 11675 / 15734 1
# 11676 / 15734 1
# 11677 / 15734 1
# 11678 / 15734 SELECT Music director FROM table WHERE Year > 2003 ['=']
# 11679 / 15734 1
# 11680 / 15734 1
# 11681 / 15734 1
# 11682 / 15734 1
# 11683 / 15734 1
# 11684 / 15734 1
# 11685 / 15734 1
# 11686 / 15734 1
# 11687 / 15734 1
# 11688 / 15734 1
# 11689 / 15734 1
# 11690 / 15734 SELECT Production code FROM table WHERE Season # > 23 AND Series # < 126 AND Written by = gary sturgis ['=', '=', '=']
# 11691 / 15734 1
# 11692 / 15734 1
# 11693 / 15734 1
# 11694 / 15734 SELECT Constructor FROM table WHERE Grid > 4 AND Driver = heinz-harald frentzen ['=', '=']
# 11695 / 15734 1
# 11696 / 15734 1
# 11697 / 15734 1
# 11698 / 15734 1
# 11699 / 15734 1
# 11700 / 15734 1
# 11701 / 15734 1
# 11702 / 15734 1
# 11703 / 15734 1
# 11704 / 15734 SELECT Name FROM table WHERE Regional County Municipality = d'autray AND Code < 52017 ['=', '=']
# 11705 / 15734 1
# 11706 / 15734 1
# 11707 / 15734 1
# 11708 / 15734 1
# 11709 / 15734 1
# 11710 / 15734 1
# 11711 / 15734 1
# 11712 / 15734 1
# 11713 / 15734 SELECT Manufacturer FROM table WHERE Year withdrawn > 1932 ['=']
# 11714 / 15734 1
# 11715 / 15734 SELECT COUNT Losses FROM table WHERE Goals For > 29 AND Team = montreal ['=', '=']
# 11716 / 15734 SELECT AVG Goals For FROM table WHERE Wins > 8 ['=']
# 11717 / 15734 SELECT MAX Games Played FROM table WHERE Losses = 3 AND Wins > 5 ['=', '=']
# 11718 / 15734 SELECT Ties FROM table WHERE Goals Against < 33 ['=']
# 11719 / 15734 SELECT SUM Goals For FROM table WHERE Games Played > 8 ['=']
# 11720 / 15734 1
# 11721 / 15734 SELECT State FROM table WHERE Born > 1955 AND Name = maria cantwell ['=', '=']
# 11722 / 15734 SELECT SUM Laps FROM table WHERE Driver = lance reventlow AND Grid > 16 ['=', '=']
# 11723 / 15734 SELECT Constructor FROM table WHERE Laps = 35 AND Grid > 5 ['=', '=']
# 11724 / 15734 1
# 11725 / 15734 1
# 11726 / 15734 SELECT Seating FROM table WHERE Diagram no > 516 AND Type = driving motor brake second (dmbs) ['=', '=']
# 11727 / 15734 SELECT MIN Total FROM table WHERE Floor Exercise < 36.724 AND Rank < 8 ['=', '=']
# 11728 / 15734 1
# 11729 / 15734 1
# 11730 / 15734 1
# 11731 / 15734 1
# 11732 / 15734 1
# 11733 / 15734 1
# 11734 / 15734 1
# 11735 / 15734 1
# 11736 / 15734 1
# 11737 / 15734 1
# 11738 / 15734 1
# 11739 / 15734 1
# 11740 / 15734 1
# 11741 / 15734 SELECT AVG Total FROM table WHERE Tournament < 0 ['=']
# 11742 / 15734 SELECT MAX Total FROM table WHERE Tournament > 0 AND Regular season > 8 ['=', '=']
# 11743 / 15734 1
# 11744 / 15734 1
# 11745 / 15734 1
# 11746 / 15734 1
# 11747 / 15734 1
# 11748 / 15734 1
# 11749 / 15734 1
# 11750 / 15734 1
# 11751 / 15734 1
# 11752 / 15734 1
# 11753 / 15734 1
# 11754 / 15734 1
# 11755 / 15734 1
# 11756 / 15734 1
# 11757 / 15734 1
# 11758 / 15734 SELECT Score FROM table WHERE Year < 2008 AND Result = loss AND Location = antalya AND Competition = europe/africa zone, group i, round robin ['=', '=', '=', '=']
# 11759 / 15734 1
# 11760 / 15734 1
# 11761 / 15734 SELECT SUM Goal Diff. FROM table WHERE Losses > 1 AND Wins < 0 ['=', '=']
# 11762 / 15734 1
# 11763 / 15734 1
# 11764 / 15734 1
# 11765 / 15734 1
# 11766 / 15734 1
# 11767 / 15734 1
# 11768 / 15734 1
# 11769 / 15734 SELECT COUNT Yards FROM table WHERE Car. > 4 AND TD's = 2 AND Long > 8 ['=', '=', '=']
# 11770 / 15734 SELECT AVG Evening Gown FROM table WHERE Swimsuit < 8.703 AND State = new york AND Preliminaries > 8.292 ['=', '=', '=']
# 11771 / 15734 SELECT COUNT Preliminaries FROM table WHERE Evening Gown > 8.631 AND Average < 8.791 AND State = massachusetts AND Interview > 8.608 ['=', '=', '=', '=']
# 11772 / 15734 SELECT Preliminaries FROM table WHERE Swimsuit < 8.948 AND Interview = 8.997 ['=', '=']
# 11773 / 15734 SELECT MIN Interview FROM table WHERE Evening Gown > 9.343 ['=']
# 11774 / 15734 SELECT COUNT Evening Gown FROM table WHERE Preliminaries < 8.647 AND State = district of columbia ['=', '=']
# 11775 / 15734 SELECT Driver FROM table WHERE Laps > 35 AND Constructor = ferrari ['=', '=']
# 11776 / 15734 1
# 11777 / 15734 1
# 11778 / 15734 1
# 11779 / 15734 1
# 11780 / 15734 1
# 11781 / 15734 1
# 11782 / 15734 1
# 11783 / 15734 1
# 11784 / 15734 1
# 11785 / 15734 SELECT Away team score FROM table WHERE Crowd > 22,000 ['=']
# 11786 / 15734 1
# 11787 / 15734 1
# 11788 / 15734 1
# 11789 / 15734 1
# 11790 / 15734 SELECT COUNT Points FROM table WHERE Place < 7 AND Draw > 2 AND Artist = piece of cake ['=', '=', '=']
# 11791 / 15734 1
# 11792 / 15734 SELECT Time/Retired FROM table WHERE Grid > 10 AND Laps > 2 AND Constructor = maserati AND Driver = masten gregory carroll shelby ['=', '=', '=', '=']
# 11793 / 15734 1
# 11794 / 15734 1
# 11795 / 15734 1
# 11796 / 15734 SELECT Constructor FROM table WHERE Grid > 17 AND Time/Retired = brakes ['=', '=']
# 11797 / 15734 1
# 11798 / 15734 SELECT Time/Retired FROM table WHERE Laps > 9 AND Grid = 6 ['=', '=']
# 11799 / 15734 1
# 11800 / 15734 1
# 11801 / 15734 1
# 11802 / 15734 1
# 11803 / 15734 1
# 11804 / 15734 SELECT Constructor FROM table WHERE Grid > 21 AND Time/Retired = suspension ['=', '=']
# 11805 / 15734 SELECT MIN Rank FROM table WHERE Player = hale irwin AND Wins < 32 ['=', '=']
# 11806 / 15734 1
# 11807 / 15734 1
# 11808 / 15734 1
# 11809 / 15734 1
# 11810 / 15734 1
# 11811 / 15734 SELECT SUM Attendance FROM table WHERE Premiership = pre-season cup AND Runner Up = north melbourne AND Season < 2000 ['=', '=', '=']
# 11812 / 15734 1
# 11813 / 15734 1
# 11814 / 15734 1
# 11815 / 15734 1
# 11816 / 15734 1
# 11817 / 15734 1
# 11818 / 15734 1
# 11819 / 15734 1
# 11820 / 15734 1
# 11821 / 15734 1
# 11822 / 15734 SELECT Loss FROM table WHERE Attendance > 35,621 AND Date = july 1 ['=', '=']
# 11823 / 15734 SELECT MIN Goals FROM table WHERE Position = second row AND Points > 12 ['=', '=']
# 11824 / 15734 SELECT MIN Points FROM table WHERE Tries = 39 AND Goals > 0 ['=', '=']
# 11825 / 15734 1
# 11826 / 15734 1
# 11827 / 15734 1
# 11828 / 15734 1
# 11829 / 15734 1
# 11830 / 15734 1
# 11831 / 15734 1
# 11832 / 15734 1
# 11833 / 15734 1
# 11834 / 15734 1
# 11835 / 15734 1
# 11836 / 15734 1
# 11837 / 15734 1
# 11838 / 15734 1
# 11839 / 15734 1
# 11840 / 15734 1
# 11841 / 15734 SELECT Away team FROM table WHERE Crowd > 29,000 ['=']
# 11842 / 15734 SELECT AVG Avg. FROM table WHERE Yards = 124 AND Rec. < 13 ['=', '=']
# 11843 / 15734 1
# 11844 / 15734 1
# 11845 / 15734 1
# 11846 / 15734 1
# 11847 / 15734 1
# 11848 / 15734 1
# 11849 / 15734 1
# 11850 / 15734 1
# 11851 / 15734 1
# 11852 / 15734 1
# 11853 / 15734 1
# 11854 / 15734 1
# 11855 / 15734 1
# 11856 / 15734 1
# 11857 / 15734 SELECT Away team FROM table WHERE Crowd > 10,530 AND Venue = vfl park ['=', '=']
# 11858 / 15734 SELECT Away team FROM table WHERE Crowd > 23,365 AND Home team = carlton ['=', '=']
# 11859 / 15734 1
# 11860 / 15734 1
# 11861 / 15734 1
# 11862 / 15734 1
# 11863 / 15734 1
# 11864 / 15734 1
# 11865 / 15734 SELECT MIN Draws FROM table WHERE Losses = 5 AND Byes > 0 ['=', '=']
# 11866 / 15734 SELECT MIN Losses FROM table WHERE Draws > 0 AND Byes > 0 ['=', '=']
# 11867 / 15734 SELECT COUNT Byes FROM table WHERE Losses = 13 AND Wins < 5 ['=', '=']
# 11868 / 15734 1
# 11869 / 15734 1
# 11870 / 15734 1
# 11871 / 15734 1
# 11872 / 15734 1
# 11873 / 15734 1
# 11874 / 15734 1
# 11875 / 15734 1
# 11876 / 15734 1
# 11877 / 15734 1
# 11878 / 15734 1
# 11879 / 15734 SELECT Chassis FROM table WHERE Year > 1990 AND Entrant = minardi scuderia italia AND Points = 4 ['=', '=', '=']
# 11880 / 15734 SELECT Player FROM table WHERE Avg. < 11.4 AND Long < 24 AND TD's > 1 ['=', '=', '=']
# 11881 / 15734 SELECT Gender FROM table WHERE Decile > 1 AND Name = south auckland seventh-day adventist school ['=', '=']
# 11882 / 15734 1
# 11883 / 15734 1
# 11884 / 15734 1
# 11885 / 15734 1
# 11886 / 15734 1
# 11887 / 15734 1
# 11888 / 15734 1
# 11889 / 15734 1
# 11890 / 15734 1
# 11891 / 15734 1
# 11892 / 15734 1
# 11893 / 15734 1
# 11894 / 15734 1
# 11895 / 15734 1
# 11896 / 15734 1
# 11897 / 15734 1
# 11898 / 15734 1
# 11899 / 15734 1
# 11900 / 15734 1
# 11901 / 15734 1
# 11902 / 15734 1
# 11903 / 15734 1
# 11904 / 15734 SELECT MAX Revenue €Million FROM table WHERE Employees (World) = 95,175 AND Rank < 8 ['=', '=']
# 11905 / 15734 SELECT AVG Goals FROM table WHERE Apps < 3 ['=']
# 11906 / 15734 SELECT Time/Retired FROM table WHERE Grid < 10 AND Laps > 20 AND Constructor = talbot-lago - talbot ['=', '=', '=']
# 11907 / 15734 1
# 11908 / 15734 SELECT MAX Grid FROM table WHERE Laps < 35 AND Constructor = maserati ['=', '=']
# 11909 / 15734 1
# 11910 / 15734 1
# 11911 / 15734 1
# 11912 / 15734 1
# 11913 / 15734 1
# 11914 / 15734 1
# 11915 / 15734 1
# 11916 / 15734 1
# 11917 / 15734 1
# 11918 / 15734 1
# 11919 / 15734 1
# 11920 / 15734 1
# 11921 / 15734 1
# 11922 / 15734 1
# 11923 / 15734 1
# 11924 / 15734 1
# 11925 / 15734 1
# 11926 / 15734 1
# 11927 / 15734 1
# 11928 / 15734 SELECT Venue FROM table WHERE Scored > 1 ['=']
# 11929 / 15734 1
# 11930 / 15734 1
# 11931 / 15734 SELECT MAX Total FROM table WHERE Gold = 2 AND Bronze = 0 AND Rank < 2 ['=', '=', '=']
# 11932 / 15734 1
# 11933 / 15734 1
# 11934 / 15734 SELECT MIN Total FROM table WHERE Bronze > 0 AND Nation = switzerland AND Gold < 1 ['=', '=', '=']
# 11935 / 15734 SELECT MAX Bronze FROM table WHERE Gold > 1 AND Silver < 0 ['=', '=']
# 11936 / 15734 1
# 11937 / 15734 1
# 11938 / 15734 1
# 11939 / 15734 1
# 11940 / 15734 1
# 11941 / 15734 1
# 11942 / 15734 1
# 11943 / 15734 1
# 11944 / 15734 1
# 11945 / 15734 1
# 11946 / 15734 1
# 11947 / 15734 1
# 11948 / 15734 1
# 11949 / 15734 1
# 11950 / 15734 1
# 11951 / 15734 1
# 11952 / 15734 1
# 11953 / 15734 1
# 11954 / 15734 SELECT COUNT Laps FROM table WHERE Constructor = brm AND Driver = piers courage AND Grid > 8 ['=', '=', '=']
# 11955 / 15734 SELECT PSIP Short Name FROM table WHERE Channel > 63.4 ['=']
# 11956 / 15734 SELECT Programming FROM table WHERE Channel < 63.2 ['=']
# 11957 / 15734 1
# 11958 / 15734 1
# 11959 / 15734 1
# 11960 / 15734 1
# 11961 / 15734 1
# 11962 / 15734 1
# 11963 / 15734 1
# 11964 / 15734 1
# 11965 / 15734 1
# 11966 / 15734 1
# 11967 / 15734 1
# 11968 / 15734 1
# 11969 / 15734 1
# 11970 / 15734 1
# 11971 / 15734 1
# 11972 / 15734 1
# 11973 / 15734 1
# 11974 / 15734 1
# 11975 / 15734 1
# 11976 / 15734 1
# 11977 / 15734 1
# 11978 / 15734 SELECT AVG Prom. (m) FROM table WHERE Height (m) > 733 AND Class = hewitt AND Peak = kirk fell east top ['=', '=', '=']
# 11979 / 15734 SELECT Venue FROM table WHERE Crowd > 30,000 AND Away team = north melbourne ['=', '=']
# 11980 / 15734 1
# 11981 / 15734 1
# 11982 / 15734 1
# 11983 / 15734 1
# 11984 / 15734 1
# 11985 / 15734 SELECT MAX Rank FROM table WHERE Earnings ( $ ) < 2,708,005 AND Events = 30 ['=', '=']
# 11986 / 15734 SELECT Season FROM table WHERE Points > 21 AND Finish = 6th north ['=', '=']
# 11987 / 15734 1
# 11988 / 15734 SELECT Film name FROM table WHERE Year > 1972 AND Language = hindi AND Lyricist = ravindra jain AND Music director = ravindra jain ['=', '=', '=', '=']
# 11989 / 15734 1
# 11990 / 15734 SELECT Make FROM table WHERE Car # < 40 AND Points < 151 AND Winnings = $84,400 ['=', '=', '=']
# 11991 / 15734 SELECT SUM Laps FROM table WHERE Winnings = $67,675 AND Points < 61 ['=', '=']
# 11992 / 15734 1
# 11993 / 15734 1
# 11994 / 15734 SELECT COUNT Drop FROM table WHERE Points < 65 ['=']
# 11995 / 15734 SELECT Name FROM table WHERE Points < 73 AND Drop > 0 ['=', '=']
# 11996 / 15734 1
# 11997 / 15734 1
# 11998 / 15734 1
# 11999 / 15734 1
# 12000 / 15734 1
# 12001 / 15734 1
# 12002 / 15734 1
# 12003 / 15734 SELECT Venue FROM table WHERE Crowd > 12,786 AND Away team score = 12.9 (81) ['=', '=']
# 12004 / 15734 1
# 12005 / 15734 1
# 12006 / 15734 SELECT MIN Laps FROM table WHERE Driver = rolf stommelen AND Grid > 18 ['=', '=']
# 12007 / 15734 1
# 12008 / 15734 1
# 12009 / 15734 1
# 12010 / 15734 1
# 12011 / 15734 1
# 12012 / 15734 SELECT MAX Lowest FROM table WHERE Stadium = ibrox stadium AND Average > 49,143 ['=', '=']
# 12013 / 15734 SELECT MIN Highest FROM table WHERE Lowest > 4,086 AND Capacity = 14,209 AND Average < 8,530 ['=', '=', '=']
# 12014 / 15734 1
# 12015 / 15734 SELECT Role FROM table WHERE Year < 1991 AND Direction = joemon ['=', '=']
# 12016 / 15734 SELECT COUNT Wins FROM table WHERE Top-10 = 2 AND Events > 8 AND Cuts made > 6 ['=', '=', '=']
# 12017 / 15734 SELECT MAX Wins FROM table WHERE Top-25 = 13 AND Events < 32 ['=', '=']
# 12018 / 15734 SELECT COUNT Wins FROM table WHERE Tournament = u.s. open AND Top-25 < 4 ['=', '=']
# 12019 / 15734 1
# 12020 / 15734 1
# 12021 / 15734 1
# 12022 / 15734 1
# 12023 / 15734 1
# 12024 / 15734 1
# 12025 / 15734 1
# 12026 / 15734 1
# 12027 / 15734 1
# 12028 / 15734 SELECT SUM Place FROM table WHERE Song = before the clock strikes 12 AND Points > 55 ['=', '=']
# 12029 / 15734 1
# 12030 / 15734 SELECT Driver FROM table WHERE Constructor = renault AND Q1 pos > 2 ['=', '=']
# 12031 / 15734 SELECT Constructor FROM table WHERE Q1 pos < 8 AND Q1 time = 1:15.038 ['=', '=']
# 12032 / 15734 1
# 12033 / 15734 1
# 12034 / 15734 1
# 12035 / 15734 1
# 12036 / 15734 1
# 12037 / 15734 1
# 12038 / 15734 1
# 12039 / 15734 1
# 12040 / 15734 1
# 12041 / 15734 1
# 12042 / 15734 1
# 12043 / 15734 1
# 12044 / 15734 1
# 12045 / 15734 1
# 12046 / 15734 1
# 12047 / 15734 1
# 12048 / 15734 1
# 12049 / 15734 1
# 12050 / 15734 1
# ...
# 15318 / 15734 SELECT COUNT Points FROM table WHERE Entrant = wolfgang seidel AND Chassis = cooper t45 AND Year > 1960 ['=', '=', '=']
# 15319 / 15734 SELECT MAX Year FROM table WHERE Chassis = emeryson 1006 AND Points > 0 ['=', '=']
# 15320 / 15734 1
# 15321 / 15734 1
# 15322 / 15734 1
# 15323 / 15734 1
# 15324 / 15734 1
# 15325 / 15734 1
# 15326 / 15734 1
# 15327 / 15734 SELECT MAX Laps FROM table WHERE Rider = marco melandri AND Grid < 10 ['=', '=']
# 15328 / 15734 SELECT MIN Grid FROM table WHERE Rider = sylvain guintoli AND Laps > 32 ['=', '=']
# 15329 / 15734 SELECT Runner-up FROM table WHERE Year > 2010 AND Winner = ding junhui ['=', '=']
# 15330 / 15734 1
# 15331 / 15734 1
# 15332 / 15734 1
# 15333 / 15734 1
# 15334 / 15734 SELECT Placement FROM table WHERE Votes < 208 AND Candidate = jordan turner ['=', '=']
# 15335 / 15734 1
# 15336 / 15734 1
# 15337 / 15734 1
# 15338 / 15734 1
# 15339 / 15734 1
# 15340 / 15734 1
# 15341 / 15734 1
# 15342 / 15734 1
# 15343 / 15734 1
# 15344 / 15734 1
# 15345 / 15734 SELECT Venue FROM table WHERE Goal > 3 AND Competition = 2011 afc asian cup ['=', '=']
# 15346 / 15734 1
# 15347 / 15734 1
# 15348 / 15734 1
# 15349 / 15734 1
# 15350 / 15734 1
# 15351 / 15734 1
# 15352 / 15734 1
# 15353 / 15734 1
# 15354 / 15734 1
# 15355 / 15734 1
# 15356 / 15734 1
# 15357 / 15734 1
# 15358 / 15734 SELECT Manufacture FROM table WHERE Opened in < 2001 AND Type = mini jet red baron ['=', '=']
# 15359 / 15734 1
# 15360 / 15734 1
# 15361 / 15734 1
# 15362 / 15734 1
# 15363 / 15734 SELECT Country FROM table WHERE Year > 2008 ['=']
# 15364 / 15734 1
# 15365 / 15734 SELECT AVG Year FROM table WHERE Points > 0 ['=']
# 15366 / 15734 1
# 15367 / 15734 SELECT Time FROM table WHERE Heat < 3 AND Lane > 2 AND Name = jean luc razakarivony ['=', '=', '=']
# 15368 / 15734 1
# 15369 / 15734 SELECT Nationality FROM table WHERE Heat < 9 AND Time = 1:01.87 ['=', '=']
# 15370 / 15734 1
# 15371 / 15734 1
# 15372 / 15734 1
# 15373 / 15734 1
# 15374 / 15734 1
# 15375 / 15734 1
# 15376 / 15734 1
# 15377 / 15734 1
# 15378 / 15734 SELECT Bronze FROM table WHERE Rank > 5 ['=']
# 15379 / 15734 SELECT MAX Bronze FROM table WHERE Rank > 5 AND Gold < 0 ['=', '=']
# 15380 / 15734 1
# 15381 / 15734 1
# 15382 / 15734 1
# 15383 / 15734 1
# 15384 / 15734 1
# 15385 / 15734 1
# 15386 / 15734 1
# 15387 / 15734 1
# 15388 / 15734 1
# 15389 / 15734 1
# 15390 / 15734 SELECT Venue FROM table WHERE Year < 2003 AND Notes = 57.73 m ['=', '=']
# 15391 / 15734 1
# 15392 / 15734 1
# 15393 / 15734 1
# 15394 / 15734 1
# 15395 / 15734 1
# 15396 / 15734 1
# 15397 / 15734 1
# 15398 / 15734 1
# 15399 / 15734 1
# 15400 / 15734 SELECT Opponent FROM table WHERE Attendance > 54,766 ['=']
# 15401 / 15734 1
# 15402 / 15734 1
# 15403 / 15734 1
# 15404 / 15734 SELECT Team #1 FROM table WHERE Time ( CEST ) < 18 ['=']
# 15405 / 15734 1
# 15406 / 15734 SELECT Method FROM table WHERE Time = 5:00 AND Round < 3 AND Res. = loss AND Event = road fc 12 ['=', '=', '=', '=']
# 15407 / 15734 1
# 15408 / 15734 1
# 15409 / 15734 SELECT Location FROM table WHERE Round > 1 AND Opponent = yoshihiro akiyama ['=', '=']
# 15410 / 15734 1
# 15411 / 15734 1
# 15412 / 15734 1
# 15413 / 15734 1
# 15414 / 15734 1
# 15415 / 15734 1
# 15416 / 15734 1
# 15417 / 15734 1
# 15418 / 15734 1
# 15419 / 15734 SELECT Player FROM table WHERE Score > 70 AND To par = +1 ['=', '=']
# 15420 / 15734 1
# 15421 / 15734 SELECT Original title FROM table WHERE Year > 1985 AND Country = uk ['=', '=']
# 15422 / 15734 SELECT English title FROM table WHERE Year > 1981 AND Country = argentina ['=', '=']
# 15423 / 15734 1
# 15424 / 15734 1
# 15425 / 15734 1
# 15426 / 15734 SELECT MIN Gold FROM table WHERE Nation = west germany AND Total > 8 ['=', '=']
# 15427 / 15734 SELECT SUM Gold FROM table WHERE Bronze < 1 ['=']
# 15428 / 15734 SELECT AVG Total FROM table WHERE Bronze < 4 AND Silver = 1 AND Rank = 7 ['=', '=', '=']
# 15429 / 15734 1
# 15430 / 15734 1
# 15431 / 15734 1
# 15432 / 15734 1
# 15433 / 15734 1
# 15434 / 15734 1
# 15435 / 15734 1
# 15436 / 15734 1
# 15437 / 15734 1
# 15438 / 15734 SELECT Place FROM table WHERE Score > 68 AND Player = camilo villegas ['=', '=']
# 15439 / 15734 1
# 15440 / 15734 SELECT Years FROM table WHERE Authority = state AND Decile > 6 AND Roll < 33 ['=', '=', '=']
# 15441 / 15734 1
# 15442 / 15734 SELECT AVG Gold Medals FROM table WHERE Bronze Medals < 1 AND Silver Medals = 0 AND Total Medals > 1 ['=', '=', '=']
# 15443 / 15734 SELECT COUNT Bronze Medals FROM table WHERE Gold Medals = 2 AND Total Medals > 4 AND Silver Medals < 5 ['=', '=', '=']
# 15444 / 15734 SELECT Ensemble FROM table WHERE Silver Medals > 1 ['=']
# 15445 / 15734 1
# 15446 / 15734 1
# 15447 / 15734 1
# 15448 / 15734 1
# 15449 / 15734 1
# 15450 / 15734 1
# 15451 / 15734 1
# 15452 / 15734 SELECT Opponent FROM table WHERE Attendance > 23,230 AND Record = 56-37 ['=', '=']
# 15453 / 15734 1
# 15454 / 15734 1
# 15455 / 15734 1
# 15456 / 15734 1
# 15457 / 15734 1
# 15458 / 15734 1
# 15459 / 15734 SELECT AVG Top-5 FROM table WHERE Top-25 = 0 AND Wins < 0 ['=', '=']
# 15460 / 15734 SELECT COUNT Top-25 FROM table WHERE Top-5 > 1 ['=']
# 15461 / 15734 SELECT SUM Top-10 FROM table WHERE Cuts made = 2 AND Wins < 0 ['=', '=']
# 15462 / 15734 SELECT AVG Top-5 FROM table WHERE Cuts made = 5 AND Tournament = the open championship AND Events < 6 ['=', '=', '=']
# 15463 / 15734 SELECT MIN Events FROM table WHERE Top-5 > 1 ['=']
# 15464 / 15734 1
# 15465 / 15734 1
# 15466 / 15734 1
# 15467 / 15734 1
# 15468 / 15734 1
# 15469 / 15734 1
# 15470 / 15734 1
# 15471 / 15734 1
# 15472 / 15734 1
# 15473 / 15734 1
# 15474 / 15734 1
# 15475 / 15734 1
# 15476 / 15734 1
# 15477 / 15734 SELECT MAX Fastest time (s) FROM table WHERE Location = enugu AND Rank > 2 ['=', '=']
# 15478 / 15734 1
# 15479 / 15734 1
# 15480 / 15734 1
# 15481 / 15734 1
# 15482 / 15734 1
# 15483 / 15734 1
# 15484 / 15734 1
# 15485 / 15734 1
# 15486 / 15734 1
# 15487 / 15734 SELECT MAX Year FROM table WHERE Pts. > 0 ['=']
# 15488 / 15734 SELECT SUM 1930s FROM table WHERE 2000s = 2000 AND 1940s < 1940 ['=', '=']
# 15489 / 15734 SELECT 1940s FROM table WHERE 1980s < 1986 AND 1990s < 1995 AND 1970s < 1973 AND 2000s > 2001 ['=', '=', '=', '=']
# 15490 / 15734 SELECT AVG 1980s FROM table WHERE 1910s = 1912 AND 1940s < 1942 ['=', '=']
# 15491 / 15734 SELECT MIN 1910s FROM table WHERE 1950s < 1952 AND 1980s > 1981 ['=', '=']
# 15492 / 15734 SELECT MAX Gold FROM table WHERE Total < 4 AND Silver = 1 AND Bronze < 2 AND Rank = 13 ['=', '=', '=', '=']
# 15493 / 15734 SELECT Nation FROM table WHERE Bronze < 1 AND Silver < 1 AND Gold > 1 ['=', '=', '=']
# 15494 / 15734 1
# 15495 / 15734 1
# 15496 / 15734 1
# 15497 / 15734 1
# 15498 / 15734 1
# 15499 / 15734 1
# 15500 / 15734 1
# 15501 / 15734 1
# 15502 / 15734 1
# 15503 / 15734 1
# 15504 / 15734 1
# 15505 / 15734 1
# 15506 / 15734 1
# 15507 / 15734 1
# 15508 / 15734 1
# 15509 / 15734 1
# 15510 / 15734 SELECT Record FROM table WHERE Attendance > 12,552 AND Score = 7-0 ['=', '=']
# 15511 / 15734 1
# 15512 / 15734 SELECT Women's singles FROM table WHERE Year > 2006 AND Men's singles = cancelled ['=', '=']
# 15513 / 15734 1
# 15514 / 15734 1
# 15515 / 15734 SELECT Name FROM table WHERE Lane < 3 AND Heat > 4 AND Time = 2:00.80 ['=', '=', '=']
# 15516 / 15734 1
# 15517 / 15734 1
# 15518 / 15734 1
# 15519 / 15734 1
# 15520 / 15734 1
# 15521 / 15734 SELECT Date FROM table WHERE Week > 6 AND Opponent = new york jets ['=', '=']
# 15522 / 15734 1
# 15523 / 15734 SELECT COUNT Goals for FROM table WHERE Lost > 35 AND Games < 80 ['=', '=']
# 15524 / 15734 SELECT SUM Goals against FROM table WHERE Points = 72 AND Lost > 37 ['=', '=']
# 15525 / 15734 SELECT SUM Points FROM table WHERE Goals for > 225 AND Goals against = 190 ['=', '=']
# 15526 / 15734 1
# 15527 / 15734 1
# 15528 / 15734 1
# 15529 / 15734 SELECT Team FROM table WHERE Value ($M) < 377 AND Country = germany AND Rank = 17 ['=', '=', '=']
# 15530 / 15734 SELECT MIN Rank FROM table WHERE Value ($M) < 1,200 AND Revenue ($M) < 396 AND Team = manchester city ['=', '=', '=']
# 15531 / 15734 SELECT AVG Revenue ($M) FROM table WHERE Team = bayern munich AND Rank > 4 ['=', '=']
# 15532 / 15734 SELECT Country FROM table WHERE % change on year > 5 AND Rank = 10 ['=', '=']
# 15533 / 15734 1
# 15534 / 15734 1
# 15535 / 15734 1
# 15536 / 15734 1
# 15537 / 15734 1
# 15538 / 15734 1
# 15539 / 15734 1
# 15540 / 15734 1
# 15541 / 15734 1
# 15542 / 15734 1
# 15543 / 15734 1
# 15544 / 15734 1
# 15545 / 15734 1
# 15546 / 15734 1
# 15547 / 15734 1
# 15548 / 15734 1
# 15549 / 15734 1
# 15550 / 15734 1
# 15551 / 15734 1
# 15552 / 15734 1
# 15553 / 15734 1
# 15554 / 15734 SELECT COUNT Rank FROM table WHERE Lane > 4 AND Nationality = great britain AND Name = margaretha pedder ['=', '=', '=']
# 15555 / 15734 1
# 15556 / 15734 SELECT COUNT Lane FROM table WHERE Time = 2:08.11 AND Rank > 3 ['=', '=']
# 15557 / 15734 SELECT Years FROM table WHERE Decile < 4 AND Name = tkkm o te ara rima ['=', '=']
# 15558 / 15734 1
# 15559 / 15734 1
# 15560 / 15734 1
# 15561 / 15734 1
# 15562 / 15734 1
# 15563 / 15734 1
# 15564 / 15734 1
# 15565 / 15734 1
# 15566 / 15734 SELECT Year FROM table WHERE Points > 0 ['=']
# 15567 / 15734 SELECT SUM Points FROM table WHERE Year < 1963 ['=']
# 15568 / 15734 1
# 15569 / 15734 1
# 15570 / 15734 1
# 15571 / 15734 1
# 15572 / 15734 1
# 15573 / 15734 SELECT Entrant FROM table WHERE Year < 1965 AND Points > 0 AND Chassis = lotus 25 ['=', '=', '=']
# 15574 / 15734 1
# 15575 / 15734 SELECT Chassis FROM table WHERE Entrant = team lotus AND Year > 1964 ['=', '=']
# 15576 / 15734 SELECT Others% FROM table WHERE Others# > 147 AND Kerry% = 39.6% ['=', '=']
# 15577 / 15734 SELECT COUNT Others# FROM table WHERE County = langlade AND Bush# > 6,235 ['=', '=']
# 15578 / 15734 SELECT AVG Bush# FROM table WHERE Others# > 57 AND Bush% = 49.2% ['=', '=']
# 15579 / 15734 SELECT County FROM table WHERE Others% = 1.1% AND Kerry# > 19,177 AND Bush% = 52.1% ['=', '=', '=']
# 15580 / 15734 1
# 15581 / 15734 1
# 15582 / 15734 1
# 15583 / 15734 1
# 15584 / 15734 1
# 15585 / 15734 1
# 15586 / 15734 1
# 15587 / 15734 1
# 15588 / 15734 1
# 15589 / 15734 1
# 15590 / 15734 1
# 15591 / 15734 SELECT MAX Played FROM table WHERE Goals Conceded = 21 AND Draw > 3 ['=', '=']
# 15592 / 15734 SELECT COUNT Points FROM table WHERE Goals Scored < 20 ['=']
# 15593 / 15734 SELECT COUNT Points FROM table WHERE Lost > 6 AND Team = once municipal AND Goals Scored < 8 ['=', '=', '=']
# 15594 / 15734 SELECT MAX Points FROM table WHERE Draw = 2 AND Played < 18 ['=', '=']
# 15595 / 15734 SELECT COUNT Place FROM table WHERE Draw < 4 AND Lost < 6 ['=', '=']
# 15596 / 15734 SELECT MIN Rank FROM table WHERE Nationality = poland AND Time > 55.34 ['=', '=']
# 15597 / 15734 SELECT Name FROM table WHERE Lane < 7 AND Time > 54.32 AND Nationality = germany AND Rank < 5 ['=', '=', '=', '=']
# 15598 / 15734 1
# 15599 / 15734 SELECT AVG Time FROM table WHERE Name = eithan urbach AND Lane > 2 ['=', '=']
# 15600 / 15734 1
# 15601 / 15734 1
# 15602 / 15734 1
# 15603 / 15734 1
# 15604 / 15734 1
# 15605 / 15734 1
# 15606 / 15734 1
# 15607 / 15734 1
# 15608 / 15734 1
# 15609 / 15734 1
# 15610 / 15734 1
# 15611 / 15734 1
# 15612 / 15734 SELECT COUNT Points FROM table WHERE Chassis = bmw 269 f2 AND Year < 1969 ['=', '=']
# 15613 / 15734 1
# 15614 / 15734 1
# 15615 / 15734 SELECT MIN Rank FROM table WHERE Nationality = netherlands AND Lane < 4 ['=', '=']
# 15616 / 15734 SELECT AVG Total FROM table WHERE League Cup > 0 AND Other > 0 ['=', '=']
# 15617 / 15734 SELECT MIN Other FROM table WHERE Total < 14 AND League = 2 AND FA Cup > 0 AND League Cup < 0 ['=', '=', '=', '=']
# 15618 / 15734 SELECT SUM FA Cup FROM table WHERE League Cup < 0 ['=']
# 15619 / 15734 1
# 15620 / 15734 1
# 15621 / 15734 1
# 15622 / 15734 SELECT Venue FROM table WHERE Event = 4x400m relay AND Year > 2002 AND Position = 4th ['=', '=', '=']
# 15623 / 15734 1
# 15624 / 15734 1
# 15625 / 15734 1
# 15626 / 15734 SELECT Engine FROM table WHERE Entrant = team lotus AND Year > 1965 ['=', '=']
# 15627 / 15734 1
# 15628 / 15734 1
# 15629 / 15734 SELECT MAX Losses FROM table WHERE Games < 25 AND Season = 2010 ['=', '=']
# 15630 / 15734 SELECT AVG Points FROM table WHERE Games = 17 AND Losses > 15 ['=', '=']
# 15631 / 15734 1
# 15632 / 15734 1
# 15633 / 15734 1
# 15634 / 15734 1
# 15635 / 15734 1
# 15636 / 15734 1
# 15637 / 15734 1
# 15638 / 15734 1
# 15639 / 15734 1
# 15640 / 15734 1
# 15641 / 15734 SELECT Written by FROM table WHERE Prod. code > 1.4 AND Directed by = rick wallace ['=', '=']
# 15642 / 15734 1
# 15643 / 15734 SELECT AVG Total FROM table WHERE Player = simon donnelly AND Scottish Cup > 0 ['=', '=']
# 15644 / 15734 SELECT SUM Challenge Cup FROM table WHERE League = 1 AND Player = simon storey AND Total > 1 ['=', '=', '=']
# 15645 / 15734 SELECT MAX Total FROM table WHERE Player = damon gray AND Challenge Cup < 0 ['=', '=']
# 15646 / 15734 SELECT MIN Scottish Cup FROM table WHERE Challenge Cup > 0 AND Player = paul keegan AND League Cup > 0 ['=', '=', '=']
# 15647 / 15734 SELECT MAX Challenge Cup FROM table WHERE League < 2 AND Total > 2 AND League Cup > 1 ['=', '=', '=']
# 15648 / 15734 SELECT MAX Total FROM table WHERE League Cup > 0 AND Player = gary harkins AND Scottish Cup > 0 ['=', '=', '=']
# 15649 / 15734 1
# 15650 / 15734 1
# 15651 / 15734 1
# 15652 / 15734 1
# 15653 / 15734 1
# 15654 / 15734 SELECT COUNT Goals for FROM table WHERE Played > 44 ['=']
# 15655 / 15734 SELECT MAX Draws FROM table WHERE Goals against > 56 AND Wins > 14 ['=', '=']
# 15656 / 15734 SELECT MIN Goals for FROM table WHERE Position > 4 AND Draws > 11 ['=', '=']
# 15657 / 15734 SELECT MAX Wins FROM table WHERE Club = elche cf AND Goals against > 43 ['=', '=']
# 15658 / 15734 SELECT SUM Shirt No FROM table WHERE Birth Date = 8 november 1980 AND Weight < 93 ['=', '=']
# 15659 / 15734 SELECT COUNT Weight FROM table WHERE Shirt No = 18 AND Height > 195 ['=', '=']
# 15660 / 15734 1
# 15661 / 15734 1
# 15662 / 15734 1
# 15663 / 15734 1
# 15664 / 15734 1
# 15665 / 15734 1
# 15666 / 15734 1
# 15667 / 15734 1
# 15668 / 15734 1
# 15669 / 15734 1
# 15670 / 15734 1
# 15671 / 15734 1
# 15672 / 15734 1
# 15673 / 15734 1
# 15674 / 15734 1
# 15675 / 15734 1
# 15676 / 15734 1
# 15677 / 15734 SELECT SUM Laps FROM table WHERE Co-Drivers = oliver gavin jan magnussen AND Class = gts AND Year < 2004 ['=', '=', '=']
# 15678 / 15734 SELECT Team FROM table WHERE Laps > 333 AND Year < 2004 ['=', '=']
# 15679 / 15734 1
# 15680 / 15734 1
# 15681 / 15734 1
# 15682 / 15734 1
# 15683 / 15734 1
# 15684 / 15734 1
# 15685 / 15734 SELECT Place FROM table WHERE Score < 69 ['=']
# 15686 / 15734 1
# 15687 / 15734 SELECT Entrant FROM table WHERE Year < 1958 AND Chassis = cooper t43 ['=', '=']
# 15688 / 15734 1
# 15689 / 15734 1
# 15690 / 15734 1
# 15691 / 15734 1
# 15692 / 15734 1
# 15693 / 15734 1
# 15694 / 15734 1
# 15695 / 15734 1
# 15696 / 15734 SELECT AVG Year FROM table WHERE Pts. > 0 AND Entrant = ecurie bleue ['=', '=']
# 15697 / 15734 1
# 15698 / 15734 1
# 15699 / 15734 1
# 15700 / 15734 1
# 15701 / 15734 1
# 15702 / 15734 1
# 15703 / 15734 SELECT COUNT Full professors FROM table WHERE Head = hartmut kliemt AND Lecturers > 0 ['=', '=']
# 15704 / 15734 SELECT MIN Lecturers FROM table WHERE Department = accounting AND Full professors < 5 ['=', '=']
# 15705 / 15734 1
# 15706 / 15734 1
# 15707 / 15734 1
# 15708 / 15734 1
# 15709 / 15734 1
# 15710 / 15734 1
# 15711 / 15734 1
# 15712 / 15734 1
# 15713 / 15734 1
# 15714 / 15734 1
# 15715 / 15734 SELECT District FROM table WHERE Counties Represented = baltimore county AND Committee = health and government operations AND First Elected < 2002 ['=', '=', '=']
# 15716 / 15734 1
# 15717 / 15734 1
# 15718 / 15734 SELECT MAX Ranking FROM table WHERE Years = 1996–13 AND Goals > 17 ['=', '=']
# 15719 / 15734 1
# 15720 / 15734 1
# 15721 / 15734 1
# 15722 / 15734 SELECT MIN Goals FROM table WHERE Ranking < 4 AND Years = 1996–13 ['=', '=']
# 15723 / 15734 SELECT MIN Top-25 FROM table WHERE Events < 17 AND Top-5 > 0 ['=', '=']
# 15724 / 15734 SELECT AVG Top-5 FROM table WHERE Tournament = totals AND Top-25 > 4 ['=', '=']
# 15725 / 15734 SELECT AVG Events FROM table WHERE Top-5 < 1 AND Top-25 > 1 ['=', '=']
# 15726 / 15734 SELECT MAX Top-5 FROM table WHERE Top-25 < 4 AND Cuts made > 3 AND Wins < 0 ['=', '=', '=']
# 15727 / 15734 SELECT COUNT Top-5 FROM table WHERE Tournament = pga championship AND Events < 4 ['=', '=']
# 15728 / 15734 1
# 15729 / 15734 SELECT Points FROM table WHERE Year > 1972 AND Entrant = marlboro team alfa romeo ['=', '=']
# 15730 / 15734 1
# 15731 / 15734 1
# 15732 / 15734 SELECT Chassis FROM table WHERE Engine = ford v8 AND Year < 1976 AND Points = 12 ['=', '=', '=']
# 15733 / 15734 1
# Operator accuracy 81.42239735604424

# %% [markdown]
# Our accuracy statistics for this case are as follows.
#
# *   Overall accuracy 81.42%

# %% [markdown]
# # Case 8: WHERE Attribute Classification Accuracy

# %% [markdown]
# We evaluate the accuracy of our word-embedding-based approach to handle NLQs where the attribute associated with an identified value in the expected WHERE clause isn't explicitly mentioned in the NLQ. In this approach, we find the attribute that has the greatest cosine similarity with the identified value and associate that attribute with the identified value. We calculate accuracy using the following formula:
#
# $$\frac{\text{#values for which attributes were correctly predicted}}{\text{#total values evaluated}}$$
#
# Note that we assume the values have been correctly identified in this section so we don't use our nlp_ner model to identify constraints even though we pass the model to the nlq2sql class.
#
# We only count a value to be evaluated if predicting an attribute was possible for that value. Sometimes, predicting an attribute is impossible because there is no word embedding for a token in the value or attribute.
#
# We also calculate the number of queries for which at least one value didn't have an attribute predicted as a percentage of the total number of queries.

# %%
tagTestSet = obtain_absent_where_attr_queries()
print(len(tagTestSet))
# Out:
# 100%|██████████| 15878/15878 [00:06<00:00, 2514.66it/s]
# 4655
# 4655

# %% [markdown]
# We download [GloVe](https://nlp.stanford.edu/projects/glove/) word embeddings.

# %%
import gensim.downloader
embed = gensim.downloader.load("glove-wiki-gigaword-200")
# Out:
# [==================================================] 100.0% 252.1/252.1MB downloaded

# %%
numValuesEvaluated = 0
numCorrect = 0
unevaluatedValueQueries = 0
nlp = spacy.load("en_core_web_lg")
i = 0
for obj in tagTestSet:
  i += 1
  sqlQuery = remove_quotes(obj['sqlQuery'])
  attributes = obj['attr']
  nlq = obj['question']
  nQueryObj = nlq2sql(nlq, "table", attributes, nlp, nlp_ner)
  sqlExtractor = sqlExtract(sqlQuery)
  whereAttr, whereAttrValue = sqlExtractor.fetch_where_attr()
  unevaluatedIndicator = False
  for attr, value in whereAttrValue.items():
    mostSimilarAttr = nQueryObj.get_most_similar_attribute(value, embed)
    if mostSimilarAttr is not None:
      numValuesEvaluated += 1
      if mostSimilarAttr.lower() == attr.lower():
        numCorrect += 1
        print(f"{i} / {len(tagTestSet)} 1")
      else:
        print(f"{i} / {len(tagTestSet)} Value: {value} Pred: {mostSimilarAttr.lower()} Correct: {attr.lower()}")
    else:
      print(f"{i} / {len(tagTestSet)} Value: {value} Pred: {mostSimilarAttr} Correct: {attr.lower()}")
      unevaluatedIndicator = True
  if unevaluatedIndicator:
    unevaluatedValueQueries += 1
if numValuesEvaluated > 0:
  print(f"Attribute Classification Accuracy: {(numCorrect / numValuesEvaluated) * 100}")
  print(f"% of queries where at least 1 value was not evaluated: {((len(tagTestSet) - unevaluatedValueQueries)/ len(tagTestSet)) * 100}")
else:
  print("0 queries evaluated.")
# Out:
# Streaming output truncated to the last 5000 lines.
# 1504 / 4655 Value: milwaukee county stadium Pred: attendance Correct: game site
# 1505 / 4655 Value: ontario Pred: shot pct. Correct: locale
# 1506 / 4655 Value: 77 Pred: ends lost Correct: shot pct.
# 1506 / 4655 Value: 11 Pred: shot pct. Correct: blank ends
# 1506 / 4655 Value: 7 Pred: shot pct. Correct: stolen ends
# 1506 / 4655 Value: 44 Pred: ends lost Correct: ends won
# 1507 / 4655 Value: the netherlands Pred: market value ( usd million) Correct: headquarters
# 1508 / 4655 1
# 1508 / 4655 Value: 23 Pred: seasons Correct: 3rd places
# 1509 / 4655 1
# 1509 / 4655 1
# 1510 / 4655 Value: dodge Pred: driver Correct: make
# 1511 / 4655 1
# 1512 / 4655 1
# 1513 / 4655 1
# 1513 / 4655 1
# 1514 / 4655 1
# 1514 / 4655 Value: 17 Pred: season Correct: podiums
# 1514 / 4655 Value: 0 Pred: wins Correct: fastest laps
# 1515 / 4655 1
# 1516 / 4655 1
# 1517 / 4655 Value: 6 Pred: year Correct: rank
# 1517 / 4655 Value: 617 / 188 Pred: year Correct: height feet / m
# 1518 / 4655 1
# 1518 / 4655 Value: 7 Pred: all years of finals appearances Correct: number of finals appearances
# 1519 / 4655 1
# 1519 / 4655 Value: 203 Pred: pick # Correct: overall
# 1520 / 4655 1
# 1520 / 4655 Value: 166 Pred: pick # Correct: overall
# 1521 / 4655 Value: 1 Pred: total Correct: bronze
# 1521 / 4655 Value: 4 Pred: total Correct: gold
# 1522 / 4655 Value: 1 Pred: earnings ( $ ) Correct: rank
# 1522 / 4655 1
# 1522 / 4655 Value: 6,028,927 Pred: None Correct: earnings ( $ )
# 1523 / 4655 1
# 1523 / 4655 Value: kbdr Pred: None Correct: callsign
# 1524 / 4655 Value: beijing Pred: launch Correct: origin
# 1525 / 4655 1
# 1525 / 4655 Value: 厦门卫视 Pred: None Correct: hanzi
# 1526 / 4655 1
# 1527 / 4655 1
# 1528 / 4655 1
# 1529 / 4655 1
# 1530 / 4655 Value: philadelphia flyers Pred: game Correct: opponent
# 1531 / 4655 Value: 424,000 Pred: peak Correct: sales
# 1531 / 4655 Value: elbow Pred: position Correct: artist
# 1532 / 4655 Value: stadion prljanije Pred: None Correct: venue
# 1533 / 4655 Value: retired republican hold Pred: party Correct: result
# 1533 / 4655 Value: rufus p. spalding Pred: district Correct: incumbent
# 1534 / 4655 Value: retired republican hold Pred: party Correct: result
# 1534 / 4655 Value: rufus p. spalding Pred: district Correct: incumbent
# 1535 / 4655 Value: marco simoncelli Pred: laps Correct: rider
# 1535 / 4655 Value: 11 Pred: time/retired Correct: grid
# 1536 / 4655 1
# 1537 / 4655 Value: – Pred: total Correct: hereditary peers
# 1537 / 4655 Value: – Pred: total Correct: lords spiritual
# 1537 / 4655 Value: 2 Pred: total Correct: life peers
# 1537 / 4655 1
# 1538 / 4655 1
# 1539 / 4655 1
# 1540 / 4655 Value: umbrellas Pred: netflix Correct: segment a
# 1541 / 4655 Value: rossville Pred: mascot Correct: location
# 1542 / 4655 Value: 2:06 Pred: opponent Correct: time
# 1542 / 4655 Value: njkf magnam 16 Pred: None Correct: event
# 1543 / 4655 Value: st. louis blues Pred: score Correct: opponent
# 1543 / 4655 Value: 58 Pred: record Correct: game
# 1544 / 4655 Value: larry mcmorran Pred: nationality Correct: player
# 1545 / 4655 1
# 1546 / 4655 1
# 1547 / 4655 Value: edmonton oilers Pred: score Correct: home
# 1547 / 4655 Value: chicago blackhawks Pred: score Correct: visitor
# 1547 / 4655 1
# 1548 / 4655 1
# 1549 / 4655 1
# 1550 / 4655 Value: charles van wyck Pred: district Correct: incumbent
# 1551 / 4655 1
# 1551 / 4655 1
# 1551 / 4655 1
# 1552 / 4655 Value: november 5, 1995 Pred: opponent in the final Correct: date
# 1553 / 4655 Value: amy frazier Pred: tournament Correct: opponent in the final
# 1554 / 4655 1
# 1555 / 4655 1
# 1556 / 4655 1
# 1557 / 4655 1
# 1558 / 4655 Value: mapei-clas Pred: points classification Correct: team classification
# 1558 / 4655 Value: 12 Pred: winner Correct: stage
# 1559 / 4655 Value: banesto Pred: stage Correct: team classification
# 1559 / 4655 Value: tony rominger Pred: stage Correct: points classification
# 1560 / 4655 1
# 1560 / 4655 Value: patricia tarabini Pred: outcome Correct: partner
# 1560 / 4655 1
# 1561 / 4655 1
# 1562 / 4655 Value: ucla Pred: mls team Correct: affiliation
# 1563 / 4655 Value: american civil war and indian wars Pred: rank order Correct: active service
# 1564 / 4655 Value: 001 1st Pred: first season of current spell in top division Correct: position in 2012–13
# 1565 / 4655 Value: 5 february 1979 Pred: first Correct: d.o.b.
# 1566 / 4655 Value: r Pred: first Correct: throws
# 1566 / 4655 1
# 1566 / 4655 Value: 26 april 1989 Pred: first Correct: d.o.b.
# 1567 / 4655 Value: pj Pred: throws Correct: first
# 1568 / 4655 1
# 1569 / 4655 Value: 5 Pred: year Correct: losses
# 1569 / 4655 Value: 0 Pred: points Correct: draws
# 1570 / 4655 Value: himco dump Pred: None Correct: name
# 1571 / 4655 1
# 1572 / 4655 Value: suzuki Pred: wins Correct: team
# 1572 / 4655 1
# 1572 / 4655 Value: 0 Pred: points Correct: wins
# 1573 / 4655 1
# 1573 / 4655 Value: lucky strike yamaha Pred: machine Correct: team
# 1573 / 4655 Value: 6 Pred: year Correct: points
# 1574 / 4655 1
# 1575 / 4655 1
# 1575 / 4655 Value: 60 Pred: record Correct: game
# 1575 / 4655 Value: new york islanders Pred: game Correct: opponent
# 1576 / 4655 Value: feb 10 Pred: 1st prize ( $ ) Correct: date
# 1577 / 4655 1
# 1577 / 4655 1
# 1578 / 4655 Value: h.e.b. texas open Pred: None Correct: tournament
# 1579 / 4655 1
# 1579 / 4655 Value: jeremy case Pred: year Correct: name
# 1580 / 4655 1
# 1581 / 4655 1
# 1581 / 4655 Value: mario chalmers Pred: position Correct: name
# 1582 / 4655 1
# 1583 / 4655 Value: runner-up Pred: score Correct: outcome
# 1583 / 4655 1
# 1584 / 4655 1
# 1585 / 4655 Value: 9 Pred: pct. Correct: mrc championships
# 1585 / 4655 Value: 192-189-3 Pred: pct. Correct: records
# 1585 / 4655 Value: 4 Pred: pct. Correct: co-champions
# 1586 / 4655 Value: 0.786 Pred: None Correct: pct.
# 1586 / 4655 Value: 6 Pred: pct. Correct: mrc championships
# 1586 / 4655 Value: 88-45-6 Pred: pct. Correct: records
# 1587 / 4655 Value: chicago black hawks Pred: game Correct: opponent
# 1588 / 4655 Value: cherry creek radio Pred: format Correct: owner
# 1588 / 4655 1
# 1589 / 4655 Value: st. george Pred: owner Correct: city of license
# 1589 / 4655 1
# 1590 / 4655 Value: marcelo filippini mark koevermans Pred: partnering Correct: opponents in the final
# 1591 / 4655 1
# 1591 / 4655 Value: march 28, 1995 Pred: opponents in the final Correct: date
# 1592 / 4655 Value: jordi arrese àlex corretja Pred: tournament Correct: opponents in the final
# 1593 / 4655 Value: t9 Pred: to par Correct: place
# 1593 / 4655 1
# 1594 / 4655 1
# 1595 / 4655 Value: soledad, california Pred: class Correct: city of license
# 1596 / 4655 1
# 1596 / 4655 Value: morro bay, california Pred: class Correct: city of license
# 1597 / 4655 Value: 7 Pred: rec. Correct: avg.
# 1597 / 4655 Value: 60 Pred: rec. Correct: long
# 1597 / 4655 1
# 1597 / 4655 Value: correll buckhalter Pred: yards Correct: player
# 1598 / 4655 Value: 11.8 Pred: yards Correct: avg.
# 1598 / 4655 Value: brent celek Pred: yards Correct: player
# 1598 / 4655 Value: 44 Pred: yards Correct: long
# 1599 / 4655 Value: 54 Pred: yards Correct: rec.
# 1599 / 4655 Value: 5 Pred: rec. Correct: long
# 1599 / 4655 Value: todd herremans Pred: None Correct: player
# 1599 / 4655 Value: 1 Pred: rec. Correct: avg.
# 1600 / 4655 Value: malacca Pred: competition Correct: opponent
# 1600 / 4655 Value: klfa stadium, cheras Pred: None Correct: venue
# 1601 / 4655 Value: city stadium, georgetown Pred: opponent Correct: venue
# 1602 / 4655 Value: police Pred: date Correct: opponent
# 1602 / 4655 1
# 1603 / 4655 Value: 3 Pred: points Correct: touchdowns
# 1603 / 4655 1
# 1603 / 4655 1
# 1604 / 4655 1
# 1604 / 4655 Value: 12 Pred: points Correct: extra points
# 1605 / 4655 Value: tracy mcgrady (24) Pred: date Correct: high points
# 1606 / 4655 Value: free choice Pred: song choice Correct: theme
# 1606 / 4655 Value: through to bootcamp Pred: theme Correct: result
# 1607 / 4655 Value: florida panthers Pred: game Correct: opponent
# 1607 / 4655 1
# 1608 / 4655 1
# 1609 / 4655 Value: gt Pred: race Correct: class
# 1609 / 4655 1
# 1610 / 4655 Value: gt Pred: race Correct: class
# 1610 / 4655 Value: portland international raceway Pred: race Correct: circuit
# 1611 / 4655 1
# 1612 / 4655 Value: 1,115.8 Pred: None Correct: revenue (€m)
# 1612 / 4655 Value: 31 december 2012 Pred: passenger load factor (%) Correct: year ended
# 1613 / 4655 Value: democrat Pred: incumbent Correct: party
# 1613 / 4655 Value: 2 Pred: status Correct: district
# 1613 / 4655 1
# 1614 / 4655 Value: ortiz Pred: champion Correct: top goalscorer
# 1614 / 4655 Value: 25 Pred: year Correct: goals
# 1615 / 4655 Value: st. louis Pred: home Correct: visitor
# 1616 / 4655 Value: canada Pred: nhl team Correct: nationality
# 1616 / 4655 Value: new york islanders Pred: college/junior/club team Correct: nhl team
# 1616 / 4655 1
# 1617 / 4655 Value: brandon wheat kings (wchl) Pred: position Correct: college/junior/club team
# 1618 / 4655 Value: university of wisconsin (wcha) Pred: position Correct: college/junior/club team
# 1618 / 4655 Value: bob lundeen Pred: nationality Correct: player
# 1619 / 4655 Value: brent meeke Pred: pick # Correct: player
# 1620 / 4655 1
# 1621 / 4655 Value: 26.39 Pred: pop. 2006 Correct: area 1996 km²
# 1621 / 4655 Value: 18,610 Pred: None Correct: pop. 2006
# 1622 / 4655 Value: 17,510 Pred: None Correct: pop. 1999
# 1622 / 4655 Value: 30 Pred: pop. 2003 Correct: area 2006 km²
# 1623 / 4655 Value: tampa bay Pred: streak end Correct: teams
# 1624 / 4655 Value: juventus Pred: season Correct: champion
# 1625 / 4655 Value: michael andretti Pred: fastest lap Correct: winning driver
# 1626 / 4655 1
# 1627 / 4655 Value: jimmy vasser Pred: fastest lap Correct: winning driver
# 1628 / 4655 Value: ken hemenway Pred: position Correct: player
# 1629 / 4655 Value: moño negro Pred: None Correct: track
# 1629 / 4655 1
# 1630 / 4655 1
# 1630 / 4655 Value: bonga sw; aparo Pred: year startup Correct: project name
# 1631 / 4655 1
# 1632 / 4655 1
# 1633 / 4655 Value: film Pred: role Correct: medium
# 1633 / 4655 Value: film classics Pred: title Correct: theatre, studio, or network
# 1634 / 4655 Value: film Pred: role Correct: medium
# 1634 / 4655 Value: 1948 Pred: title Correct: date
# 1634 / 4655 1
# 1635 / 4655 Value: reuschel (12-3) Pred: date Correct: loss
# 1636 / 4655 Value: new england patriots Pred: kickoff Correct: opponent
# 1637 / 4655 Value: $30,471 Pred: None Correct: gross (worldwide)
# 1638 / 4655 1
# 1639 / 4655 1
# 1640 / 4655 Value: 2 Pred: home Correct: round
# 1640 / 4655 1
# 1641 / 4655 1
# 1642 / 4655 1
# 1643 / 4655 Value: 0 Pred: total Correct: gold
# 1643 / 4655 Value: 0 Pred: total Correct: bronze
# 1643 / 4655 Value: 0 Pred: total Correct: silver
# 1643 / 4655 Value: 1 Pred: year Correct: sports
# 1644 / 4655 1
# 1645 / 4655 Value: chuck klein Pred: opponent Correct: player
# 1646 / 4655 Value: josh hamilton Pred: team Correct: player
# 1647 / 4655 Value: 15 Pred: release date Correct: classifaction
# 1648 / 4655 1
# 1648 / 4655 Value: n/a Pred: country Correct: classifaction
# 1648 / 4655 Value: spectrum dvd Pred: format Correct: publisher
# 1649 / 4655 Value: 32,012 Pred: None Correct: attendance
# 1649 / 4655 1
# 1649 / 4655 1
# 1650 / 4655 Value: cryptogramophon Pred: None Correct: label
# 1651 / 4655 Value: karen frohner Pred: None Correct: name
# 1651 / 4655 Value: 1266 Pred: name Correct: points
# 1652 / 4655 1
# 1652 / 4655 1
# 1653 / 4655 1
# 1653 / 4655 1
# 1654 / 4655 Value: thirst Pred: result Correct: film/series
# 1654 / 4655 1
# 1654 / 4655 Value: green globe film awards Pred: award Correct: group
# 1655 / 4655 Value: nominated Pred: award Correct: result
# 1655 / 4655 Value: thirst Pred: result Correct: film/series
# 1655 / 4655 1
# 1655 / 4655 Value: baeksang arts awards Pred: award Correct: group
# 1656 / 4655 1
# 1656 / 4655 Value: thirst Pred: result Correct: film/series
# 1657 / 4655 Value: over the rainbow Pred: group Correct: film/series
# 1658 / 4655 1
# 1659 / 4655 1
# 1660 / 4655 Value: new england revolution Pred: position Correct: mls team
# 1661 / 4655 1
# 1662 / 4655 1
# 1662 / 4655 Value: andrew combs Pred: week Correct: offensive
# 1663 / 4655 1
# 1664 / 4655 Value: 0:0 - 4:1 (pen) Pred: home Correct: score
# 1665 / 4655 Value: – Pred: season Correct: play-off
# 1665 / 4655 Value: 2008–09 Pred: None Correct: year
# 1666 / 4655 Value: fullback Pred: player Correct: position
# 1666 / 4655 1
# 1667 / 4655 1
# 1668 / 4655 Value: 2 Pred: date of birth (age) Correct: caps
# 1668 / 4655 1
# 1668 / 4655 Value: alberto sgarbi Pred: club/province Correct: player
# 1669 / 4655 Value: elisabeth of lorraine Pred: ceased to be duchess Correct: image
# 1670 / 4655 Value: william iv Pred: father Correct: husband
# 1671 / 4655 1
# 1672 / 4655 Value: adh2350iaa5do Pred: None Correct: part number(s)
# 1673 / 4655 Value: athlon x2 be-2400 Pred: None Correct: model number
# 1674 / 4655 Value: june 5, 2007 Pred: multi 1 Correct: release date
# 1675 / 4655 Value: st. louis Pred: home Correct: visitor
# 1675 / 4655 1
# 1676 / 4655 Value: philadelphia Pred: home Correct: visitor
# 1677 / 4655 1
# 1678 / 4655 Value: twins Pred: loss Correct: opponent
# 1678 / 4655 1
# 1679 / 4655 Value: devil rays Pred: loss Correct: opponent
# 1679 / 4655 1
# 1680 / 4655 Value: day 1 Pred: known for Correct: entered
# 1680 / 4655 1
# 1681 / 4655 Value: day 1 Pred: known for Correct: entered
# 1681 / 4655 1
# 1682 / 4655 Value: 29 september 1766 Pred: ceased to be queen Correct: birth
# 1683 / 4655 Value: 10 may 1788 Pred: marriage Correct: birth
# 1684 / 4655 1
# 1685 / 4655 1
# 1685 / 4655 Value: 0 Pred: total Correct: silver
# 1686 / 4655 Value: oakland seals Pred: date Correct: home
# 1687 / 4655 1
# 1688 / 4655 Value: 100,000 Pred: city of license Correct: watts
# 1688 / 4655 Value: guymon, oklahoma Pred: watts Correct: city of license
# 1689 / 4655 Value: 1960 rome Pred: event Correct: games
# 1689 / 4655 Value: men's freestyle welterweight Pred: medal Correct: event
# 1690 / 4655 Value: national team Pred: games Correct: name
# 1690 / 4655 Value: 1968 mexico city Pred: name Correct: games
# 1691 / 4655 1
# 1691 / 4655 Value: russia Pred: position Correct: nationality
# 1692 / 4655 Value: defenceman Pred: player Correct: position
# 1693 / 4655 Value: audenshaw urban district Pred: district Correct: former local authority
# 1694 / 4655 Value: derrick harvey Pred: college Correct: name
# 1694 / 4655 Value: 1 Pred: pick # Correct: round
# 1695 / 4655 Value: defensive end Pred: round Correct: position
# 1695 / 4655 Value: 2 Pred: pick # Correct: round
# 1696 / 4655 1
# 1696 / 4655 Value: 24 Pred: round Correct: pick #
# 1697 / 4655 1
# 1697 / 4655 Value: 5 Pred: pick # Correct: round
# 1698 / 4655 Value: 1,521 Pred: total convictions Correct: fraud (art. 146 stgb)
# 1698 / 4655 1
# 1699 / 4655 Value: tamworth Pred: home team Correct: away team
# 1700 / 4655 1
# 1700 / 4655 Value: 109–1–2 Pred: None Correct: record
# 1701 / 4655 Value: 10 Pred: res. Correct: rd., time
# 1701 / 4655 Value: sammy angott Pred: None Correct: opponent
# 1701 / 4655 Value: 33–0 Pred: None Correct: record
# 1702 / 4655 1
# 1703 / 4655 1
# 1704 / 4655 Value: 2–2 Pred: None Correct: result
# 1704 / 4655 Value: 5,760 Pred: venue Correct: attendance
# 1705 / 4655 Value: 11,045 Pred: None Correct: attendance
# 1706 / 4655 Value: 0–0 Pred: None Correct: 2nd leg
# 1706 / 4655 1
# 1707 / 4655 Value: cs sfaxien Pred: team 1 Correct: team 2
# 1708 / 4655 Value: lee janzen Pred: to par Correct: player
# 1709 / 4655 Value: new york jets Pred: week Correct: opponent
# 1710 / 4655 1
# 1711 / 4655 Value: flat stage Pred: winner Correct: type
# 1711 / 4655 1
# 1712 / 4655 1
# 1713 / 4655 Value: 1964 Pred: number of votes received Correct: election date
# 1714 / 4655 1
# 1715 / 4655 1
# 1716 / 4655 Value: golden state warriors Pred: game Correct: opponent
# 1717 / 4655 1
# 1718 / 4655 Value: 5 Pred: lost Correct: try bonus
# 1718 / 4655 Value: 517 Pred: points Correct: points for
# 1719 / 4655 Value: 10.9% Pred: freight (metric tonnes) Correct: % change 2005/2006
# 1719 / 4655 Value: 4,022 Pred: None Correct: freight (metric tonnes)
# 1720 / 4655 Value: st. louis cardinals Pred: attendance Correct: opponent
# 1720 / 4655 Value: 80,010 Pred: None Correct: attendance
# 1721 / 4655 Value: hayes & yeading united Pred: result Correct: opponent
# 1722 / 4655 1
# 1722 / 4655 Value: rr:08,09 Pred: None Correct: result
# 1723 / 4655 1
# 1724 / 4655 1
# 1724 / 4655 1
# 1725 / 4655 Value: 565.39 Pred: None Correct: area (km²)
# 1725 / 4655 Value: 23.54 Pred: population Correct: population density (per km 2 )
# 1726 / 4655 1
# 1727 / 4655 Value: 0 Pred: average Correct: int's
# 1728 / 4655 Value: 0 Pred: average Correct: int's
# 1728 / 4655 Value: randy scott Pred: int's Correct: player
# 1728 / 4655 Value: 3 Pred: average Correct: sacks
# 1729 / 4655 Value: 14 Pred: length (m) Correct: bobsleigh-skeleton curves
# 1729 / 4655 1
# 1730 / 4655 Value: h Pred: match Correct: venue
# 1730 / 4655 1
# 1730 / 4655 1
# 1731 / 4655 1
# 1732 / 4655 Value: win Pred: round Correct: res.
# 1732 / 4655 Value: 2 Pred: res. Correct: round
# 1732 / 4655 Value: makoto ishikawa Pred: round Correct: opponent
# 1733 / 4655 1
# 1734 / 4655 Value: 60/120/180/240 Pred: None Correct: capacities (gb)
# 1735 / 4655 Value: sandforce Pred: None Correct: controller
# 1735 / 4655 Value: 80/120/180/240/360/480 Pred: None Correct: capacities (gb)
# 1735 / 4655 1
# 1736 / 4655 Value: 25nm mlc-het Pred: rnd 4kb read/write iops (k) Correct: nand type
# 1736 / 4655 Value: 270/210 Pred: None Correct: seq. read/write mb/s
# 1737 / 4655 Value: sandforce Pred: None Correct: controller
# 1737 / 4655 Value: sierra star Pred: seq. read/write mb/s Correct: codename
# 1738 / 4655 Value: 12:30pm Pred: None Correct: time ( et )
# 1738 / 4655 Value: shea stadium Pred: week Correct: location
# 1739 / 4655 1
# 1739 / 4655 1
# 1739 / 4655 Value: 17 Pred: year Correct: start
# 1740 / 4655 Value: tokyo, japan Pred: date Correct: tournament
# 1740 / 4655 1
# 1741 / 4655 1
# 1741 / 4655 1
# 1742 / 4655 1
# 1743 / 4655 1
# 1744 / 4655 Value: st. petersburg - moscow Pred: report Correct: name
# 1745 / 4655 1
# 1746 / 4655 1
# 1746 / 4655 1
# 1747 / 4655 1
# 1747 / 4655 Value: 16 Pred: total Correct: gold
# 1748 / 4655 Value: 3 Pred: total Correct: bronze
# 1748 / 4655 Value: 0 Pred: total Correct: silver
# 1749 / 4655 1
# 1749 / 4655 Value: 461 Pred: losing bonus Correct: points against
# 1750 / 4655 1
# 1751 / 4655 Value: 23,394 Pred: None Correct: attendance
# 1752 / 4655 1
# 1752 / 4655 1
# 1753 / 4655 Value: 7 Pred: lost Correct: games
# 1754 / 4655 Value: 4495 Pred: None Correct: net yds
# 1754 / 4655 1
# 1754 / 4655 Value: 5.5 Pred: long Correct: yds/att
# 1755 / 4655 1
# 1755 / 4655 Value: 5 Pred: start Correct: yds/att
# 1755 / 4655 Value: 1 Pred: start Correct: rank
# 1756 / 4655 Value: 68 Pred: touchdowns Correct: long
# 1756 / 4655 Value: 1984 Pred: name Correct: start
# 1757 / 4655 Value: 3 Pred: start Correct: rank
# 1757 / 4655 Value: 1984 Pred: name Correct: start
# 1757 / 4655 Value: 6.1 Pred: touchdowns Correct: yds/att
# 1758 / 4655 1
# 1759 / 4655 Value: annabelle Pred: film Correct: role
# 1760 / 4655 1
# 1761 / 4655 Value: g1 Pred: jockey Correct: group
# 1761 / 4655 1
# 1762 / 4655 Value: december 23, 2001 Pred: result Correct: date
# 1763 / 4655 Value: december 2, 2001 Pred: result Correct: date
# 1764 / 4655 1
# 1765 / 4655 Value: hkg/vhhh Pred: None Correct: code (iata/icao)
# 1766 / 4655 Value: 3 Pred: lost Correct: points
# 1766 / 4655 Value: 0 Pred: points Correct: lost
# 1767 / 4655 Value: tiger stadium Pred: attendance Correct: game site
# 1767 / 4655 Value: 7 Pred: date Correct: week
# 1768 / 4655 1
# 1768 / 4655 Value: 26 Pred: year Correct: pick
# 1769 / 4655 1
# 1769 / 4655 Value: 2 Pred: year Correct: pick
# 1770 / 4655 1
# 1770 / 4655 1
# 1770 / 4655 1
# 1771 / 4655 1
# 1772 / 4655 Value: car Pred: vehicle Correct: class
# 1772 / 4655 1
# 1773 / 4655 Value: azeri tv tower Pred: pinnacle height Correct: name
# 1774 / 4655 1
# 1775 / 4655 Value: emley moor tower (mk.3) Pred: None Correct: name
# 1776 / 4655 1
# 1776 / 4655 Value: transmitter solt Pred: pinnacle height Correct: name
# 1777 / 4655 Value: 321 Pred: percentage of possible points Correct: points
# 1777 / 4655 1
# 1777 / 4655 Value: 16 Pred: percentage of possible points Correct: races
# 1778 / 4655 Value: honda 1000cc Pred: race Correct: machine
# 1778 / 4655 Value: bruce anstey Pred: average speed Correct: rider(s)
# 1779 / 4655 1
# 1780 / 4655 1
# 1780 / 4655 1
# 1780 / 4655 Value: 0 Pred: points Correct: drawn
# 1781 / 4655 1
# 1782 / 4655 Value: 0 Pred: college Correct: specialist
# 1783 / 4655 Value: 32 Pred: score Correct: tie no
# 1784 / 4655 Value: replay Pred: score Correct: tie no
# 1784 / 4655 Value: 24 november 1998 Pred: home team Correct: attendance
# 1784 / 4655 Value: rotherham united Pred: tie no Correct: home team
# 1785 / 4655 1
# 1786 / 4655 Value: michael hjalm Pred: None Correct: player
# 1787 / 4655 Value: 6 Pred: college/junior/club team (league) Correct: round
# 1787 / 4655 Value: bill campbell Pred: college/junior/club team (league) Correct: player
# 1788 / 4655 1
# 1789 / 4655 1
# 1790 / 4655 Value: over 4,000 Pred: number stayed in southeast Correct: total number emigrated or forcibly removed
# 1791 / 4655 1
# 1791 / 4655 1
# 1792 / 4655 1
# 1792 / 4655 1
# 1793 / 4655 1
# 1793 / 4655 Value: 2 Pred: total Correct: bronze
# 1794 / 4655 Value: seoul Pred: year Correct: location
# 1795 / 4655 1
# 1796 / 4655 Value: hiroshima Pred: year Correct: location
# 1797 / 4655 1
# 1798 / 4655 1
# 1799 / 4655 Value: martine ludwig angele da cruz Pred: year Correct: women's doubles
# 1799 / 4655 1
# 1800 / 4655 1
# 1801 / 4655 Value: philadelphia Pred: game Correct: road team
# 1801 / 4655 1
# 1802 / 4655 Value: philadelphia Pred: game Correct: road team
# 1802 / 4655 1
# 1803 / 4655 Value: completed Pred: task no. Correct: result
# 1803 / 4655 1
# 1803 / 4655 Value: nan Pred: day announced Correct: viewers' selection
# 1804 / 4655 1
# 1805 / 4655 1
# 1806 / 4655 1
# 1807 / 4655 Value: 0 Pred: total Correct: bronze
# 1808 / 4655 Value: 7 Pred: total Correct: rank
# 1808 / 4655 1
# 1809 / 4655 Value: 0 Pred: total Correct: silver
# 1809 / 4655 Value: 3 Pred: total Correct: rank
# 1809 / 4655 1
# 1810 / 4655 Value: 0 Pred: total Correct: gold
# 1810 / 4655 Value: 5 Pred: total Correct: rank
# 1810 / 4655 Value: 0 Pred: total Correct: bronze
# 1811 / 4655 1
# 1811 / 4655 Value: 0 Pred: wins Correct: top-25
# 1812 / 4655 Value: 4 Pred: cuts made Correct: events
# 1812 / 4655 Value: 4 Pred: cuts made Correct: top-10
# 1813 / 4655 Value: 4 Pred: cuts made Correct: top-10
# 1813 / 4655 Value: 0 Pred: wins Correct: cuts made
# 1814 / 4655 1
# 1814 / 4655 Value: 4 Pred: cuts made Correct: events
# 1815 / 4655 1
# 1816 / 4655 Value: burleigh sullivan Pred: leading lady Correct: character name
# 1817 / 4655 Value: t415 Pred: None Correct: delivered as
# 1818 / 4655 Value: t413 Pred: None Correct: delivered as
# 1819 / 4655 Value: los angeles rams Pred: record Correct: opponent
# 1820 / 4655 1
# 1821 / 4655 1
# 1821 / 4655 Value: third round Pred: year Correct: progress
# 1822 / 4655 Value: no entrants Pred: year Correct: progress
# 1822 / 4655 1
# 1823 / 4655 Value: west germany Pred: date Correct: opponent
# 1823 / 4655 1
# 1824 / 4655 Value: gcn Pred: title Correct: platform(s)
# 1824 / 4655 1
# 1824 / 4655 Value: battalion wars 2 Pred: year Correct: title
# 1825 / 4655 Value: metroid prime hunters 5 Pred: year Correct: title
# 1826 / 4655 1
# 1827 / 4655 Value: 3:27 Pred: score Correct: time
# 1828 / 4655 1
# 1829 / 4655 Value: linebacker Pred: college Correct: position
# 1829 / 4655 1
# 1830 / 4655 Value: manual motorcycle transmissions Pred: series ep. Correct: segment d
# 1831 / 4655 1
# 1832 / 4655 1
# 1833 / 4655 1
# 1833 / 4655 Value: 5:2 Pred: opponent Correct: results¹
# 1834 / 4655 1
# 1834 / 4655 Value: wales Pred: city Correct: opponent
# 1835 / 4655 Value: 3:1 Pred: type of game Correct: results¹
# 1835 / 4655 Value: france Pred: date Correct: opponent
# 1836 / 4655 1
# 1837 / 4655 1
# 1838 / 4655 1
# 1839 / 4655 1
# 1839 / 4655 Value: mali Pred: resident country Correct: mission
# 1840 / 4655 Value: none Pred: resident country Correct: local location
# 1840 / 4655 Value: high commissioner Pred: resident country Correct: local position
# 1840 / 4655 1
# 1840 / 4655 Value: tonga Pred: resident country Correct: mission
# 1841 / 4655 1
# 1841 / 4655 1
# 1842 / 4655 1
# 1842 / 4655 Value: junior men individual 6.595km Pred: None Correct: notes
# 1843 / 4655 1
# 1843 / 4655 Value: men individual 9.84km Pred: venue Correct: notes
# 1844 / 4655 1
# 1845 / 4655 Value: overkill Pred: label Correct: artist
# 1845 / 4655 1
# 1846 / 4655 Value: kanpur central Pred: arrival Correct: station name
# 1847 / 4655 Value: april 5 Pred: att. Correct: date
# 1848 / 4655 1
# 1849 / 4655 Value: 4–1 Pred: None Correct: agg.
# 1849 / 4655 Value: rapid wien Pred: competition Correct: opponent
# 1850 / 4655 Value: suzuki gsx-r1000 k7 Pred: None Correct: bike
# 1850 / 4655 Value: +13.283 Pred: None Correct: time
# 1851 / 4655 Value: 6 Pred: time Correct: grid
# 1851 / 4655 1
# 1852 / 4655 Value: 6 Pred: time Correct: grid
# 1852 / 4655 1
# 1852 / 4655 Value: 23 Pred: time Correct: laps
# 1853 / 4655 Value: karl muggeridge Pred: laps Correct: rider
# 1853 / 4655 Value: 16 Pred: time Correct: grid
# 1854 / 4655 Value: 126 Pred: overall nt points Correct: 2nd (m)
# 1854 / 4655 Value: aut Pred: overall wc points (rank) Correct: nationality
# 1855 / 4655 Value: snow patrol Pred: pop act Correct: band
# 1855 / 4655 Value: aslan Pred: male Correct: lifetime achievement award
# 1856 / 4655 Value: snow patrol Pred: pop act Correct: band
# 1856 / 4655 Value: juliet turner Pred: lifetime achievement award Correct: female
# 1857 / 4655 Value: samantha mumba Pred: pop act Correct: female
# 1858 / 4655 Value: 0 Pred: wins Correct: draws
# 1858 / 4655 1
# 1859 / 4655 Value: 18 Pred: season Correct: losses
# 1859 / 4655 Value: north melbourne Pred: season Correct: team
# 1859 / 4655 1
# 1860 / 4655 Value: san jose earthquakes Pred: goalkeeper Correct: club
# 1860 / 4655 1
# 1861 / 4655 Value: 1993 Pred: opponent in the final Correct: date
# 1861 / 4655 Value: 6–2, 2–6, 7–5 Pred: None Correct: score in the final
# 1862 / 4655 1
# 1862 / 4655 Value: 1 Pred: total Correct: silver
# 1863 / 4655 Value: mother's live remix Pred: album Correct: version
# 1864 / 4655 Value: 10th overall Pred: year Correct: pick
# 1865 / 4655 1
# 1865 / 4655 Value: wide receiver Pred: player Correct: position
# 1866 / 4655 1
# 1867 / 4655 Value: 26 october 1993 Pred: season Correct: date
# 1868 / 4655 Value: wa Pred: first elected Correct: state
# 1868 / 4655 Value: hon victor garland Pred: state Correct: member
# 1869 / 4655 Value: 08 jul Pred: set 4 Correct: date
# 1869 / 4655 Value: 3–1 Pred: None Correct: score
# 1870 / 4655 Value: 31 january 1987 Pred: result Correct: date
# 1871 / 4655 1
# 1871 / 4655 Value: free agency Pred: number Correct: acquisition via
# 1871 / 4655 1
# 1872 / 4655 Value: trade Pred: position Correct: acquisition via
# 1872 / 4655 1
# 1873 / 4655 1
# 1873 / 4655 1
# 1874 / 4655 Value: far eastern Pred: position Correct: school/club team
# 1875 / 4655 Value: 3 Pred: points Correct: draws
# 1875 / 4655 Value: 5 Pred: points Correct: loses
# 1875 / 4655 Value: 39 Pred: goals scored Correct: points
# 1876 / 4655 Value: 5.22 Pred: record Correct: time (seconds)
# 1877 / 4655 1
# 1878 / 4655 Value: dajuan wagner (25) Pred: date Correct: leading scorer
# 1878 / 4655 Value: 89–82 Pred: None Correct: score
# 1879 / 4655 Value: 14 december 2002 Pred: record Correct: date
# 1880 / 4655 Value: day 1 Pred: city Correct: entered the house
# 1880 / 4655 Value: day 29 Pred: city Correct: evicted
# 1880 / 4655 Value: skaj vikler Pred: None Correct: name
# 1881 / 4655 Value: slađana pejić Pred: None Correct: name
# 1882 / 4655 1
# 1883 / 4655 1
# 1884 / 4655 Value: uefa cup Pred: season Correct: competition
# 1884 / 4655 1
# 1884 / 4655 1
# 1885 / 4655 Value: uefa champions league Pred: season Correct: competition
# 1886 / 4655 1
# 1886 / 4655 Value: 4 Pred: total Correct: rank
# 1886 / 4655 1
# 1886 / 4655 Value: 5 Pred: total Correct: silver
# 1887 / 4655 1
# 1887 / 4655 Value: mighty ducks of anaheim Pred: height (cm) Correct: 1997–1998 team
# 1888 / 4655 1
# 1888 / 4655 Value: 84 Pred: height (cm) Correct: weight (kg)
# 1889 / 4655 1
# 1889 / 4655 Value: 91 Pred: height (cm) Correct: weight (kg)
# 1889 / 4655 Value: bloomington, minnesota Pred: height (cm) Correct: birthplace
# 1890 / 4655 1
# 1891 / 4655 Value: mary murphy Pred: couple Correct: chosen by
# 1891 / 4655 Value: contemporary Pred: music Correct: style
# 1892 / 4655 1
# 1892 / 4655 1
# 1893 / 4655 Value: 6 Pred: cuts made Correct: top-25
# 1893 / 4655 1
# 1893 / 4655 1
# 1894 / 4655 Value: 12 Pred: cuts made Correct: events
# 1894 / 4655 Value: 1 Pred: cuts made Correct: top-5
# 1894 / 4655 1
# 1895 / 4655 Value: onalaska Pred: mascot Correct: location
# 1896 / 4655 Value: public Pred: institution Correct: affiliation
# 1896 / 4655 1
# 1897 / 4655 Value: 9 Pred: years Correct: lost
# 1897 / 4655 1
# 1898 / 4655 Value: varricchio Pred: None Correct: authors
# 1899 / 4655 Value: varricchio Pred: None Correct: authors
# 1900 / 4655 Value: 8 Pred: lost Correct: tied
# 1900 / 4655 Value: 82 Pred: lost Correct: games
# 1900 / 4655 Value: bryan mclay † morris lallo ‡ gerry moore ‡ Pred: None Correct: coach
# 1900 / 4655 Value: 322 Pred: points Correct: goals against
# 1901 / 4655 Value: chamara kapugedera Pred: overs bowled Correct: name
# 1901 / 4655 Value: 4.59 Pred: maidens Correct: e.r.
# 1902 / 4655 Value: muttiah muralitharan Pred: overs bowled Correct: name
# 1902 / 4655 Value: 353 Pred: wickets Correct: runs conceded
# 1903 / 4655 Value: farveez maharoof Pred: overs bowled Correct: name
# 1903 / 4655 1
# 1904 / 4655 Value: thaipusam Pred: date Correct: english name
# 1905 / 4655 1
# 1906 / 4655 Value: switzerland Pred: third Correct: nation
# 1907 / 4655 1
# 1908 / 4655 1
# 1909 / 4655 1
# 1910 / 4655 Value: raintree pictures Pred: director Correct: producer
# 1911 / 4655 Value: siu wing Pred: production cost Correct: director
# 1912 / 4655 1
# 1913 / 4655 Value: nathalie tauziat Pred: opponents in the final Correct: partnering
# 1914 / 4655 Value: september 20, 1993 Pred: opponents in the final Correct: date
# 1915 / 4655 1
# 1916 / 4655 Value: 4 Pred: season Correct: rank
# 1916 / 4655 Value: natalia lesz Pred: None Correct: celebrity
# 1917 / 4655 1
# 1918 / 4655 Value: operational Pred: entered service Correct: status
# 1918 / 4655 Value: aurizon Pred: None Correct: owner
# 1918 / 4655 Value: g534 Pred: None Correct: locomotive
# 1919 / 4655 Value: viscount 700 Pred: tail number Correct: aircraft
# 1920 / 4655 1
# 1921 / 4655 Value: brazil Pred: name Correct: location
# 1921 / 4655 Value: caturrita formation Pred: None Correct: unit
# 1922 / 4655 1
# 1923 / 4655 1
# 1924 / 4655 Value: vyazniki assemblage Pred: None Correct: unit
# 1924 / 4655 Value: malasaurus Pred: None Correct: name
# 1925 / 4655 Value: jiyai shin Pred: winner's share Correct: champion
# 1925 / 4655 1
# 1926 / 4655 Value: 0 Pred: total Correct: silver
# 1926 / 4655 1
# 1926 / 4655 1
# 1927 / 4655 1
# 1928 / 4655 Value: cavaliers Pred: leading scorer Correct: home
# 1928 / 4655 Value: warriors Pred: leading scorer Correct: visitor
# 1929 / 4655 Value: pilots Pred: location Correct: team nickname
# 1930 / 4655 1
# 1930 / 4655 Value: coyotes Pred: primary conference Correct: team nickname
# 1931 / 4655 Value: loggers Pred: location Correct: team nickname
# 1932 / 4655 1
# 1932 / 4655 1
# 1933 / 4655 Value: ford field Pred: result Correct: game site
# 1934 / 4655 1
# 1934 / 4655 Value: 0 Pred: points Correct: draw
# 1935 / 4655 Value: 0 Pred: points Correct: draw
# 1935 / 4655 1
# 1935 / 4655 Value: 10 Pred: lost Correct: match
# 1936 / 4655 1
# 1936 / 4655 1
# 1937 / 4655 Value: “some lapse of time” Pred: exists? Correct: title
# 1938 / 4655 Value: stanley miller Pred: director Correct: adapted by
# 1938 / 4655 Value: “thirteen to centaurus” Pred: exists? Correct: title
# 1939 / 4655 1
# 1939 / 4655 1
# 1940 / 4655 Value: 0 Pred: appearances Correct: bronze medals
# 1941 / 4655 Value: 11 Pred: total Correct: agricultural panel
# 1941 / 4655 Value: 3 Pred: total Correct: industrial and commercial panel
# 1941 / 4655 Value: 4 Pred: total Correct: labour panel
# 1942 / 4655 1
# 1943 / 4655 Value: 50 Pred: class Correct: erp w
# 1943 / 4655 1
# 1944 / 4655 1
# 1945 / 4655 Value: 1600mhz Pred: None Correct: frequency
# 1945 / 4655 Value: june 22, 2005 Pred: multi 1 Correct: release date
# 1945 / 4655 Value: 1.35 Pred: multi 1 Correct: voltage
# 1946 / 4655 1
# 1947 / 4655 Value: peter schmeichel Pred: team Correct: name
# 1948 / 4655 Value: 34 Pred: combined Correct: overall
# 1949 / 4655 Value: reunion Pred: album Correct: label
# 1949 / 4655 1
# 1950 / 4655 Value: reunion Pred: album Correct: label
# 1950 / 4655 Value: guitar Pred: album Correct: credit
# 1950 / 4655 Value: christmas Pred: year Correct: album
# 1951 / 4655 Value: piano Pred: album Correct: credit
# 1952 / 4655 Value: dnp Pred: event Correct: 2010–11
# 1953 / 4655 Value: g Pred: weight Correct: pos.
# 1953 / 4655 Value: los angeles d-fenders Pred: weight Correct: team
# 1954 / 4655 1
# 1955 / 4655 Value: germany Pred: time Correct: nationality
# 1955 / 4655 Value: 9 Pred: time Correct: rank
# 1955 / 4655 Value: mike fenner Pred: rank Correct: name
# 1955 / 4655 Value: 13.52 Pred: nationality Correct: time
# 1956 / 4655 Value: 100 w. pender st. Pred: name Correct: street address
# 1957 / 4655 Value: 207 w. hastings st. Pred: name Correct: street address
# 1958 / 4655 Value: 1356436 Pred: None Correct: list entry number
# 1958 / 4655 1
# 1959 / 4655 Value: 9 Pred: year Correct: # of home games
# 1960 / 4655 1
# 1960 / 4655 Value: 52nd Pred: league rank Correct: canada - usa rank
# 1960 / 4655 Value: 992 Pred: year Correct: average attendance
# 1961 / 4655 Value: 6 Pred: musical guest (song performed) Correct: episode number
# 1962 / 4655 Value: 5 Pred: musical guest (song performed) Correct: episode number
# 1963 / 4655 Value: 1984 Pred: opponents in the final Correct: date
# 1963 / 4655 Value: 7–6, 6–1 Pred: None Correct: score in the final
# 1964 / 4655 Value: arras paul arras Pred: location Correct: opponent
# 1965 / 4655 Value: king Pred: name Correct: title
# 1965 / 4655 Value: xiang Pred: title Correct: name
# 1966 / 4655 1
# 1967 / 4655 1
# 1968 / 4655 1
# 1968 / 4655 Value: guinness tower Pred: floors Correct: name
# 1969 / 4655 Value: 1247 Pred: span metres Correct: span feet
# 1969 / 4655 1
# 1970 / 4655 1
# 1970 / 4655 Value: 12 Pred: lost Correct: played
# 1971 / 4655 Value: garth mulroy Pred: margin of victory Correct: runner(s)-up
# 1972 / 4655 1
# 1973 / 4655 Value: 1 stroke Pred: tournament Correct: margin of victory
# 1973 / 4655 Value: garth mulroy Pred: margin of victory Correct: runner(s)-up
# 1974 / 4655 Value: johan cruyff Pred: goals Correct: name
# 1974 / 4655 Value: 3 Pred: years Correct: rank
# 1975 / 4655 1
# 1976 / 4655 Value: dejuan collins Pred: team Correct: name
# 1976 / 4655 1
# 1977 / 4655 1
# 1977 / 4655 Value: tsukuba Pred: prefecture Correct: name
# 1978 / 4655 Value: 八尾 Pred: None Correct: japanese
# 1979 / 4655 1
# 1980 / 4655 1
# 1981 / 4655 1
# 1982 / 4655 Value: top 9 Pred: order # Correct: week #
# 1983 / 4655 1
# 1983 / 4655 Value: top 12 Pred: result Correct: week #
# 1984 / 4655 Value: 4,569 Pred: None Correct: regional gross value added
# 1984 / 4655 1
# 1985 / 4655 Value: rodney harrison p Pred: position Correct: name
# 1985 / 4655 Value: 145 Pred: round Correct: pick
# 1986 / 4655 1
# 1986 / 4655 1
# 1987 / 4655 Value: 66-69=135 Pred: None Correct: score
# 1988 / 4655 Value: 9 Pred: place Correct: hole
# 1988 / 4655 1
# 1989 / 4655 Value: garion weller Pred: 2011 Correct: 2012
# 1990 / 4655 Value: 2 Pred: res. Correct: round
# 1990 / 4655 Value: mostapha al-turk Pred: time Correct: opponent
# 1991 / 4655 Value: 25–21 Pred: None Correct: set 2
# 1991 / 4655 Value: 29 may Pred: time Correct: date
# 1992 / 4655 Value: 30 may Pred: time Correct: date
# 1992 / 4655 Value: 20–25 Pred: None Correct: set 1
# 1993 / 4655 Value: 4 Pred: against Correct: losses
# 1993 / 4655 1
# 1993 / 4655 Value: 1819 Pred: ballarat fl Correct: against
# 1994 / 4655 1
# 1995 / 4655 Value: 19 Pred: total Correct: rank
# 1996 / 4655 Value: 46,196 Pred: None Correct: population of england and wales '000
# 1996 / 4655 Value: 1971 Pred: muslim (% of total population) Correct: census year
# 1997 / 4655 1
# 1998 / 4655 Value: 1r Pred: career sr Correct: 1995
# 1998 / 4655 Value: a Pred: 1995 Correct: 1986
# 1998 / 4655 Value: sf Pred: 1997 Correct: 1988
# 1999 / 4655 Value: 2008-07-18 Pred: time Correct: date
# 2000 / 4655 Value: 1908–1928 Pred: None Correct: years
# 2001 / 4655 Value: 1947–1958 Pred: None Correct: years
# 2002 / 4655 Value: 1926–1938 Pred: None Correct: years
# 2003 / 4655 Value: 1953–1964 Pred: None Correct: years
# 2004 / 4655 Value: winner Pred: opponent in the final Correct: outcome
# 2004 / 4655 Value: hard Pred: opponent in the final Correct: surface
# 2004 / 4655 1
# 2005 / 4655 Value: iva majoli Pred: tournament Correct: opponent in the final
# 2006 / 4655 Value: 8 Pred: date Correct: week
# 2006 / 4655 1
# 2007 / 4655 Value: 60,092 Pred: None Correct: attendance
# 2007 / 4655 Value: w 21-9 Pred: date Correct: result
# 2008 / 4655 Value: 59,743 Pred: None Correct: attendance
# 2008 / 4655 Value: atlanta falcons Pred: week Correct: opponent
# 2009 / 4655 Value: win Pred: round Correct: res.
# 2009 / 4655 1
# 2010 / 4655 1
# 2010 / 4655 Value: 5 Pred: total Correct: women's
# 2010 / 4655 Value: 3 Pred: total Correct: junior's
# 2011 / 4655 1
# 2011 / 4655 Value: 1-40122-892-5 Pred: None Correct: isbn
# 2012 / 4655 1
# 2012 / 4655 1
# 2013 / 4655 Value: evergreen park, illinois Pred: jersey # Correct: birthplace
# 2013 / 4655 Value: 86 Pred: jersey # Correct: weight (kg)
# 2014 / 4655 Value: montreal canadiens Pred: position Correct: 1983–1984 team
# 2014 / 4655 1
# 2015 / 4655 Value: c Pred: height (cm) Correct: position
# 2015 / 4655 Value: new york rangers Pred: height (cm) Correct: 1983–1984 team
# 2015 / 4655 Value: 188 Pred: jersey # Correct: height (cm)
# 2016 / 4655 1
# 2017 / 4655 Value: 8 october 1986 Pred: result Correct: date
# 2018 / 4655 Value: dundee Pred: result Correct: opponent
# 2018 / 4655 Value: a Pred: result Correct: venue
# 2018 / 4655 Value: 6 september 1986 Pred: result Correct: date
# 2019 / 4655 Value: 91 Pred: height (cm) Correct: weight (kg)
# 2019 / 4655 Value: march 5, 1977 Pred: height (cm) Correct: birthdate
# 2020 / 4655 1
# 2020 / 4655 Value: 18 Pred: total Correct: league
# 2020 / 4655 1
# 2021 / 4655 1
# 2021 / 4655 Value: 30 Pred: total Correct: league
# 2021 / 4655 Value: 3 Pred: total Correct: fa cup
# 2022 / 4655 1
# 2022 / 4655 1
# 2023 / 4655 1
# 2024 / 4655 Value: raymond bonney Pred: birthdate Correct: name
# 2025 / 4655 Value: northfield, minnesota Pred: team Correct: birthplace
# 2026 / 4655 Value: moose goheen Pred: birthplace Correct: name
# 2027 / 4655 Value: leon tuck Pred: position Correct: name
# 2028 / 4655 1
# 2029 / 4655 1
# 2030 / 4655 1
# 2030 / 4655 Value: 19,792 Pred: None Correct: attendance
# 2030 / 4655 1
# 2031 / 4655 1
# 2032 / 4655 Value: new york jets Pred: week Correct: opponent
# 2033 / 4655 Value: ±0.00017 Pred: None Correct: lng error
# 2033 / 4655 Value: 20 Pred: lng error Correct: lng bits
# 2034 / 4655 1
# 2034 / 4655 Value: 3 Pred: total Correct: rank
# 2035 / 4655 Value: 0 Pred: total Correct: bronze
# 2035 / 4655 1
# 2036 / 4655 Value: 18,648 Pred: None Correct: attendance
# 2036 / 4655 1
# 2037 / 4655 Value: p. maelius capitolinus Pred: None Correct: name
# 2038 / 4655 Value: l. publilius philo vulscus Pred: None Correct: name
# 2039 / 4655 Value: l. publilius philo vulscus Pred: None Correct: name
# 2040 / 4655 Value: p. maelius capitolinus Pred: None Correct: name
# 2041 / 4655 Value: forward Pred: player Correct: position
# 2041 / 4655 Value: depaul Pred: years in orlando Correct: school/club team
# 2042 / 4655 1
# 2043 / 4655 1
# 2044 / 4655 Value: none Pred: date Correct: catalog
# 2044 / 4655 1
# 2045 / 4655 Value: netherlands Pred: date Correct: region
# 2046 / 4655 Value: 21 Pred: year Correct: events played
# 2046 / 4655 Value: n/a Pred: year Correct: rank
# 2046 / 4655 1
# 2047 / 4655 Value: metodija gogov Pred: None Correct: birth name
# 2048 / 4655 Value: n/a Pred: not out Correct: strike rate
# 2048 / 4655 Value: matthew hoggard Pred: innings Correct: player
# 2049 / 4655 1
# 2049 / 4655 Value: iraq Pred: result Correct: opponent
# 2050 / 4655 1
# 2051 / 4655 Value: russia Pred: result Correct: venue
# 2051 / 4655 1
# 2052 / 4655 1
# 2053 / 4655 1
# 2053 / 4655 1
# 2054 / 4655 Value: cleveland browns Pred: attendance Correct: opponent
# 2054 / 4655 Value: 54,205 Pred: None Correct: attendance
# 2055 / 4655 1
# 2056 / 4655 1
# 2057 / 4655 Value: 54,533 Pred: None Correct: attendance
# 2057 / 4655 1
# 2058 / 4655 Value: 6.76 Pred: lane Correct: mark
# 2058 / 4655 Value: ihor bodrov Pred: lane Correct: name
# 2058 / 4655 Value: 1 Pred: mark Correct: lane
# 2059 / 4655 Value: 2 Pred: heat Correct: lane
# 2059 / 4655 1
# 2059 / 4655 Value: rabangaki nawai Pred: None Correct: name
# 2060 / 4655 1
# 2060 / 4655 1
# 2060 / 4655 Value: 8 Pred: mark Correct: heat
# 2061 / 4655 Value: march 21, 1979 Pred: height (cm) Correct: birthdate
# 2062 / 4655 Value: 88 Pred: height (cm) Correct: weight (kg)
# 2062 / 4655 1
# 2062 / 4655 Value: march 26, 1980 Pred: height (cm) Correct: birthdate
# 2063 / 4655 1
# 2063 / 4655 Value: paul seymour Pred: pick Correct: player
# 2064 / 4655 Value: 10/05/1974 Pred: None Correct: date
# 2065 / 4655 1
# 2065 / 4655 Value: nebdj058 Pred: None Correct: catalog
# 2066 / 4655 Value: 494 Pred: lner class Correct: 1st built
# 2066 / 4655 Value: 4-4-0t Pred: lner class Correct: w.a.
# 2067 / 4655 Value: 1976 Pred: country Correct: year(s) won
# 2068 / 4655 1
# 2069 / 4655 1
# 2070 / 4655 Value: 11 Pred: total Correct: gold
# 2070 / 4655 Value: 2 Pred: total Correct: bronze
# 2071 / 4655 Value: 1 Pred: total Correct: bronze
# 2071 / 4655 Value: 5 Pred: total Correct: silver
# 2071 / 4655 Value: 9 Pred: total Correct: rank
# 2072 / 4655 Value: 1 Pred: 2000s to date Correct: total to date
# 2072 / 4655 Value: 0 Pred: 2000s to date Correct: 1980s
# 2073 / 4655 Value: 0 Pred: 2000s to date Correct: 1960s
# 2073 / 4655 1
# 2073 / 4655 Value: 3 Pred: 2000s to date Correct: 1930s
# 2074 / 4655 1
# 2075 / 4655 Value: 11/26/1988 Pred: None Correct: last meeting
# 2076 / 4655 Value: philadelphia eagles Pred: week Correct: opponent
# 2076 / 4655 Value: 9 Pred: date Correct: week
# 2077 / 4655 Value: cold & dry (autumn/earth) Pred: season: south Correct: season: north
# 2077 / 4655 Value: water Pred: season: south Correct: element
# 2078 / 4655 Value: shabnam paryani Pred: None Correct: coat of cash wearing celebrity
# 2079 / 4655 Value: 5 Pred: total Correct: rank
# 2079 / 4655 1
# 2079 / 4655 1
# 2080 / 4655 Value: nigel connell Pred: points Correct: performer
# 2081 / 4655 Value: nigel connell Pred: points Correct: performer
# 2082 / 4655 Value: soccer Pred: league Correct: sport
# 2082 / 4655 1
# 2083 / 4655 1
# 2083 / 4655 Value: soccer Pred: league Correct: sport
# 2083 / 4655 1
# 2084 / 4655 1
# 2085 / 4655 Value: 2013 Pred: 2012 Correct: current run since
# 2085 / 4655 Value: järve Pred: None Correct: club
# 2086 / 4655 1
# 2086 / 4655 Value: 10/02/1982 Pred: None Correct: date
# 2087 / 4655 Value: 6 Pred: years Correct: rank
# 2087 / 4655 Value: oleksandr kosyrin Pred: None Correct: name
# 2088 / 4655 Value: chicago bears Pred: record Correct: opponent
# 2089 / 4655 Value: maserati Pred: chassis Correct: constructor
# 2089 / 4655 Value: officine a. maserati Pred: chassis Correct: entrant
# 2089 / 4655 Value: luigi fagioli Pred: constructor Correct: driver
# 2090 / 4655 Value: mercedes-benz Pred: chassis Correct: constructor
# 2090 / 4655 1
# 2091 / 4655 1
# 2091 / 4655 Value: new york jets Pred: week Correct: opponent
# 2092 / 4655 Value: 4 Pred: season Correct: rank
# 2093 / 4655 Value: 1.97 Pred: hardness ( mohs' scale ) Correct: refractive index(es) 589.3nm
# 2094 / 4655 1
# 2095 / 4655 Value: colorado river Pred: basin Correct: outlet
# 2095 / 4655 Value: a038 84.8% Pred: None Correct: % in-state
# 2096 / 4655 Value: 2011 Pred: nat. Correct: ends
# 2096 / 4655 Value: thrasyvoulos Pred: transfer window Correct: moving from
# 2097 / 4655 Value: 2010 Pred: nat. Correct: ends
# 2097 / 4655 Value: winter Pred: nat. Correct: transfer window
# 2098 / 4655 1
# 2099 / 4655 Value: charles coody Pred: tournament Correct: runner(s)-up
# 2100 / 4655 Value: a Pred: 2007 Correct: 2006
# 2100 / 4655 1
# 2101 / 4655 1
# 2102 / 4655 1
# 2103 / 4655 1
# 2104 / 4655 Value: dodge Pred: team Correct: manufacturer
# 2104 / 4655 Value: 9 Pred: year Correct: start
# 2104 / 4655 1
# 2105 / 4655 1
# 2105 / 4655 Value: midfield Pred: player Correct: position
# 2106 / 4655 Value: october 27, 2003 Pred: opponent in final Correct: date
# 2107 / 4655 Value: david nalbandian Pred: tournament Correct: opponent in final
# 2108 / 4655 1
# 2108 / 4655 Value: 70-70-71=211 Pred: None Correct: score
# 2109 / 4655 1
# 2109 / 4655 1
# 2110 / 4655 Value: tom kite Pred: to par Correct: player
# 2111 / 4655 1
# 2112 / 4655 1
# 2113 / 4655 Value: dick weber open Pred: runner-up Correct: event
# 2114 / 4655 1
# 2114 / 4655 Value: go rv'ing classic Pred: None Correct: event
# 2115 / 4655 1
# 2116 / 4655 1
# 2116 / 4655 Value: team Pred: position Correct: notes
# 2117 / 4655 Value: 1.13.12 (99) Pred: None Correct: away team score
# 2118 / 4655 1
# 2118 / 4655 1
# 2118 / 4655 1
# 2119 / 4655 1
# 2120 / 4655 1
# 2121 / 4655 Value: 7 Pred: avg/g Correct: loss
# 2121 / 4655 Value: 25.1 Pred: gain Correct: avg/g
# 2122 / 4655 1
# 2122 / 4655 1
# 2123 / 4655 1
# 2123 / 4655 1
# 2123 / 4655 Value: metz, france Pred: year Correct: venue
# 2124 / 4655 1
# 2124 / 4655 Value: 1 Pred: cuts made Correct: top-10
# 2125 / 4655 1
# 2125 / 4655 Value: 3 Pred: cuts made Correct: top-25
# 2126 / 4655 1
# 2126 / 4655 Value: 11 Pred: cuts made Correct: top-25
# 2127 / 4655 Value: 7 Pred: date Correct: game
# 2127 / 4655 1
# 2128 / 4655 Value: charlotte Pred: high rebounds Correct: team
# 2129 / 4655 1
# 2129 / 4655 1
# 2130 / 4655 Value: mexico city, mexico Pred: result Correct: venue
# 2130 / 4655 1
# 2130 / 4655 Value: 8 Pred: date Correct: goal
# 2131 / 4655 Value: t3 Pred: to par Correct: place
# 2131 / 4655 Value: lee janzen Pred: to par Correct: player
# 2132 / 4655 Value: 5 Pred: 2011 Correct: 2010
# 2132 / 4655 1
# 2132 / 4655 Value: 4 Pred: 2011 Correct: 2012
# 2133 / 4655 1
# 2134 / 4655 1
# 2135 / 4655 Value: ernst-abbe-sportfeld Pred: None Correct: stadium
# 2136 / 4655 1
# 2137 / 4655 Value: leonard nimoy Pred: title Correct: director
# 2138 / 4655 Value: martin brest Pred: rank Correct: director
# 2139 / 4655 Value: neal briggs Pred: tournament Correct: runner(s)-up
# 2140 / 4655 Value: anthony wall Pred: date Correct: runner(s)-up
# 2141 / 4655 Value: 65 Pred: to par Correct: score
# 2141 / 4655 Value: rocco mediate Pred: to par Correct: player
# 2142 / 4655 Value: t7 Pred: to par Correct: place
# 2142 / 4655 Value: england Pred: place Correct: country
# 2143 / 4655 Value: 3 Pred: total Correct: other
# 2143 / 4655 Value: 3 Pred: total Correct: league
# 2143 / 4655 Value: lauri dalla valle Pred: league Correct: player
# 2143 / 4655 1
# 2144 / 4655 Value: ud lérida Pred: draws Correct: club
# 2144 / 4655 Value: 41 Pred: points Correct: goals for
# 2145 / 4655 Value: ncaa champion Pred: team Correct: notes
# 2146 / 4655 1
# 2146 / 4655 1
# 2147 / 4655 Value: ottawa senators Pred: score Correct: home
# 2147 / 4655 1
# 2148 / 4655 Value: montreal canadiens Pred: score Correct: visitor
# 2148 / 4655 1
# 2149 / 4655 Value: orenburg Pred: shipyard Correct: name
# 2150 / 4655 Value: brandon rush Pred: pick Correct: player
# 2151 / 4655 1
# 2151 / 4655 Value: 55 Pred: round Correct: pick
# 2152 / 4655 Value: aston Pred: name Correct: location
# 2153 / 4655 Value: jewellery quarter Pred: height metres / ft Correct: location
# 2154 / 4655 Value: aston Pred: name Correct: location
# 2155 / 4655 Value: jewellery quarter Pred: height metres / ft Correct: location
# 2156 / 4655 1
# 2156 / 4655 1
# 2157 / 4655 1
# 2157 / 4655 Value: 8 Pred: runs Correct: matches
# 2157 / 4655 Value: 35.57 Pred: 100s Correct: average
# 2158 / 4655 Value: hard Pred: opponent Correct: surface
# 2158 / 4655 Value: jesse levine Pred: score Correct: opponent
# 2159 / 4655 Value: december 6, 1998 Pred: week Correct: date
# 2160 / 4655 Value: 114 Pred: round Correct: pick
# 2160 / 4655 Value: jerry corcoran Pred: college Correct: player
# 2161 / 4655 Value: away Pred: result Correct: venue
# 2161 / 4655 Value: lost 2-4 Pred: date Correct: result
# 2162 / 4655 Value: bracknell bees Pred: competition Correct: opponent
# 2163 / 4655 Value: away Pred: result Correct: venue
# 2163 / 4655 1
# 2164 / 4655 Value: usa Pred: assets (billion $) Correct: headquarters
# 2164 / 4655 Value: 3 Pred: market value (billion $) Correct: rank
# 2164 / 4655 Value: 208.34 Pred: None Correct: assets (billion $)
# 2164 / 4655 1
# 2165 / 4655 Value: summer Pred: gregorian months Correct: season in english
# 2166 / 4655 1
# 2167 / 4655 Value: குளிர் Pred: None Correct: season in tamil
# 2168 / 4655 Value: late dew Pred: season in sanskrit Correct: english translation
# 2169 / 4655 1
# 2170 / 4655 Value: h Pred: result Correct: venue
# 2170 / 4655 1
# 2171 / 4655 Value: glory alozie Pred: heat Correct: name
# 2172 / 4655 Value: 0.257 Pred: None Correct: react
# 2172 / 4655 Value: fadwa al bouza Pred: mark Correct: name
# ...
# 4424 / 4655 Value: 23 Pred: year Correct: goals
# 4424 / 4655 Value: football league division 3 Pred: year Correct: league
# 4424 / 4655 Value: 1997–98 Pred: None Correct: year
# 4425 / 4655 Value: cuneo to turin Pred: stage Correct: course
# 4426 / 4655 1
# 4427 / 4655 1
# 4427 / 4655 Value: 2 Pred: total Correct: rank
# 4428 / 4655 1
# 4428 / 4655 Value: xuxa 3 Pred: year Correct: álbum
# 4428 / 4655 Value: 750,000 Pred: year Correct: sales
# 4429 / 4655 1
# 4430 / 4655 1
# 4430 / 4655 Value: 1,780 Pred: (aramac) Correct: (barcaldine)
# 4431 / 4655 Value: 3,492 Pred: year Correct: population (total)
# 4431 / 4655 Value: 1,818 Pred: (aramac) Correct: (barcaldine)
# 4432 / 4655 Value: 4,059 Pred: (aramac) Correct: population (total)
# 4432 / 4655 1
# 4432 / 4655 Value: 1,779 Pred: year Correct: (barcaldine)
# 4433 / 4655 Value: 3,594 Pred: (aramac) Correct: population (total)
# 4433 / 4655 Value: 920 Pred: year Correct: (jericho)
# 4433 / 4655 1
# 4434 / 4655 1
# 4434 / 4655 1
# 4434 / 4655 Value: hoover motor express Pred: engine Correct: entrant
# 4435 / 4655 1
# 4435 / 4655 Value: belanger motors Pred: engine Correct: entrant
# 4436 / 4655 1
# 4437 / 4655 Value: gold Pred: eye color: Correct: hair color:
# 4438 / 4655 1
# 4438 / 4655 Value: march 85b Pred: None Correct: chassis
# 4439 / 4655 Value: corbari italia Pred: None Correct: entrant
# 4439 / 4655 1
# 4440 / 4655 1
# 4441 / 4655 Value: jack roush Pred: team Correct: owner(s)
# 4441 / 4655 Value: greg biffle Pred: team Correct: driver(s)
# 4442 / 4655 Value: 119978 Pred: None Correct: northeast total
# 4443 / 4655 Value: kimberly kim Pred: winner Correct: runner-up
# 4443 / 4655 1
# 4444 / 4655 Value: 1b Pred: pick Correct: position
# 4444 / 4655 1
# 4445 / 4655 Value: 2007-08-06 Pred: comp Correct: date
# 4446 / 4655 Value: grant brebner Pred: finals Correct: name
# 4447 / 4655 Value: gene littler Pred: to par Correct: player
# 4448 / 4655 1
# 4449 / 4655 Value: oakura Pred: None Correct: area
# 4450 / 4655 Value: francis douglas memorial college Pred: years Correct: name
# 4451 / 4655 1
# 4452 / 4655 1
# 4452 / 4655 Value: 14 Pred: total Correct: to par
# 4453 / 4655 Value: team tyrrell Pred: chassis Correct: entrant
# 4453 / 4655 Value: 14 Pred: year Correct: points
# 4454 / 4655 Value: 1 Pred: points for Correct: drawn
# 4454 / 4655 1
# 4454 / 4655 Value: 7 Pred: lost Correct: try bonus
# 4455 / 4655 1
# 4456 / 4655 1
# 4457 / 4655 1
# 4457 / 4655 Value: qaanaaq Pred: municipality Correct: name
# 4458 / 4655 Value: 4,082 Pred: population (region total) Correct: population (isis)
# 4458 / 4655 Value: 55,990 Pred: None Correct: population (region total)
# 4459 / 4655 1
# 4460 / 4655 Value: banpresto Pred: genre Correct: developer
# 4460 / 4655 Value: ranma ½: netsuretsu kakutouhen Pred: None Correct: japanese title
# 4461 / 4655 Value: t3 Pred: to par Correct: place
# 4461 / 4655 1
# 4461 / 4655 Value: steve flesch Pred: to par Correct: player
# 4462 / 4655 1
# 4462 / 4655 Value: t8 Pred: to par Correct: place
# 4463 / 4655 1
# 4463 / 4655 Value: 121 Pred: percentage Correct: played
# 4464 / 4655 Value: 0 Pred: lost Correct: drawn
# 4465 / 4655 1
# 4465 / 4655 1
# 4465 / 4655 Value: 0 Pred: lost Correct: drawn
# 4466 / 4655 Value: 1992, 2003 Pred: club Correct: not winning editions
# 4467 / 4655 Value: theodore n183 Pred: None Correct: chassis
# 4468 / 4655 Value: 100 Pred: points for Correct: tries for
# 4469 / 4655 1
# 4470 / 4655 Value: 1 Pred: points for Correct: drawn
# 4470 / 4655 Value: 515 Pred: lost Correct: points for
# 4471 / 4655 1
# 4472 / 4655 1
# 4472 / 4655 Value: 104 Pred: area (sq mi) Correct: area (km²)
# 4472 / 4655 1
# 4473 / 4655 1
# 4473 / 4655 1
# 4474 / 4655 Value: danny allsopp Pred: games per goal Correct: name
# 4475 / 4655 Value: drilling Pred: area of operation Correct: services
# 4475 / 4655 Value: 1999 Pred: country Correct: years of operation
# 4476 / 4655 1
# 4476 / 4655 1
# 4477 / 4655 Value: wxmi Pred: None Correct: callsign
# 4478 / 4655 1
# 4478 / 4655 Value: 26 Pred: media market name Correct: digital
# 4479 / 4655 1
# 4480 / 4655 1
# 4481 / 4655 Value: olga baillif Pred: None Correct: director(s)
# 4482 / 4655 1
# 4483 / 4655 1
# 4484 / 4655 1
# 4484 / 4655 1
# 4484 / 4655 Value: mann basiyo sanwariyo Pred: None Correct: song
# 4485 / 4655 Value: 377 Pred: class Correct: laps
# 4485 / 4655 Value: 1st Pred: class Correct: pos.
# 4486 / 4655 Value: 27 Pred: lost Correct: goals scored
# 4486 / 4655 Value: 24 Pred: place Correct: goals conceded
# 4486 / 4655 1
# 4487 / 4655 Value: bryant heating Pred: engine Correct: entrant
# 4488 / 4655 1
# 4489 / 4655 Value: prix uip vilo do conde Pred: None Correct: nominating festival
# 4490 / 4655 Value: le portefeuille Pred: None Correct: film
# 4491 / 4655 Value: iao lethem Pred: film Correct: director(s)
# 4492 / 4655 Value: julio robledo Pred: category Correct: director(s)
# 4493 / 4655 Value: (a) torzija Pred: None Correct: film
# 4494 / 4655 Value: 12 Pred: goals for Correct: wins
# 4494 / 4655 Value: 40-4 Pred: goals for Correct: points
# 4494 / 4655 Value: 57 Pred: points Correct: goals for
# 4495 / 4655 Value: rayo vallecano Pred: draws Correct: club
# 4495 / 4655 Value: 12 Pred: goals for Correct: wins
# 4496 / 4655 Value: 2005 Pred: played Correct: first game
# 4497 / 4655 Value: ron barnett Pred: college Correct: player
# 4498 / 4655 1
# 4499 / 4655 Value: vietnam Pred: project Correct: operator
# 4500 / 4655 Value: 120 Pred: height Correct: max. fps
# 4500 / 4655 Value: 2048 Pred: max. fps Correct: width
# 4500 / 4655 Value: 1024 Pred: width Correct: height
# 4501 / 4655 1
# 4502 / 4655 1
# 4503 / 4655 Value: paul tracy Pred: team Correct: name
# 4503 / 4655 1
# 4504 / 4655 Value: 6,074 Pred: None Correct: population (eacham)
# 4504 / 4655 Value: 10,119 Pred: None Correct: population (atherton)
# 4505 / 4655 Value: wolfgang seidel Pred: chassis Correct: entrant
# 4505 / 4655 1
# 4505 / 4655 1
# 4506 / 4655 1
# 4507 / 4655 1
# 4507 / 4655 Value: direct fire Pred: nature of incident Correct: circumstances
# 4508 / 4655 Value: 71-69-71-70=281 Pred: None Correct: winning score
# 4509 / 4655 Value: bubba watson Pred: to par Correct: runner(s)-up
# 4510 / 4655 Value: john senden Pred: to par Correct: runner(s)-up
# 4511 / 4655 Value: memphis state Pred: year Correct: runner-up
# 4511 / 4655 1
# 4512 / 4655 Value: les triplettes de belleville Pred: None Correct: original title
# 4513 / 4655 1
# 4514 / 4655 1
# 4515 / 4655 Value: mexico/spain/usa Pred: english title Correct: country
# 4516 / 4655 1
# 4517 / 4655 Value: 3 Pred: time Correct: heat
# 4517 / 4655 Value: 2 Pred: time Correct: lane
# 4517 / 4655 Value: jean luc razakarivony Pred: None Correct: name
# 4518 / 4655 Value: 5 Pred: time Correct: lane
# 4518 / 4655 Value: domenico fioravanti Pred: nationality Correct: name
# 4519 / 4655 1
# 4520 / 4655 Value: amherst, ma Pred: nickname Correct: location
# 4521 / 4655 Value: 5 Pred: total Correct: rank
# 4522 / 4655 1
# 4523 / 4655 1
# 4524 / 4655 Value: august 21, 2007 Pred: result Correct: date
# 4525 / 4655 Value: august 25, 2007 Pred: result Correct: date
# 4526 / 4655 Value: august 25, 2007 Pred: result Correct: date
# 4527 / 4655 Value: january 14, 2008 Pred: result Correct: date
# 4528 / 4655 Value: 20 Pred: points for Correct: lost
# 4529 / 4655 1
# 4530 / 4655 1
# 4530 / 4655 Value: 57.73 m Pred: year Correct: notes
# 4531 / 4655 Value: s diesel engine all direct injection (dci) Pred: engine type Correct: max. power
# 4532 / 4655 Value: last days of the victim Pred: original name Correct: film title used in nomination
# 4533 / 4655 1
# 4534 / 4655 1
# 4534 / 4655 Value: 3 Pred: res. Correct: round
# 4534 / 4655 1
# 4534 / 4655 Value: road fc 12 Pred: res. Correct: event
# 4535 / 4655 1
# 4536 / 4655 Value: draw Pred: round Correct: res.
# 4536 / 4655 Value: 4-4-1 Pred: res. Correct: record
# 4537 / 4655 Value: lael van keuren Pred: character Correct: first us tour cast
# 4538 / 4655 Value: dave douglas Pred: score Correct: player
# 4539 / 4655 1
# 4539 / 4655 1
# 4540 / 4655 1
# 4540 / 4655 1
# 4541 / 4655 1
# 4541 / 4655 1
# 4542 / 4655 1
# 4543 / 4655 1
# 4544 / 4655 Value: 4 Pred: total Correct: bronze
# 4544 / 4655 Value: 1 Pred: total Correct: silver
# 4544 / 4655 Value: 7 Pred: total Correct: rank
# 4545 / 4655 Value: hillsboro, west virginia Pred: coverage area Correct: city of license
# 4546 / 4655 1
# 4547 / 4655 Value: marton Pred: decile Correct: area
# 4547 / 4655 Value: 3 Pred: years Correct: decile
# 4547 / 4655 Value: turakina maori girls' college Pred: None Correct: name
# 4548 / 4655 Value: nick jonas Pred: award Correct: recipient(s)
# 4548 / 4655 Value: kids' choice awards mexico Pred: year Correct: award
# 4549 / 4655 Value: joe jonas Pred: award Correct: recipient(s)
# 4549 / 4655 Value: kids' choice awards mexico Pred: year Correct: award
# 4550 / 4655 Value: nominated Pred: award Correct: result
# 4550 / 4655 1
# 4550 / 4655 Value: kids' choice awards mexico Pred: year Correct: award
# 4550 / 4655 Value: joe jonas Pred: award Correct: recipient(s)
# 4551 / 4655 Value: wwer-440/230 Pred: None Correct: type
# 4551 / 4655 Value: 24.10.1977 Pred: None Correct: finish construction
# 4552 / 4655 1
# 4552 / 4655 1
# 4553 / 4655 1
# 4553 / 4655 1
# 4553 / 4655 Value: 6 Pred: cuts made Correct: events
# 4554 / 4655 1
# 4555 / 4655 1
# 4556 / 4655 1
# 4557 / 4655 Value: 1 Pred: res. Correct: round
# 4557 / 4655 1
# 4558 / 4655 Value: jr schumacher Pred: time Correct: opponent
# 4559 / 4655 Value: ied Pred: casualties Correct: circumstances
# 4560 / 4655 1
# 4561 / 4655 Value: 2000 Pred: 1990s Correct: 2000s
# 4561 / 4655 Value: 1940 Pred: 1930s Correct: 1940s
# 4562 / 4655 Value: 37,119 Pred: None Correct: attendance
# 4563 / 4655 Value: yankees Pred: score Correct: opponent
# 4563 / 4655 Value: 27,652 Pred: None Correct: attendance
# 4564 / 4655 Value: 18 Pred: year Correct: rank
# 4564 / 4655 1
# 4565 / 4655 1
# 4566 / 4655 1
# 4567 / 4655 Value: 4 Pred: years Correct: decile
# 4567 / 4655 Value: spring creek school Pred: years Correct: name
# 4568 / 4655 Value: chicopee, massachusetts Pred: joined Correct: location
# 4569 / 4655 Value: wildcats Pred: current conference Correct: nickname
# 4569 / 4655 Value: longmeadow, massachusetts Pred: joined Correct: location
# 4570 / 4655 1
# 4571 / 4655 1
# 4572 / 4655 1
# 4573 / 4655 Value: 72 Pred: tied Correct: points
# 4573 / 4655 Value: 37 Pred: points Correct: lost
# 4574 / 4655 Value: 225 Pred: points Correct: goals for
# 4574 / 4655 Value: 190 Pred: lost Correct: goals against
# 4575 / 4655 Value: ~355,100 Pred: None Correct: number of broadband subscribers
# 4576 / 4655 Value: 377 Pred: % change on year Correct: value ($m)
# 4576 / 4655 1
# 4576 / 4655 Value: 17 Pred: % change on year Correct: rank
# 4577 / 4655 Value: 1,200 Pred: % change on year Correct: value ($m)
# 4577 / 4655 Value: 396 Pred: % change on year Correct: revenue ($m)
# 4577 / 4655 Value: manchester city Pred: country Correct: team
# 4578 / 4655 Value: 5 Pred: revenue ($m) Correct: % change on year
# 4578 / 4655 Value: 10 Pred: % change on year Correct: rank
# 4579 / 4655 1
# 4579 / 4655 Value: w 5-1 Pred: date Correct: score
# 4580 / 4655 1
# 4580 / 4655 1
# 4581 / 4655 Value: stereo lp Pred: label Correct: format
# 4582 / 4655 1
# 4583 / 4655 Value: mark smith Pred: team Correct: owner(s)
# 4583 / 4655 Value: paul clapprood Pred: None Correct: crew chief
# 4584 / 4655 Value: mike wallace Pred: team Correct: driver(s)
# 4585 / 4655 Value: reed sorenson Pred: crew chief Correct: driver(s)
# 4586 / 4655 Value: austin dillon Pred: crew chief Correct: driver(s)
# 4587 / 4655 1
# 4587 / 4655 Value: eric mcclure Pred: crew chief Correct: driver(s)
# 4588 / 4655 Value: great britain Pred: time Correct: nationality
# 4588 / 4655 Value: 2:10.33 Pred: None Correct: time
# 4589 / 4655 Value: 4 Pred: years Correct: decile
# 4589 / 4655 Value: tkkm o te ara rima Pred: None Correct: name
# 4590 / 4655 Value: susan jacobson Pred: film Correct: director(s)
# 4591 / 4655 Value: hannah gal Pred: award Correct: director(s)
# 4592 / 4655 Value: 22/3/06 Pred: None Correct: date
# 4592 / 4655 Value: redhouse lane / perfect world Pred: film Correct: recipient
# 4593 / 4655 1
# 4594 / 4655 Value: cooper car company Pred: year Correct: entrant
# 4595 / 4655 1
# 4596 / 4655 1
# 4596 / 4655 1
# 4597 / 4655 1
# 4597 / 4655 1
# 4597 / 4655 Value: lotus 25 Pred: year Correct: chassis
# 4598 / 4655 Value: team lotus Pred: chassis Correct: entrant
# 4598 / 4655 1
# 4599 / 4655 Value: fubuki Pred: kanji Correct: name
# 4600 / 4655 Value: harusame Pred: None Correct: name
# 4601 / 4655 Value: lille Pred: score Correct: location
# 4602 / 4655 Value: test Pred: score Correct: competition
# 4602 / 4655 Value: 23 apr 1988 Pred: serial no. Correct: date
# 4603 / 4655 Value: 11 feb 1990 Pred: serial no. Correct: date
# 4604 / 4655 Value: 4 apr 1997 Pred: serial no. Correct: date
# 4605 / 4655 Value: northampton Pred: score Correct: location
# 4606 / 4655 1
# 4606 / 4655 Value: nominee Pred: year Correct: result
# 4607 / 4655 Value: music in the air Pred: result Correct: title
# 4608 / 4655 1
# 4609 / 4655 1
# 4610 / 4655 1
# 4611 / 4655 1
# 4611 / 4655 1
# 4612 / 4655 Value: netherlands Pred: time Correct: nationality
# 4612 / 4655 Value: 4 Pred: time Correct: lane
# 4613 / 4655 Value: 5'4 Pred: None Correct: height
# 4613 / 4655 1
# 4614 / 4655 Value: team lotus Pred: chassis Correct: entrant
# 4614 / 4655 1
# 4615 / 4655 1
# 4616 / 4655 Value: 25 Pred: points Correct: games
# 4616 / 4655 1
# 4617 / 4655 Value: gunnar nilsson Pred: time/retired Correct: driver
# 4618 / 4655 Value: rs:x Pred: None Correct: 2014 santander
# 4619 / 4655 Value: laser radial Pred: 2011 perth Correct: 2007 cascais
# 4620 / 4655 Value: archery Pred: series Correct: reverse
# 4621 / 4655 1
# 4621 / 4655 Value: 43 Pred: points Correct: goals against
# 4622 / 4655 Value: 18 Pred: birth date Correct: shirt no
# 4622 / 4655 1
# 4623 / 4655 1
# 4624 / 4655 1
# 4625 / 4655 Value: dick metz Pred: place Correct: player
# 4626 / 4655 1
# 4627 / 4655 Value: 14 april 2001 Pred: result Correct: date
# 4628 / 4655 Value: 21 april 2001 Pred: result Correct: date
# 4629 / 4655 Value: 21 april 2001 Pred: result Correct: date
# 4630 / 4655 Value: 71,789 Pred: None Correct: attendance
# 4631 / 4655 Value: 51,100 Pred: None Correct: attendance
# 4632 / 4655 Value: kingdome Pred: attendance Correct: game site
# 4632 / 4655 Value: october 13, 1991 Pred: week Correct: date
# 4633 / 4655 Value: ynysybwl rfc Pred: None Correct: club
# 4634 / 4655 Value: tommy bolt Pred: place Correct: player
# 4635 / 4655 Value: t6 Pred: to par Correct: place
# 4635 / 4655 Value: tommy bolt Pred: place Correct: player
# 4636 / 4655 Value: 1958 Pred: pts. Correct: year
# 4636 / 4655 1
# 4637 / 4655 1
# 4638 / 4655 1
# 4639 / 4655 1
# 4639 / 4655 1
# 4640 / 4655 Value: north/south Pred: starting point Correct: operates
# 4640 / 4655 Value: palafox street Pred: starting point Correct: name
# 4641 / 4655 1
# 4641 / 4655 Value: pensacola beach Pred: starting point Correct: terminus
# 4642 / 4655 Value: hartmut kliemt Pred: None Correct: head
# 4642 / 4655 Value: 0 Pred: department Correct: lecturers
# 4643 / 4655 Value: 1 Pred: department Correct: lecturers
# 4643 / 4655 Value: economics Pred: full professors Correct: department
# 4644 / 4655 1
# 4644 / 4655 Value: ways and means Pred: party Correct: committee
# 4645 / 4655 Value: baltimore county Pred: district Correct: counties represented
# 4645 / 4655 Value: 06.0 6 Pred: None Correct: district
# 4645 / 4655 1
# 4646 / 4655 Value: 1996–13 Pred: None Correct: years
# 4646 / 4655 Value: 17 Pred: years Correct: goals
# 4647 / 4655 Value: saudi arabia Pred: years Correct: nationality
# 4647 / 4655 1
# 4648 / 4655 Value: hamzah idris Pred: nationality Correct: name
# 4649 / 4655 Value: 4 Pred: years Correct: ranking
# 4649 / 4655 Value: 1996–13 Pred: None Correct: years
# 4650 / 4655 Value: 1 Pred: cuts made Correct: top-5
# 4650 / 4655 Value: 1 Pred: cuts made Correct: top-25
# 4651 / 4655 Value: elf team tyrrell Pred: chassis Correct: entrant
# 4651 / 4655 1
# 4652 / 4655 1
# 4652 / 4655 Value: marlboro team alfa romeo Pred: engine Correct: entrant
# 4653 / 4655 1
# 4653 / 4655 Value: tyrrell 007 Pred: entrant Correct: chassis
# 4654 / 4655 1
# 4654 / 4655 1
# 4654 / 4655 Value: 12 Pred: year Correct: points
# 4655 / 4655 Value: elf team tyrrell Pred: chassis Correct: entrant
# 4655 / 4655 1
# 4655 / 4655 Value: tyrrell 007 Pred: entrant Correct: chassis
# Attribute Classification Accuracy: 38.914179733603106
# % of queries where at least 1 value was not evaluated: 83.37271750805584

# %% [markdown]
# Our accuracy statistics for this case are as follows.
#
# *   Attribute Classification Accuracy: 38.91%
# *   Percentage of queries for which the attribute for at least 1 value could not be predicted: 83.37%

# %% [markdown]
# # View Queries for which SELECT attributes are not explicitly present in the NLQ

# %% [markdown]
# In this section, we display what kind of NLQs don't have the SELECT attributes explicitly present in them so that we can come up with future ways to address these types of queries.

# %%
def obtain_absent_select_queries():
  """Return the queries where the SELECT attributes aren't explicitly present in the NLQ."""
  tagTestSet= []
  i = 0
  for row in tqdm(dataset['test']):
    question = row['question']
    sqlQuery = row['sql']['human_readable']
    columns = row['table']['header']
    question = remove_unicode_characters(question)
    sqlQuery = remove_unicode_characters(sqlQuery)
    sqlExtractor = sqlExtract(sqlQuery)
    addedIndicator = False
    for i in range(len(columns)):
      columns[i] = remove_unicode_characters(columns[i])
    selectAttr = sqlExtractor.fetch_select_attr()
    if is_select_not_present_in_nlq(selectAttr, question):
      tagTestSet.append({'question': question, 'sqlQuery': sqlQuery, 'attr': columns})
  print(f"\n% of NLQs where the SELECT attr is not explicitly present in the NLQ: {(len(tagTestSet)/ len(dataset['test'])) * 100}\n")
  return tagTestSet

# %%
obtain_absent_select_queries()
# Out:
# 100%|██████████| 15878/15878 [00:06<00:00, 2639.12it/s]
# % of NLQs where the SELECT attr is not explicitly present in the NLQ: 24.259982365537223
# [{'question': 'What clu was in toronto 1995-96',
#   'sqlQuery': 'SELECT School/Club Team FROM table WHERE Years in Toronto = 1995-96',
#   'attr': ['Player',
#    'No.',
#    'Nationality',
#    'Position',
#    'Years in Toronto',
#    'School/Club Team']},
#  {'question': 'which club was in toronto 2003-06',
#   'sqlQuery': 'SELECT School/Club Team FROM table WHERE Years in Toronto = 2003-06',
#   'attr': ['Player',
#    'No.',
#    'Nationality',
#    'Position',
#    'Years in Toronto',
#    'School/Club Team']},
#  {'question': 'how many schools or teams had jalen rose',
#   'sqlQuery': 'SELECT COUNT School/Club Team FROM table WHERE Player = Jalen Rose',
#   'attr': ['Player',
#    'No.',
#    'Nationality',
#    'Position',
#    'Years in Toronto',
#    'School/Club Team']},
#  {'question': 'Where was Assen held?',
#   'sqlQuery': 'SELECT Round FROM table WHERE Circuit = Assen',
#   'attr': ['No',
#    'Date',
#    'Round',
#    'Circuit',
#    'Pole Position',
#    'Fastest Lap',
#    'Race winner',
#    'Report']},
#  {'question': 'What was the number of race that Kevin Curtain won?',
#   'sqlQuery': 'SELECT COUNT No FROM table WHERE Pole Position = Kevin Curtain',
#   'attr': ['No',
#    'Date',
#    'Round',
#    'Circuit',
#    'Pole Position',
#    'Fastest Lap',
#    'Race winner',
#    'Report']},
#  {'question': 'How many different positions did Sherbrooke Faucons (qmjhl) provide in the draft?',
#   'sqlQuery': 'SELECT COUNT Position FROM table WHERE College/junior/club team = Sherbrooke Faucons (QMJHL)',
#   'attr': ['Pick',
#    'Player',
#    'Position',
#    'Nationality',
#    'NHL team',
#    'College/junior/club team']},
#  {'question': 'What are the nationalities of the player picked from Thunder Bay Flyers (ushl)',
#   'sqlQuery': 'SELECT Nationality FROM table WHERE College/junior/club team = Thunder Bay Flyers (USHL)',
#   'attr': ['Pick',
#    'Player',
#    'Position',
#    'Nationality',
#    'NHL team',
#    'College/junior/club team']},
#  {'question': 'How many different college/junior/club teams provided a player to the Washington Capitals NHL Team?',
#   'sqlQuery': 'SELECT COUNT College/junior/club team FROM table WHERE NHL team = Washington Capitals',
#   'attr': ['Pick',
#    'Player',
#    'Position',
#    'Nationality',
#    'NHL team',
#    'College/junior/club team']},
#  {'question': 'How many different nationalities do the players of New Jersey Devils come from?',
#   'sqlQuery': 'SELECT COUNT Nationality FROM table WHERE NHL team = New Jersey Devils',
#   'attr': ['Pick',
#    'Player',
#    'Position',
#    'Nationality',
#    'NHL team',
#    'College/junior/club team']},
#  {'question': ' What could a spanish coronel be addressed as in the commonwealth military?',
#   'sqlQuery': 'SELECT Commonwealth equivalent FROM table WHERE Rank in Spanish = Coronel',
#   'attr': ['Equivalent NATO Rank Code',
#    'Rank in Spanish',
#    'Rank in English',
#    'Commonwealth equivalent',
#    'US Air Force equivalent']},
#  {'question': 'Give me a list of all spanish officer titles that could receive recognition as group captain in english',
#   'sqlQuery': 'SELECT Rank in English FROM table WHERE Commonwealth equivalent = Group Captain',
#   'attr': ['Equivalent NATO Rank Code',
#    'Rank in Spanish',
#    'Rank in English',
#    'Commonwealth equivalent',
#    'US Air Force equivalent']},
#  {'question': 'If you are a pilot officer in the commonwealth then what will you called as in the US air force?',
#   'sqlQuery': 'SELECT US Air Force equivalent FROM table WHERE Commonwealth equivalent = Pilot Officer',
#   'attr': ['Equivalent NATO Rank Code',
#    'Rank in Spanish',
#    'Rank in English',
#    'Commonwealth equivalent',
#    'US Air Force equivalent']},
#  {'question': "If you're a major general in the US air force then what ranking will you receive in the commonwealth's air force?",
#   'sqlQuery': 'SELECT Commonwealth equivalent FROM table WHERE US Air Force equivalent = Major General',
#   'attr': ['Equivalent NATO Rank Code',
#    'Rank in Spanish',
#    'Rank in English',
#    'Commonwealth equivalent',
#    'US Air Force equivalent']},
#  {'question': 'If you get a ranking as major in the  english military then what would the spanish military address you as? ',
#   'sqlQuery': 'SELECT Rank in Spanish FROM table WHERE Rank in English = Major',
#   'attr': ['Equivalent NATO Rank Code',
#    'Rank in Spanish',
#    'Rank in English',
#    'Commonwealth equivalent',
#    'US Air Force equivalent']},
#  {'question': 'Which wrestlers have had 2 reigns?',
#   'sqlQuery': 'SELECT Wrestler FROM table WHERE # of reigns = 2',
#   'attr': ['Rank Each wrestlers total number of days as champion are ranked highest to lowest; wrestlers with the same number mean that they are tied for that certain rank.',
#    'Wrestler',
#    '# of reigns',
#    'Combined defenses',
#    'Combined days']},
#  {'question': 'In terms of reigns, what is the lowest number listed?',
#   'sqlQuery': 'SELECT MIN # of reigns FROM table',
#   'attr': ['Rank Each wrestlers total number of days as champion are ranked highest to lowest; wrestlers with the same number mean that they are tied for that certain rank.',
#    'Wrestler',
#    '# of reigns',
#    'Combined defenses',
#    'Combined days']},
#  {'question': 'What rank was Bryan Danielson in this chart?',
#   'sqlQuery': 'SELECT Rank Each wrestlers total number of days as champion are ranked highest to lowest; wrestlers with the same number mean that they are tied for that certain rank. FROM table WHERE Wrestler = Bryan Danielson',
#   'attr': ['Rank Each wrestlers total number of days as champion are ranked highest to lowest; wrestlers with the same number mean that they are tied for that certain rank.',
#    'Wrestler',
#    '# of reigns',
#    'Combined defenses',
#    'Combined days']},
#  {'question': "What was Go Shiozaki's rank?",
#   'sqlQuery': 'SELECT MIN Rank Each wrestlers total number of days as champion are ranked highest to lowest; wrestlers with the same number mean that they are tied for that certain rank. FROM table WHERE Wrestler = Go Shiozaki',
#   'attr': ['Rank Each wrestlers total number of days as champion are ranked highest to lowest; wrestlers with the same number mean that they are tied for that certain rank.',
#    'Wrestler',
#    '# of reigns',
#    'Combined defenses',
#    'Combined days']},
#  {'question': 'What is the regulated retail price for the tariff code ff0 prs?',
#   'sqlQuery': 'SELECT BTs retail price (regulated) FROM table WHERE Tariff code = ff0 PRS',
#   'attr': ['Scheme',
#    'Tariff code',
#    'BTs retail price (regulated)',
#    'Approx premium',
#    'Prefixes']},
#  {'question': 'What is the premium associated with tariff code g9?',
#   'sqlQuery': 'SELECT Approx premium FROM table WHERE Tariff code = g9',
#   'attr': ['Scheme',
#    'Tariff code',
#    'BTs retail price (regulated)',
#    'Approx premium',
#    'Prefixes']},
#  {'question': 'How many tariff codes have a bts retail price of 2p/min or inclusive?',
#   'sqlQuery': 'SELECT COUNT Tariff code FROM table WHERE BTs retail price (regulated) = 2p/min or inclusive',
#   'attr': ['Scheme',
#    'Tariff code',
#    'BTs retail price (regulated)',
#    'Approx premium',
#    'Prefixes']},
#  {'question': 'How many tariff codes have a bts retail price of 2.553p/min?',
#   'sqlQuery': 'SELECT COUNT Tariff code FROM table WHERE BTs retail price (regulated) = 2.553p/min',
#   'attr': ['Scheme',
#    'Tariff code',
#    'BTs retail price (regulated)',
#    'Approx premium',
#    'Prefixes']},
#  {'question': 'What is the tone for gen.sing. plague?',
#   'sqlQuery': 'SELECT Tone (Latvian notation: /~/ - level, /^/ - broken) FROM table WHERE Translation = Gen.Sing. plague',
#   'attr': ['Nominative',
#    'Old orthography',
#    'New orthography',
#    '/e/ or /æ/ (IPA)',
#    'Tone (Latvian notation: /~/ - level, /^/ - broken)',
#    'Translation']},
#  {'question': 'What is the smallest possible radius?',
#   'sqlQuery': 'SELECT MIN Radius (R ☉ ) FROM table',
#   'attr': ['Star (Pismis24-#)',
#    'Spectral type',
#    'Magnitude (M bol )',
#    'Temperature (K)',
#    'Radius (R ☉ )',
#    'Mass (M ☉ )']},
#  {'question': 'What are all the spectral types for star mismis24-# is 1sw?',
#   'sqlQuery': 'SELECT Spectral type FROM table WHERE Star (Pismis24-#) = 1SW',
#   'attr': ['Star (Pismis24-#)',
#    'Spectral type',
#    'Magnitude (M bol )',
#    'Temperature (K)',
#    'Radius (R ☉ )',
#    'Mass (M ☉ )']},
#  {'question': 'If a radius is 10, what  is the lowest possible mass?',
#   'sqlQuery': 'SELECT MIN Mass (M ☉ ) FROM table WHERE Radius (R ☉ ) = 10',
#   'attr': ['Star (Pismis24-#)',
#    'Spectral type',
#    'Magnitude (M bol )',
#    'Temperature (K)',
#    'Radius (R ☉ )',
#    'Mass (M ☉ )']},
#  {'question': 'What percentage of seats were filled in 2006?',
#   'sqlQuery': 'SELECT Seat factor FROM table WHERE Year = 2006',
#   'attr': ['Year',
#    'Aircraft kilometers',
#    'Departures',
#    'Flying hours',
#    'Passengers',
#    'Seat factor',
#    'Employees',
#    'Profit/loss']},
#  {'question': 'How many hours were flown in each of the years where more than 64379058.0 kilometers were flown?',
#   'sqlQuery': 'SELECT Flying hours FROM table WHERE Aircraft kilometers > 64379058.0',
#   'attr': ['Year',
#    'Aircraft kilometers',
#    'Departures',
#    'Flying hours',
#    'Passengers',
#    'Seat factor',
#    'Employees',
#    'Profit/loss']},
#  {'question': 'How many significant relationships list Will as a virtue?',
#   'sqlQuery': 'SELECT COUNT Significant Relationship FROM table WHERE Virtues = Will',
#   'attr': ['Approximate Age',
#    'Virtues',
#    'Psycho Social Crisis',
#    'Significant Relationship',
#    'Existential Question [ not in citation given ]',
#    'Examples']},
#  {'question': 'How many countries got 796.7 points?',
#   'sqlQuery': 'SELECT COUNT Rank FROM table WHERE Points = 796.7',
#   'attr': ['Rank',
#    'Member Association',
#    'Points',
#    'Group stage',
#    'Play-off',
#    'AFC Cup']},
#  {'question': 'What is the lowest group to earn 886.6 points?',
#   'sqlQuery': 'SELECT MIN Group stage FROM table WHERE Points = 886.6',
#   'attr': ['Rank',
#    'Member Association',
#    'Points',
#    'Group stage',
#    'Play-off',
#    'AFC Cup']},
#  {'question': 'How many countries earned 177.2 points?',
#   'sqlQuery': 'SELECT COUNT Member Association FROM table WHERE Points = 177.2',
#   'attr': ['Rank',
#    'Member Association',
#    'Points',
#    'Group stage',
#    'Play-off',
#    'AFC Cup']},
#  {'question': 'What country had the total 18,900 (r)?',
#   'sqlQuery': 'SELECT County FROM table WHERE Total = 18,900 (R)',
#   'attr': ['County',
#    'Precincts',
#    'Lunsford',
#    '% Lunsford',
#    'McConnell',
#    '% McConnell',
#    'Total']},
#  {'question': 'When % mcconnell is 44.54% what are the total number of counties?',
#   'sqlQuery': 'SELECT COUNT County FROM table WHERE % McConnell = 44.54%',
#   'attr': ['County',
#    'Precincts',
#    'Lunsford',
#    '% Lunsford',
#    'McConnell',
#    '% McConnell',
#    'Total']},
#  {'question': 'When did the stadium where Bursaspor is the tenant open?',
#   'sqlQuery': 'SELECT MIN Opening FROM table WHERE Tenant = Bursaspor',
#   'attr': ['Stadium', 'Capacity', 'City', 'Country', 'Tenant', 'Opening']},
#  {'question': 'How many tenants are there in the city of Samsun?',
#   'sqlQuery': 'SELECT COUNT Tenant FROM table WHERE City = Samsun',
#   'attr': ['Stadium', 'Capacity', 'City', 'Country', 'Tenant', 'Opening']},
#  {'question': 'What is the state of Ted Stevens?',
#   'sqlQuery': 'SELECT State represented FROM table WHERE Name = Ted Stevens',
#   'attr': ['Total tenure rank',
#    'Uninterrupted rank',
#    'Name',
#    'State represented',
#    'Dates of service',
#    'Total tenure time',
#    'Uninterrupted time']},
#  {'question': 'What religious groups made up 0.72% of the Indian population in 2001?',
#   'sqlQuery': 'SELECT Religious group FROM table WHERE Population % 2001 = 0.72%',
#   'attr': ['Religious group',
#    'Population % 1961',
#    'Population % 1971',
#    'Population % 1981',
#    'Population % 1991',
#    'Population % 2001']},
#  {'question': 'How many episodes in season 6 titles "Poppin\' Tags"?',
#   'sqlQuery': 'SELECT COUNT No. in season FROM table WHERE Title = "Poppin\' Tags"',
#   'attr': ['No. in series',
#    'No. in season',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'U.S. viewers (millions)']},
#  {'question': 'How many drivers on the williams team had a margin of defeat of 2?',
#   'sqlQuery': 'SELECT COUNT Driver FROM table WHERE Team = Williams AND Margin of defeat = 2',
#   'attr': ['Season',
#    'Driver',
#    'Team',
#    'Engine',
#    'Poles',
#    'Wins',
#    'Podiums',
#    'Points',
#    'Margin of defeat']},
#  {'question': 'How many seasons was clay regazzoni the driver?',
#   'sqlQuery': 'SELECT COUNT Season FROM table WHERE Driver = Clay Regazzoni',
#   'attr': ['Season',
#    'Driver',
#    'Team',
#    'Engine',
#    'Poles',
#    'Wins',
#    'Podiums',
#    'Points',
#    'Margin of defeat']},
#  {'question': 'Which margin of defeats had points of 30?',
#   'sqlQuery': 'SELECT Margin of defeat FROM table WHERE Points = 30',
#   'attr': ['Season',
#    'Driver',
#    'Team',
#    'Engine',
#    'Poles',
#    'Wins',
#    'Podiums',
#    'Points',
#    'Margin of defeat']},
#  {'question': 'How many people were pick #30?',
#   'sqlQuery': 'SELECT COUNT Position FROM table WHERE Pick # = 30',
#   'attr': ['Pick #', 'CFL Team', 'Player', 'Position', 'College']},
#  {'question': 'Which lava domes erupted or had a growth episode during the Holocene period?',
#   'sqlQuery': 'SELECT Name of lava dome FROM table WHERE Last eruption or growth episode = Holocene',
#   'attr': ['Name of lava dome',
#    'Country',
#    'Volcanic area',
#    'Composition',
#    'Last eruption or growth episode']},
#  {'question': 'How many countries are the Tata Sabaya Lava domes located in?',
#   'sqlQuery': 'SELECT COUNT Country FROM table WHERE Name of lava dome = Tata Sabaya lava domes',
#   'attr': ['Name of lava dome',
#    'Country',
#    'Volcanic area',
#    'Composition',
#    'Last eruption or growth episode']},
#  {'question': 'What countries have had eruptions of growth episodes in 1986?',
#   'sqlQuery': 'SELECT Country FROM table WHERE Last eruption or growth episode = 1986',
#   'attr': ['Name of lava dome',
#    'Country',
#    'Volcanic area',
#    'Composition',
#    'Last eruption or growth episode']},
#  {'question': 'What is the highest track number?',
#   'sqlQuery': 'SELECT MAX Track # FROM table',
#   'attr': ['Track #',
#    'Song',
#    'Singers',
#    'Picturization',
#    'Length',
#    'Lyricist']},
#  {'question': 'What publishers were involved with product number SCUS-97265?',
#   'sqlQuery': 'SELECT Publisher FROM table WHERE Product No. = SCUS-97265',
#   'attr': ['Title',
#    'System',
#    'Publisher',
#    'Product No.',
#    'Compatible with 20/60GB NTSC PS3 (CECHA/CECHB)',
#    'Compatible with 60GB PAL/80GB NTSC PS3 (CECHC/CECHE)']},
#  {'question': 'How many products have the title "Jak 3"?',
#   'sqlQuery': 'SELECT COUNT Product No. FROM table WHERE Title = Jak 3',
#   'attr': ['Title',
#    'System',
#    'Publisher',
#    'Product No.',
#    'Compatible with 20/60GB NTSC PS3 (CECHA/CECHB)',
#    'Compatible with 60GB PAL/80GB NTSC PS3 (CECHC/CECHE)']},
#  {'question': 'Which James Bond 007: Agent Under Fire from Electronic Arts is compatible with 60 gb pal/80 gb NTSC PS3 (CECHC/CECHE)?',
#   'sqlQuery': 'SELECT Compatible with 60GB PAL/80GB NTSC PS3 (CECHC/CECHE) FROM table WHERE Publisher = Electronic Arts AND Title = James Bond 007: Agent Under Fire',
#   'attr': ['Title',
#    'System',
#    'Publisher',
#    'Product No.',
#    'Compatible with 20/60GB NTSC PS3 (CECHA/CECHB)',
#    'Compatible with 60GB PAL/80GB NTSC PS3 (CECHC/CECHE)']},
#  {'question': 'What publishers produce product number SLUS-20265?',
#   'sqlQuery': 'SELECT Publisher FROM table WHERE Product No. = SLUS-20265',
#   'attr': ['Title',
#    'System',
#    'Publisher',
#    'Product No.',
#    'Compatible with 20/60GB NTSC PS3 (CECHA/CECHB)',
#    'Compatible with 60GB PAL/80GB NTSC PS3 (CECHC/CECHE)']},
#  {'question': 'How many titles have the product number SCUS-97330?',
#   'sqlQuery': 'SELECT COUNT Title FROM table WHERE Product No. = SCUS-97330',
#   'attr': ['Title',
#    'System',
#    'Publisher',
#    'Product No.',
#    'Compatible with 20/60GB NTSC PS3 (CECHA/CECHB)',
#    'Compatible with 60GB PAL/80GB NTSC PS3 (CECHC/CECHE)']},
#  {'question': 'How many series are named "Lockdown"?',
#   'sqlQuery': 'SELECT COUNT Series # FROM table WHERE Title = "Lockdown"',
#   'attr': ['Series #',
#    'Episode #',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date']},
#  {'question': 'Who directed the second episode of "The Homecoming" which was written by Tommy Thompson?',
#   'sqlQuery': 'SELECT Directed by FROM table WHERE Written by = Tommy Thompson',
#   'attr': ['Series #',
#    'Episode #',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date']},
#  {'question': 'What was the latest episode of "House of Cards"?',
#   'sqlQuery': 'SELECT MAX Episode # FROM table WHERE Title = "House of Cards"',
#   'attr': ['Series #',
#    'Episode #',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date']},
#  {'question': 'Who was the republican candidate in 2013 when Staten Island was 451?',
#   'sqlQuery': 'SELECT 2013 Republican primary FROM table WHERE Staten Island = 451',
#   'attr': ['2013 Republican primary',
#    'Manhattan',
#    'The Bronx',
#    'Brooklyn',
#    'Queens',
#    'Staten Island',
#    'Total',
#    '%']},
#  {'question': 'The candidate who received 133 votes in the Bronx won what percentage overall?',
#   'sqlQuery': 'SELECT % FROM table WHERE The Bronx = 133',
#   'attr': ['1921',
#    'party',
#    'Manhattan',
#    'The Bronx',
#    'Brooklyn',
#    'Queens',
#    'Richmond [Staten Is.]',
#    'Total',
#    '%']},
#  {'question': 'The man who received 87,676 votes in Queens won what percentage of the total for the election?',
#   'sqlQuery': 'SELECT % FROM table WHERE Queens = 87,676',
#   'attr': ['1921',
#    'party',
#    'Manhattan',
#    'The Bronx',
#    'Brooklyn',
#    'Queens',
#    'Richmond [Staten Is.]',
#    'Total',
#    '%']},
#  {'question': 'How many parties received 29.9% of the vote in Manhattan?',
#   'sqlQuery': 'SELECT COUNT party FROM table WHERE Manhattan = 29.9%',
#   'attr': ['1921',
#    'party',
#    'Manhattan',
#    'The Bronx',
#    'Brooklyn',
#    'Queens',
#    'Richmond [Staten Is.]',
#    'Total',
#    '%']},
#  {'question': 'What is the least september 1943 when late 1943 is 78000',
#   'sqlQuery': 'SELECT MIN Sept. 1943 FROM table WHERE Late 1943 = 78000',
#   'attr': ['! Late 1941',
#    'Late 1942',
#    'Sept. 1943',
#    'Late 1943',
#    'Late 1944',
#    '1978 Veteran membership']},
#  {'question': 'What is the late 1941 when 1978 veteran membership is 20000',
#   'sqlQuery': 'SELECT ! Late 1941 FROM table WHERE 1978 Veteran membership = 20000',
#   'attr': ['! Late 1941',
#    'Late 1942',
#    'Sept. 1943',
#    'Late 1943',
#    'Late 1944',
#    '1978 Veteran membership']},
#  {'question': 'Which stadiums have a capacity of 51082?',
#   'sqlQuery': 'SELECT Stadium FROM table WHERE Capacity = 51082',
#   'attr': ['Team', 'Stadium', 'Capacity', 'Lowest', 'Highest', 'Average']},
#  {'question': 'How many stadiums are there with a capacity of 7500?',
#   'sqlQuery': 'SELECT COUNT Stadium FROM table WHERE Capacity = 7500',
#   'attr': ['Team', 'Stadium', 'Capacity', 'Lowest', 'Highest', 'Average']},
#  {'question': 'Which stadiums have an average attendance of 13840?',
#   'sqlQuery': 'SELECT Stadium FROM table WHERE Average = 13840',
#   'attr': ['Team', 'Stadium', 'Capacity', 'Lowest', 'Highest', 'Average']},
#  {'question': 'During the 2013 debut, what is the w-I(total) number?',
#   'sqlQuery': 'SELECT COUNT W-L (Total) FROM table WHERE Debut = 2013',
#   'attr': ['Player',
#    'W-L (Total)',
#    'W-L ( Singles )',
#    'W-L ( Doubles )',
#    'Ties',
#    'Debut',
#    'Years Played']},
#  {'question': 'how many studios have the catalog number "cal03 / 0091037137333"?',
#   'sqlQuery': 'SELECT COUNT Studio FROM table WHERE Catalog Number = CAL03 / 0091037137333',
#   'attr': ['Year',
#    'Title',
#    'Format',
#    'Studio',
#    'Release Date',
#    'Copyright Information',
#    'Catalog Number']},
#  {'question': 'how many titles have the name "quick callanetics"?',
#   'sqlQuery': 'SELECT COUNT Catalog Number FROM table WHERE Title = Quick Callanetics',
#   'attr': ['Year',
#    'Title',
#    'Format',
#    'Studio',
#    'Release Date',
#    'Copyright Information',
#    'Catalog Number']},
#  {'question': 'Who creates the catalog with the number "cal03 / 0091037137333"?',
#   'sqlQuery': 'SELECT Studio FROM table WHERE Catalog Number = CAL03 / 0091037137333',
#   'attr': ['Year',
#    'Title',
#    'Format',
#    'Studio',
#    'Release Date',
#    'Copyright Information',
#    'Catalog Number']},
#  {'question': 'What was the number of channels in New Zealand?',
#   'sqlQuery': 'SELECT COUNT Channel FROM table WHERE Country/Region = New Zealand',
#   'attr': ['Country/Region',
#    'Show Title',
#    'Languages',
#    'Host',
#    'Channel',
#    'Premiere',
#    'Seasons',
#    'Status']},
#  {'question': 'What is the symbol for Windpower in China?',
#   'sqlQuery': 'SELECT Wind power (WP) FROM table WHERE Country = China',
#   'attr': ['Country',
#    'Renewable energy (RE)',
#    'Solar power (SP)',
#    'Wind power (WP)',
#    'Geothermal energy (GE)',
#    'Biofuel (BF)',
#    'Hydro power (Hydro)']},
#  {'question': 'who were the winners in west virginia',
#   'sqlQuery': 'SELECT Candidates Winning candidate in bold FROM table WHERE State (linked to summaries below) = West Virginia',
#   'attr': ['State (linked to summaries below)',
#    'Senator',
#    'Party',
#    'Electoral history',
#    'Result',
#    'Candidates Winning candidate in bold']},
#  {'question': 'tell the final for lindsey graham',
#   'sqlQuery': 'SELECT Result FROM table WHERE Senator = Lindsey Graham',
#   'attr': ['State (linked to summaries below)',
#    'Senator',
#    'Party',
#    'Electoral history',
#    'Result',
#    'Candidates Winning candidate in bold']},
#  {'question': 'who won the senate seat in arkansas',
#   'sqlQuery': 'SELECT Senator FROM table WHERE State (linked to summaries below) = Arkansas',
#   'attr': ['State (linked to summaries below)',
#    'Senator',
#    'Party',
#    'Electoral history',
#    'Result',
#    'Candidates Winning candidate in bold']},
#  {'question': 'What is williow canyon of Roberta Lockhart?',
#   'sqlQuery': 'SELECT Willow Canyon FROM table WHERE Dysart = Roberta Lockhart',
#   'attr': ['Information',
#    'Dysart',
#    'Shadow Ridge',
#    'Valley Vista',
#    'Willow Canyon']},
#  {'question': 'How many informations does Michael Hawkins have?',
#   'sqlQuery': 'SELECT COUNT Information FROM table WHERE Shadow Ridge = Michael Hawkins',
#   'attr': ['Information',
#    'Dysart',
#    'Shadow Ridge',
#    'Valley Vista',
#    'Willow Canyon']},
#  {'question': 'How many total rounds did Damon Hill come in First Place?',
#   'sqlQuery': 'SELECT COUNT Round FROM table WHERE Winning Driver = Damon Hill',
#   'attr': ['Round',
#    'Grand Prix',
#    'Pole Position',
#    'Fastest Lap',
#    'Winning Driver',
#    'Winning Constructor',
#    'Report']},
#  {'question': 'Who drove the winning car constructed by Jordan - Mugen-Honda?',
#   'sqlQuery': 'SELECT Winning Driver FROM table WHERE Winning Constructor = Jordan - Mugen-Honda',
#   'attr': ['Round',
#    'Grand Prix',
#    'Pole Position',
#    'Fastest Lap',
#    'Winning Driver',
#    'Winning Constructor',
#    'Report']},
#  {'question': 'The president, peter williamson, had how many home grounds?',
#   'sqlQuery': 'SELECT COUNT Home Ground FROM table WHERE President = Peter Williamson',
#   'attr': ['Team',
#    'Head Coach',
#    'President',
#    'Home Ground',
#    'Location',
#    'Founded',
#    'Website']},
#  {'question': 'How many head coaches are there for the website, http://www.burleighbulldogs.org/?',
#   'sqlQuery': 'SELECT COUNT Head Coach FROM table WHERE Website = http://www.burleighbulldogs.org/',
#   'attr': ['Team',
#    'Head Coach',
#    'President',
#    'Home Ground',
#    'Location',
#    'Founded',
#    'Website']},
#  {'question': 'The head coach, steve radoslavic, is related to which websites?',
#   'sqlQuery': 'SELECT Website FROM table WHERE Head Coach = Steve Radoslavic',
#   'attr': ['Team',
#    'Head Coach',
#    'President',
#    'Home Ground',
#    'Location',
#    'Founded',
#    'Website']},
#  {'question': 'Who is the driver of the european grand prix?',
#   'sqlQuery': 'SELECT Winning Driver FROM table WHERE Grand Prix = European Grand Prix',
#   'attr': ['Round',
#    'Grand Prix',
#    'Pole Position',
#    'Fastest Lap',
#    'Winning Driver',
#    'Winning Constructor',
#    'Report']},
#  {'question': 'How many teams did they play week 6',
#   'sqlQuery': 'SELECT COUNT Opponent FROM table WHERE Week = 6',
#   'attr': ['Week',
#    'Date',
#    'Opponent',
#    'Result',
#    'Kickoff [a ]',
#    'Venue',
#    'TV',
#    'Attendance',
#    'Record']},
#  {'question': 'What is the number of reports for the italian grand prix?',
#   'sqlQuery': 'SELECT COUNT Report FROM table WHERE Race = Italian Grand Prix',
#   'attr': ['Rnd',
#    'Race',
#    'Date',
#    'Location',
#    'Pole Position',
#    'Fastest Lap',
#    'Race Winner',
#    'Constructor',
#    'Report']},
#  {'question': 'Where is the German Grand Prix?',
#   'sqlQuery': 'SELECT Location FROM table WHERE Race = German Grand Prix',
#   'attr': ['Rnd',
#    'Race',
#    'Date',
#    'Location',
#    'Pole Position',
#    'Fastest Lap',
#    'Race Winner',
#    'Constructor',
#    'Report']},
#  {'question': 'Which driver won the i race of champions?',
#   'sqlQuery': 'SELECT Winning driver FROM table WHERE Race Name = I Race of Champions',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'How many winners did I Dessau Autobahnspinne have?',
#   'sqlQuery': 'SELECT COUNT Winning driver FROM table WHERE Race Name = I Dessau Autobahnspinne',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'How many races take place in Dessau circuit?',
#   'sqlQuery': 'SELECT COUNT Race Name FROM table WHERE Circuit = Dessau',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'Which races did Paul Greifzu win?',
#   'sqlQuery': 'SELECT Race Name FROM table WHERE Winning driver = Paul Greifzu',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'Which driver won at the Sachsenring circuit?',
#   'sqlQuery': 'SELECT Winning driver FROM table WHERE Circuit = Sachsenring',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'How many different constructors had Paul Thiel as a winning driver?',
#   'sqlQuery': 'SELECT COUNT Constructor FROM table WHERE Winning driver = Paul Thiel',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'When was the Albi circuit race driven? ',
#   'sqlQuery': 'SELECT Date FROM table WHERE Circuit = Albi',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'Would built the winning car in the IV J.C.C. Jersey Road Race? ',
#   'sqlQuery': 'SELECT Constructor FROM table WHERE Race Name = IV J.C.C. Jersey Road Race',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'Who won the race at the Jersey circuit? ',
#   'sqlQuery': 'SELECT Winning driver FROM table WHERE Circuit = Jersey',
#   'attr': ['Race Name',
#    'Circuit',
#    'Date',
#    'Winning driver',
#    'Constructor',
#    'Report']},
#  {'question': 'When did the season air where the viewership was 14.71 million?',
#   'sqlQuery': 'SELECT Season premiere FROM table WHERE Viewers (in millions) = 14.71',
#   'attr': ['Season',
#    'Season premiere',
#    'Season finale',
#    'TV season',
#    'Ranking',
#    'Viewers (in millions)']},
#  {'question': 'What is the power capacity when the generators were 781?',
#   'sqlQuery': 'SELECT Power Capacity (GW) FROM table WHERE Number of Generators = 781',
#   'attr': ['Power Source',
#    'Number of Generators',
#    'Power Capacity (GW)',
#    '% of total Capacity',
#    'Capacity factor',
#    'Annual Energy (billion kWh)',
#    '% of annual production']},
#  {'question': 'What is the percentage of total capacity when the energy is 120.2?',
#   'sqlQuery': 'SELECT % of total Capacity FROM table WHERE Annual Energy (billion kWh) = 120.2',
#   'attr': ['Power Source',
#    'Number of Generators',
#    'Power Capacity (GW)',
#    '% of total Capacity',
#    'Capacity factor',
#    'Annual Energy (billion kWh)',
#    '% of annual production']},
#  {'question': 'What school or team does Al Jefferson play for?',
#   'sqlQuery': 'SELECT School/Club Team FROM table WHERE Player = Al Jefferson',
#   'attr': ['Player',
#    'No.',
#    'Nationality',
#    'Position',
#    'Years for Jazz',
#    'School/Club Team']},
#  {'question': 'What number does the player from Ohio play with?',
#   'sqlQuery': 'SELECT No. FROM table WHERE School/Club Team = Ohio',
#   'attr': ['Player',
#    'No.',
#    'Nationality',
#    'Position',
#    'Years for Jazz',
#    'School/Club Team']},
#  {'question': 'During which years did player number 35 play for Jazz?',
#   'sqlQuery': 'SELECT Years for Jazz FROM table WHERE No. = 35',
#   'attr': ['Player',
#    'No.',
#    'Nationality',
#    'Position',
#    'Years for Jazz',
#    'School/Club Team']},
#  {'question': 'When was the game in Mexico played? ',
#   'sqlQuery': 'SELECT Date FROM table WHERE Location = Mexico',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse( $ )',
#    'Winner',
#    'Score',
#    '1st Prize( $ )']},
#  {'question': 'What University has the acrronym of USF',
#   'sqlQuery': 'SELECT University Name FROM table WHERE Acronym = USF',
#   'attr': ['University Name',
#    'Acronym',
#    'Date founded',
#    'Website',
#    'Official registration notes']},
#  {'question': 'Are there registration notes on usek.edu.lb?',
#   'sqlQuery': 'SELECT Official registration notes FROM table WHERE Website = usek.edu.lb',
#   'attr': ['University Name',
#    'Acronym',
#    'Date founded',
#    'Website',
#    'Official registration notes']},
#  {'question': 'What year was USF founded?',
#   'sqlQuery': 'SELECT Date founded FROM table WHERE Acronym = USF',
#   'attr': ['University Name',
#    'Acronym',
#    'Date founded',
#    'Website',
#    'Official registration notes']},
#  {'question': 'How many prizes were there at the transamerica?',
#   'sqlQuery': 'SELECT COUNT 1st Prize( $ ) FROM table WHERE Tournament = The Transamerica',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse( $ )',
#    'Winner',
#    'Score',
#    '1st Prize( $ )']},
#  {'question': 'What is the sum of the largest purse?',
#   'sqlQuery': 'SELECT MAX Purse( $ ) FROM table',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse( $ )',
#    'Winner',
#    'Score',
#    '1st Prize( $ )']},
#  {'question': 'When was the tournament in Washington held?',
#   'sqlQuery': 'SELECT Date FROM table WHERE Location = Washington',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse( $ )',
#    'Winner',
#    'Score',
#    '1st Prize( $ )']},
#  {'question': 'How many tournaments in Texas had a purse higher than 330105.1624276874?',
#   'sqlQuery': 'SELECT COUNT 1st Prize( $ ) FROM table WHERE Location = Texas AND Purse( $ ) > 330105.1624276874',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse( $ )',
#    'Winner',
#    'Score',
#    '1st Prize( $ )']},
#  {'question': 'What is the first season written by joseph hampton & dani renee?',
#   'sqlQuery': 'SELECT MIN Season no. FROM table WHERE Written by = Joseph Hampton & Dani Renee',
#   'attr': ['Series no.',
#    'Season no.',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'Production Code']},
#  {'question': 'How many air dates are there for production code 206?',
#   'sqlQuery': 'SELECT COUNT Original air date FROM table WHERE Production Code = 206',
#   'attr': ['Series no.',
#    'Season no.',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'Production Code']},
#  {'question': 'What is the series number for the title "Bad Influence"',
#   'sqlQuery': 'SELECT MAX Series no. FROM table WHERE Title = "Bad Influence"',
#   'attr': ['Series no.',
#    'Season no.',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'Production Code']},
#  {'question': 'How many seasons was series number 47 shown?',
#   'sqlQuery': 'SELECT COUNT Season no. FROM table WHERE Series no. = 47',
#   'attr': ['Series no.',
#    'Season no.',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'Production Code']},
#  {'question': 'When did the episode with production code 410 air?',
#   'sqlQuery': 'SELECT Original air date FROM table WHERE Production code = 410',
#   'attr': ['Series #',
#    'Season #',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'Production code']},
#  {'question': 'What is the most series number with season 3?',
#   'sqlQuery': 'SELECT MAX Series # FROM table WHERE Season # = 3',
#   'attr': ['Series #',
#    'Season #',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'Production code']},
#  {'question': 'What is the purse value for the New York location?',
#   'sqlQuery': 'SELECT Purse( $ ) FROM table WHERE Location = New York',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse( $ )',
#    'Winner',
#    'Score',
#    '1st Prize( $ )']},
#  {'question': 'List all areas within 1000 km in the city of Lubelskie?',
#   'sqlQuery': 'SELECT Area in 1000km² (1930) FROM table WHERE Voivodeship Separate city = lubelskie',
#   'attr': ['car plates (since 1937)',
#    'Voivodeship Separate city',
#    'Capital',
#    'Area in 1000km² (1930)',
#    'Population in 1000 (1931)']},
#  {'question': 'What is the population in the city of Pomorskie?',
#   'sqlQuery': 'SELECT Population in 1000 (1931) FROM table WHERE Voivodeship Separate city = pomorskie',
#   'attr': ['car plates (since 1937)',
#    'Voivodeship Separate city',
#    'Capital',
#    'Area in 1000km² (1930)',
#    'Population in 1000 (1931)']},
#  {'question': 'List all car plates in the capital of Wilno since the year of 1937.',
#   'sqlQuery': 'SELECT car plates (since 1937) FROM table WHERE Capital = Wilno',
#   'attr': ['car plates (since 1937)',
#    'Voivodeship Separate city',
#    'Capital',
#    'Area in 1000km² (1930)',
#    'Population in 1000 (1931)']},
#  {'question': 'List population when their car plates are 30-34.',
#   'sqlQuery': 'SELECT Population in 1000 (1931) FROM table WHERE car plates (since 1937) = 30-34',
#   'attr': ['car plates (since 1937)',
#    'Voivodeship Separate city',
#    'Capital',
#    'Area in 1000km² (1930)',
#    'Population in 1000 (1931)']},
#  {'question': 'WHAT TEAM CLASSIFIED IN THE STAGE WHERE BRADLEY WIGGINS WON THE POINTS CLASSIFICATION ?',
#   'sqlQuery': 'SELECT Team Classification FROM table WHERE Points classification = Bradley Wiggins',
#   'attr': ['Stage (Winner)',
#    'General classification',
#    'Mountains classification',
#    'Points classification',
#    'Combination classification',
#    'Team Classification']},
#  {'question': 'IN WHAT STAGE DID ALEXANDER VINOKOUROV WON THE GENERAL CLASSIFICATION?',
#   'sqlQuery': 'SELECT Stage (Winner) FROM table WHERE General classification = Alexander Vinokourov',
#   'attr': ['Stage (Winner)',
#    'General classification',
#    'Mountains classification',
#    'Points classification',
#    'Combination classification',
#    'Team Classification']},
#  {'question': 'What are the swimsuits for south africa?',
#   'sqlQuery': 'SELECT Swimsuit FROM table WHERE Delegate = South Africa',
#   'attr': ['Delegate', 'Interview', 'Swimsuit', 'Evening Gown', 'Average']},
#  {'question': 'How many players have the hometown Pennsauken, NJ?',
#   'sqlQuery': 'SELECT COUNT Player FROM table WHERE Hometown = Pennsauken, NJ',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'MLB Draft']},
#  {'question': 'WHAT TOWN IS WEST BROOK SENIOR HIGH SCHOOL FROM?',
#   'sqlQuery': 'SELECT Hometown FROM table WHERE School = West Brook Senior High School',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'MLB Draft']},
#  {'question': 'How many offensive line players played for a college in Alabama?',
#   'sqlQuery': 'SELECT COUNT Hometown FROM table WHERE College = Alabama AND Position = Offensive line',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'College']},
#  {'question': 'How many players attended Hillcrest High School?',
#   'sqlQuery': 'SELECT COUNT College FROM table WHERE School = Hillcrest High School',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'College']},
#  {'question': 'How many players hometown was Cincinnati, Ohio?',
#   'sqlQuery': 'SELECT COUNT Player FROM table WHERE Hometown = Cincinnati, Ohio',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'College']},
#  {'question': "How many players' hometown was Akron, Ohio?",
#   'sqlQuery': 'SELECT COUNT School FROM table WHERE Hometown = Akron, Ohio',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'College']},
#  {'question': 'Which player is from Saguaro High School?',
#   'sqlQuery': 'SELECT Position FROM table WHERE School = Saguaro High School',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'College']},
#  {'question': 'Where is longview high school',
#   'sqlQuery': 'SELECT Hometown FROM table WHERE School = Longview High School',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'College']},
#  {'question': 'Where is friendship collegiate charter school located',
#   'sqlQuery': 'SELECT Hometown FROM table WHERE School = Friendship Collegiate Charter School',
#   'attr': ['Player', 'Position', 'School', 'Hometown', 'College']},
#  {'question': 'Who had an evening gown score of 9.78?',
#   'sqlQuery': 'SELECT Interview FROM table WHERE Evening Gown = 9.78',
#   'attr': ['Country', 'Interview', 'Swimsuit', 'Evening Gown', 'Average']},
#  {'question': 'How many interviews were there for Miss Virginia?',
#   'sqlQuery': 'SELECT COUNT Interview FROM table WHERE Country = Virginia',
#   'attr': ['Country', 'Interview', 'Swimsuit', 'Evening Gown', 'Average']},
#  {'question': 'Who had a swimsuit score of 9.87?',
#   'sqlQuery': 'SELECT COUNT Country FROM table WHERE Swimsuit = 9.87',
#   'attr': ['Country', 'Interview', 'Swimsuit', 'Evening Gown', 'Average']},
#  {'question': 'Who had evening gown score of 9.82?',
#   'sqlQuery': 'SELECT Country FROM table WHERE Evening Gown = 9.82',
#   'attr': ['Country', 'Interview', 'Swimsuit', 'Evening Gown', 'Average']},
#  {'question': 'How many ladies scored a 9.89 for the evening gown?',
#   'sqlQuery': 'SELECT COUNT Swimsuit FROM table WHERE Evening Gown = 9.89',
#   'attr': ['Country', 'Interview', 'Swimsuit', 'Evening Gown', 'Average']},
#  {'question': 'Who scored a 9.72 in the swimsuit?',
#   'sqlQuery': 'SELECT Interview FROM table WHERE Swimsuit = 9.72',
#   'attr': ['Country', 'Interview', 'Swimsuit', 'Evening Gown', 'Average']},
#  {'question': 'What episode was writted by John A. Norris?',
#   'sqlQuery': 'SELECT Title FROM table WHERE Written by = John A. Norris',
#   'attr': ['No. in series',
#    'No. in season',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'Production code',
#    'U.S. viewers (millions)']},
#  {'question': 'How many episodes did David Jackson write and direct?',
#   'sqlQuery': 'SELECT COUNT Written by FROM table WHERE Directed by = David Jackson',
#   'attr': ['No. in series',
#    'No. in season',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date',
#    'Production code',
#    'U.S. viewers (millions)']},
#  {'question': 'How may times did a player that attended Iowa state appear on the all time roster?',
#   'sqlQuery': 'SELECT COUNT Years for Rockets FROM table WHERE School/Club Team/Country = Iowa State',
#   'attr': ['Player',
#    'No.(s)',
#    'Height in Ft.',
#    'Position',
#    'Years for Rockets',
#    'School/Club Team/Country']},
#  {'question': 'What height was the player that played for the Rockets between 1992-93?',
#   'sqlQuery': 'SELECT Height in Ft. FROM table WHERE Years for Rockets = 1992-93',
#   'attr': ['Player',
#    'No.(s)',
#    'Height in Ft.',
#    'Position',
#    'Years for Rockets',
#    'School/Club Team/Country']},
#  {'question': 'How many times did a center that attended Oral Roberts play for the Rockets?',
#   'sqlQuery': 'SELECT COUNT Years for Rockets FROM table WHERE Position = Center AND School/Club Team/Country = Oral Roberts',
#   'attr': ['Player',
#    'No.(s)',
#    'Height in Ft.',
#    'Position',
#    'Years for Rockets',
#    'School/Club Team/Country']},
#  {'question': 'What is the height in ft for the rockets from 1973-78?',
#   'sqlQuery': 'SELECT Height in Ft. FROM table WHERE Years for Rockets = 1973-78',
#   'attr': ['Player',
#    'No.(s)',
#    'Height in Ft.',
#    'Position',
#    'Years for Rockets',
#    'School/Club Team/Country']},
#  {'question': 'Which players were number 3?',
#   'sqlQuery': 'SELECT Player FROM table WHERE No.(s) = 3',
#   'attr': ['Player',
#    'No.(s)',
#    'Height in Ft.',
#    'Position',
#    'Years for Rockets',
#    'School/Club Team/Country']},
#  {'question': 'What is the height in ft for number 42 for the rockets in 1993-94?',
#   'sqlQuery': 'SELECT Height in Ft. FROM table WHERE No.(s) = 42 AND Years for Rockets = 1993-94',
#   'attr': ['Player',
#    'No.(s)',
#    'Height in Ft.',
#    'Position',
#    'Years for Rockets',
#    'School/Club Team/Country']},
#  {'question': 'What are the players that attented long beach state?',
#   'sqlQuery': 'SELECT Player FROM table WHERE School/Club Team/Country = Long Beach State',
#   'attr': ['Player',
#    'No.(s)',
#    'Height in Ft.',
#    'Position',
#    'Years for Rockets',
#    'School/Club Team/Country']},
#  {'question': 'what is the total amount of players for the rockets in 1998 only?',
#   'sqlQuery': 'SELECT COUNT Player FROM table WHERE Years for Rockets = 1998',
#   'attr': ['Player',
#    'No.(s)',
#    'Height in Ft.',
#    'Position',
#    'Years for Rockets',
#    'School/Club Team/Country']},
#  {'question': 'What was the number of music directors where the suresh wadkar co singer of bhayanak?',
#   'sqlQuery': 'SELECT COUNT Music director FROM table WHERE Co-singer = Suresh Wadkar AND Film name = Bhayanak',
#   'attr': ['Year',
#    'Song name',
#    'Film name',
#    'Co-singer',
#    'Music director',
#    'Lyricist',
#    'Language']},
#  {'question': 'What was the lyricst of "na jane aise ho gaya kaise"?',
#   'sqlQuery': 'SELECT Lyricist FROM table WHERE Song name = "Na Jane Aise Ho Gaya Kaise"',
#   'attr': ['Year',
#    'Song name',
#    'Film name',
#    'Co-singer',
#    'Music director',
#    'Lyricist',
#    'Language']},
#  {'question': 'how many times is the co-singer suresh wadkar and the film name is tera dukh mera dukh?',
#   'sqlQuery': 'SELECT COUNT Lyricist FROM table WHERE Co-singer = Suresh Wadkar AND Film name = Tera Dukh Mera Dukh',
#   'attr': ['Year',
#    'Song name',
#    'Film name',
#    'Co-singer',
#    'Music director',
#    'Lyricist',
#    'Language']},
#  {'question': 'what are the film names with the co-singer vinod rathod?',
#   'sqlQuery': 'SELECT Film name FROM table WHERE Co-singer = Vinod Rathod',
#   'attr': ['Year',
#    'Song name',
#    'Film name',
#    'Co-singer',
#    'Music director',
#    'Lyricist',
#    'Language']},
#  {'question': 'what are the song names for the film kaal bhairav?',
#   'sqlQuery': 'SELECT Song name FROM table WHERE Film name = Kaal Bhairav',
#   'attr': ['Year',
#    'Song name',
#    'Film name',
#    'Co-singer',
#    'Music director',
#    'Lyricist',
#    'Language']},
#  {'question': 'What was the maximum l&cr number for archimedes?',
#   'sqlQuery': 'SELECT MAX L&CR No. FROM table WHERE Name = Archimedes',
#   'attr': ['L&CR No.',
#    'Type',
#    'Manufacturer',
#    'Delivered',
#    'Name',
#    'Jt. Cttee No.',
#    '1845 disposal']},
#  {'question': 'Where did Test Mission: War Heads and Missile Payload launch when there was a partial failure?',
#   'sqlQuery': 'SELECT Launch site FROM table WHERE Mission = Test Mission: war heads and Missile payload AND Results = Partial Failure',
#   'attr': ['Launch Vehicle',
#    'Launch date',
#    'Mission',
#    'Institutional authority',
#    'Launch site',
#    'Results']},
#  {'question': 'Which missions were scheduled to launch on November 16, 2006?',
#   'sqlQuery': 'SELECT Mission FROM table WHERE Launch date = November 16, 2006',
#   'attr': ['Launch Vehicle',
#    'Launch date',
#    'Mission',
#    'Institutional authority',
#    'Launch site',
#    'Results']},
#  {'question': 'Which authority has a rocket launch called rehbar-ii?',
#   'sqlQuery': 'SELECT Institutional authority FROM table WHERE Rocket launch = Rehbar-II',
#   'attr': ['Rocket launch',
#    'Launch Date',
#    'Mission',
#    'Institutional authority',
#    'Launch Site',
#    'Outcomes',
#    'Derivatives']},
#  {'question': 'Which authority has a rocket launch called rehnuma-8?',
#   'sqlQuery': 'SELECT Institutional authority FROM table WHERE Rocket launch = Rehnuma-8',
#   'attr': ['Rocket launch',
#    'Launch Date',
#    'Mission',
#    'Institutional authority',
#    'Launch Site',
#    'Outcomes',
#    'Derivatives']},
#  {'question': 'Which authority has a rocket launch called shahpar-2?',
#   'sqlQuery': 'SELECT Institutional authority FROM table WHERE Rocket launch = Shahpar-2',
#   'attr': ['Rocket launch',
#    'Launch Date',
#    'Mission',
#    'Institutional authority',
#    'Launch Site',
#    'Outcomes',
#    'Derivatives']},
#  {'question': 'Which authority has a rocket launch called rehbar-5?',
#   'sqlQuery': 'SELECT COUNT Derivatives FROM table WHERE Rocket launch = Rehbar-5',
#   'attr': ['Rocket launch',
#    'Launch Date',
#    'Mission',
#    'Institutional authority',
#    'Launch Site',
#    'Outcomes',
#    'Derivatives']},
#  {'question': 'What denominations are the stamps with themes opera, léopold simoneau and pierrette alarie?',
#   'sqlQuery': 'SELECT Denomination FROM table WHERE Theme = Opera, Léopold Simoneau and Pierrette Alarie',
#   'attr': ['Date of Issue',
#    'Theme',
#    'Denomination',
#    'Design',
#    'Illustration',
#    'Printing Process',
#    'Paper Type',
#    'First Day Cover Cancellation']},
#  {'question': "What kind of paper were the stamps with the theme duck decoys, barrow's golden eye printed on?",
#   'sqlQuery': "SELECT Paper Type FROM table WHERE Theme = Duck Decoys, Barrow's Golden Eye",
#   'attr': ['Date of Issue',
#    'Theme',
#    'Denomination',
#    'Design',
#    'Illustration',
#    'Printing Process',
#    'Paper Type',
#    'First Day Cover Cancellation']},
#  {'question': 'List all the themes designed by Isabelle Toussaint.',
#   'sqlQuery': 'SELECT Theme FROM table WHERE Design = Isabelle Toussaint',
#   'attr': ['Date of Issue',
#    'Theme',
#    'Denomination',
#    'Design',
#    'Illustration',
#    'Printing Process',
#    'Paper Type',
#    'First Day Cover Cancellation']},
#  {'question': 'How many paper types did Ian Drolet design stamps on?',
#   'sqlQuery': 'SELECT COUNT Paper Type FROM table WHERE Design = Ian Drolet',
#   'attr': ['Date of Issue',
#    'Theme',
#    'Denomination',
#    'Design',
#    'Illustration',
#    'Printing Process',
#    'Paper Type',
#    'First Day Cover Cancellation']},
#  {'question': 'Who is the designer of the Christmas: Winter Fun (USA) stamp?',
#   'sqlQuery': 'SELECT Design FROM table WHERE Theme = Christmas: Winter Fun (USA)',
#   'attr': ['Date of Issue',
#    'Theme',
#    'Denomination',
#    'Design',
#    'Illustration',
#    'Printing Process',
#    'Paper Type',
#    'First Day Cover Cancellation']},
#  {'question': 'How many stamps were designed for the theme of XII Summit de la Francophonie?',
#   'sqlQuery': 'SELECT COUNT Design FROM table WHERE Theme = XII Summit de la Francophonie',
#   'attr': ['Date of Issue',
#    'Theme',
#    'Denomination',
#    'Design',
#    'Illustration',
#    'Printing Process',
#    'Paper Type',
#    'First Day Cover Cancellation']},
#  {'question': "How many premier episodes were there with the title survivor's law ii?",
#   'sqlQuery': "SELECT COUNT Premiere FROM table WHERE English title = Survivor's Law II",
#   'attr': ['Rank',
#    'English title',
#    'Chinese title',
#    'Average',
#    'Peak',
#    'Premiere',
#    'Finale',
#    'HK viewers']},
#  {'question': 'What is the Chinese name that has a 31 average?',
#   'sqlQuery': 'SELECT Chinese title FROM table WHERE Average = 31',
#   'attr': ['Rank',
#    'English title',
#    'Chinese title',
#    'Average',
#    'Peak',
#    'Premiere',
#    'Finale',
#    'HK viewers']},
#  {'question': 'what is the Chinese name for Forensic heroes ii?',
#   'sqlQuery': 'SELECT Chinese title FROM table WHERE English title = Forensic Heroes II',
#   'attr': ['Rank',
#    'English title',
#    'Chinese title',
#    'Average',
#    'Peak',
#    'Premiere',
#    'Finale',
# ...
#    'Viewers (in millions)',
#    'Archive']},
#  {'question': 'Name the broadcast day and timings for tv saitama',
#   'sqlQuery': 'SELECT Broadcast day and timings (in JST ) FROM table WHERE Broadcast network = TV Saitama',
#   'attr': ['Broadcast scope',
#    'Broadcast network',
#    'Broadcast term',
#    'Broadcast day and timings (in JST )',
#    'Broadcast format']},
#  {'question': 'How many seats in 2006 has a % 1997 rating of 38.9?',
#   'sqlQuery': 'SELECT COUNT Seats 2006 FROM table WHERE % 1997 = 38.9',
#   'attr': ['Political parties',
#    '% 2006',
#    'Seats 2006',
#    '% 2001',
#    'Seats 2001',
#    '% 1997']},
#  {'question': 'How many time was the political party the social democratic party of germany?',
#   'sqlQuery': 'SELECT COUNT % 2006 FROM table WHERE Political parties = Social Democratic Party of Germany',
#   'attr': ['Political parties',
#    '% 2006',
#    'Seats 2006',
#    '% 2001',
#    'Seats 2001',
#    '% 1997']},
#  {'question': 'How many seats were there in 2001 when there were 11 seats in 2006?',
#   'sqlQuery': 'SELECT MIN Seats 2001 FROM table WHERE Seats 2006 = 11',
#   'attr': ['Political parties',
#    '% 2006',
#    'Seats 2006',
#    '% 2001',
#    'Seats 2001',
#    '% 1997']},
#  {'question': 'Among  deaths  106 000  how many is crude rate.',
#   'sqlQuery': 'SELECT Crude Death Rate FROM table WHERE Deaths = 106 000',
#   'attr': ['Period',
#    'Births',
#    'Deaths',
#    'Difference',
#    'Crude Birth Rate',
#    'Crude Death Rate',
#    'Natural Increase',
#    'Total Fertility Rate',
#    'Infant Mortality Rate']},
#  {'question': 'How many times could you earn $470,000 as the grand prize?',
#   'sqlQuery': 'SELECT COUNT Score FROM table WHERE 1st Prize ( $ ) = 470,000',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse ( $ )',
#    'Winner',
#    'Score',
#    '1st Prize ( $ )']},
#  {'question': 'How many winners scored exactly 202 (-11)?',
#   'sqlQuery': 'SELECT COUNT Winner FROM table WHERE Score = 202 (-11)',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse ( $ )',
#    'Winner',
#    'Score',
#    '1st Prize ( $ )']},
#  {'question': 'How many tournaments were held at Alabama?',
#   'sqlQuery': 'SELECT COUNT Score FROM table WHERE Location = Alabama',
#   'attr': ['Date',
#    'Tournament',
#    'Location',
#    'Purse ( $ )',
#    'Winner',
#    'Score',
#    '1st Prize ( $ )']},
#  {'question': 'When the tournament winner was virginia tech, who won player of the year?',
#   'sqlQuery': 'SELECT Conference Player of the Year FROM table WHERE Tournament Winner = Virginia Tech',
#   'attr': ['Conference',
#    'Regular Season Winner',
#    'Conference Player of the Year',
#    'Conference Tournament',
#    'Tournament Venue (City)',
#    'Tournament Winner']},
#  {'question': 'Where was the tourney when Louisville won the regular season?',
#   'sqlQuery': 'SELECT Tournament Venue (City) FROM table WHERE Regular Season Winner = Louisville',
#   'attr': ['Conference',
#    'Regular Season Winner',
#    'Conference Player of the Year',
#    'Conference Tournament',
#    'Tournament Venue (City)',
#    'Tournament Winner']},
#  {'question': 'Where was the tourney when  UCLA won the regular season?',
#   'sqlQuery': 'SELECT Tournament Venue (City) FROM table WHERE Regular Season Winner = UCLA',
#   'attr': ['Conference',
#    'Regular Season Winner',
#    'Conference Player of the Year',
#    'Conference Tournament',
#    'Tournament Venue (City)',
#    'Tournament Winner']},
#  {'question': 'Where was the tourney when  Weber State won the regular season?',
#   'sqlQuery': 'SELECT Tournament Venue (City) FROM table WHERE Regular Season Winner = Weber State',
#   'attr': ['Conference',
#    'Regular Season Winner',
#    'Conference Player of the Year',
#    'Conference Tournament',
#    'Tournament Venue (City)',
#    'Tournament Winner']},
#  {'question': 'Where was the tourney when  conference player of the year is larry smith , alcorn state?',
#   'sqlQuery': 'SELECT Tournament Venue (City) FROM table WHERE Conference Player of the Year = Larry Smith , Alcorn State',
#   'attr': ['Conference',
#    'Regular Season Winner',
#    'Conference Player of the Year',
#    'Conference Tournament',
#    'Tournament Venue (City)',
#    'Tournament Winner']},
#  {'question': 'Which drivers won $40,000 in the NASCAR Winston Cup?',
#   'sqlQuery': 'SELECT Driver FROM table WHERE Series = NASCAR Winston Cup AND Winnings = $40,000',
#   'attr': ['Position', 'Driver', 'Points', 'Winnings', 'Series']},
#  {'question': 'How much did Dale Jarrett win?',
#   'sqlQuery': 'SELECT Winnings FROM table WHERE Driver = Dale Jarrett',
#   'attr': ['Position', 'Driver', 'Points', 'Winnings', 'Series']},
#  {'question': 'When nº is 3, what are all the ministires?',
#   'sqlQuery': 'SELECT COUNT ministries FROM table WHERE Nº = 3',
#   'attr': ['Nº',
#    'Cabinet (Nickname)',
#    'Took office',
#    'Left office',
#    'Duration',
#    'Coalition parties',
#    'ministers',
#    'ministries',
#    'King']},
#  {'question': 'When nº is 3, what are all the coaliton parties?',
#   'sqlQuery': 'SELECT Coalition parties FROM table WHERE Nº = 3',
#   'attr': ['Nº',
#    'Cabinet (Nickname)',
#    'Took office',
#    'Left office',
#    'Duration',
#    'Coalition parties',
#    'ministers',
#    'ministries',
#    'King']},
#  {'question': 'When 1 is the number what episodes were used?',
#   'sqlQuery': 'SELECT Episodes used FROM table WHERE # = 1',
#   'attr': ['#',
#    'Japanese title',
#    'Rōmaji',
#    'Japanese translation',
#    'Vocalist',
#    'Episodes used']},
#  {'question': 'When momoiro clover z is the vocalist how many japanese titles are there?',
#   'sqlQuery': 'SELECT COUNT Japanese title FROM table WHERE Vocalist = Momoiro Clover Z',
#   'attr': ['#',
#    'Japanese title',
#    'Rōmaji',
#    'Japanese translation',
#    'Vocalist',
#    'Episodes used']},
#  {'question': 'Name the miles for jeff gordon',
#   'sqlQuery': 'SELECT Miles (km) FROM table WHERE Driver = Jeff Gordon',
#   'attr': ['Year',
#    'Date',
#    'Driver',
#    'Team',
#    'Manufacturer',
#    'Laps',
#    'Miles (km)',
#    'Race Time',
#    'Average Speed (mph)',
#    'Report']},
#  {'question': 'Which week is the theme First Solo',
#   'sqlQuery': 'SELECT Week # FROM table WHERE Theme = First Solo',
#   'attr': ['Week #',
#    'Theme',
#    'Song choice',
#    'Original artist',
#    'Order #',
#    'Result']},
#  {'question': 'Which week is the theme n/a',
#   'sqlQuery': 'SELECT Week # FROM table WHERE Theme = N/A',
#   'attr': ['Week #',
#    'Theme',
#    'Song choice',
#    'Original artist',
#    'Order #',
#    'Result']},
#  {'question': 'How many total songs has the order #1',
#   'sqlQuery': 'SELECT COUNT Song choice FROM table WHERE Order # = 1',
#   'attr': ['Week #',
#    'Theme',
#    'Song choice',
#    'Original artist',
#    'Order #',
#    'Result']},
#  {'question': 'Which order #1 has a result of bottom 2',
#   'sqlQuery': 'SELECT Order # FROM table WHERE Result = Bottom 2',
#   'attr': ['Week #',
#    'Theme',
#    'Song choice',
#    'Original artist',
#    'Order #',
#    'Result']},
#  {'question': 'Whats the song of name with an original artist Garth Brooks',
#   'sqlQuery': 'SELECT Song choice FROM table WHERE Original artist = Garth Brooks',
#   'attr': ['Week #',
#    'Theme',
#    'Song choice',
#    'Original artist',
#    'Order #',
#    'Result']},
#  {'question': 'What was the date when Terry McAuliffe won 19%?',
#   'sqlQuery': 'SELECT Dates Administered FROM table WHERE Terry McAuliffe = 19%',
#   'attr': ['Source',
#    'Dates Administered',
#    'Terry McAuliffe',
#    'Brian Moran',
#    'Creigh Deeds']},
#  {'question': 'How many years did he have an average start of 20.7?',
#   'sqlQuery': 'SELECT COUNT Avg. Finish FROM table WHERE Avg. Start = 20.7',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'What was his average finish when his average start was 27.7?',
#   'sqlQuery': 'SELECT Avg. Finish FROM table WHERE Avg. Start = 27.7',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'What is the point total for the Formula Renault 2.0 Italy series?',
#   'sqlQuery': 'SELECT COUNT Points FROM table WHERE Series = Formula Renault 2.0 Italy',
#   'attr': ['Season',
#    'Series',
#    'Team',
#    'Races',
#    'Wins',
#    'Poles',
#    'F/Laps',
#    'Podiums',
#    'Points',
#    'Position']},
#  {'question': 'Name the year for is my magic',
#   'sqlQuery': 'SELECT Year (Ceremony) FROM table WHERE Film title used in nomination = My Magic',
#   'attr': ['Year (Ceremony)',
#    'Film title used in nomination',
#    'Language(s)',
#    'Director',
#    'Result']},
#  {'question': 'Name the year for japanese',
#   'sqlQuery': 'SELECT Year (Ceremony) FROM table WHERE Language(s) = Japanese',
#   'attr': ['Year (Ceremony)',
#    'Film title used in nomination',
#    'Language(s)',
#    'Director',
#    'Result']},
#  {'question': 'What was the best top five result when the average start is 28.5? ',
#   'sqlQuery': 'SELECT MAX Top 5 FROM table WHERE Avg. Start = 28.5',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'What was the average finish in 2007?',
#   'sqlQuery': 'SELECT Avg. Finish FROM table WHERE Year = 2007',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'With team #21/#07 ss-green light racing, what was the average finish number?',
#   'sqlQuery': 'SELECT Avg. Finish FROM table WHERE Team(s) = #21/#07 SS-Green Light Racing',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'If the average start is 11.8, what was the team name?',
#   'sqlQuery': 'SELECT Team(s) FROM table WHERE Avg. Start = 11.8',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'With an average finish of 29.0, what was the average start?',
#   'sqlQuery': 'SELECT Avg. Start FROM table WHERE Avg. Finish = 29.0',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'what is the total number of reasons for change where the date the successor was seated is june 8, 1876?',
#   'sqlQuery': 'SELECT COUNT Reason for change FROM table WHERE Date successor seated = June 8, 1876',
#   'attr': ['District',
#    'Vacator',
#    'Reason for change',
#    'Successor',
#    'Date successor seated']},
#  {'question': 'What was the average speed for a racetime of 3:08:08?',
#   'sqlQuery': 'SELECT Average Speed (mph) FROM table WHERE Race Time = 3:08:08',
#   'attr': ['Year',
#    'Date',
#    'Driver',
#    'Team',
#    'Manufacturer',
#    'Laps',
#    'Miles (km)',
#    'Race Time',
#    'Average Speed (mph)',
#    'Report']},
#  {'question': 'How many numbers were recorded under miles for the 3:00:46 race time?',
#   'sqlQuery': 'SELECT COUNT Miles (km) FROM table WHERE Race Time = 3:00:46',
#   'attr': ['Year',
#    'Date',
#    'Driver',
#    'Team',
#    'Manufacturer',
#    'Laps',
#    'Miles (km)',
#    'Race Time',
#    'Average Speed (mph)',
#    'Report']},
#  {'question': 'What is every deduction for pyramids of 49?',
#   'sqlQuery': 'SELECT Deductions FROM table WHERE Pyramids = 49',
#   'attr': ['Rank',
#    'School',
#    'Basic Elements',
#    'Tumbling',
#    'Stunts',
#    'Pyramids',
#    'Tosses',
#    'Deductions',
#    'Total']},
#  {'question': 'What are the scores in matches against Tony Roche?',
#   'sqlQuery': 'SELECT Score in the final FROM table WHERE Opponent in the final = Tony Roche',
#   'attr': ['Outcome',
#    'Year',
#    'Championship',
#    'Surface',
#    'Opponent in the final',
#    'Score in the final']},
#  {'question': 'List the total number of years that have a score of 3–6, 4–6, 2–6.',
#   'sqlQuery': 'SELECT COUNT Year FROM table WHERE Score in the final = 3–6, 4–6, 2–6',
#   'attr': ['Outcome',
#    'Year',
#    'Championship',
#    'Surface',
#    'Opponent in the final',
#    'Score in the final']},
#  {'question': 'List the final score of Wimbledon (2/2).',
#   'sqlQuery': 'SELECT Score in the final FROM table WHERE Championship = Wimbledon (2/2)',
#   'attr': ['Outcome',
#    'Year',
#    'Championship',
#    'Surface',
#    'Opponent in the final',
#    'Score in the final']},
#  {'question': 'Which positions are the poles 2?',
#   'sqlQuery': 'SELECT Position FROM table WHERE Poles = 2',
#   'attr': ['Season',
#    'Series',
#    'Team',
#    'Races',
#    'Wins',
#    'Poles',
#    'F/Laps',
#    'Podiums',
#    'Points',
#    'Position']},
#  {'question': 'How many positions have f/laps of 1 and british formula three series?',
#   'sqlQuery': 'SELECT COUNT Position FROM table WHERE F/Laps = 1 AND Series = British Formula Three',
#   'attr': ['Season',
#    'Series',
#    'Team',
#    'Races',
#    'Wins',
#    'Poles',
#    'F/Laps',
#    'Podiums',
#    'Points',
#    'Position']},
#  {'question': 'How many teams have 7th position?',
#   'sqlQuery': 'SELECT COUNT Team FROM table WHERE Position = 7th',
#   'attr': ['Season',
#    'Series',
#    'Team',
#    'Races',
#    'Wins',
#    'Poles',
#    'F/Laps',
#    'Podiums',
#    'Points',
#    'Position']},
#  {'question': 'how many wiaa classifications does fort vancouver high school have?',
#   'sqlQuery': 'SELECT COUNT WIAA Classification FROM table WHERE High School = Fort Vancouver',
#   'attr': ['High School',
#    'Type',
#    'Established',
#    'Enrollment',
#    'Mascot',
#    'WIAA Classification']},
#  {'question': 'How many high schools have storm mascots?',
#   'sqlQuery': 'SELECT High School FROM table WHERE Mascot = Storm',
#   'attr': ['High School',
#    'Type',
#    'Established',
#    'Enrollment',
#    'Mascot',
#    'WIAA Classification']},
#  {'question': 'What wiaa classifications does vancouver itech prepratory have?',
#   'sqlQuery': 'SELECT WIAA Classification FROM table WHERE High School = Vancouver iTech Prepratory',
#   'attr': ['High School',
#    'Type',
#    'Established',
#    'Enrollment',
#    'Mascot',
#    'WIAA Classification']},
#  {'question': 'What school classifications have trappers as mascot?',
#   'sqlQuery': 'SELECT Type FROM table WHERE Mascot = Trappers',
#   'attr': ['High School',
#    'Type',
#    'Established',
#    'Enrollment',
#    'Mascot',
#    'WIAA Classification']},
#  {'question': 'How many prefectures have an area of 361.719 kilometers squared?',
#   'sqlQuery': 'SELECT COUNT Prefecture FROM table WHERE Area (km²) = 361.719',
#   'attr': ['Number in map',
#    'Prefecture',
#    'Area (km²)',
#    'Population (2001)',
#    'Pop. density (/km²)']},
#  {'question': 'How many prefectures have a population density of 16 people/kilometers squared?',
#   'sqlQuery': 'SELECT COUNT Pop. density (/km²) FROM table WHERE Number in map = 16',
#   'attr': ['Number in map',
#    'Prefecture',
#    'Area (km²)',
#    'Population (2001)',
#    'Pop. density (/km²)']},
#  {'question': 'How many top 10s did he have the year he won $80,490?',
#   'sqlQuery': 'SELECT COUNT Top 10 FROM table WHERE Winnings = $80,490',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'How many top 5s when he was on team #28/#49 jay robinson racing?',
#   'sqlQuery': 'SELECT MAX Top 5 FROM table WHERE Team(s) = #28/#49 Jay Robinson Racing',
#   'attr': ['Year',
#    'Starts',
#    'Wins',
#    'Top 5',
#    'Top 10',
#    'Poles',
#    'Avg. Start',
#    'Avg. Finish',
#    'Winnings',
#    'Position',
#    'Team(s)']},
#  {'question': 'What date did episode 258 in the series originally air?',
#   'sqlQuery': 'SELECT Original air date FROM table WHERE Series # = 258',
#   'attr': ['Series #',
#    'Season #',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date']},
#  {'question': 'Who directed "loathe and marriage"?',
#   'sqlQuery': 'SELECT Directed by FROM table WHERE Title = "Loathe and Marriage"',
#   'attr': ['Series #',
#    'Season #',
#    'Title',
#    'Directed by',
#    'Written by',
#    'Original air date']},
#  ...]

# %% [markdown]
# We found that about 24% of the queries in the test split do not have the SELECT attributes explicitly present in them. We have discussed potential ways to address these types of queries in our report's Future Work section.
