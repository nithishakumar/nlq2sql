# %% [markdown]
# # Training a Custom NER Model with spaCy
#
#   This notebook contains our code to train custom named-entity recognition (NER) models. We trained one NER model with 2 custom tags: "SELECT" or "CONSTRAINT". "SELECT" words are attributes that need to be selected. "CONTRAINT" words are values that limit the number of records to be selected. For instance, in "WHERE player = Paul Seiler", "Paul Selier" is the constraint. We also trained another NER model that supports aggregate function tagging, that is,  it supports the following custom tags: "COUNT SELECT", "AVG SELECT", "SUM SELECT", "MIN SELECT", "MAX SELECT", "SELECT". Thus, this model identifies which select attributes are associated with an aggregate function. The outputs of this notebook currently reflect our training process for the aggregate NER model. The notebook requires functions from the sqlExtract class.  It also assumes spaCy is already installed as spaCy comes pre-installed in the Google Colab environment.
#
#   Note: change file paths wherever appropriate to avoid errors.
#
#   References:
#
#
# *   [Custom NER with spaCy v3 Tutorial by 1littlecoder](https://www.youtube.com/watch?v=p_7hJvl7P2A)
#
# *   [Training Pipelines and Models - spaCy Documentation](https://spacy.io/usage/training)

# %% [markdown]
# # Setup
#
# Mount this notebook so that it can access Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Verify that the notebook is connected to a premium Colab GPU - either a V100 or an A100.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Dec 14 00:54:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Verify that the version of spacy installed is >= 3.

# %%
# !python -m spacy info
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.6.1
# Location         /usr/local/lib/python3.10/dist-packages/spacy
# Platform         Linux-6.1.58+-x86_64-with-glibc2.35
# Python version   3.10.12
# Pipelines        en_core_web_sm (3.6.0)

# %% [markdown]
# Import the sqlExtract file which will extract values and attributes from a given SQL query.

# %%
# %load_ext autoreload
# %autoreload 2

from sqlExtract import *

# %% [markdown]
# # Create Custom NER Annotations

# %% [markdown]
# Automate the process of annotating words in the Natural Language Queries (NLQ) that are present in the train and validation split of the WikiSQL dataset.

# %% [markdown]
# Import necessary libraries and load the WikiSQL dataset.

# %%
# !pip install datasets
# Out:
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6

# %%
from tqdm import tqdm
from datasets import load_dataset
import json
from operator import itemgetter

# %%
dataset = load_dataset('wikisql')
# Out:
# Downloading builder script:   0%|          | 0.00/6.57k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.76k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.80k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/26.2M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/15878 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/8421 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/56355 [00:00<?, ? examples/s]

# %% [markdown]
# The function below checks for overlapping entities. Overlapping entities are when one word or a part of a word is tagged multiple times. Consider the below example:
#
#   NLQ:
#
# *   NLQ:
#
#     What is the report for races where Will Power had both pole position and fastest lap?
#
# *   Expected SQL Query:
#
#     SELECT Report FROM table WHERE Pole position = Will Power AND Fastest lap = Will Power
#
#
# Will Power shouldn't be tagged as a value multiple times as a Value.

# %%
def is_overlap(s2, e2, iterable):
  """Check for overlapping Entities."""
  for elt in iterable:
    s1 = elt[0]
    e1 = elt[1]
    if s2 <= e1 and s1 <= e2:
      return True
  return False

# %% [markdown]
# The functions below check if the extracted select attributes and values are explicitly present in the NLQ. While select attributes may not always be present in the NLQ, it may seem weird for a NLQ to not have a value explicitly present in it. This is due to some formatting issues in the wikiSQL dataset. Following is an example of the same:
#
# *   NLQ:
#
#   If the lorentz factor γ dt/dτ = e/mc 2 is √5 ≅ 2.236, what is the proper velocity w dx/dτ in units of c
# *   Expected SQL Query:
#
#   SELECT Proper velocity w dx/dτ in units of c FROM table WHERE Lorentz factor γ dt/dτ = E/mc 2 = √5 ≅ 2.236
#
# The value to be tagged here has an '=' sign in it which whereas the actual value has an 'is' instead in the NLQ. To avoid such queries, these are filtered out from the training and validation data.

# %%
def is_select_not_present_in_nlq(selectAttr, question):
  # assume all the select attributes are explicitly present in the nlq
  for attr in selectAttr:
    idx = question.lower().find(attr.lower())
    if attr != '*' and idx == -1:
        return True
  return False

# %%
def value_not_present_in_nlq(whereAttrValue, question):
  for attr, value in whereAttrValue.items():
      if question.lower().find(value.lower()) == -1:
        return True
  return False

# %% [markdown]
# The create_annotation function automatically annotates tags words in the NLQ to be either of type "SELECT" or "CONSTRAINT" or others based on the select attributes and where attributes extracted from the NLQ's corresponding expected SQL quert in the WikiSQL dataset's train or validation split. The function filters out queries that have select attributes and values explicitly present in them.
#
# The count variable will do this for the first 'count' rows, that is, if count is set to 5, the function will only annotate the first 5 rows of the WikiSQL dataset.

# %%
def create_annotations(split='train', count=None):
  assert split in {'train', 'validation'}
  tags = ["CONSTRAINT", "COUNT SELECT", "AVG SELECT", "SUM SELECT", "MIN SELECT", "MAX SELECT", "SELECT"]
  jsonObject = {"classes": tags,"annotations":[]}
  if count == None:
    count = len(dataset[split])
  i = 0
  for row in tqdm(dataset[split]):
      nlq = row['question']
      sqlQuery = row['sql']['human_readable']
      columns = row['table']['header']
      entityList = []
      sqlExtractor = sqlExtract(sqlQuery)
      selectAttr = sqlExtractor.fetch_select_attr()
      correctWhereAttr, whereAttrVals = sqlExtractor.fetch_where_attr()
      if is_select_not_present_in_nlq(selectAttr, nlq):
        continue
      if value_not_present_in_nlq(whereAttrVals, nlq):
        continue
      for val in whereAttrVals.values():
          idx = nlq.lower().find(val.lower())
          if idx == -1:
            print(nlq)
            print(sqlQuery)
            print(val)
          # assert that the value exists in the NLQ
          assert idx != -1
          if not is_overlap(idx, idx + len(val), entityList):
              entityList.append([idx, idx + len(val), jsonObject["classes"][0]])
      for attr, aggr in selectAttr.items():
          idx = nlq.lower().find(attr.lower())
          if idx == -1:
            print(nlq)
            print(sqlQuery)
            print(attr)
            # assert that the attribute exists in the NLQ
          assert idx != -1
          end = idx + len(attr)
          if not is_overlap(idx, end, entityList):
            if aggr == 'COUNT':
              entityList.append([idx, end, jsonObject["classes"][1]])
            elif aggr == 'AVG':
              entityList.append([idx, end, jsonObject["classes"][2]])
            elif aggr == 'SUM':
              entityList.append([idx, end, jsonObject["classes"][3]])
            elif aggr == 'MIN':
              entityList.append([idx, end, jsonObject["classes"][4]])
            elif aggr == 'MAX':
              entityList.append([idx, end, jsonObject["classes"][5]])
            else:
              entityList.append([idx, end, jsonObject["classes"][6]])
      sorted_list = sorted(entityList, key=itemgetter(0, 1))
      temp = [nlq, {"entities": sorted_list}]
      jsonObject["annotations"].append(temp)
      i += 1
      if i == count:
        break
  return jsonObject

# %% [markdown]
# The function below saves annotated data to a json file.

# %%
def save_annotated_data(filePath, jsonObject):
    f = open(filePath, "w")
    json_string = json.dumps(jsonObject, ensure_ascii=False)
    f.write(json_string)
    f.close()

# %% [markdown]
# In the cell below, the automatically annotated data's format is tested by comparing it with manually annotated data for the first 17 rows. Data was manually annotated using a mannual NER annotator from [this](https://tecoholic.github.io/ner-annotator/) link and then saved in the mannual_annotations.json file. The mannual annotator added carriage return characters ('\r') at the end of every string. Those were manually removed to ensure fair testing.

# %%
autoAnnotations = create_annotations('train', 17)
mannualAnnotationsFilePath = '/content/drive/MyDrive/train_spacy/mannual_annotations.json'
f1 = open(mannualAnnotationsFilePath)
assert json.load(f1) == autoAnnotations
f1.close()

# %% [markdown]
# Call the previously defined functions above to automatically annotate the training and validation split of the WikiSQL dataset.

# %%
trainingDataFilePath = '/content/drive/MyDrive/train_spacy/training_data.json'
validationDataFilePath = '/content/drive/MyDrive/train_spacy/validation_data.json'
trainJsonObject = create_annotations('train')
print(f'\nNumber of NLQs annotated from the train split:', len(trainJsonObject["annotations"]), '\n')
save_annotated_data(trainingDataFilePath, trainJsonObject)
validationJsonObject = create_annotations('validation')
print(f'\nNumber of NLQs annotated from the validation split:', len(validationJsonObject["annotations"]), '\n')
save_annotated_data(validationDataFilePath, validationJsonObject)
print("Completed annotations!")
# Out:
# 100%|██████████| 56355/56355 [00:20<00:00, 2719.08it/s]
# Number of NLQs annotated from the train split: 44570
# 100%|██████████| 8421/8421 [00:02<00:00, 3271.46it/s]
# Number of NLQs annotated from the validation split: 6713
#
# Completed annotations!

# %% [markdown]
# The saved annotated training and validation data are opened to convert them into a .spacy object.

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm

nlp = spacy.blank("en") # load a new spacy model
db = DocBin() # create a DocBin object

# %%
import json
f = open(trainingDataFilePath)
TRAIN_DATA = json.load(f)
f1  = open(validationDataFilePath)
VALIDATION_DATA = json.load(f1)

# %% [markdown]
# Verifying the training and validation data by displaying them.

# %%
TRAIN_DATA
# Out:
# {'classes': ['CONSTRAINT',
#   'COUNT SELECT',
#   'AVG SELECT',
#   'SUM SELECT',
#   'MIN SELECT',
#   'MAX SELECT',
#   'SELECT'],
#  'annotations': [['Tell me what the notes are for South Australia ',
#    {'entities': [[17, 22, 'SELECT'], [31, 46, 'CONSTRAINT']]}],
#   ['What is the current series where the new series began in June 2011?',
#    {'entities': [[12, 26, 'SELECT'], [37, 66, 'CONSTRAINT']]}],
#   ['What is the format for South Australia?',
#    {'entities': [[12, 18, 'SELECT'], [23, 38, 'CONSTRAINT']]}],
#   ['what is the fuel propulsion where the fleet series (quantity) is 310-329 (20)?',
#    {'entities': [[12, 27, 'SELECT'], [65, 77, 'CONSTRAINT']]}],
#   ['who is the manufacturer for the order year 1998?',
#    {'entities': [[11, 23, 'SELECT'], [43, 47, 'CONSTRAINT']]}],
#   ['what is the powertrain (engine/transmission) when the order year is 2000?',
#    {'entities': [[12, 44, 'SELECT'], [68, 72, 'CONSTRAINT']]}],
#   ['What if the description of a ch-47d chinook?',
#    {'entities': [[12, 23, 'SELECT'], [29, 43, 'CONSTRAINT']]}],
#   ['What is the max gross weight of the Robinson R-22?',
#    {'entities': [[12, 28, 'SELECT'], [36, 49, 'CONSTRAINT']]}],
#   ['What position did the player from Baylor play?',
#    {'entities': [[5, 13, 'SELECT'], [34, 40, 'CONSTRAINT']]}],
#   ['Which position does Loren Woods play?',
#    {'entities': [[6, 14, 'SELECT'], [20, 31, 'CONSTRAINT']]}],
#   ["What's Dell Curry nationality?",
#    {'entities': [[7, 17, 'CONSTRAINT'], [18, 29, 'SELECT']]}],
#   ['which player is from georgia',
#    {'entities': [[6, 12, 'SELECT'], [21, 28, 'CONSTRAINT']]}],
#   ['what nationality is the player who played from 1997-98',
#    {'entities': [[5, 16, 'SELECT'], [47, 54, 'CONSTRAINT']]}],
#   ['what position did the player from connecticut play',
#    {'entities': [[5, 13, 'SELECT'], [34, 45, 'CONSTRAINT']]}],
#   ['Which positions were in Toronto in 2004?',
#    {'entities': [[6, 14, 'SELECT'], [35, 39, 'CONSTRAINT']]}],
#   ['What nationality is the player Muggsy Bogues?',
#    {'entities': [[5, 16, 'SELECT'], [31, 44, 'CONSTRAINT']]}],
#   ['How many players were with the school or club team La Salle?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [51, 59, 'CONSTRAINT']]}],
#   ['When the scoring rank was 117, what was the best finish?',
#    {'entities': [[26, 29, 'CONSTRAINT'], [44, 55, 'SELECT']]}],
#   ['When the best finish was T69, how many people came in 2nd?',
#    {'entities': [[25, 28, 'CONSTRAINT'], [54, 57, 'SELECT']]}],
#   ['How many wins were there when the money list rank was 183?',
#    {'entities': [[9, 13, 'COUNT SELECT'], [54, 57, 'CONSTRAINT']]}],
#   ['When the money list rank was n/a, what was the scoring average?',
#    {'entities': [[29, 32, 'CONSTRAINT'], [47, 62, 'SELECT']]}],
#   ['What time was the highest for 2nd finishers?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [30, 33, 'MAX SELECT']]}],
#   ['What college did the Rookie of the Year from the Columbus Crew attend?',
#    {'entities': [[5, 12, 'SELECT'], [49, 62, 'CONSTRAINT']]}],
#   ['How many teams had a #1 draft pick that won the Rookie of the Year Award?',
#    {'entities': [[9, 13, 'COUNT SELECT'], [22, 23, 'CONSTRAINT']]}],
#   ['What position did the #10 draft pick play?',
#    {'entities': [[5, 13, 'SELECT'], [23, 25, 'CONSTRAINT']]}],
#   ["what's the\xa0years played\xa0with\xa0singles w-l\xa0of 3–2",
#    {'entities': [[11, 23, 'SELECT'], [44, 47, 'CONSTRAINT']]}],
#   ["what's the\xa0doubles w-l\xa0for player\xa0seol jae-min (none)",
#    {'entities': [[11, 22, 'SELECT'], [34, 53, 'CONSTRAINT']]}],
#   ["what's the\xa0singles w-l\xa0for kim doo-hwan",
#    {'entities': [[11, 22, 'SELECT'], [27, 39, 'CONSTRAINT']]}],
#   ["what's the total number of\xa0singles w-l\xa0with\xa0doubles w-l\xa0of 0–0 and\xa0total w-l\xa0of 3–1",
#    {'entities': [[27, 38, 'COUNT SELECT'],
#      [59, 62, 'CONSTRAINT'],
#      [80, 83, 'CONSTRAINT']]}],
#   ["what's the\xa0doubles w-l\xa0with\xa0years played\xa0value of 1 (1968)",
#    {'entities': [[11, 22, 'SELECT'], [50, 58, 'CONSTRAINT']]}],
#   ['What is the name of the 375 crest length?',
#    {'entities': [[12, 16, 'SELECT'], [24, 27, 'CONSTRAINT']]}],
#   ['What is year of construction of spitallamm?',
#    {'entities': [[8, 28, 'MIN SELECT'], [32, 42, 'CONSTRAINT']]}],
#   ['What is the canton of grande dixence?',
#    {'entities': [[12, 18, 'SELECT'], [22, 36, 'CONSTRAINT']]}],
#   ['What is the name where lago di luzzone is?',
#    {'entities': [[12, 16, 'SELECT'], [23, 38, 'CONSTRAINT']]}],
#   ['What is the  guardian mātṛkā for the guardian whose consort is Svāhā?',
#    {'entities': [[13, 28, 'SELECT'], [63, 68, 'CONSTRAINT']]}],
#   ['Where the mantra is "oṃ yaṃ vāyuve namaḥ", what is the direction of the guardian?',
#    {'entities': [[21, 40, 'CONSTRAINT'], [55, 64, 'SELECT']]}],
#   ['What weapon is used by the guardian whose consort is śacī?',
#    {'entities': [[5, 11, 'SELECT'], [53, 57, 'CONSTRAINT']]}],
#   ['What are the directions for the guardian whose weapon is khaḍga (sword)?',
#    {'entities': [[13, 22, 'SELECT'], [57, 71, 'CONSTRAINT']]}],
#   ['What are the weapons used by guardians for the direction East?',
#    {'entities': [[13, 19, 'SELECT'], [57, 61, 'CONSTRAINT']]}],
#   ['What are the directions for the guardian whose graha (planet) is bṛhaspati (Jupiter)?',
#    {'entities': [[13, 22, 'SELECT'], [65, 84, 'CONSTRAINT']]}],
#   ['What is the number of chapters listed for the fraternity with a headquarters in Austin, Texas?',
#    {'entities': [[22, 30, 'MAX SELECT'],
#      [46, 56, 'CONSTRAINT'],
#      [80, 93, 'CONSTRAINT']]}],
#   ['What are the members listed with the sorority classification',
#    {'entities': [[13, 19, 'SELECT'], [37, 45, 'CONSTRAINT']]}],
#   ['Name the member that has 12 chapters',
#    {'entities': [[9, 15, 'SELECT'], [25, 27, 'CONSTRAINT']]}],
#   ['Where is the headquarters of Alpha Nu Omega',
#    {'entities': [[13, 25, 'SELECT'], [29, 43, 'CONSTRAINT']]}],
#   ['what is the number of relapsing fever when malaria is 3000',
#    {'entities': [[22, 37, 'MIN SELECT'], [54, 58, 'CONSTRAINT']]}],
#   ['what is the typhoid fever number for the year 1934',
#    {'entities': [[12, 25, 'SELECT'], [46, 50, 'CONSTRAINT']]}],
#   ['What are all the typhus number when smallpox is 4',
#    {'entities': [[17, 23, 'SELECT'], [48, 49, 'CONSTRAINT']]}],
#   ['what is the number of smallpox when typhoid fever is 293',
#    {'entities': [[22, 30, 'MAX SELECT'], [53, 56, 'CONSTRAINT']]}],
#   ['what is the typhoid fever number for the year 1929',
#    {'entities': [[12, 25, 'SELECT'], [46, 50, 'CONSTRAINT']]}],
#   ['In what year was Lindenwood University founded?',
#    {'entities': [[17, 38, 'CONSTRAINT'], [39, 46, 'MIN SELECT']]}],
#   ['The season premiere aired on September 11, 2000 aired on how many networks? ',
#    {'entities': [[29, 47, 'CONSTRAINT'], [66, 73, 'COUNT SELECT']]}],
#   ['What was the ranking of the season finale aired on May 8, 2006? ',
#    {'entities': [[13, 20, 'SELECT'], [51, 62, 'CONSTRAINT']]}],
#   ['what is the minimum\xa0population canada 2011 census\xa0with\xa0seat of rcm\xa0being cowansville',
#    {'entities': [[20, 49, 'MIN SELECT'], [73, 84, 'CONSTRAINT']]}],
#   ["what's the\xa0land area\xa0with\xa0seat of rcm\xa0being granby",
#    {'entities': [[11, 20, 'SELECT'], [44, 50, 'CONSTRAINT']]}],
#   ['What is the population for County Mayo with the English Name Carrowteige?',
#    {'entities': [[12, 22, 'SELECT'],
#      [27, 38, 'CONSTRAINT'],
#      [61, 72, 'CONSTRAINT']]}],
#   ['What is the Irish name listed with 62% Irish speakers?',
#    {'entities': [[12, 22, 'SELECT'], [35, 38, 'CONSTRAINT']]}],
#   ['What is the population for the Irish Name Leitir mealláin?',
#    {'entities': [[12, 22, 'SELECT'], [42, 57, 'CONSTRAINT']]}],
#   ['What is the county for the Irish name Carna?',
#    {'entities': [[12, 18, 'SELECT'], [38, 43, 'CONSTRAINT']]}],
#   ['What is the population for the English name Spiddal?',
#    {'entities': [[12, 22, 'SELECT'], [44, 51, 'CONSTRAINT']]}],
#   ['What is the the Chinese population for the state that has a Filipino population of 1474707?',
#    {'entities': [[16, 23, 'MIN SELECT'], [83, 90, 'CONSTRAINT']]}],
#   ['What is the highest Indian population?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [20, 26, 'MAX SELECT']]}],
#   ['What is the UN operation title with the UN operation name, Uncok?',
#    {'entities': [[12, 30, 'SELECT'], [59, 64, 'CONSTRAINT']]}],
#   ['What is the number of season premieres were 10.17 people watched?',
#    {'entities': [[22, 37, 'COUNT SELECT'], [44, 49, 'CONSTRAINT']]}],
#   ['How many wins happened in 1983?',
#    {'entities': [[9, 13, 'MIN SELECT'], [26, 30, 'CONSTRAINT']]}],
#   ['How many poles had an average finish of 19.1?',
#    {'entities': [[9, 14, 'MAX SELECT'], [40, 44, 'CONSTRAINT']]}],
#   ['How many starts did Hendrick motorsports have?',
#    {'entities': [[9, 15, 'MIN SELECT'], [20, 40, 'CONSTRAINT']]}],
#   ['NHL players are all centre in Florida panthers.',
#    {'entities': [[4, 10, 'SELECT'],
#      [20, 26, 'CONSTRAINT'],
#      [30, 46, 'CONSTRAINT']]}],
#   ['NHL team player San Jose Sharks is United States nationally.',
#    {'entities': [[9, 15, 'SELECT'],
#      [16, 31, 'CONSTRAINT'],
#      [35, 48, 'CONSTRAINT']]}],
#   ['All players are position mark polak.',
#    {'entities': [[16, 24, 'SELECT'], [25, 35, 'CONSTRAINT']]}],
#   ['Position in nhl team centre are all smaller pick than 243.0',
#    {'entities': [[12, 20, 'SELECT'],
#      [21, 27, 'CONSTRAINT'],
#      [54, 59, 'CONSTRAINT']]}],
#   ['What college/junior/club teams do the players from the St. Louis Blues come from?',
#    {'entities': [[5, 29, 'SELECT'], [55, 70, 'CONSTRAINT']]}],
#   ['What is the nationality of Shayne Wright?',
#    {'entities': [[12, 23, 'SELECT'], [27, 40, 'CONSTRAINT']]}],
#   ['How many votes did Southern England cast whilst Northern Ireland cast 3?',
#    {'entities': [[19, 35, 'SELECT'], [70, 71, 'CONSTRAINT']]}],
#   ['What was the lowest number of votes Scotland cast?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [36, 44, 'MIN SELECT']]}],
#   ['What is the total number of votes if Scotland cast 35?',
#    {'entities': [[37, 45, 'COUNT SELECT'], [51, 53, 'CONSTRAINT']]}],
#   ['How many votes did Northern Ireland cast if the total was 35?',
#    {'entities': [[19, 35, 'SELECT'], [58, 60, 'CONSTRAINT']]}],
#   ['How many votes did Wales cast when Northern England cast 6?',
#    {'entities': [[19, 24, 'MIN SELECT'], [57, 58, 'CONSTRAINT']]}],
#   ['What positions do the hartford whalers nhl team have?',
#    {'entities': [[5, 13, 'SELECT'], [22, 38, 'CONSTRAINT']]}],
#   ['What is the smallest pick for the player, brett lindros?',
#    {'entities': [[21, 25, 'MIN SELECT'], [42, 55, 'CONSTRAINT']]}],
#   ['What positions does the college/junior/club team, molot perm (russia) have?',
#    {'entities': [[5, 13, 'SELECT'], [50, 69, 'CONSTRAINT']]}],
#   ['The nhl team new york islanders is what nationality?',
#    {'entities': [[13, 31, 'CONSTRAINT'], [40, 51, 'SELECT']]}],
#   ['What is the name of the vacator for district Louisiana 1st?',
#    {'entities': [[24, 31, 'SELECT'], [45, 58, 'CONSTRAINT']]}],
#   ['What is the crystal structure for the formula yba 2 cu 3 o 7?',
#    {'entities': [[12, 29, 'SELECT'], [46, 60, 'CONSTRAINT']]}],
#   ['What is the number for t c (k) when the notation is tl-2212?',
#    {'entities': [[23, 30, 'COUNT SELECT'], [52, 59, 'CONSTRAINT']]}],
#   ["What's the 2001 census of the region of Abruzzo where the 1871 census is bigger than 51092.0?",
#    {'entities': [[11, 22, 'MIN SELECT'],
#      [40, 47, 'CONSTRAINT'],
#      [85, 92, 'CONSTRAINT']]}],
#   ["What's the 1991 census of the city of Carpi?",
#    {'entities': [[11, 22, 'MAX SELECT'], [38, 43, 'CONSTRAINT']]}],
#   ['How many 2001 censuses are there on number 13?',
#    {'entities': [[9, 20, 'COUNT SELECT'], [43, 45, 'CONSTRAINT']]}],
#   ["What's the 1981 census of Livorno?",
#    {'entities': [[11, 22, 'SELECT'], [26, 33, 'CONSTRAINT']]}],
#   ['Which NHL team has player Mike Loach?',
#    {'entities': [[6, 14, 'SELECT'], [26, 36, 'CONSTRAINT']]}],
#   ['What is the NHL team that has Peter Strom?',
#    {'entities': [[12, 20, 'SELECT'], [30, 41, 'CONSTRAINT']]}],
#   ['How many songs received a 10 from Goodman and were rated by Tonioli?',
#    {'entities': [[26, 28, 'CONSTRAINT'], [60, 67, 'COUNT SELECT']]}],
#   ['What score did Goodman give to all songs with safe results, which received a 7 from Horwood and have a total score of 31?',
#    {'entities': [[15, 22, 'SELECT'],
#      [46, 50, 'CONSTRAINT'],
#      [77, 78, 'CONSTRAINT'],
#      [118, 120, 'CONSTRAINT']]}],
#   ['What score did Dixon give to the song "samba / young hearts run free", which was in second place?',
#    {'entities': [[15, 20, 'SELECT'],
#      [39, 68, 'CONSTRAINT'],
#      [84, 96, 'CONSTRAINT']]}],
#   ['How many scores did Goodman give to "samba / young hearts run free", which was in second place?',
#    {'entities': [[20, 27, 'COUNT SELECT'],
#      [37, 66, 'CONSTRAINT'],
#      [82, 94, 'CONSTRAINT']]}],
#   ['What is we two when the case/suffix is loc.?',
#    {'entities': [[8, 14, 'SELECT'], [39, 43, 'CONSTRAINT']]}],
#   ['What is them two (the two) when we two is ngalbelpa?',
#    {'entities': [[8, 26, 'SELECT'], [42, 51, 'CONSTRAINT']]}],
#   ['What is them two (the two) when you and i is ngœbalngu?',
#    {'entities': [[8, 26, 'SELECT'], [45, 54, 'CONSTRAINT']]}],
#   ['What is who-two where you and i is ngœban?',
#    {'entities': [[8, 15, 'SELECT'], [35, 41, 'CONSTRAINT']]}],
#   ['What is we two where you two is ngipen?',
#    {'entities': [[8, 14, 'SELECT'], [32, 38, 'CONSTRAINT']]}],
#   ['What is who-two when you two is ngipelngu?',
#    {'entities': [[8, 15, 'SELECT'], [32, 41, 'CONSTRAINT']]}],
#   ["what's the\xa0points\xa0with\xa0driver\xa0 mark martin",
#    {'entities': [[11, 17, 'SELECT'], [31, 42, 'CONSTRAINT']]}],
#   ["what's the\xa0points\xa0with\xa0driver\xa0 rusty wallace",
#    {'entities': [[11, 17, 'SELECT'], [31, 44, 'CONSTRAINT']]}],
#   ["what's the total number of\xa0position\xa0with\xa0driver\xa0 robby gordon",
#    {'entities': [[27, 35, 'COUNT SELECT'], [49, 61, 'CONSTRAINT']]}],
#   ["what's the maximum\xa0position\xa0with\xa0winnings\xa0 $50,000",
#    {'entities': [[19, 27, 'MAX SELECT'], [43, 50, 'CONSTRAINT']]}],
#   ['Which nominations was the film 27 Stolen Kisses nominated for?',
#    {'entities': [[6, 16, 'SELECT'], [31, 47, 'CONSTRAINT']]}],
#   ['Vsevolod Shilovskiy is from what country?',
#    {'entities': [[0, 19, 'CONSTRAINT'], [33, 40, 'SELECT']]}],
#   ['Which nominations are connected to the film Totalitarian Romance?',
#    {'entities': [[6, 16, 'SELECT'], [44, 64, 'CONSTRAINT']]}],
#   ['Srdjan Dragojevic worked on a film which earned what nomination?',
#    {'entities': [[0, 17, 'CONSTRAINT'], [53, 63, 'SELECT']]}],
#   ['What was the actors name that vadim ilyenko directed?',
#    {'entities': [[13, 24, 'SELECT'], [30, 43, 'CONSTRAINT']]}],
#   ['What was the actors name for fuchzhou and nomination was best non-professional actor?',
#    {'entities': [[13, 24, 'SELECT'],
#      [29, 37, 'CONSTRAINT'],
#      [57, 84, 'CONSTRAINT']]}],
#   ['What was the number of nominations for natalia raskokoha?',
#    {'entities': [[23, 33, 'COUNT SELECT'], [39, 56, 'CONSTRAINT']]}],
#   ['What is the highest value of Total Goals?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [29, 40, 'MAX SELECT']]}],
#   ['When FA Cup Apps is 9 what is the smallest number of FA Cup Goals?',
#    {'entities': [[20, 21, 'CONSTRAINT'], [53, 65, 'MIN SELECT']]}],
#   ['What is the smallest number of Total Goals?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [31, 42, 'MIN SELECT']]}],
#   ['What circuit was the race where Hideki Mutoh had the fastest lap?',
#    {'entities': [[5, 12, 'SELECT'], [32, 44, 'CONSTRAINT']]}],
#   ['what is the minimum production code with title "foreign exchange problem / turn about"',
#    {'entities': [[20, 35, 'MIN SELECT'], [47, 86, 'CONSTRAINT']]}],
#   ['what is the episode # for title "the yindianapolis 500 / personality problem"',
#    {'entities': [[12, 21, 'SELECT'], [32, 77, 'CONSTRAINT']]}],
#   ['what is the episode # for production code 227',
#    {'entities': [[12, 21, 'SELECT'], [42, 45, 'CONSTRAINT']]}],
#   ['what is the production code with title "skirting the issue / moon over my yinnie"',
#    {'entities': [[12, 27, 'SELECT'], [39, 81, 'CONSTRAINT']]}],
#   ['Whatis the number of total goals maximum?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [21, 32, 'MAX SELECT']]}],
#   ['What is the score with partner Jim Pugh?',
#    {'entities': [[12, 17, 'SELECT'], [31, 39, 'CONSTRAINT']]}],
#   ['What is the score of the match with partner Jim Pugh?',
#    {'entities': [[12, 17, 'SELECT'], [44, 52, 'CONSTRAINT']]}],
#   ['What year was the championship in Wimbledon (2)?',
#    {'entities': [[5, 9, 'SELECT'], [34, 47, 'CONSTRAINT']]}],
#   ['What is the score of the match with opponents Gretchen Magers Kelly Jones?',
#    {'entities': [[12, 17, 'SELECT'], [46, 73, 'CONSTRAINT']]}],
#   ['Which politican party has a birthday of November 10, 1880',
#    {'entities': [[16, 21, 'SELECT'], [40, 57, 'CONSTRAINT']]}],
#   ['Which representative has a birthday of January 31, 1866?',
#    {'entities': [[6, 20, 'SELECT'], [39, 55, 'CONSTRAINT']]}],
#   ['What is the Current singles ranking for the player named Mantas Bugailiškis?',
#    {'entities': [[12, 35, 'SELECT'], [57, 75, 'CONSTRAINT']]}],
#   ['How many playerd Mrs. Darling in the 1999 Broadway?',
#    {'entities': [[17, 29, 'CONSTRAINT'], [37, 50, 'COUNT SELECT']]}],
#   ['Who played Peter Pan in the 1990 Broadway?',
#    {'entities': [[11, 20, 'CONSTRAINT'], [28, 41, 'SELECT']]}],
#   ['Who played in the 1991 Broadway before Barbara McCulloh played the part in the 1999 Broadway?',
#    {'entities': [[18, 31, 'SELECT'], [39, 55, 'CONSTRAINT']]}],
#   ['Who played in the 1990 Broadway after Tom Halloran played the character in the 1955 Broadcast?',
#    {'entities': [[18, 31, 'SELECT'], [38, 50, 'CONSTRAINT']]}],
#   ['What character did Drake English play in the 1998 Broadway?',
#    {'entities': [[5, 14, 'SELECT'], [19, 32, 'CONSTRAINT']]}],
#   ['How many years did BBC One rank 20th?',
#    {'entities': [[9, 13, 'COUNT SELECT'], [32, 36, 'CONSTRAINT']]}],
#   ['What year was the BBC two total viewing 7,530,000?',
#    {'entities': [[5, 9, 'MIN SELECT'], [40, 49, 'CONSTRAINT']]}],
#   [' how many\xa0↓ function / genus →\xa0with\xa0escherichia\xa0being espd',
#    {'entities': [[10, 30, 'COUNT SELECT'], [54, 58, 'CONSTRAINT']]}],
#   ["what's the\xa0salmonella\xa0with\xa0escherichia\xa0being espd",
#    {'entities': [[11, 21, 'SELECT'], [45, 49, 'CONSTRAINT']]}],
#   ["what's the\xa0↓ function / genus →\xa0with\xa0shigella\xa0being spa32",
#    {'entities': [[11, 31, 'SELECT'], [52, 57, 'CONSTRAINT']]}],
#   ["what's the\xa0salmonella\xa0with\xa0shigella\xa0being ipgc",
#    {'entities': [[11, 21, 'SELECT'], [42, 46, 'CONSTRAINT']]}],
#   ["what's the\xa0salmonella\xa0with\xa0escherichia\xa0being sepb (escn)",
#    {'entities': [[11, 21, 'SELECT'], [45, 56, 'CONSTRAINT']]}],
#   ["what's the\xa0shigella\xa0with\xa0yersinia\xa0being yscp",
#    {'entities': [[11, 19, 'SELECT'], [40, 44, 'CONSTRAINT']]}],
#   ['How many original titles did Marriage Italian-Style have? ',
#    {'entities': [[9, 23, 'COUNT SELECT'], [29, 51, 'CONSTRAINT']]}],
#   ["what's the\xa0camp\xa0with\xa0estimated deaths\xa0of 600,000",
#    {'entities': [[11, 15, 'SELECT'], [41, 48, 'CONSTRAINT']]}],
#   ["what's the\xa0operational period\xa0with\xa0camp\xa0 sajmište",
#    {'entities': [[11, 22, 'SELECT'], [41, 49, 'CONSTRAINT']]}],
#   ["what's the\xa0estimated deaths\xa0with\xa0operational period\xa0of 17 march 1942 – end of june 1943",
#    {'entities': [[11, 27, 'SELECT'], [55, 87, 'CONSTRAINT']]}],
#   ["what's the\xa0current country of location\xa0with\xa0operational period\xa0\xa0of summer of 1941 to 28 june 1944",
#    {'entities': [[11, 38, 'SELECT'], [67, 97, 'CONSTRAINT']]}],
#   ["what's the\xa0occupied territory\xa0with\xa0estimated deaths\xa0of 600,000",
#    {'entities': [[11, 29, 'SELECT'], [55, 62, 'CONSTRAINT']]}],
#   ["what's the\xa0occupied territory\xa0with\xa0operational\xa0period of may 1940 – january 1945",
#    {'entities': [[11, 29, 'SELECT'], [57, 80, 'CONSTRAINT']]}],
#   ['Which overall pick was traded to the Cleveland Browns?',
#    {'entities': [[6, 13, 'SELECT'], [23, 53, 'CONSTRAINT']]}],
#   ['Overall pick 240 was a pick in which round?',
#    {'entities': [[13, 16, 'CONSTRAINT'], [37, 42, 'SELECT']]}],
#   ['Which overall pick number went to college at Youngstown State?',
#    {'entities': [[6, 13, 'MIN SELECT'], [45, 61, 'CONSTRAINT']]}],
#   ['What position is played by pick 255 overall?',
#    {'entities': [[5, 13, 'SELECT'], [32, 35, 'CONSTRAINT']]}],
#   ['The record of 7-3 had the largest attendance of what?',
#    {'entities': [[14, 17, 'CONSTRAINT'], [34, 44, 'MAX SELECT']]}],
#   ['The record of 9-4 was against which opponent?',
#    {'entities': [[14, 17, 'CONSTRAINT'], [36, 44, 'SELECT']]}],
#   ['The game number of 8 had a record of what?',
#    {'entities': [[19, 20, 'CONSTRAINT'], [27, 33, 'SELECT']]}],
#   ['What round was Steve Stonebreaker drafted?',
#    {'entities': [[5, 10, 'MAX SELECT'], [15, 33, 'CONSTRAINT']]}],
#   ['Where is the college where Keith Hartwig plays?',
#    {'entities': [[13, 20, 'SELECT'], [27, 40, 'CONSTRAINT']]}],
#   ['What is the greatest round of overall 83?',
#    {'entities': [[21, 26, 'MAX SELECT'], [38, 40, 'CONSTRAINT']]}],
#   ['Which round did Tommy Kramer play in>',
#    {'entities': [[6, 11, 'SELECT'], [16, 28, 'CONSTRAINT']]}],
#   ['What is Bruce Cerone overall?',
#    {'entities': [[8, 20, 'CONSTRAINT'], [21, 28, 'MIN SELECT']]}],
#   ['What is the highest choice?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [20, 26, 'MAX SELECT']]}],
#   ['What college did Bill Cappleman go to?',
#    {'entities': [[5, 12, 'SELECT'], [17, 31, 'CONSTRAINT']]}],
#   ['For the functional type of light ball, what were the other features?',
#    {'entities': [[27, 37, 'CONSTRAINT'], [53, 67, 'SELECT']]}],
#   ['How many touchdowns were scored in the year with a completion percentage of 56.0?',
#    {'entities': [[9, 19, 'MIN SELECT'], [76, 80, 'CONSTRAINT']]}],
#   ['What number of completions are recorded for the year with 12 games started?',
#    {'entities': [[15, 26, 'SELECT'], [58, 60, 'CONSTRAINT']]}],
#   ['How many people play Frank in London?',
#    {'entities': [[21, 26, 'CONSTRAINT'], [30, 36, 'COUNT SELECT']]}],
#   ['Who was Class AAA during the school year of 2000-01?',
#    {'entities': [[8, 17, 'SELECT'], [44, 51, 'CONSTRAINT']]}],
#   ['Who was Class AAA during the same year that Class A was (tie) Apple Springs/Texline?',
#    {'entities': [[8, 17, 'SELECT'], [56, 83, 'CONSTRAINT']]}],
#   ['Who was Class AAAAA during the school year of 1995-96?',
#    {'entities': [[8, 19, 'SELECT'], [46, 53, 'CONSTRAINT']]}],
#   ['Who was Class AAA during the same year that Class AAAAA was Brownsville Pace?',
#    {'entities': [[8, 17, 'SELECT'], [60, 76, 'CONSTRAINT']]}],
#   ['What was the total number of Class AAA during the same year that Class AAA was White Oak?',
#    {'entities': [[29, 37, 'COUNT SELECT'], [79, 88, 'CONSTRAINT']]}],
#   ['How many opponents were played on Saturday, June 9?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [34, 50, 'CONSTRAINT']]}],
#   ['In what week was the first game played at the Commerzbank-Arena?',
#    {'entities': [[8, 12, 'MIN SELECT'], [46, 63, 'CONSTRAINT']]}],
#   ['What was the original air date of an episode set in 1544?',
#    {'entities': [[13, 30, 'SELECT'], [52, 56, 'CONSTRAINT']]}],
#   ['How many settings where there for episode 29 of the season?',
#    {'entities': [[9, 16, 'COUNT SELECT'], [42, 44, 'CONSTRAINT']]}],
#   ['What is the album namethat has the track title Sweetness 甜甜的 (tián tián de)?',
#    {'entities': [[12, 22, 'SELECT'], [47, 75, 'CONSTRAINT']]}],
#   ['What is the duration of the song where the major instrument is the piano and the date is 2004-02-03?',
#    {'entities': [[12, 20, 'SELECT'],
#      [67, 72, 'CONSTRAINT'],
#      [89, 99, 'CONSTRAINT']]}],
#   ['What is the total number of lyricist where the lyrics theme is romance and the song lasts 3:50?',
#    {'entities': [[28, 36, 'COUNT SELECT'],
#      [63, 70, 'CONSTRAINT'],
#      [90, 94, 'CONSTRAINT']]}],
#   ['What is the total number of music genre/style in which the lyrics are a detective story?',
#    {'entities': [[28, 45, 'COUNT SELECT'], [72, 87, 'CONSTRAINT']]}],
#   ['What is the playoffs for the usl pro select league?',
#    {'entities': [[12, 20, 'SELECT'], [29, 50, 'CONSTRAINT']]}],
#   ['What is the number of the division for the 1st round?',
#    {'entities': [[26, 34, 'COUNT SELECT'], [43, 52, 'CONSTRAINT']]}],
#   ['What was the team where series is formula renault 2.0 nec?',
#    {'entities': [[13, 17, 'SELECT'], [34, 57, 'CONSTRAINT']]}],
#   ['What is the total number of poles for arden international?',
#    {'entities': [[28, 33, 'COUNT SELECT'], [38, 57, 'CONSTRAINT']]}],
#   ['What is the number of wins for gp2 series for racing engineering?',
#    {'entities': [[22, 26, 'COUNT SELECT'],
#      [31, 41, 'CONSTRAINT'],
#      [46, 64, 'CONSTRAINT']]}],
#   ['What is the number of podiums for season 2010 for campionato italiano superstars.',
#    {'entities': [[22, 29, 'COUNT SELECT'],
#      [41, 45, 'CONSTRAINT'],
#      [50, 80, 'CONSTRAINT']]}],
#   ['How many writers had an US air date of september 25, 1993?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [39, 57, 'CONSTRAINT']]}],
#   ['what being the maximum\xa0year\xa0where\xa0regular season\xa0is 4th, northwest',
#    {'entities': [[23, 27, 'MAX SELECT'], [52, 66, 'CONSTRAINT']]}],
#   ['what is the total number of\xa0playoffs\xa0where\xa0regular season\xa0is 6th, southwest',
#    {'entities': [[28, 36, 'COUNT SELECT'], [61, 75, 'CONSTRAINT']]}],
#   ['what is the maximum\xa0division',
#    {'entities': [[0, 0, 'CONSTRAINT'], [20, 28, 'MAX SELECT']]}],
#   [" what's the\xa0league\xa0where\xa0regular season\xa0is 2nd, northwest",
#    {'entities': [[12, 18, 'SELECT'], [43, 57, 'CONSTRAINT']]}],
#   ['what are all the regular season where year is 2011',
#    {'entities': [[17, 31, 'SELECT'], [46, 50, 'CONSTRAINT']]}],
#   ['How many titles have the number 11',
#    {'entities': [[9, 14, 'COUNT SELECT'], [32, 34, 'CONSTRAINT']]}],
#   ['Who is the storyteller in the episode called "The Tale of the Jagged Sign"?',
#    {'entities': [[11, 22, 'SELECT'], [45, 74, 'CONSTRAINT']]}],
#   ['Who are the villains in the episode titled "The Tale of the Forever Game"?',
#    {'entities': [[12, 20, 'SELECT'], [43, 73, 'CONSTRAINT']]}],
#   ['How many villains appeared in the episode titled "The Tale of the Virtual Pets"?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [49, 79, 'CONSTRAINT']]}],
#   ['Who are the villains in the episodes where Megan is the storyteller and Lorette LeBlanc is the director?',
#    {'entities': [[12, 20, 'SELECT'],
#      [43, 48, 'CONSTRAINT'],
#      [72, 87, 'CONSTRAINT']]}],
#   ['What is the largest # for an episode that was written by Allison Lea Bingeman?',
#    {'entities': [[20, 21, 'MAX SELECT'], [57, 77, 'CONSTRAINT']]}],
#   ['Name the species when petal width is 2.0 and petal length is 4.9',
#    {'entities': [[9, 16, 'SELECT'],
#      [37, 40, 'CONSTRAINT'],
#      [61, 64, 'CONSTRAINT']]}],
#   ['Name the sepal width for i.virginica with petal length of 5.1',
#    {'entities': [[9, 20, 'SELECT'],
#      [25, 36, 'CONSTRAINT'],
#      [58, 61, 'CONSTRAINT']]}],
#   ['Name the number of species with sepal width of 3.4 and sepal length of 5.4',
#    {'entities': [[19, 26, 'COUNT SELECT'],
#      [47, 50, 'CONSTRAINT'],
#      [71, 74, 'CONSTRAINT']]}],
#   ['Name the sepal length for sepal width of 2.8 and petal length of 5.1',
#    {'entities': [[9, 21, 'SELECT'],
#      [41, 44, 'CONSTRAINT'],
#      [65, 68, 'CONSTRAINT']]}],
#   ['Name the sepal width when sepal length is 6.5 and petal width is 2.2',
#    {'entities': [[9, 20, 'SELECT'],
#      [42, 45, 'CONSTRAINT'],
#      [65, 68, 'CONSTRAINT']]}],
#   ['Who is the director and what number is the episode for episode #1 of Are You Afraid of the Dark season 3?',
#    {'entities': [[11, 19, 'COUNT SELECT'], [64, 65, 'CONSTRAINT']]}],
#   ['Who is the director of the episode whom Scott Peters is the writer?',
#    {'entities': [[11, 19, 'SELECT'], [40, 52, 'CONSTRAINT']]}],
#   ["What was Datsun Twin 200's fastest lap?",
#    {'entities': [[9, 24, 'CONSTRAINT'], [27, 38, 'SELECT']]}],
#   ['In the Datsun Twin 200 race, what was the fastest lap?',
#    {'entities': [[7, 22, 'CONSTRAINT'], [42, 53, 'SELECT']]}],
#   ["What's the report for the True Value 500?",
#    {'entities': [[11, 17, 'SELECT'], [26, 40, 'CONSTRAINT']]}],
#   ["What was Johnny Rutherford's fastest lap while Al Unser was the pole position?",
#    {'entities': [[9, 26, 'CONSTRAINT'],
#      [29, 40, 'SELECT'],
#      [47, 55, 'CONSTRAINT']]}],
#   ["What's the report on Penske Racing winning while the pole position was Al Unser?",
#    {'entities': [[11, 17, 'COUNT SELECT'],
#      [21, 34, 'CONSTRAINT'],
#      [71, 79, 'CONSTRAINT']]}],
#   ['What is the model number introduced May 1999?',
#    {'entities': [[12, 17, 'MAX SELECT'], [36, 44, 'CONSTRAINT']]}],
#   ['What is the maximum memory for the model discontinued in November 2001?',
#    {'entities': [[12, 26, 'SELECT'], [57, 70, 'CONSTRAINT']]}],
#   ['What is main presenters of La Granja?',
#    {'entities': [[8, 23, 'SELECT'], [27, 36, 'CONSTRAINT']]}],
#   ['How many winners are there of farma?',
#    {'entities': [[9, 16, 'COUNT SELECT'], [30, 35, 'CONSTRAINT']]}],
#   ['What is the most cup goals for seasson 1911-12?',
#    {'entities': [[17, 26, 'MAX SELECT'], [39, 46, 'CONSTRAINT']]}],
#   ['What is the league apps for season 1923-24?',
#    {'entities': [[12, 23, 'SELECT'], [35, 42, 'CONSTRAINT']]}],
#   ['What is the team for season 1911-12?',
#    {'entities': [[12, 16, 'SELECT'], [28, 35, 'CONSTRAINT']]}],
#   ["what's the minimum\xa0attendance\xa0with\xa0score\xa0 10.16 (76) – 9.22 (76)",
#    {'entities': [[19, 29, 'MIN SELECT'], [42, 64, 'CONSTRAINT']]}],
#   ["who's the\xa0premier\xa0with\xa0in 1970",
#    {'entities': [[10, 17, 'SELECT'], [26, 30, 'CONSTRAINT']]}],
#   ['who are all the runner-up for premier in richmond',
#    {'entities': [[16, 25, 'SELECT'], [41, 49, 'CONSTRAINT']]}],
#   ['what is the minimum attendance with score 8.16 (64) – 8.12 (60)',
#    {'entities': [[20, 30, 'MIN SELECT'], [42, 63, 'CONSTRAINT']]}],
#   ['How many mileposts are there on Anne Street?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [32, 43, 'CONSTRAINT']]}],
#   ['What is the minimum amount for wool for 2001-02?',
#    {'entities': [[31, 35, 'CONSTRAINT'], [40, 47, 'MIN SELECT']]}],
#   ["Name the joined for the wolfpack women's nickname",
#    {'entities': [[9, 15, 'SELECT'], [24, 32, 'CONSTRAINT']]}],
#   ['Name the left of the Lady Pilots.',
#    {'entities': [[9, 13, 'SELECT'], [21, 32, 'CONSTRAINT']]}],
#   ['What is the Mens Nickname for the member location of Jacksonville, florida?',
#    {'entities': [[12, 25, 'SELECT'], [53, 74, 'CONSTRAINT']]}],
#   ['What is the enrollment for the institution that was founded in 1866 and is a private/(african methodist) type?',
#    {'entities': [[12, 22, 'MAX SELECT'],
#      [63, 67, 'CONSTRAINT'],
#      [77, 104, 'CONSTRAINT']]}],
#   ['That is the year founded for the institution location of Nashville, Tennessee?',
#    {'entities': [[17, 24, 'MIN SELECT'], [57, 77, 'CONSTRAINT']]}],
#   ['What is the year the institution Tougaloo College joined?',
#    {'entities': [[33, 49, 'CONSTRAINT'], [50, 56, 'SELECT']]}],
#   ['What is the date of vacancy when the date of appointment is 28 november 2007 and replaced by is alex mcleish?',
#    {'entities': [[12, 27, 'SELECT'],
#      [60, 76, 'CONSTRAINT'],
#      [96, 108, 'CONSTRAINT']]}],
#   ['What is the date of appointment when the date of vacancy is 21 december 2007?',
#    {'entities': [[12, 31, 'SELECT'], [60, 76, 'CONSTRAINT']]}],
#   ['What is the date of vacancy when the team is manchester city and replaced by is mark hughes?',
#    {'entities': [[12, 27, 'SELECT'],
#      [45, 60, 'CONSTRAINT'],
#      [80, 91, 'CONSTRAINT']]}],
#   ['What is the date of appointment when replaced by is roy hodgson?',
#    {'entities': [[12, 31, 'SELECT'], [52, 63, 'CONSTRAINT']]}],
#   ['What was the score of the game when the team reached a record of 6-9?',
#    {'entities': [[13, 18, 'SELECT'], [65, 68, 'CONSTRAINT']]}],
#   ['What type institution is point park university',
#    {'entities': [[5, 9, 'SELECT'], [25, 46, 'CONSTRAINT']]}],
#   ['point park university is what type of institution',
#    {'entities': [[0, 21, 'CONSTRAINT'], [30, 34, 'SELECT']]}],
#   ['how many founded dates are listed for carlow university 1',
#    {'entities': [[9, 16, 'COUNT SELECT'], [38, 57, 'CONSTRAINT']]}],
#   ['what is the original air date of the episode no in season 9?',
#    {'entities': [[12, 29, 'SELECT'], [58, 59, 'CONSTRAINT']]}],
#   ['What is the title of the episode written by denis leary, peter tolan and evan reilly?',
#    {'entities': [[12, 17, 'SELECT'], [44, 84, 'CONSTRAINT']]}],
#   ["What was the cyclone's pressure in the storm that death was equal to 95km/h (60mph)?",
#    {'entities': [[23, 31, 'SELECT'], [69, 83, 'CONSTRAINT']]}],
#   ['What was the damage (usd) from the cyclones that measured 1003hPa (29.62inHg) pressure?',
#    {'entities': [[13, 25, 'SELECT'], [58, 77, 'CONSTRAINT']]}],
#   [" what's the\xa0average\xa0where\xa0high score\xa0is 120",
#    {'entities': [[12, 19, 'SELECT'], [40, 43, 'CONSTRAINT']]}],
#   [" what's the\xa0player\xa0where\xa050\xa0is 2 and\xa0n/o\xa0is 0",
#    {'entities': [[12, 18, 'SELECT'],
#      [26, 27, 'CONSTRAINT'],
#      [31, 32, 'CONSTRAINT']]}],
#   [" what's the\xa0player\xa0where\xa0inns\xa0is 21",
#    {'entities': [[12, 18, 'SELECT'], [33, 35, 'CONSTRAINT']]}],
#   ['Which general election had a pq majority and a 44.75% of the popular vote?',
#    {'entities': [[6, 22, 'SELECT'],
#      [29, 40, 'CONSTRAINT'],
#      [47, 53, 'CONSTRAINT']]}],
#   ['How many weeks are there?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [9, 13, 'MAX SELECT']]}],
#   ['On december 16, 1985, all the records were what?',
#    {'entities': [[3, 20, 'CONSTRAINT'], [30, 36, 'SELECT']]}],
#   ['How many results are there for the 0-4 record?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [35, 38, 'CONSTRAINT']]}],
#   ['How many weeks are there that include the date October 11, 1969.',
#    {'entities': [[9, 13, 'COUNT SELECT'], [47, 63, 'CONSTRAINT']]}],
#   ['How many weeks are there that include the date November 9, 1969.',
#    {'entities': [[9, 13, 'COUNT SELECT'], [47, 63, 'CONSTRAINT']]}],
#   ['How many records are there at the War Memorial Stadium?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [34, 54, 'CONSTRAINT']]}],
#   ['What was the minimum attendance on December 7, 1969?',
#    {'entities': [[21, 31, 'MIN SELECT'], [35, 51, 'CONSTRAINT']]}],
#   ['What week corresponds to the last one to be played at the memorial stadium?',
#    {'entities': [[5, 9, 'MAX SELECT'], [58, 74, 'CONSTRAINT']]}],
#   ['In which stadium is the week 5 game played?',
#    {'entities': [[9, 16, 'SELECT'], [29, 30, 'CONSTRAINT']]}],
#   [' what is the\xa0nfl team\xa0where\xa0player\xa0is thane gash',
#    {'entities': [[13, 21, 'SELECT'], [38, 48, 'CONSTRAINT']]}],
#   ['what is the maximum\xa0pick #\xa0where\xa0player\xa0is anthony blaylock',
#    {'entities': [[20, 26, 'MAX SELECT'], [43, 59, 'CONSTRAINT']]}],
#   [" what's the\xa0nfl team\xa0where\xa0player\xa0is clifford charlton",
#    {'entities': [[12, 20, 'SELECT'], [37, 54, 'CONSTRAINT']]}],
#   [" what's the\xa0position\xa0where\xa0player\xa0is anthony blaylock",
#    {'entities': [[12, 20, 'SELECT'], [37, 53, 'CONSTRAINT']]}],
#   ['what is the minimum\xa0pick #\xa0where\xa0position\xa0is defensive tackle',
#    {'entities': [[20, 26, 'MIN SELECT'], [45, 61, 'CONSTRAINT']]}],
#   ['Which province has a density of 971.4?',
#    {'entities': [[6, 14, 'SELECT'], [32, 37, 'CONSTRAINT']]}],
#   ['Which province has a gdp of 38355€  million euros?',
#    {'entities': [[6, 14, 'SELECT'], [28, 33, 'CONSTRAINT']]}],
#   ['What is the title when original air date is may15,2008?',
#    {'entities': [[12, 17, 'SELECT'], [44, 54, 'CONSTRAINT']]}],
#   ['What is the highest no. in season?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [20, 33, 'MAX SELECT']]}],
#   ['What date did the DVD for season six come out in region 2?',
#    {'entities': [[26, 36, 'CONSTRAINT'], [49, 57, 'SELECT']]}],
#   ['How many points for 2005?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [20, 24, 'CONSTRAINT']]}],
#   ['how many positions in 2009?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [22, 26, 'CONSTRAINT']]}],
#   ['what is the least number of poles?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [28, 33, 'MIN SELECT']]}],
#   ['Which series with 62 points?',
#    {'entities': [[6, 12, 'SELECT'], [18, 20, 'CONSTRAINT']]}],
#   ['how many reports of races took place on october 16?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [40, 50, 'CONSTRAINT']]}],
#   ['what is the name of the report that lists the race name as long beach grand prix?',
#    {'entities': [[24, 30, 'SELECT'], [59, 80, 'CONSTRAINT']]}],
#   ['what is the report called where the circuit took place at the nazareth speedway?',
#    {'entities': [[12, 18, 'SELECT'], [62, 79, 'CONSTRAINT']]}],
#   ['meadowlands sports complex is the circuit at which city/location?',
#    {'entities': [[0, 26, 'CONSTRAINT'], [51, 64, 'SELECT']]}],
#   ['What is the original air date for the title "felonious monk"?',
#    {'entities': [[12, 29, 'SELECT'], [44, 60, 'CONSTRAINT']]}],
#   ['What is the title of the episode directed by Peter Markle and written by Jerry Stahl?',
#    {'entities': [[12, 17, 'SELECT'],
#      [45, 57, 'CONSTRAINT'],
#      [73, 84, 'CONSTRAINT']]}],
#   ['Who does the lap-by-lap in 2011?',
#    {'entities': [[13, 23, 'SELECT'], [27, 31, 'CONSTRAINT']]}],
#   ['Which network has Marty Reid as host and lap-by-lap broadcaster?',
#    {'entities': [[6, 13, 'SELECT'], [18, 28, 'CONSTRAINT']]}],
#   ['How many titles got a viewership of 26.53 million?',
#    {'entities': [[9, 14, 'COUNT SELECT'], [36, 41, 'CONSTRAINT']]}],
#   ['How many titles were there for the 113 episode?',
#    {'entities': [[9, 14, 'COUNT SELECT'], [35, 38, 'CONSTRAINT']]}],
#   ['Which circuits had a race on October 4?',
#    {'entities': [[6, 13, 'SELECT'], [29, 38, 'CONSTRAINT']]}],
#   ['In which reports does Michael Andretti have the pole position and Galles-Kraco Racing is the winning team?',
#    {'entities': [[9, 15, 'SELECT'],
#      [22, 38, 'CONSTRAINT'],
#      [66, 85, 'CONSTRAINT']]}],
#   ['On how many dates did the Michigan International Speedway hold a round?',
#    {'entities': [[12, 16, 'COUNT SELECT'], [26, 57, 'CONSTRAINT']]}],
#   ['Name the round of 32 in conference usa',
#    {'entities': [[9, 20, 'SELECT'], [24, 38, 'CONSTRAINT']]}],
#   ['What is the record when round of 32 is 0 and metro atlantic conference?',
#    {'entities': [[12, 18, 'SELECT'],
#      [39, 40, 'CONSTRAINT'],
#      [45, 59, 'CONSTRAINT']]}],
#   ['What is the title of the episode wtih 10.34 million U.S viewers?',
#    {'entities': [[12, 17, 'SELECT'], [38, 43, 'CONSTRAINT']]}],
#   ['how many races were in 2009 with 0 wins?',
#    {'entities': [[9, 14, 'SELECT'], [23, 27, 'CONSTRAINT']]}],
#   ['what is the greatest number of wins by japanese formula three?',
#    {'entities': [[31, 35, 'MAX SELECT'], [39, 61, 'CONSTRAINT']]}],
#   ['How many directors were there for the film Course Completed?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [43, 59, 'CONSTRAINT']]}],
#   ['What is the pick # for the position de?',
#    {'entities': [[12, 18, 'SELECT'], [36, 38, 'CONSTRAINT']]}],
#   ["Which player went to college at Saint Mary's?",
#    {'entities': [[6, 12, 'SELECT'], [32, 44, 'CONSTRAINT']]}],
#   ['What is the position for the player with cfl team Winnipeg blue bombers?',
#    {'entities': [[12, 20, 'SELECT'], [50, 71, 'CONSTRAINT']]}],
#   ['Which player went to college at Laval?',
#    {'entities': [[6, 12, 'SELECT'], [32, 37, 'CONSTRAINT']]}],
#   ['What was the college for the player with the cfl team of Edmonton Eskimos (via calgary)?',
#    {'entities': [[13, 20, 'SELECT'], [57, 87, 'CONSTRAINT']]}],
#   ['What player is on the Montreal Alouettes CFl team?',
#    {'entities': [[5, 11, 'SELECT'], [22, 40, 'CONSTRAINT']]}],
#   ['What player went to Ohio State College?',
#    {'entities': [[5, 11, 'SELECT'], [20, 30, 'CONSTRAINT']]}],
#   ['What is the minimum introduced value for the Departmental region?',
#    {'entities': [[20, 30, 'MIN SELECT'], [45, 57, 'CONSTRAINT']]}],
#   ['What is the smallest introduced value?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [21, 31, 'MIN SELECT']]}],
#   ['Which CFL Teams drafted an OL in 2006?',
#    {'entities': [[6, 14, 'SELECT'], [27, 29, 'CONSTRAINT']]}],
#   ['Which college is aligned to the Saskatchewan Roughriders?',
#    {'entities': [[6, 13, 'SELECT'], [32, 56, 'CONSTRAINT']]}],
#   ['What Position did the Hamilton Tiger-Cats (via Ottawa) pick in the 2006 Draft.',
#    {'entities': [[5, 13, 'SELECT'], [22, 54, 'CONSTRAINT']]}],
#   ['How many seasons is the season finale on May 26, 2010?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [41, 53, 'CONSTRAINT']]}],
#   ['What episodes are there where the season premier is September 23, 2009?',
#    {'entities': [[5, 13, 'SELECT'], [52, 70, 'CONSTRAINT']]}],
#   ['What is the season finale for season 4?',
#    {'entities': [[12, 25, 'SELECT'], [37, 38, 'CONSTRAINT']]}],
#   ['What is the max memory of the t5120 model?',
#    {'entities': [[12, 22, 'SELECT'], [30, 35, 'CONSTRAINT']]}],
#   ['What is the lowest ru?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [19, 21, 'MIN SELECT']]}],
#   ['What ga date do the models with 1.0, 1.2, 1.4ghz processor frequencies have?',
#    {'entities': [[5, 12, 'SELECT'], [32, 48, 'CONSTRAINT']]}],
#   ['What is the ga date of the t5120 model?',
#    {'entities': [[12, 19, 'SELECT'], [27, 32, 'CONSTRAINT']]}],
#   ['What is the sport of the La Liga league?',
#    {'entities': [[12, 17, 'SELECT'], [25, 32, 'CONSTRAINT']]}],
#   ["What's the minimum total attendance of the Premier League association football?",
#    {'entities': [[19, 35, 'MIN SELECT'],
#      [43, 57, 'CONSTRAINT'],
#      [58, 78, 'CONSTRAINT']]}],
#   ["What's the average attendance of the leagues in the season of 2013?",
#    {'entities': [[11, 29, 'MIN SELECT'], [62, 66, 'CONSTRAINT']]}],
#   ["What's the total attendance of the leagues in season of 2010?",
#    {'entities': [[11, 27, 'COUNT SELECT'], [56, 60, 'CONSTRAINT']]}],
#   ['Who were the directors of the film submitted with the title Young Törless?',
#    {'entities': [[13, 21, 'SELECT'], [60, 73, 'CONSTRAINT']]}],
#   ['What was the original title of the film submitted with the title A Woman in Flames?',
#    {'entities': [[13, 27, 'SELECT'], [65, 82, 'CONSTRAINT']]}],
#   ['Who were the directors of the film with the original title o.k.?',
#    {'entities': [[13, 21, 'SELECT'], [59, 63, 'CONSTRAINT']]}],
#   ['What is the division for the division semifinals playoffs?',
#    {'entities': [[12, 20, 'SELECT'], [29, 48, 'CONSTRAINT']]}],
#   ['What is the title written by David Mamet?',
#    {'entities': [[12, 17, 'SELECT'], [29, 40, 'CONSTRAINT']]}],
#   ['What was the finale for 潮爆大狀',
#    {'entities': [[13, 19, 'SELECT'], [24, 28, 'CONSTRAINT']]}],
#   ['What was the finale for  潮爆大狀',
#    {'entities': [[13, 19, 'SELECT'], [25, 29, 'CONSTRAINT']]}],
#   ['Who was the director of the episode with a production code of 2393059?',
#    {'entities': [[12, 20, 'SELECT'], [62, 69, 'CONSTRAINT']]}],
#   ['What is the production code of the episode written by José Molina that aired on October 12, 2004?',
#    {'entities': [[12, 27, 'SELECT'],
#      [54, 65, 'CONSTRAINT'],
#      [80, 96, 'CONSTRAINT']]}],
#   ['What was the original air date of the episode "Quarry"?',
#    {'entities': [[13, 30, 'SELECT'], [46, 54, 'CONSTRAINT']]}],
#   ['what are the original air dates with a production code of 2394087',
#    {'entities': [[13, 30, 'SELECT'], [58, 65, 'CONSTRAINT']]}],
#   ['What are the production codes for the title "all about brooke"',
#    {'entities': [[13, 28, 'SELECT'], [44, 62, 'CONSTRAINT']]}],
#   ['Who are the writer(s) for the production code 2394084',
#    {'entities': [[12, 21, 'SELECT'], [46, 53, 'CONSTRAINT']]}],
#   ['How long is the orbital period for the planet that has a semimajor axis of 5.20 au?',
#    {'entities': [[16, 30, 'SELECT'], [75, 79, 'CONSTRAINT']]}],
#   ['Which planet has an orbital period of 11.86 years?',
#    {'entities': [[6, 12, 'SELECT'], [38, 49, 'CONSTRAINT']]}],
#   ['What player is pick #2?',
#    {'entities': [[5, 11, 'SELECT'], [21, 22, 'CONSTRAINT']]}],
#   ["Which player's college is Saskatchewan?",
#    {'entities': [[6, 12, 'SELECT'], [26, 38, 'CONSTRAINT']]}],
#   ['Which position does Colt Brennan play?',
#    {'entities': [[6, 14, 'SELECT'], [20, 32, 'CONSTRAINT']]}],
#   ['What is the height of the person that weighs 320 pounds?',
#    {'entities': [[12, 18, 'SELECT'], [45, 48, 'CONSTRAINT']]}],
#   ['How many colleges have a DB position?',
#    {'entities': [[9, 16, 'COUNT SELECT'], [25, 27, 'CONSTRAINT']]}],
#   ['How many CFL teams are from York college?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [28, 32, 'CONSTRAINT']]}],
#   ['What CFL teams are part of Simon Fraser college?',
#    {'entities': [[5, 13, 'SELECT'], [27, 39, 'CONSTRAINT']]}],
#   ['Which players have a pick number of 27?',
#    {'entities': [[6, 12, 'SELECT'], [36, 38, 'CONSTRAINT']]}],
#   ['How many players played for adams state school?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [28, 39, 'CONSTRAINT']]}],
#   ['What college did Craig Zimmer go to?',
#    {'entities': [[5, 12, 'SELECT'], [17, 29, 'CONSTRAINT']]}],
#   ['What is the player who is lb and cfl team is saskatchewan roughriders?',
#    {'entities': [[12, 18, 'SELECT'],
#      [26, 28, 'CONSTRAINT'],
#      [45, 69, 'CONSTRAINT']]}],
#   ['What is the cfl team that has a position of ol?',
#    {'entities': [[12, 20, 'SELECT'], [44, 46, 'CONSTRAINT']]}],
#   ['What is the number of position where the pick number is 43?',
#    {'entities': [[22, 30, 'COUNT SELECT'], [56, 58, 'CONSTRAINT']]}],
#   ['What is the cfl team with ryan folk?',
#    {'entities': [[12, 20, 'SELECT'], [26, 35, 'CONSTRAINT']]}],
#   ['What release date is when kids-270 is a reference? ',
#    {'entities': [[5, 17, 'SELECT'], [26, 34, 'CONSTRAINT']]}],
#   ['who is the reference when romaji title is heartbreak sniper?',
#    {'entities': [[11, 20, 'SELECT'], [42, 59, 'CONSTRAINT']]}],
#   ['What was the  partial thromboplastin time for factor x deficiency as seen in amyloid purpura',
#    {'entities': [[14, 41, 'SELECT'], [46, 92, 'CONSTRAINT']]}],
#   ['How many conditions have an unaffected prothrombin time and a prolonged bleeding time',
#    {'entities': [[9, 18, 'COUNT SELECT'],
#      [28, 38, 'CONSTRAINT'],
#      [62, 71, 'CONSTRAINT']]}],
#   ['What was the bleeding time for the factor x deficiency as seen in amyloid purpura',
#    {'entities': [[13, 26, 'SELECT'], [35, 81, 'CONSTRAINT']]}],
#   ['What conditions had both prolonged bleeding times and prolonged partial thromboplastin times',
#    {'entities': [[5, 14, 'SELECT'], [25, 34, 'CONSTRAINT']]}],
#   ['What was the bleeding time for  factor xii deficiency',
#    {'entities': [[13, 26, 'SELECT'], [32, 53, 'CONSTRAINT']]}],
#   ['What were the bleeding times when both the platelet count was unaffected and the partial thromboplastin time was unaffected',
#    {'entities': [[14, 27, 'SELECT'], [62, 72, 'CONSTRAINT']]}],
#   ["what's the\xa0tuesday\xa0time with\xa0location\xa0being millhopper",
#    {'entities': [[11, 18, 'SELECT'], [44, 54, 'CONSTRAINT']]}],
#   ["what's the\xa0wednesday time\xa0with\xa0monday\xa0being 10:00-8:00",
#    {'entities': [[11, 20, 'SELECT'], [44, 54, 'CONSTRAINT']]}],
#   ["what's the\xa0thursday\xa0time with\xa0location\xa0being hawthorne",
#    {'entities': [[11, 19, 'SELECT'], [45, 54, 'CONSTRAINT']]}],
#   ["what's the\xa0saturday\xa0time with\xa0wednesday\xa0being 10:00-5:00",
#    {'entities': [[11, 19, 'SELECT'], [46, 56, 'CONSTRAINT']]}],
#   ["what's the\xa0thursday\xa0time with\xa0sunday\xa0being 1:00-5:00 and\xa0tuesday\xa0being 1:00-7:00",
#    {'entities': [[11, 19, 'SELECT'],
#      [43, 52, 'CONSTRAINT'],
#      [71, 80, 'CONSTRAINT']]}],
#   ["what's the\xa0monday\xa0time with\xa0tuesday\xa0being 9:00-6:00",
#    {'entities': [[11, 17, 'SELECT'], [42, 51, 'CONSTRAINT']]}],
#   ['What are all the reports where Paul Tracy had the fastest lap?',
#    {'entities': [[17, 23, 'SELECT'], [31, 41, 'CONSTRAINT']]}],
#   ['Who drove the fastest lap at the Tenneco Automotive Grand Prix of Detroit?',
#    {'entities': [[14, 25, 'SELECT'], [33, 73, 'CONSTRAINT']]}],
#   ['Who had the fastest lap in the races won by Max Papis?',
#    {'entities': [[12, 23, 'SELECT'], [44, 53, 'CONSTRAINT']]}],
#   ['In Round 6, how many winning drivers were there?',
# ...
#   ['What is the position of player Tobias Lindberg?',
#    {'entities': [[12, 20, 'SELECT'], [31, 46, 'CONSTRAINT']]}],
#   ['How many players had overall 78?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [29, 31, 'CONSTRAINT']]}],
#   ['What is the last round with club team Guelph Storm (ohl)?',
#    {'entities': [[17, 22, 'MAX SELECT'], [38, 56, 'CONSTRAINT']]}],
#   ['How many positions did player Ben Harpur play?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [30, 40, 'CONSTRAINT']]}],
#   ['What is the position of player Marcus Hogberg?',
#    {'entities': [[12, 20, 'SELECT'], [31, 45, 'CONSTRAINT']]}],
#   ['Barry University had the highest enrollment of what number?',
#    {'entities': [[0, 16, 'CONSTRAINT'], [33, 43, 'MAX SELECT']]}],
#   ['The fighting knights has what type of nickname?',
#    {'entities': [[4, 20, 'CONSTRAINT'], [30, 34, 'SELECT']]}],
#   ['Boca Raton, Florida had what joined amount?',
#    {'entities': [[0, 19, 'CONSTRAINT'], [29, 35, 'SELECT']]}],
#   ["If the enrollment is 3584, what's the largest founded?",
#    {'entities': [[21, 25, 'CONSTRAINT'], [46, 53, 'MAX SELECT']]}],
#   ['Barry University had a maximum enrollment of what?',
#    {'entities': [[0, 16, 'CONSTRAINT'], [31, 41, 'MAX SELECT']]}],
#   ['what are all the\xa0percent (1990)\xa0where\xa0state\xa0is united states',
#    {'entities': [[17, 31, 'SELECT'], [47, 60, 'CONSTRAINT']]}],
#   ['what is the total number of\xa0percent (2000)\xa0where\xa0percent (1980)\xa0is 3.4%',
#    {'entities': [[28, 42, 'COUNT SELECT'], [67, 71, 'CONSTRAINT']]}],
#   ['what are all the\xa0percent (1990)\xa0where\xa0state\xa0is mississippi',
#    {'entities': [[17, 31, 'SELECT'], [47, 58, 'CONSTRAINT']]}],
#   ['what is the maximum\xa0norwegian americans (2000)\xa0where\xa0norwegian americans (1990)\xa0is 9170',
#    {'entities': [[20, 46, 'MAX SELECT'], [83, 87, 'CONSTRAINT']]}],
#   ['what is the minimum\xa0norwegian americans (1980)\xa0where\xa0state\xa0is rhode island',
#    {'entities': [[20, 46, 'MIN SELECT'], [62, 74, 'CONSTRAINT']]}],
#   ['What is the smallest track number?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [21, 26, 'MIN SELECT']]}],
#   ['How many tracks are titled Mō Sukoshi Tōku?',
#    {'entities': [[9, 14, 'COUNT SELECT'], [27, 42, 'CONSTRAINT']]}],
#   ['What is the Japanese title for Fantasy?',
#    {'entities': [[12, 26, 'SELECT'], [31, 38, 'CONSTRAINT']]}],
#   ['Who was the GT2 winning team when the GT3 winning team was #1 PTG?',
#    {'entities': [[12, 28, 'SELECT'], [59, 65, 'CONSTRAINT']]}],
#   ['How many doubles champions were there for the Serbia f6 Futures tournament?',
#    {'entities': [[9, 26, 'COUNT SELECT'], [46, 63, 'CONSTRAINT']]}],
#   ['How many singles tournaments did Ludovic Walter win?',
#    {'entities': [[17, 27, 'COUNT SELECT'], [33, 47, 'CONSTRAINT']]}],
#   ['What is the type where the country is esp?',
#    {'entities': [[12, 16, 'SELECT'], [38, 41, 'CONSTRAINT']]}],
#   ['What is the name where p is mf?',
#    {'entities': [[12, 16, 'SELECT'], [28, 30, 'CONSTRAINT']]}],
#   ['What is the type where the name is bojan?',
#    {'entities': [[12, 16, 'SELECT'], [35, 40, 'CONSTRAINT']]}],
#   ['What was the first day cover cancellation for the University of Saskatchewan themed stamp?',
#    {'entities': [[13, 41, 'SELECT'], [50, 76, 'CONSTRAINT']]}],
#   ['Who was responsible  for the design of the Jasper National Park theme?',
#    {'entities': [[29, 35, 'SELECT'], [43, 63, 'CONSTRAINT']]}],
#   ['What is the paper type of the University of Saskatchewan themed stamp?',
#    {'entities': [[12, 22, 'SELECT'], [30, 56, 'CONSTRAINT']]}],
#   ['Who created the illustration for the stamp that was themed 100 years of scouting?',
#    {'entities': [[16, 28, 'SELECT'], [59, 80, 'CONSTRAINT']]}],
#   ['What is the number of nicknames for the meaning of god knows my journey.',
#    {'entities': [[22, 30, 'COUNT SELECT'], [51, 71, 'CONSTRAINT']]}],
#   ['What is the number of meaning where full name is chidinma anulika?',
#    {'entities': [[22, 29, 'COUNT SELECT'], [49, 65, 'CONSTRAINT']]}],
#   ['What is the nickname that means god holds my life?',
#    {'entities': [[12, 20, 'SELECT'], [32, 49, 'CONSTRAINT']]}],
#   ['Who had the high assists for game 49?',
#    {'entities': [[12, 24, 'SELECT'], [34, 36, 'CONSTRAINT']]}],
#   ['What was the score for the game in which Emeka Okafor (10) had high rebounds?',
#    {'entities': [[13, 18, 'SELECT'], [41, 58, 'CONSTRAINT']]}],
#   ['what is the total number of\xa0location\xa0where\xa0station number\xa0is c03',
#    {'entities': [[28, 36, 'COUNT SELECT'], [61, 64, 'CONSTRAINT']]}],
#   ['what are all the\xa0type\xa0where\xa0station number\xa0is c08',
#    {'entities': [[17, 21, 'SELECT'], [46, 49, 'CONSTRAINT']]}],
#   ['what are all the\xa0type\xa0where\xa0location\xa0is st ives, cambridgeshire',
#    {'entities': [[17, 21, 'SELECT'], [40, 63, 'CONSTRAINT']]}],
#   ['what are all the\xa0registrations\xa0where\xa0station number\xa0is c26',
#    {'entities': [[17, 30, 'SELECT'], [55, 58, 'CONSTRAINT']]}],
#   ['what are all the\xa0location\xa0where\xa0station number\xa0is c11',
#    {'entities': [[17, 25, 'SELECT'], [50, 53, 'CONSTRAINT']]}],
#   ['what are all the\xa0registrations\xa0where\xa0location\xa0is yaxley',
#    {'entities': [[17, 30, 'SELECT'], [49, 55, 'CONSTRAINT']]}],
#   ['What is the issue price (proof) where the issue price (bu) is 34.95?',
#    {'entities': [[12, 31, 'SELECT'], [62, 67, 'CONSTRAINT']]}],
#   ['What is the earliest year where the mintage (proof) is 25,000?',
#    {'entities': [[21, 25, 'MIN SELECT'], [55, 61, 'CONSTRAINT']]}],
#   ['What is the year that the issue price (bu) is $26.95?',
#    {'entities': [[12, 16, 'SELECT'], [46, 52, 'CONSTRAINT']]}],
#   ['What is the number of first class team with birthday of 5 december 1970?',
#    {'entities': [[22, 38, 'COUNT SELECT'], [56, 71, 'CONSTRAINT']]}],
#   ['What is the bowling style of chris harris?',
#    {'entities': [[12, 25, 'SELECT'], [29, 41, 'CONSTRAINT']]}],
#   ['Where is the first class team of date of birth 20 november 1969?',
#    {'entities': [[13, 29, 'SELECT'], [47, 63, 'CONSTRAINT']]}],
#   ["What's Javagal Srinath's batting style?",
#    {'entities': [[7, 22, 'CONSTRAINT'], [25, 38, 'SELECT']]}],
#   ['Shivnarine Chanderpaul used what bowling style? ',
#    {'entities': [[0, 22, 'CONSTRAINT'], [33, 46, 'SELECT']]}],
#   ['What is theoriginal air date of the episode directed by timothy van patten?',
#    {'entities': [[11, 28, 'SELECT'], [56, 74, 'CONSTRAINT']]}],
#   ['What is the original air date for the title "no place like hell"?',
#    {'entities': [[12, 29, 'SELECT'], [44, 64, 'CONSTRAINT']]}],
#   ['What is the season # where production code is k1505?',
#    {'entities': [[12, 20, 'MIN SELECT'], [46, 51, 'CONSTRAINT']]}],
#   ['What is the title of the episode with the original air date of february 6, 1997?',
#    {'entities': [[12, 17, 'SELECT'], [63, 79, 'CONSTRAINT']]}],
#   ['How many titles are there for season 8',
#    {'entities': [[9, 14, 'COUNT SELECT'], [37, 38, 'CONSTRAINT']]}],
#   ['what are the original air dates with a title of "spare Parts"',
#    {'entities': [[13, 30, 'SELECT'], [48, 61, 'CONSTRAINT']]}],
#   ['What was the final score on March 26?',
#    {'entities': [[19, 24, 'SELECT'], [28, 36, 'CONSTRAINT']]}],
#   ['What is the team when the score is 88–86?',
#    {'entities': [[12, 16, 'SELECT'], [35, 40, 'CONSTRAINT']]}],
#   ['What is the score when high points is from pierce (30)?',
#    {'entities': [[12, 17, 'SELECT'], [43, 54, 'CONSTRAINT']]}],
#   ['What is the game that the location attendance is pepsi center 19,894?',
#    {'entities': [[12, 16, 'MAX SELECT'], [49, 68, 'CONSTRAINT']]}],
#   ['What is the team when location attendance is us airways center 18,422?',
#    {'entities': [[12, 16, 'SELECT'], [45, 69, 'CONSTRAINT']]}],
#   ['What is the record where high assists is pierce (6)?',
#    {'entities': [[12, 18, 'SELECT'], [41, 51, 'CONSTRAINT']]}],
#   ['Who did the high points of game 5?',
#    {'entities': [[12, 23, 'SELECT'], [32, 33, 'CONSTRAINT']]}],
#   ['How many high points were at the wachovia center 18,347?',
#    {'entities': [[9, 20, 'COUNT SELECT'], [33, 55, 'CONSTRAINT']]}],
#   ['What is the team of april 25?',
#    {'entities': [[12, 16, 'SELECT'], [20, 28, 'CONSTRAINT']]}],
#   ['Who had the high rebounds when Chris Bosh (16) had the high points?',
#    {'entities': [[12, 25, 'SELECT'], [31, 46, 'CONSTRAINT']]}],
#   ['What was the score when the location attendance was Air Canada Centre 18,067?',
#    {'entities': [[13, 18, 'SELECT'], [52, 76, 'CONSTRAINT']]}],
#   ['Who had the high points on January 23?',
#    {'entities': [[12, 23, 'SELECT'], [27, 37, 'CONSTRAINT']]}],
#   ['What is San Antonio  game number?',
#    {'entities': [[8, 19, 'CONSTRAINT'], [21, 25, 'MAX SELECT']]}],
#   ['Who had high points when high rebound is gray (8)?',
#    {'entities': [[8, 19, 'SELECT'], [41, 49, 'CONSTRAINT']]}],
#   ['What is the date deng (20) had high points?',
#    {'entities': [[12, 16, 'SELECT'], [17, 26, 'CONSTRAINT']]}],
#   ['What was the score of united center 22,097?',
#    {'entities': [[13, 18, 'SELECT'], [22, 42, 'CONSTRAINT']]}],
#   ['When gordon (27) had high points, what was the number of high assists?',
#    {'entities': [[5, 16, 'CONSTRAINT'], [57, 69, 'COUNT SELECT']]}],
#   ['What was the location attendance on the date of November 15?',
#    {'entities': [[13, 32, 'SELECT'], [48, 59, 'CONSTRAINT']]}],
#   ['What date was the game for the score  L 88–79?',
#    {'entities': [[5, 9, 'SELECT'], [38, 45, 'CONSTRAINT']]}],
#   ['How many high points were there in the game 67?',
#    {'entities': [[9, 20, 'COUNT SELECT'], [44, 46, 'CONSTRAINT']]}],
#   ['Which team was played when the high points was from Wallace (20)?',
#    {'entities': [[6, 10, 'SELECT'], [52, 64, 'CONSTRAINT']]}],
#   ['Which date was the team playing @ Memphis?',
#    {'entities': [[6, 10, 'SELECT'], [32, 41, 'CONSTRAINT']]}],
#   ['Who had the high assists on the date December 12?',
#    {'entities': [[12, 24, 'SELECT'], [37, 48, 'CONSTRAINT']]}],
#   ['What date was game 57 held on?',
#    {'entities': [[5, 9, 'SELECT'], [19, 21, 'CONSTRAINT']]}],
#   ['Who did the most high rebounds in the game 24?',
#    {'entities': [[17, 30, 'SELECT'], [43, 45, 'CONSTRAINT']]}],
#   ['What was the score of the game played on December 8?',
#    {'entities': [[13, 18, 'SELECT'], [41, 51, 'CONSTRAINT']]}],
#   ['What was the total number of games where A. Johnson (6) gave the most high assists?',
#    {'entities': [[29, 33, 'COUNT SELECT'], [41, 55, 'CONSTRAINT']]}],
#   ["What's the minimal game number in the season?",
#    {'entities': [[0, 0, 'CONSTRAINT'], [19, 23, 'MIN SELECT']]}],
#   ['How had the high points when the high assists were from J. Johnson (7)?',
#    {'entities': [[12, 23, 'SELECT'], [56, 70, 'CONSTRAINT']]}],
#   ['Who had the high rebounds when the high assists were from J. Johnson (7)?',
#    {'entities': [[12, 25, 'SELECT'], [58, 72, 'CONSTRAINT']]}],
#   ['Which team was played on April 20?',
#    {'entities': [[6, 10, 'SELECT'], [25, 33, 'CONSTRAINT']]}],
#   ['Who had the high rebounds for the game on april 23?',
#    {'entities': [[12, 25, 'SELECT'], [42, 50, 'CONSTRAINT']]}],
#   ['What was the score in the game on May 11? ',
#    {'entities': [[13, 18, 'SELECT'], [34, 40, 'CONSTRAINT']]}],
#   ['What was the series count at for game 5? ',
#    {'entities': [[13, 19, 'SELECT'], [38, 39, 'CONSTRAINT']]}],
#   ['What is the lowest #?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [19, 20, 'MIN SELECT']]}],
#   ['What is the score of the game with the streak l5',
#    {'entities': [[12, 17, 'SELECT'], [46, 48, 'CONSTRAINT']]}],
#   ['What is the attendance for the home game at Los Angeles Lakers?',
#    {'entities': [[12, 22, 'SELECT'], [44, 62, 'CONSTRAINT']]}],
#   ['What is the record for the game at home Los Angeles Lakers?',
#    {'entities': [[12, 18, 'SELECT'], [40, 58, 'CONSTRAINT']]}],
#   ['What was the result and score of Game #29?',
#    {'entities': [[24, 29, 'SELECT'], [39, 41, 'CONSTRAINT']]}],
#   ['Who was the leading scorer in Game #26?',
#    {'entities': [[12, 26, 'SELECT'], [36, 38, 'CONSTRAINT']]}],
#   ['Who had the high rebounds when the score was l 84–102 (ot)?',
#    {'entities': [[12, 25, 'SELECT'], [45, 58, 'CONSTRAINT']]}],
#   ['Who had the high assists when the high rebounds were from Nick Collison (15)?',
#    {'entities': [[12, 24, 'SELECT'], [58, 76, 'CONSTRAINT']]}],
#   ['Who had the high assists @ Dallas?',
#    {'entities': [[12, 24, 'SELECT'], [25, 33, 'CONSTRAINT']]}],
#   ['Who had the high assists when the location attendance was Toyota Center 18,370?',
#    {'entities': [[12, 24, 'SELECT'], [58, 78, 'CONSTRAINT']]}],
#   ['What was the record when the high rebounds was from Nick Collison (11)?',
#    {'entities': [[13, 19, 'SELECT'], [52, 70, 'CONSTRAINT']]}],
#   ['What is the number of the leading scorer for keyarena 16,640?',
#    {'entities': [[26, 40, 'COUNT SELECT'], [45, 60, 'CONSTRAINT']]}],
#   ['What is the number of leading scorer of february 21?',
#    {'entities': [[22, 36, 'COUNT SELECT'], [40, 51, 'CONSTRAINT']]}],
#   ['What is the leading scorer on february 1?',
#    {'entities': [[12, 26, 'SELECT'], [30, 40, 'CONSTRAINT']]}],
#   [" what's the\xa0score\xa0where\xa0record\xa0is 35–33",
#    {'entities': [[12, 17, 'SELECT'], [34, 39, 'CONSTRAINT']]}],
#   [" what's the\xa0home\xa0where\xa0date\xa0is march 27",
#    {'entities': [[12, 16, 'SELECT'], [31, 39, 'CONSTRAINT']]}],
#   [" what's the\xa0date\xa0where\xa0visitor\xa0is phoenix suns and\xa0record\xa0is 31–30",
#    {'entities': [[12, 16, 'SELECT'],
#      [34, 46, 'CONSTRAINT'],
#      [61, 66, 'CONSTRAINT']]}],
#   [" what's the\xa0home team\xa0where\xa0score\xa0is l 80–88",
#    {'entities': [[12, 16, 'SELECT'], [37, 44, 'CONSTRAINT']]}],
#   [" what's the\xa0leading scorer on march 2",
#    {'entities': [[12, 26, 'SELECT'], [30, 37, 'CONSTRAINT']]}],
#   [" what's the\xa0leading scorer where home is sacramento kings",
#    {'entities': [[12, 26, 'SELECT'], [41, 57, 'CONSTRAINT']]}],
#   [" what's the\xa0team\xa0where\xa0date\xa0is february 8",
#    {'entities': [[12, 16, 'SELECT'], [31, 41, 'CONSTRAINT']]}],
#   [" what's the\xa0location attendance\xa0where\xa0high rebounds\xa0is nick collison (14)",
#    {'entities': [[12, 31, 'SELECT'], [55, 73, 'CONSTRAINT']]}],
#   [" what's the\xa0record\xa0where\xa0score\xa0is w 105–92 (ot)",
#    {'entities': [[12, 18, 'SELECT'], [34, 47, 'CONSTRAINT']]}],
#   [" what's the\xa0location attendance\xa0where\xa0record\xa0is 14–39",
#    {'entities': [[12, 31, 'SELECT'], [48, 53, 'CONSTRAINT']]}],
#   ['what is the maximum\xa0game\xa0where\xa0high points\xa0is mickaël gelabale (21)',
#    {'entities': [[20, 24, 'MAX SELECT'], [46, 67, 'CONSTRAINT']]}],
#   [" what's the\xa0record\xa0where\xa0location attendance\xa0is keyarena 13,627",
#    {'entities': [[12, 18, 'SELECT'], [48, 63, 'CONSTRAINT']]}],
#   ['What is the score for april 29?',
#    {'entities': [[12, 17, 'SELECT'], [22, 30, 'CONSTRAINT']]}],
#   ['Name the minimum game',
#    {'entities': [[0, 0, 'CONSTRAINT'], [17, 21, 'MIN SELECT']]}],
#   ['Name the high points for toyota center 18,269?',
#    {'entities': [[9, 20, 'SELECT'], [25, 45, 'CONSTRAINT']]}],
#   ["what's the\xa0preliminaries\xa0with\xa0average\xa0being 9.135",
#    {'entities': [[11, 24, 'SELECT'], [44, 49, 'CONSTRAINT']]}],
#   ["what's the\xa0evening gown\xa0with\xa0preliminaries\xa0being 9.212",
#    {'entities': [[11, 23, 'SELECT'], [49, 54, 'CONSTRAINT']]}],
#   ["what's the\xa0interview\xa0with\xa0swimsuit\xa0being 9.140",
#    {'entities': [[11, 20, 'SELECT'], [41, 46, 'CONSTRAINT']]}],
#   ["what's the\xa0evening gown\xa0with\xa0swimsuit\xa0being 9.134",
#    {'entities': [[11, 23, 'SELECT'], [44, 49, 'CONSTRAINT']]}],
#   ["what's the\xa0preliminaries\xa0with\xa0average\xa0being 9.360",
#    {'entities': [[11, 24, 'SELECT'], [44, 49, 'CONSTRAINT']]}],
#   ['How many successors were seated in the New York 20th district?',
#    {'entities': [[9, 18, 'COUNT SELECT'], [39, 52, 'CONSTRAINT']]}],
#   ['What was the result of the open cup when they finished 4th in the regular season?',
#    {'entities': [[27, 35, 'SELECT'], [55, 58, 'CONSTRAINT']]}],
#   ['How many open cups were hosted in 1993?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [34, 38, 'CONSTRAINT']]}],
#   ...]}

# %%
VALIDATION_DATA
# Out:
# {'classes': ['CONSTRAINT',
#   'COUNT SELECT',
#   'AVG SELECT',
#   'SUM SELECT',
#   'MIN SELECT',
#   'MAX SELECT',
#   'SELECT'],
#  'annotations': [['What position does the player who played for butler cc (ks) play?',
#    {'entities': [[5, 13, 'SELECT'], [45, 59, 'CONSTRAINT']]}],
#   ['Who is the player that wears number 42?',
#    {'entities': [[11, 17, 'SELECT'], [36, 38, 'CONSTRAINT']]}],
#   ['What player played guard for toronto in 1996-97?',
#    {'entities': [[5, 11, 'SELECT'],
#      [19, 24, 'CONSTRAINT'],
#      [40, 47, 'CONSTRAINT']]}],
#   ['Who are all of the players on the Westchester High School club team?',
#    {'entities': [[19, 25, 'SELECT'], [34, 57, 'CONSTRAINT']]}],
#   ['What school/club team is Amir Johnson on?',
#    {'entities': [[5, 21, 'SELECT'], [25, 37, 'CONSTRAINT']]}],
#   ['What are the total number of positions on the Toronto team in 2006-07?',
#    {'entities': [[29, 37, 'COUNT SELECT'], [62, 69, 'CONSTRAINT']]}],
#   ['What are the nationality of the players on the Fresno State school/club team?',
#    {'entities': [[13, 24, 'SELECT'], [47, 59, 'CONSTRAINT']]}],
#   ['What school/club team is Trey Johnson on?',
#    {'entities': [[5, 21, 'SELECT'], [25, 37, 'CONSTRAINT']]}],
#   ['What is the amount of trees, that require replacement when prevailing types, % is pine — 29.37 poplar — 26.12 acer negundo — 13.2?',
#    {'entities': [[12, 27, 'SELECT'],
#      [29, 53, 'SELECT'],
#      [82, 129, 'CONSTRAINT']]}],
#   ['What is the amount of trees, that require replacement when district is leninsky?',
#    {'entities': [[12, 27, 'SELECT'],
#      [29, 53, 'SELECT'],
#      [71, 79, 'CONSTRAINT']]}],
#   ['What is the district when the total amount of trees is smaller than 150817.6878461314 and amount of old trees is 1,928 (1.89%)?',
#    {'entities': [[12, 20, 'SELECT'],
#      [68, 85, 'CONSTRAINT'],
#      [113, 126, 'CONSTRAINT']]}],
#   ['What is the amount of trees, that require replacement when the district is motovilikhinsky?',
#    {'entities': [[12, 27, 'SELECT'],
#      [29, 53, 'SELECT'],
#      [75, 90, 'CONSTRAINT']]}],
#   ['What is the total amount of trees when district is leninsky?',
#    {'entities': [[12, 33, 'MAX SELECT'], [51, 59, 'CONSTRAINT']]}],
#   ['What is the district when prevailing types, % is acer negundo — 30.22 tilia — 18.6 poplar — 15.23?',
#    {'entities': [[12, 20, 'SELECT'], [49, 97, 'CONSTRAINT']]}],
#   ['When the value of "since beginning of big 12" is synonymous with its\' category, what are the in Ames values?',
#    {'entities': [[19, 44, 'CONSTRAINT'], [93, 100, 'SELECT']]}],
#   ["what's the\xa0u.s. open cup status\xa0for regular season\xa0of 4th, atlantic division ",
#    {'entities': [[11, 24, 'SELECT'], [54, 76, 'CONSTRAINT']]}],
#   ['how many division  did not qualify for u.s. open cup in 2003',
#    {'entities': [[9, 17, 'SELECT'],
#      [19, 34, 'CONSTRAINT'],
#      [56, 60, 'CONSTRAINT']]}],
#   ['which round is u.s. open cup division semifinals',
#    {'entities': [[15, 28, 'SELECT'], [29, 48, 'CONSTRAINT']]}],
#   ['what are all the playoffs for regular season is 1st, atlantic division',
#    {'entities': [[17, 25, 'SELECT'], [48, 70, 'CONSTRAINT']]}],
#   ['what are all the playoffs for u.s. open cup in 1st round',
#    {'entities': [[17, 25, 'SELECT'], [47, 56, 'CONSTRAINT']]}],
#   ['what is the total number of\xa02nd leg\xa0where\xa0aggregate\xa0is 7-2',
#    {'entities': [[28, 35, 'COUNT SELECT'], [55, 58, 'CONSTRAINT']]}],
#   [" what's the\xa0aggregate\xa0where\xa01st leg\xa0is 3–2",
#    {'entities': [[12, 21, 'SELECT'], [39, 42, 'CONSTRAINT']]}],
#   [" what's the\xa0competition\xa0where\xa0aggregate\xa0is 4–7",
#    {'entities': [[12, 23, 'SELECT'], [43, 46, 'CONSTRAINT']]}],
#   [" what's the\xa0competition\xa0where\xa01st leg\xa0is 4-1 (h)",
#    {'entities': [[12, 23, 'SELECT'], [41, 48, 'CONSTRAINT']]}],
#   ['what is the total number of\xa0round\xa0where\xa0opponents\xa0is haugar',
#    {'entities': [[28, 33, 'COUNT SELECT'], [53, 59, 'CONSTRAINT']]}],
#   [" what's the\xa01st leg\xa0where\xa0opponents\xa0is galatasaray",
#    {'entities': [[12, 19, 'SELECT'], [39, 50, 'CONSTRAINT']]}],
#   ['What is the highest Rd that Tom Sneva had the pole position in?',
#    {'entities': [[20, 22, 'MAX SELECT'], [28, 37, 'CONSTRAINT']]}],
#   ['How many winning drivers were there in the race that had a fastest lap time of 56.920?',
#    {'entities': [[9, 23, 'COUNT SELECT'], [79, 85, 'CONSTRAINT']]}],
#   ['How many reports are there in the race that Forsythe Racing won and Teo Fabi had the pole position in?',
#    {'entities': [[9, 15, 'COUNT SELECT'],
#      [44, 59, 'CONSTRAINT'],
#      [68, 76, 'CONSTRAINT']]}],
#   ['Which Rd took place at the Indianapolis 500?',
#    {'entities': [[6, 8, 'SELECT'], [27, 43, 'CONSTRAINT']]}],
#   ['What was the fastest lap time in the Escort Radar Warning 200?',
#    {'entities': [[13, 24, 'SELECT'], [37, 61, 'CONSTRAINT']]}],
#   ['What report was there for the porsche north america?',
#    {'entities': [[5, 11, 'SELECT'], [30, 51, 'CONSTRAINT']]}],
#   ['What rnds were there for the phoenix international raceway?',
#    {'entities': [[5, 8, 'SELECT'], [29, 58, 'CONSTRAINT']]}],
#   ['Who was the pole position for the rnd equalling 12?',
#    {'entities': [[12, 25, 'SELECT'], [48, 50, 'CONSTRAINT']]}],
#   ['How many reports were the for the cleveland burke lakefront airport circut?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [34, 67, 'CONSTRAINT']]}],
#   ['How many winning drivers were the for the rnd equalling 5?',
#    {'entities': [[9, 23, 'COUNT SELECT'], [56, 57, 'CONSTRAINT']]}],
#   ['The race tony bettenhausen 200 has what smallest rd?',
#    {'entities': [[9, 30, 'CONSTRAINT'], [49, 51, 'MIN SELECT']]}],
#   ['The winning team of the race, los angeles times 500 is who?',
#    {'entities': [[4, 16, 'SELECT'], [30, 51, 'CONSTRAINT']]}],
#   ['How many winning drivers in the kraco twin 125 (r2) race were there?',
#    {'entities': [[9, 23, 'COUNT SELECT'], [32, 51, 'CONSTRAINT']]}],
#   ['How many fastest laps were there for a rd that equals 10?',
#    {'entities': [[9, 20, 'COUNT SELECT'], [54, 56, 'CONSTRAINT']]}],
#   ['Provide me with the name of all the village (German) that are part of the village (Slovenian) with sele srednji kot. ',
#    {'entities': [[36, 52, 'SELECT'], [99, 115, 'CONSTRAINT']]}],
#   ['Provide me with the name of all the village (German) that are part of the village (Slovenian) with sele borovnica.',
#    {'entities': [[36, 52, 'SELECT'], [99, 113, 'CONSTRAINT']]}],
#   ['Provide me with the name of the village (German) where there is 96.9% Slovenes in 1951. ',
#    {'entities': [[32, 48, 'SELECT'], [64, 69, 'CONSTRAINT']]}],
#   ['Provide with the names of the village (German) that is part of village (Slovenian) with sele srednji kot.',
#    {'entities': [[30, 46, 'SELECT'], [88, 104, 'CONSTRAINT']]}],
#   ['What was the score of the game on November 12?',
#    {'entities': [[13, 18, 'SELECT'], [34, 45, 'CONSTRAINT']]}],
#   ['Who had high assists when they played against San Antonio?',
#    {'entities': [[8, 20, 'SELECT'], [46, 57, 'CONSTRAINT']]}],
#   ['The U.S. airdate of 4 april 2008 had a production code of what?',
#    {'entities': [[20, 32, 'CONSTRAINT'], [39, 54, 'MAX SELECT']]}],
#   ['The U.S. airdate of 8 august 2008 also had canadian airdates of what?',
#    {'entities': [[20, 33, 'CONSTRAINT'], [43, 59, 'SELECT']]}],
#   ['Which player from the 2004 CFL draft attended Wilfrid Laurier?',
#    {'entities': [[6, 12, 'SELECT'], [46, 61, 'CONSTRAINT']]}],
#   ['What position does Christian Leibl-Cote play?',
#    {'entities': [[5, 13, 'SELECT'], [19, 39, 'CONSTRAINT']]}],
#   ['Which leagues have Raiders as their mascot?',
#    {'entities': [[6, 12, 'SELECT'], [19, 26, 'CONSTRAINT']]}],
#   ['Which leagues is the Galena school in?',
#    {'entities': [[6, 12, 'SELECT'], [21, 27, 'CONSTRAINT']]}],
#   ['Which school has the Raiders as their mascot?',
#    {'entities': [[6, 12, 'SELECT'], [21, 28, 'CONSTRAINT']]}],
#   ['Where was the tournament dated nov 3, 2002?',
#    {'entities': [[14, 24, 'SELECT'], [31, 42, 'CONSTRAINT']]}],
#   ['Where is the margin of victory dated mar 28, 2004?',
#    {'entities': [[13, 30, 'SELECT'], [37, 49, 'CONSTRAINT']]}],
#   ['What is the to par dated may 4, 2003?',
#    {'entities': [[12, 18, 'SELECT'], [25, 36, 'CONSTRAINT']]}],
#   ['What date were the runner ups pat hurst juli inkster?',
#    {'entities': [[5, 9, 'SELECT'], [30, 52, 'CONSTRAINT']]}],
#   ['what are all the actor where first episode is "ambush"',
#    {'entities': [[17, 22, 'SELECT'], [46, 54, 'CONSTRAINT']]}],
#   ["what's the\xa0character\xa0with\xa0fate\xa0being deceased: knife wound",
#    {'entities': [[11, 20, 'SELECT'], [37, 58, 'CONSTRAINT']]}],
#   ["what's the\xa0actor\xa0with\xa0character\xa0being judge joseph ratner",
#    {'entities': [[11, 16, 'SELECT'], [38, 57, 'CONSTRAINT']]}],
#   ['List the scores of all games when Miami were listed as the first Semi finalist',
#    {'entities': [[9, 14, 'SELECT'], [34, 39, 'CONSTRAINT']]}],
#   ['Which round had Michael Schumacher in the pole position, David Coulthard with the fastest lap, and McLaren - Mercedes as the winning constructor?',
#    {'entities': [[6, 11, 'COUNT SELECT'],
#      [16, 34, 'CONSTRAINT'],
#      [57, 72, 'CONSTRAINT'],
#      [99, 117, 'CONSTRAINT']]}],
#   ['What was the report of the Belgian Grand Prix?',
#    {'entities': [[13, 19, 'SELECT'], [27, 45, 'CONSTRAINT']]}],
#   ['Who had the fastest lap in the Belgian Grand Prix?',
#    {'entities': [[12, 23, 'SELECT'], [31, 49, 'CONSTRAINT']]}],
#   ['When was the date successor seated when the vacator was charles e. chamberlain (r)?',
#    {'entities': [[13, 34, 'SELECT'], [56, 82, 'CONSTRAINT']]}],
#   ['Who was the successor when the vacator was chester e. holifield (d)?',
#    {'entities': [[12, 21, 'SELECT'], [43, 67, 'CONSTRAINT']]}],
#   ['Who was the vacator when the date successor seated was august 21, 1973?',
#    {'entities': [[12, 19, 'SELECT'], [55, 70, 'CONSTRAINT']]}],
#   ['What was the district when the reason for change was died January 1, 1974?',
#    {'entities': [[13, 21, 'SELECT'], [53, 73, 'CONSTRAINT']]}],
#   ['Which junctions have "replaced by bsi-35" listed in their remarks section?',
#    {'entities': [[6, 15, 'SELECT'], [22, 40, 'CONSTRAINT']]}],
#   ['How many junctions have "replaced by bsi-35" listed in their remarks section?',
#    {'entities': [[9, 18, 'COUNT SELECT'], [25, 43, 'CONSTRAINT']]}],
#   ['What unit of length is being used for the route with "replaced by us 81" in their remarks section?',
#    {'entities': [[13, 19, 'SELECT'], [54, 71, 'CONSTRAINT']]}],
#   ['Which population areas have "replaced by us 83" listed in their remarks section?',
#    {'entities': [[6, 21, 'SELECT'], [29, 46, 'CONSTRAINT']]}],
#   ['How many termini are there that have "east west" listed in their direction section, "none" listed in their junction section, and have a route name of "sh 202"?',
#    {'entities': [[9, 16, 'COUNT SELECT'],
#      [38, 47, 'CONSTRAINT'],
#      [85, 89, 'CONSTRAINT'],
#      [151, 157, 'CONSTRAINT']]}],
#   ['Find all the result(s) with the record of 2-13.',
#    {'entities': [[13, 19, 'SELECT'], [42, 46, 'CONSTRAINT']]}],
#   ['What is the vault score for the total of 56.635?',
#    {'entities': [[12, 17, 'SELECT'], [41, 47, 'CONSTRAINT']]}],
#   ['What is the total score when the score for floor exercise was 9.287?',
#    {'entities': [[12, 17, 'SELECT'], [62, 67, 'CONSTRAINT']]}],
#   [" what's the\xa0margin\xa0where\xa0runner(s)-up\xa0is phil mickelson",
#    {'entities': [[12, 18, 'SELECT'], [41, 55, 'CONSTRAINT']]}],
#   [' who is the\xa0runner(s)-up\xa0where\xa054 holes\xa0is tied for lead and\xa0margin\xa0is 5 strokes',
#    {'entities': [[12, 24, 'SELECT'],
#      [43, 56, 'CONSTRAINT'],
#      [71, 80, 'CONSTRAINT']]}],
#   [" what's the\xa0championship\xa0where\xa054 holes\xa0is 1 shot lead and\xa0runner(s)-up\xa0is chris dimarco",
#    {'entities': [[12, 24, 'SELECT'],
#      [43, 54, 'CONSTRAINT'],
#      [75, 88, 'CONSTRAINT']]}],
#   ['what is the minimum\xa0year\xa0where\xa0winning score\xa0is −8 (71-63-69-69=272)',
#    {'entities': [[20, 24, 'MIN SELECT'], [48, 68, 'CONSTRAINT']]}],
#   [" what's the\xa0championship\xa0where\xa0winning score\xa0is −12 (74-66-65-71=276)",
#    {'entities': [[12, 24, 'SELECT'], [48, 69, 'CONSTRAINT']]}],
#   [" what's the\xa054 holes\xa0where\xa0winning score\xa0is −19 (67-66-67-69=269)",
#    {'entities': [[12, 20, 'SELECT'], [44, 65, 'CONSTRAINT']]}],
#   [" what's the\xa0title\xa0where\xa0original air date\xa0is january18,2009",
#    {'entities': [[12, 17, 'SELECT'], [45, 59, 'CONSTRAINT']]}],
#   [" what's the\xa0original air date\xa0where\xa0written by\xa0is iain morris & damon beesley",
#    {'entities': [[12, 29, 'SELECT'], [50, 77, 'CONSTRAINT']]}],
#   ['What is the date of entry for the UK Albums Top 75 chart?',
#    {'entities': [[12, 25, 'SELECT'], [34, 50, 'CONSTRAINT']]}],
#   ['What was the total number of weeks on peak for the Ireland Albums Top 75 chart?',
#    {'entities': [[29, 42, 'COUNT SELECT'], [51, 72, 'CONSTRAINT']]}],
#   ['what is the total number of\xa0constancy\xa0where\xa0purity\xa0is falling',
#    {'entities': [[28, 37, 'COUNT SELECT'], [54, 61, 'CONSTRAINT']]}],
#   [" what's the\xa0permanence of the body\xa0where\xa0purity\xa0is rudra",
#    {'entities': [[12, 34, 'SELECT'], [51, 56, 'CONSTRAINT']]}],
#   [" what's the\xa0permanence of the body\xa0where\xa0purity\xa0is apprehension",
#    {'entities': [[12, 34, 'SELECT'], [51, 63, 'CONSTRAINT']]}],
#   [" what's the\xa0permanence of the body\xa0where\xa0penance\xa0is the undifferenced",
#    {'entities': [[12, 34, 'SELECT'], [52, 69, 'CONSTRAINT']]}],
#   [" what's the\xa0constancy\xa0where\xa0permanence of the body\xa0is meditation",
#    {'entities': [[12, 21, 'SELECT'], [54, 64, 'CONSTRAINT']]}],
#   [" what's the\xa0permanence of the body\xa0where\xa0constancy\xa0is interestedness",
#    {'entities': [[12, 34, 'SELECT'], [54, 68, 'CONSTRAINT']]}],
#   ['What is the original air dates for the title "firestorm"?',
#    {'entities': [[12, 29, 'SELECT'], [45, 56, 'CONSTRAINT']]}],
#   ['What is the title of the episode with the production code 624?',
#    {'entities': [[12, 17, 'SELECT'], [58, 61, 'CONSTRAINT']]}],
#   ['What is the original air date of the episode written by Karen Felix and Don Woodard?',
#    {'entities': [[12, 29, 'SELECT'], [56, 83, 'CONSTRAINT']]}],
#   ["what's the total number of\xa0species in the peruvian amazon\xa0with\xa08411 species in the world\xa0",
#    {'entities': [[27, 57, 'COUNT SELECT'], [63, 67, 'CONSTRAINT']]}],
#   ["what's the minimum\xa0species in the peruvian amazon\xa0with\xa0taxonomy\xa0s fern ( pteridophyta )",
#    {'entities': [[19, 49, 'MIN SELECT'], [64, 87, 'CONSTRAINT']]}],
#   ["what's the\xa0species in the world\xa0with\xa0peruvian amazon vs. peru (percent)\xa0 of 63",
#    {'entities': [[11, 31, 'SELECT'], [76, 78, 'CONSTRAINT']]}],
#   ["what's the minimum\xa0species in the peruvian amazon\xa0with\xa0species in peru\xa0of 1000",
#    {'entities': [[19, 49, 'MIN SELECT'], [74, 78, 'CONSTRAINT']]}],
#   ["what's the minimum\xa0species in the peruvian amazon\xa0with\xa0peru vs. world (percent)\xa0value of 7",
#    {'entities': [[19, 49, 'MIN SELECT'], [89, 90, 'CONSTRAINT']]}],
#   ["what's the maximum\xa0peru vs. world (percent)\xa0with\xa09672 species in the world\xa0",
#    {'entities': [[19, 43, 'MAX SELECT'], [49, 53, 'CONSTRAINT']]}],
#   ['What position is number 35 whose height is 6-6?',
#    {'entities': [[5, 13, 'SELECT'],
#      [24, 26, 'CONSTRAINT'],
#      [43, 46, 'CONSTRAINT']]}],
#   ['Which player who played for the Rockets for the years 1986-92?',
#    {'entities': [[6, 12, 'SELECT'], [54, 61, 'CONSTRAINT']]}],
#   ['How many members arrived on the main island in week 4?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [52, 53, 'CONSTRAINT']]}],
#   ['What was the evening gown score when the swimsuit was 9.61?',
#    {'entities': [[13, 25, 'SELECT'], [54, 58, 'CONSTRAINT']]}],
#   ['What is the swimsuit score when the interview was 9.74?',
#    {'entities': [[12, 20, 'SELECT'], [50, 54, 'CONSTRAINT']]}],
#   ['Which country had an interview score of 9.40 and average of 9.44?',
#    {'entities': [[6, 13, 'SELECT'],
#      [40, 44, 'CONSTRAINT'],
#      [60, 64, 'CONSTRAINT']]}],
#   ['Which country had the swimsuit score 9.67?',
#    {'entities': [[6, 13, 'SELECT'], [37, 41, 'CONSTRAINT']]}],
#   ['What was the average for the country with the swimsuit score of 9.57?',
#    {'entities': [[13, 20, 'SELECT'], [64, 68, 'CONSTRAINT']]}],
#   ['What was the interview score for Hawaii?',
#    {'entities': [[13, 22, 'SELECT'], [33, 39, 'CONSTRAINT']]}],
#   ['What is the date of Game 50?',
#    {'entities': [[12, 16, 'SELECT'], [25, 27, 'CONSTRAINT']]}],
#   ['Name the number of teams at the philips arena 19,335?',
#    {'entities': [[19, 23, 'COUNT SELECT'], [32, 52, 'CONSTRAINT']]}],
#   ['What is the team located at philips arena 18,227?',
#    {'entities': [[12, 16, 'SELECT'], [28, 48, 'CONSTRAINT']]}],
#   ['what are all the records with a score is w 98–91',
#    {'entities': [[17, 23, 'SELECT'], [41, 48, 'CONSTRAINT']]}],
#   ['what records have a score of l 109–116 2 ot',
#    {'entities': [[5, 11, 'SELECT'], [29, 43, 'CONSTRAINT']]}],
#   ['who are all the visitor with a record of 25–18',
#    {'entities': [[16, 23, 'SELECT'], [41, 46, 'CONSTRAINT']]}],
#   ['Which visitors have a leading scorer of roy : 25',
#    {'entities': [[6, 13, 'SELECT'], [40, 48, 'CONSTRAINT']]}],
#   ['what is the total number of dates where the scorer is gordon : 32',
#    {'entities': [[28, 32, 'COUNT SELECT'], [54, 65, 'CONSTRAINT']]}],
#   [" what's the\xa0home\xa0team where\xa0streak\xa0is l3 and\xa0leading scorer\xa0is roy : 23",
#    {'entities': [[12, 16, 'SELECT'],
#      [38, 40, 'CONSTRAINT'],
#      [63, 71, 'CONSTRAINT']]}],
#   [" what's the\xa0attendance\xa0where\xa0score\xa0is l 92–101",
#    {'entities': [[12, 22, 'SELECT'], [38, 46, 'CONSTRAINT']]}],
#   ['what is the total number of\xa0date\xa0where\xa0visitor\xa0is new jersey nets',
#    {'entities': [[28, 32, 'COUNT SELECT'], [50, 65, 'CONSTRAINT']]}],
#   [' who is the\xa0leading scorer\xa0where\xa0home\xa0is charlotte bobcats',
#    {'entities': [[12, 26, 'SELECT'], [41, 58, 'CONSTRAINT']]}],
#   [" what's the\xa0score\xa0where\xa0record\xa0is 0–2",
#    {'entities': [[12, 17, 'SELECT'], [34, 37, 'CONSTRAINT']]}],
#   ['what is the total number of\xa0record\xa0where\xa0streak\xa0is l2 and\xa0leading scorer\xa0is roy : 23',
#    {'entities': [[28, 34, 'COUNT SELECT'],
#      [51, 53, 'CONSTRAINT'],
#      [76, 84, 'CONSTRAINT']]}],
#   ['Name the number of games on june 12',
#    {'entities': [[19, 23, 'COUNT SELECT'], [28, 35, 'CONSTRAINT']]}],
#   ['Name the series on june 5',
#    {'entities': [[9, 15, 'SELECT'], [19, 25, 'CONSTRAINT']]}],
#   ['what is the somerset for the  year 2009?',
#    {'entities': [[12, 20, 'SELECT'], [35, 39, 'CONSTRAINT']]}],
#   ['what is the bristol & n. som where the somerset is ashcott and shapwick?',
#    {'entities': [[12, 28, 'SELECT'], [51, 71, 'CONSTRAINT']]}],
#   ['what is the latest year where glos & wilts is warminster?',
#    {'entities': [[19, 23, 'MAX SELECT'], [46, 56, 'CONSTRAINT']]}],
#   ['what is the glos & wilts where the bristol & somerset is lansdown?',
#    {'entities': [[12, 24, 'SELECT'], [57, 65, 'CONSTRAINT']]}],
#   ['what is the year where glos & wilts is gloucester city winget?',
#    {'entities': [[12, 16, 'SELECT'], [39, 61, 'CONSTRAINT']]}],
#   [" what's the\xa0preliminaries\xa0where\xa0evening gown\xa0is 8.988",
#    {'entities': [[12, 25, 'SELECT'], [48, 53, 'CONSTRAINT']]}],
#   [" what's the\xa0swimsuit\xa0where\xa0average\xa0is 8.670",
#    {'entities': [[12, 20, 'SELECT'], [38, 43, 'CONSTRAINT']]}],
#   [" what's the\xa0evening gown\xa0where\xa0preliminaries\xa0is 8.977",
#    {'entities': [[12, 24, 'SELECT'], [48, 53, 'CONSTRAINT']]}],
#   [" what's the\xa0preliminaries\xa0where\xa0state\xa0is south dakota",
#    {'entities': [[12, 25, 'SELECT'], [41, 53, 'CONSTRAINT']]}],
#   [" what's the\xa0evening gown\xa0where\xa0state\xa0is south dakota",
#    {'entities': [[12, 24, 'SELECT'], [40, 52, 'CONSTRAINT']]}],
#   ['what is the total number of\xa0average\xa0where\xa0evening gown\xa0is 8.988',
#    {'entities': [[28, 35, 'COUNT SELECT'], [58, 63, 'CONSTRAINT']]}],
#   ['What are the womens singles of imam sodikin irawan andi tandaputra?',
#    {'entities': [[13, 27, 'SELECT'], [31, 66, 'CONSTRAINT']]}],
#   ['What are the womens singles of naoko fukuman kurumi yonao?',
#    {'entities': [[13, 27, 'SELECT'], [31, 57, 'CONSTRAINT']]}],
#   ['What is the womens singles of marcus ellis gabrielle white?',
#    {'entities': [[12, 26, 'SELECT'], [30, 58, 'CONSTRAINT']]}],
#   ['What is the mens singles of 2008?',
#    {'entities': [[12, 24, 'SELECT'], [28, 32, 'CONSTRAINT']]}],
#   ['what is the gdp ( bn ) where capital is capital?',
#    {'entities': [[12, 22, 'SELECT'], [29, 36, 'CONSTRAINT']]}],
#   ['what is the population where the area (sq. mi.) is area (sq. mi.)?',
#    {'entities': [[12, 22, 'SELECT'], [33, 47, 'CONSTRAINT']]}],
#   ['What is the toll for light vehicles at the plaza where the toll for heavy vehicles with 2 axles is r87.00?',
#    {'entities': [[21, 34, 'SELECT'], [99, 105, 'CONSTRAINT']]}],
#   ['What is the name of the plaza where the toll for heavy vehicles with 2 axles is r87.00?',
#    {'entities': [[12, 16, 'SELECT'], [80, 86, 'CONSTRAINT']]}],
#   ['What is the location of the Carousel toll plaza?',
#    {'entities': [[12, 20, 'SELECT'], [28, 47, 'CONSTRAINT']]}],
#   ['What is the toll for light vehicles at the plaza between bela bela and modimolle?',
#    {'entities': [[21, 34, 'SELECT'], [49, 80, 'CONSTRAINT']]}],
#   ['What is the name of the plaza where the told for heavy vehicles with 2 axles is r20.50?',
#    {'entities': [[12, 16, 'SELECT'], [80, 86, 'CONSTRAINT']]}],
#   ['What is the inclination when the alt name is OPS-1584?',
#    {'entities': [[12, 23, 'SELECT'], [45, 53, 'CONSTRAINT']]}],
#   ['How many alt names does 1964-011a have?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [24, 33, 'CONSTRAINT']]}],
#   ['Who is the top scorer where gf is 41?',
#    {'entities': [[11, 21, 'SELECT'], [34, 36, 'CONSTRAINT']]}],
#   ['How many goals were scored in the 2005-06 season?',
#    {'entities': [[9, 14, 'SELECT'], [34, 41, 'CONSTRAINT']]}],
#   ['How many seasons had a rank of 16?',
#    {'entities': [[9, 15, 'COUNT SELECT'], [31, 33, 'CONSTRAINT']]}],
#   ['Who is the manager whose rank is 16?',
#    {'entities': [[11, 18, 'SELECT'], [33, 35, 'CONSTRAINT']]}],
#   ['What is the rank of manager Rob Mcdonald?',
#    {'entities': [[12, 16, 'COUNT SELECT'], [28, 40, 'CONSTRAINT']]}],
#   ['What was the result of the Top 3 episode?',
#    {'entities': [[13, 19, 'SELECT'], [27, 32, 'CONSTRAINT']]}],
#   ["What's the original artist of the song performed in the top 3 episode?",
#    {'entities': [[11, 26, 'SELECT'], [56, 61, 'CONSTRAINT']]}],
#   ['What year was the election when the # of seats won was 65?',
#    {'entities': [[18, 26, 'SELECT'], [55, 57, 'CONSTRAINT']]}],
#   ['What is the election year when the # of candidates nominated was 262?',
#    {'entities': [[12, 20, 'COUNT SELECT'], [65, 68, 'CONSTRAINT']]}],
#   ['What was the lowest # of total votes?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [20, 36, 'MIN SELECT']]}],
#   ['What is the strongs words compounded when the english spelling is jonadab?',
#    {'entities': [[12, 36, 'SELECT'], [66, 73, 'CONSTRAINT']]}],
#   ['What is the english spelling of the word that has the strongs trasliteration of y e howram?',
#    {'entities': [[12, 28, 'SELECT'], [80, 90, 'CONSTRAINT']]}],
#   ['What is the strongs # of the english spelling word jehojakin?',
#    {'entities': [[12, 21, 'SELECT'], [51, 60, 'CONSTRAINT']]}],
#   ['What is the strongs transliteration of the hebrew word יוֹחָנָן?',
#    {'entities': [[12, 35, 'SELECT'], [55, 63, 'CONSTRAINT']]}],
#   ['How many strongs transliteration of the english spelling of the work jehojakin?',
#    {'entities': [[9, 32, 'COUNT SELECT'], [69, 78, 'CONSTRAINT']]}],
#   ['Kaluvanchikudy is the main town in what DS division?',
#    {'entities': [[0, 14, 'CONSTRAINT'], [40, 51, 'SELECT']]}],
#   ['What DS division has S. L. M. Haneefa as the divisional secretary?',
#    {'entities': [[5, 16, 'SELECT'], [21, 37, 'CONSTRAINT']]}],
#   ['What is the name of the DS division where the divisional secretary is S. H. Muzammil?',
#    {'entities': [[24, 35, 'SELECT'], [70, 84, 'CONSTRAINT']]}],
#   ['How many persons had immunity in the episode when Wanda was eliminated?',
#    {'entities': [[21, 29, 'COUNT SELECT'], [50, 55, 'CONSTRAINT']]}],
#   ['What was the vote tally on the episode aired May 5, 2005?',
#    {'entities': [[13, 17, 'SELECT'], [45, 56, 'CONSTRAINT']]}],
#   ['Who received the reward on the episode where the finish was "3rd voted out day 8"?',
#    {'entities': [[17, 23, 'SELECT'], [61, 80, 'CONSTRAINT']]}],
#   ['What was the vote on the episode where the finish was "10th voted out 3rd jury member day 30"?',
#    {'entities': [[13, 17, 'SELECT'], [55, 92, 'CONSTRAINT']]}],
#   ['How many votes were taken when the outcome was "6th voted out day 12"?',
#    {'entities': [[9, 13, 'COUNT SELECT'], [48, 68, 'CONSTRAINT']]}],
#   ['What is the short stem for garbitzen?',
#    {'entities': [[12, 22, 'SELECT'], [27, 36, 'CONSTRAINT']]}],
#   ['What is the perfect stem for pozten?',
#    {'entities': [[12, 24, 'SELECT'], [29, 35, 'CONSTRAINT']]}],
#   ['Name the perfect stem for jo',
#    {'entities': [[9, 21, 'COUNT SELECT'], [26, 28, 'CONSTRAINT']]}],
#   ['What is the number for future stem for poztu?',
#    {'entities': [[23, 34, 'COUNT SELECT'], [39, 44, 'CONSTRAINT']]}],
#   ['Name the try bonus of points against at 430',
#    {'entities': [[9, 18, 'SELECT'], [40, 43, 'CONSTRAINT']]}],
#   ['Name the losing bonus of 96 points',
#    {'entities': [[9, 21, 'SELECT'], [25, 27, 'CONSTRAINT']]}],
#   ['Name the points against for 51 points',
#    {'entities': [[9, 23, 'SELECT'], [28, 30, 'CONSTRAINT']]}],
#   ['Name the tries against for 87 points',
#    {'entities': [[9, 22, 'SELECT'], [27, 29, 'CONSTRAINT']]}],
#   ['Name the tries against for drawn',
#    {'entities': [[9, 22, 'COUNT SELECT'], [27, 32, 'CONSTRAINT']]}],
#   ['Name the losing bonus for 27',
#    {'entities': [[9, 21, 'SELECT'], [26, 28, 'CONSTRAINT']]}],
#   ['What is the rear sight in the Cole model no. 735?',
#    {'entities': [[12, 22, 'SELECT'], [45, 48, 'CONSTRAINT']]}],
#   ["What's the type of muzzle devices on the models with round hand guards?",
#    {'entities': [[19, 32, 'SELECT'], [53, 58, 'CONSTRAINT']]}],
#   ['Clubs involved is 8, what number would you find from winners from previous round?',
#    {'entities': [[18, 19, 'CONSTRAINT'], [53, 80, 'SELECT']]}],
#   ['From the round name of third round; what would the new entries this round that would be found?',
#    {'entities': [[23, 34, 'CONSTRAINT'], [51, 73, 'SELECT']]}],
#   ['When looking at new entries this round and seeing 8; what number in total is there for clubs remaining?',
#    {'entities': [[50, 51, 'CONSTRAINT'], [87, 102, 'COUNT SELECT']]}],
#   ['During the first phase portion of phase and having 16 clubs involved; what would you find for the winners from previous round?',
#    {'entities': [[11, 22, 'CONSTRAINT'],
#      [51, 53, 'CONSTRAINT'],
#      [98, 125, 'SELECT']]}],
#   ['The new entries this round was shown to be 12, in which phase would you find this?',
#    {'entities': [[43, 45, 'CONSTRAINT'], [56, 61, 'SELECT']]}],
#   ['What year did University of Saskatchewan have their first season?',
#    {'entities': [[14, 40, 'CONSTRAINT'], [52, 64, 'MAX SELECT']]}],
#   ['What football stadium has a school enrollment of 43579?',
#    {'entities': [[5, 21, 'SELECT'], [49, 54, 'CONSTRAINT']]}],
#   ['How many endowments does Mosaic Stadium have?',
#    {'entities': [[9, 18, 'COUNT SELECT'], [25, 39, 'CONSTRAINT']]}],
#   ['What is the enrollment for Foote Field?',
#    {'entities': [[12, 22, 'MAX SELECT'], [27, 38, 'CONSTRAINT']]}],
#   ['Name the number of points for south korea',
#    {'entities': [[19, 25, 'COUNT SELECT'], [30, 41, 'CONSTRAINT']]}],
#   ['How many dismissals did the player Peter McGlashan have?',
#    {'entities': [[9, 19, 'SELECT'], [35, 50, 'CONSTRAINT']]}],
#   ['How many stumpings did the player Tim Latham have?',
#    {'entities': [[9, 18, 'MAX SELECT'], [34, 44, 'CONSTRAINT']]}],
#   ['List the ranks of all dismissals with a value of 4',
#    {'entities': [[9, 13, 'SELECT'], [49, 50, 'CONSTRAINT']]}],
#   ['How many innings had a total of 2 catches and 0 stumpings?',
#    {'entities': [[9, 16, 'COUNT SELECT'],
#      [32, 33, 'CONSTRAINT'],
#      [46, 47, 'CONSTRAINT']]}],
#   ['In what district was the incumbent Steve Chabot? ',
#    {'entities': [[8, 16, 'SELECT'], [35, 47, 'CONSTRAINT']]}],
#   ['Incumbent Deborah Pryce was a member of what party? ',
#    {'entities': [[10, 23, 'CONSTRAINT'], [45, 50, 'SELECT']]}],
#   ['Who were the candidates in the election where Saxby Chambliss was the incumbent?',
#    {'entities': [[13, 23, 'SELECT'], [46, 61, 'CONSTRAINT']]}],
#   ['What party does William J. Jefferson?',
#    {'entities': [[5, 10, 'SELECT'], [16, 36, 'CONSTRAINT']]}],
#   ['What were the results for incumbent Jim McCrery?',
#    {'entities': [[14, 21, 'SELECT'], [36, 47, 'CONSTRAINT']]}],
#   ['How many candidates were elected first in 1980?',
#    {'entities': [[9, 19, 'COUNT SELECT'], [42, 46, 'CONSTRAINT']]}],
#   ['What district does John Cooksey represent?',
#    {'entities': [[5, 13, 'SELECT'], [19, 31, 'CONSTRAINT']]}],
#   ['What district was John Porter elected in?',
#    {'entities': [[5, 13, 'SELECT'], [18, 29, 'CONSTRAINT']]}],
#   ['Who were the candidates in the district where Jerry Costello won?',
#    {'entities': [[13, 23, 'SELECT'], [46, 60, 'CONSTRAINT']]}],
#   ['What district is ruben hinojosa from?',
#    {'entities': [[5, 13, 'SELECT'], [17, 31, 'CONSTRAINT']]}],
#   ['What district is nick lampson from?',
#    {'entities': [[5, 13, 'SELECT'], [17, 29, 'CONSTRAINT']]}],
#   ['What year was incumbent jim mcdermott first elected?',
#    {'entities': [[24, 37, 'CONSTRAINT'], [38, 51, 'MIN SELECT']]}],
#   ['What districts does incumbent Curt Weldon hold?',
#    {'entities': [[5, 13, 'SELECT'], [30, 41, 'CONSTRAINT']]}],
#   ['How many champions were there when the first driver was hiroki yoshimoto ( 2005 )?',
#    {'entities': [[9, 18, 'SELECT'], [56, 81, 'CONSTRAINT']]}],
#   ['How many entries are there for total drivers when the Last driver for september 22, 2013 was gianmarco raimondo?',
#    {'entities': [[31, 44, 'SELECT'], [93, 111, 'CONSTRAINT']]}],
#   ['How many champions were there when the last driver for September 22, 2013 was vladimir arabadzhiev ( 2010 )?',
#    {'entities': [[9, 18, 'SELECT'], [78, 107, 'CONSTRAINT']]}],
#   ['How many champions were there when the last driver was Gianmarco Raimondo?',
#    {'entities': [[9, 18, 'SELECT'], [55, 73, 'CONSTRAINT']]}],
#   ['Name the candidates for georgia 8',
#    {'entities': [[9, 19, 'SELECT'], [24, 33, 'CONSTRAINT']]}],
#   ['Name the party of georgia 4',
#    {'entities': [[9, 14, 'SELECT'], [18, 27, 'CONSTRAINT']]}],
#   ['Name the party for jack thomas brinkley',
#    {'entities': [[9, 14, 'SELECT'], [19, 39, 'CONSTRAINT']]}],
#   ["what's the\xa0result\xa0with\xa0district being florida 7",
#    {'entities': [[11, 17, 'SELECT'], [38, 47, 'CONSTRAINT']]}],
#   ["what's the\xa0district with\xa0result\xa0being new seat democratic gain",
#    {'entities': [[11, 19, 'SELECT'], [38, 62, 'CONSTRAINT']]}],
#   [' how many\xa0candidates\xa0with\xa0result\xa0being new seat democratic gain',
#    {'entities': [[10, 20, 'COUNT SELECT'], [39, 63, 'CONSTRAINT']]}],
#   [' how many\xa0result\xa0with\xa0district being florida 14',
#    {'entities': [[10, 16, 'COUNT SELECT'], [37, 47, 'CONSTRAINT']]}],
#   ["what's the\xa0first elected\xa0with\xa0district\xa0being florida 7",
#    {'entities': [[11, 24, 'SELECT'], [45, 54, 'CONSTRAINT']]}],
#   ['who is the the\xa0candidates\xa0with\xa0incumbent\xa0being don fuqua',
#    {'entities': [[15, 25, 'SELECT'], [47, 56, 'CONSTRAINT']]}],
#   ['How many candidates were first elected in 1972?',
#    {'entities': [[9, 19, 'COUNT SELECT'], [42, 46, 'CONSTRAINT']]}],
#   ['What is the party with the candidates newt gingrich (r) 59.1% dock h. davis (d) 40.9%?',
#    {'entities': [[12, 17, 'SELECT'], [38, 85, 'CONSTRAINT']]}],
#   ['What is the earliest first elected for district georgia 1?',
#    {'entities': [[21, 34, 'MIN SELECT'], [48, 57, 'CONSTRAINT']]}],
#   ['How many incumbents were for district georgia 6?',
#    {'entities': [[9, 18, 'COUNT SELECT'], [38, 47, 'CONSTRAINT']]}],
#   ['Name the district for tim lee hall',
#    {'entities': [[9, 17, 'SELECT'], [22, 34, 'CONSTRAINT']]}],
#   ['Name the number of first elected for phil crane',
#    {'entities': [[19, 32, 'COUNT SELECT'], [37, 47, 'CONSTRAINT']]}],
#   ['Name the party for tim lee hall',
#    {'entities': [[9, 14, 'SELECT'], [19, 31, 'CONSTRAINT']]}],
#   ['Name the candidates for illinois 15',
#    {'entities': [[9, 19, 'SELECT'], [24, 35, 'CONSTRAINT']]}],
#   ['Name the first elected for abner j. mikva',
#    {'entities': [[9, 22, 'SELECT'], [27, 41, 'CONSTRAINT']]}],
#   ['Name the total number of incumbent for first elected of 1944',
#    {'entities': [[25, 34, 'COUNT SELECT'], [56, 60, 'CONSTRAINT']]}],
#   ['Who were the candidates in the Kentucky 4 voting district?',
#    {'entities': [[13, 23, 'SELECT'], [31, 41, 'CONSTRAINT']]}],
#   ['How many times was incumbent Noble Jones Gregory first elected?',
#    {'entities': [[29, 48, 'CONSTRAINT'], [49, 62, 'COUNT SELECT']]}],
#   ['What was the result in the voting district Kentucky 2?',
#    {'entities': [[13, 19, 'SELECT'], [43, 53, 'CONSTRAINT']]}],
#   ['What was the result of the election incumbent Brent Spence took place in?',
#    {'entities': [[13, 19, 'SELECT'], [46, 58, 'CONSTRAINT']]}],
#   ['Which party won in the election in voting district Kentucky 5?',
#    {'entities': [[6, 11, 'SELECT'], [51, 61, 'CONSTRAINT']]}],
#   ['List all candidates in the democratic party where the election had the incumbent Frank Chelf running.',
#    {'entities': [[9, 19, 'SELECT'],
#      [27, 37, 'CONSTRAINT'],
#      [81, 92, 'CONSTRAINT']]}],
#   ['Which district is jamie l. whitten from?',
#    {'entities': [[6, 14, 'SELECT'], [18, 34, 'CONSTRAINT']]}],
#   ['What candidates are from mississippi 6?',
#    {'entities': [[5, 15, 'SELECT'], [25, 38, 'CONSTRAINT']]}],
#   ['What is the incumbent from 1941?',
#    {'entities': [[12, 21, 'SELECT'], [27, 31, 'CONSTRAINT']]}],
#   ['What is the result for w. arthur winstead?',
#    {'entities': [[12, 18, 'SELECT'], [23, 41, 'CONSTRAINT']]}],
#   ['How many were first elected in the Arkansas 4 district?',
#    {'entities': [[14, 27, 'COUNT SELECT'], [35, 45, 'CONSTRAINT']]}],
#   ['How many districts had William F. Norrell as the incumbent?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [23, 41, 'CONSTRAINT']]}],
#   ['Which party has a first elected number bigger than 1939.0?',
#    {'entities': [[6, 11, 'SELECT'], [51, 57, 'CONSTRAINT']]}],
#   ['How many incumbents had a district of Arkansas 3?',
#    {'entities': [[9, 18, 'COUNT SELECT'], [38, 48, 'CONSTRAINT']]}],
#   ['What party did the incumbent from the Arkansas 5 district belong to? ',
#    {'entities': [[5, 10, 'SELECT'], [38, 48, 'CONSTRAINT']]}],
#   ['What party did the incumbent of the Arkansas 6 district belong to? ',
#    {'entities': [[5, 10, 'SELECT'], [36, 46, 'CONSTRAINT']]}],
#   ['What is the earliest years any of the incumbents were first elected? ',
#    {'entities': [[0, 0, 'CONSTRAINT'], [54, 67, 'MIN SELECT']]}],
#   ['What party did incumbent Brooks Hays belong to? ',
#    {'entities': [[5, 10, 'SELECT'], [25, 36, 'CONSTRAINT']]}],
#   ['What kind of party is the district in Alabama 1?',
#    {'entities': [[13, 18, 'SELECT'], [38, 47, 'CONSTRAINT']]}],
#   ['In what district was John E. Miller the incumbent? ',
#    {'entities': [[8, 16, 'SELECT'], [21, 35, 'CONSTRAINT']]}],
#   ['In how many districts was the incumbent David Delano Glover? ',
#    {'entities': [[12, 20, 'COUNT SELECT'], [40, 59, 'CONSTRAINT']]}],
#   ['What year was incumbent Claude Fuller first elected? ',
#    {'entities': [[24, 37, 'CONSTRAINT'], [38, 51, 'SELECT']]}],
#   ['What is the result for thomas s. mcmillan?',
#    {'entities': [[12, 18, 'SELECT'], [23, 41, 'CONSTRAINT']]}],
#   ['What is the party for south carolina 3?',
#    {'entities': [[12, 17, 'SELECT'], [22, 38, 'CONSTRAINT']]}],
#   ['What is the party for south carolina 3?',
#    {'entities': [[12, 17, 'SELECT'], [22, 38, 'CONSTRAINT']]}],
#   ['What is the result for south carolina 4?',
#    {'entities': [[12, 18, 'SELECT'], [23, 39, 'CONSTRAINT']]}],
#   ["what's the\xa0district with\xa0incumbent\xa0being richard j. welch",
#    {'entities': [[11, 19, 'SELECT'], [41, 57, 'CONSTRAINT']]}],
#   ["what's the\xa0districtwith\xa0party\xa0being democratic",
#    {'entities': [[11, 19, 'SELECT'], [36, 46, 'CONSTRAINT']]}],
#   ["what's the\xa0district with\xa0candidates\xa0being harry lane englebright (r) unopposed",
#    {'entities': [[11, 19, 'SELECT'], [42, 78, 'CONSTRAINT']]}],
#   [' how many\xa0candidates\xa0with\xa0district being california 7',
#    {'entities': [[10, 20, 'COUNT SELECT'], [41, 53, 'CONSTRAINT']]}],
#   ["what's the\xa0party\xa0with\xa0incumbent\xa0being william e. evans",
#    {'entities': [[11, 16, 'SELECT'], [38, 54, 'CONSTRAINT']]}],
#   ['What was the result of the election featuring william madison whittington?',
#    {'entities': [[13, 19, 'SELECT'], [46, 73, 'CONSTRAINT']]}],
#   ['what is the total number of results where the district is south carolina 5?',
#    {'entities': [[28, 34, 'COUNT SELECT'], [58, 74, 'CONSTRAINT']]}],
#   ['what year was william francis stevenson first elected?',
#    {'entities': [[14, 39, 'CONSTRAINT'], [40, 53, 'SELECT']]}],
#   ['What political party for burton e. sweet?',
#    {'entities': [[15, 20, 'SELECT'], [25, 40, 'CONSTRAINT']]}],
#   ['What is the original air date of the episode directed by Jeff Melman?',
#    {'entities': [[12, 29, 'SELECT'], [57, 68, 'CONSTRAINT']]}],
#   ['What is the median household income of sacramento?',
#    {'entities': [[12, 35, 'SELECT'], [39, 49, 'CONSTRAINT']]}],
#   ['What is the per capita income of shasta?',
#    {'entities': [[12, 29, 'SELECT'], [33, 39, 'CONSTRAINT']]}],
#   ['Name the median family income for riverside',
#    {'entities': [[9, 29, 'SELECT'], [34, 43, 'CONSTRAINT']]}],
#   ['What is the median household income of butte?',
#    {'entities': [[12, 35, 'SELECT'], [39, 44, 'CONSTRAINT']]}],
#   ['What club got 239 points against?',
#    {'entities': [[5, 9, 'SELECT'], [14, 17, 'CONSTRAINT']]}],
#   ['What is the value of the points column when the value of the column lost is "lost"',
#    {'entities': [[25, 31, 'SELECT'], [68, 72, 'CONSTRAINT']]}],
#   ['How many tries against got the club with 62 tries for?',
#    {'entities': [[9, 22, 'SELECT'], [41, 43, 'CONSTRAINT']]}],
#   ['What group info is available for the 56.5 kg weight?',
#    {'entities': [[5, 10, 'SELECT'], [37, 41, 'CONSTRAINT']]}],
#   ['What was the result for the railway stakes race?',
#    {'entities': [[13, 19, 'SELECT'], [28, 42, 'CONSTRAINT']]}],
#   ['What district is incument terry kilgore from?',
#    {'entities': [[5, 13, 'SELECT'], [26, 39, 'CONSTRAINT']]}],
#   ['How many times was incumbent onzlee ware elected?',
#    {'entities': [[29, 40, 'CONSTRAINT'], [41, 48, 'COUNT SELECT']]}],
#   ['What was the last year someone was elected to the 14th district?',
#    {'entities': [[35, 42, 'MAX SELECT'], [50, 54, 'CONSTRAINT']]}],
#   ['What was the score against san antonio?',
#    {'entities': [[13, 18, 'SELECT'], [27, 38, 'CONSTRAINT']]}],
#   ['Who was the opposing team for game 53?',
#    {'entities': [[21, 25, 'SELECT'], [35, 37, 'CONSTRAINT']]}],
#   ['How many games were played when the record was 26-21?',
#    {'entities': [[9, 13, 'COUNT SELECT'], [47, 52, 'CONSTRAINT']]}],
#   ['How many people had the high assists @ minnesota?',
#    {'entities': [[24, 36, 'COUNT SELECT'], [37, 48, 'CONSTRAINT']]}],
#   ["what's the\xa0turing complete\xa0with\xa0numeral system\xa0being decimal",
#    {'entities': [[11, 26, 'SELECT'], [53, 60, 'CONSTRAINT']]}],
#   ["what's the\xa0name\xa0with\xa0first operational\xa0being march 1945",
#    {'entities': [[11, 15, 'SELECT'], [45, 55, 'CONSTRAINT']]}],
#   ["what's the\xa0turing complete\xa0with\xa0name\xa0being atanasoff–berry computer (us)",
#    {'entities': [[11, 26, 'SELECT'], [43, 72, 'CONSTRAINT']]}],
#   ["what's the\xa0first operational\xa0with\xa0programming\xa0being not programmable—single purpose",
#    {'entities': [[11, 28, 'SELECT'], [52, 83, 'CONSTRAINT']]}],
#   ['How many times is denmark ranked in technology?',
#    {'entities': [[18, 25, 'CONSTRAINT'], [36, 46, 'COUNT SELECT']]}],
#   ['What is the environment rating of the country with an overall average rating of 4.7?',
#    {'entities': [[12, 23, 'SELECT'], [80, 83, 'CONSTRAINT']]}],
#   ['What is the migration rating when trade is 5.7?',
#    {'entities': [[12, 21, 'SELECT'], [43, 46, 'CONSTRAINT']]}],
#   ['What is the lowest PF?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [19, 21, 'MIN SELECT']]}],
#   ['What is the PA when the skip is Colleen Jones?',
#    {'entities': [[12, 14, 'SELECT'], [32, 45, 'CONSTRAINT']]}],
#   ['What is the minimum PA when ends lost is 45?',
#    {'entities': [[20, 22, 'MIN SELECT'], [41, 43, 'CONSTRAINT']]}],
#   ['What is the PA when the PF is 77?',
#    {'entities': [[12, 14, 'SELECT'], [30, 32, 'CONSTRAINT']]}],
#   ['What is the total number of ends won when the locale is Northwest Territories Yukon?',
#    {'entities': [[28, 36, 'COUNT SELECT'], [56, 83, 'CONSTRAINT']]}],
#   ["what's the\xa0won\xa0with\xa0try bonus\xa0being 8",
#    {'entities': [[11, 14, 'SELECT'], [36, 37, 'CONSTRAINT']]}],
#   ["what's the\xa0club\xa0with\xa0losing bonus\xa0being 1",
#    {'entities': [[11, 15, 'SELECT'], [40, 41, 'CONSTRAINT']]}],
#   [' how many\xa0losing bonus\xa0with\xa0won\xa0being 10 and\xa0points against\xa0being 283',
#    {'entities': [[10, 22, 'COUNT SELECT'],
#      [38, 40, 'CONSTRAINT'],
#      [66, 69, 'CONSTRAINT']]}],
#   [' how many\xa0points against\xa0with\xa0tries for\xa0being 43',
#    {'entities': [[10, 24, 'COUNT SELECT'], [46, 48, 'CONSTRAINT']]}],
#   ["what's the\xa0points\xa0with\xa0tries for\xa0being 64",
#    {'entities': [[11, 17, 'SELECT'], [39, 41, 'CONSTRAINT']]}],
#   ["what's the\xa0won\xa0with\xa0points against\xa0being 597",
#    {'entities': [[11, 14, 'SELECT'], [41, 44, 'CONSTRAINT']]}],
#   ['What is the type of the player whose transfer fee was €20m?',
#    {'entities': [[12, 16, 'SELECT'], [54, 58, 'CONSTRAINT']]}],
#   ['What is the EU status of ESP?',
#    {'entities': [[12, 14, 'SELECT'], [25, 28, 'CONSTRAINT']]}],
#   ['How many numbers are ending in 1 year?',
#    {'entities': [[6, 7, 'COUNT SELECT'], [31, 37, 'CONSTRAINT']]}],
#   ['which station is located in edmonton',
#    {'entities': [[6, 13, 'SELECT'], [28, 36, 'CONSTRAINT']]}],
#   ['What was the outcome for the match in 1989?',
#    {'entities': [[13, 20, 'SELECT'], [38, 42, 'CONSTRAINT']]}],
#   ['How many locations hosted Claudia Kohde-Kilsch Eva Pfaff?',
#    {'entities': [[9, 17, 'COUNT SELECT'], [26, 56, 'CONSTRAINT']]}],
#   ['Who were all of the opponents in 1984?',
#    {'entities': [[20, 29, 'SELECT'], [33, 37, 'CONSTRAINT']]}],
#   ['How many partners were there in 1988?',
#    {'entities': [[9, 16, 'COUNT SELECT'], [32, 36, 'CONSTRAINT']]}],
#   ["What is Maksim Botin's position? ",
#    {'entities': [[8, 20, 'CONSTRAINT'], [23, 31, 'SELECT']]}],
#   ["What is Roman Bragin's position? ",
#    {'entities': [[8, 20, 'CONSTRAINT'], [23, 31, 'SELECT']]}],
#   ['How many position does Teodor Salparov play on? ',
#    {'entities': [[9, 17, 'COUNT SELECT'], [23, 38, 'CONSTRAINT']]}],
#   ['what is the minimum\xa0points\xa0with\xa0goals for/against\xa0being 8-5',
#    {'entities': [[20, 26, 'MIN SELECT'], [56, 59, 'CONSTRAINT']]}],
#   ["what's the\xa0w-l-d\xa0with\xa0position\xa0being 1",
#    {'entities': [[11, 16, 'SELECT'], [37, 38, 'CONSTRAINT']]}],
#   ['who is the the\xa0club (city/town)\xa0with\xa0goals for/against\xa0being 14-2',
#    {'entities': [[15, 31, 'SELECT'], [61, 65, 'CONSTRAINT']]}],
#   ["what's the\xa0goals for/against\xa0with\xa0w-l-d\xa0being 3-1-1",
#    {'entities': [[11, 28, 'SELECT'], [46, 51, 'CONSTRAINT']]}],
#   ['what is the minimum\xa0games played\xa0with\xa0goals for/against\xa0being 7-5',
#    {'entities': [[20, 32, 'MIN SELECT'], [62, 65, 'CONSTRAINT']]}],
#   ['What is the nationality of the player whose college/junior/club team (league) is Seattle Thunderbirds (WHL)?',
#    {'entities': [[12, 23, 'SELECT'], [81, 107, 'CONSTRAINT']]}],
#   ['What is the college/junior/club team (league) of the player who was pick number 130?',
#    {'entities': [[12, 45, 'SELECT'], [80, 83, 'CONSTRAINT']]}],
#   ['What the name of  the school where the last win in 2007-08?',
#    {'entities': [[22, 28, 'SELECT'], [51, 58, 'CONSTRAINT']]}],
#   ['What is the name of the school where the year of last win is 1985-86?',
#    {'entities': [[24, 30, 'SELECT'], [61, 68, 'CONSTRAINT']]}],
#   ['How many total finals where there when the last win was in 2012-13?',
#    {'entities': [[9, 21, 'SELECT'], [59, 66, 'CONSTRAINT']]}],
#   ['Name the team for 1993-94 for 32',
#    {'entities': [[9, 13, 'SELECT'], [30, 32, 'CONSTRAINT']]}],
#   ['Name the most played',
#    {'entities': [[0, 0, 'CONSTRAINT'], [14, 20, 'MAX SELECT']]}],
#   ['Name the total number of 1992-93 for 115 points',
#    {'entities': [[25, 32, 'COUNT SELECT'], [37, 40, 'CONSTRAINT']]}],
#   ['Name the most played',
#    {'entities': [[0, 0, 'CONSTRAINT'], [14, 20, 'MAX SELECT']]}],
#   ['Name the most touchdowns for field goals being 1',
#    {'entities': [[14, 24, 'MAX SELECT'], [47, 48, 'CONSTRAINT']]}],
#   ['Name the starter for position being left end',
#    {'entities': [[9, 16, 'SELECT'], [36, 44, 'CONSTRAINT']]}],
#   ['Name the fewest touchdowns',
#    {'entities': [[0, 0, 'CONSTRAINT'], [16, 26, 'MIN SELECT']]}],
#   ['Name the most extra points for right tackle',
#    {'entities': [[14, 26, 'MAX SELECT'], [31, 43, 'CONSTRAINT']]}],
#   ['Name the number of points for field goals being 1',
#    {'entities': [[19, 25, 'COUNT SELECT'], [48, 49, 'CONSTRAINT']]}],
#   ['Name the most touchdowns for becker ',
#    {'entities': [[14, 24, 'MAX SELECT'], [29, 35, 'CONSTRAINT']]}],
#   ['Name the extra points for left guard',
#    {'entities': [[9, 21, 'SELECT'], [26, 36, 'CONSTRAINT']]}],
#   ['Name the least touchdowns for 11 points',
#    {'entities': [[15, 25, 'MIN SELECT'], [30, 32, 'CONSTRAINT']]}],
#   ['Name the most field goals',
#    {'entities': [[0, 0, 'CONSTRAINT'], [14, 25, 'MAX SELECT']]}],
#   ['Name the number of field goals for 19 extra points',
#    {'entities': [[19, 30, 'COUNT SELECT'], [35, 37, 'CONSTRAINT']]}],
#   ['Name the most touchdowns for norcross',
#    {'entities': [[14, 24, 'MAX SELECT'], [29, 37, 'CONSTRAINT']]}],
#   ['Name who was famous for finished in 9th',
#    {'entities': [[13, 23, 'SELECT'], [36, 39, 'CONSTRAINT']]}],
#   ['Name the finished for exited day 13',
#    {'entities': [[9, 17, 'SELECT'], [29, 35, 'CONSTRAINT']]}],
#   ['Name the entered for famous for page 3 model',
#    {'entities': [[9, 16, 'SELECT'], [32, 44, 'CONSTRAINT']]}],
#   ['Name the finished for kerry katona',
#    {'entities': [[9, 17, 'COUNT SELECT'], [22, 34, 'CONSTRAINT']]}],
#   ['Name the finished for exited of day 13',
#    {'entities': [[9, 17, 'SELECT'], [32, 38, 'CONSTRAINT']]}],
#   ['Name the number of celebrity for athlete',
#    {'entities': [[19, 28, 'COUNT SELECT'], [33, 40, 'CONSTRAINT']]}],
#   ['What is the total number of values for "Teleplay by" category for series # 35?',
#    {'entities': [[40, 51, 'COUNT SELECT'], [75, 77, 'CONSTRAINT']]}],
#   ['Who is the teleplay by when the director is Rob Bailey?',
#    {'entities': [[11, 22, 'SELECT'], [44, 54, 'CONSTRAINT']]}],
#   ['What is the season # for a teleplay by Richard Price and the director is Steve Shill?',
#    {'entities': [[12, 20, 'SELECT'],
#      [39, 52, 'CONSTRAINT'],
#      [73, 84, 'CONSTRAINT']]}],
#   ['What are the names of all unix shell with PowerShell (Cmdlet) of select-string?',
#    {'entities': [[26, 36, 'SELECT'], [65, 78, 'CONSTRAINT']]}],
#   ['What are all values of CMD.EXE / COMMAND.COM for the unix shell echo?',
#    {'entities': [[23, 44, 'SELECT'], [64, 68, 'CONSTRAINT']]}],
#   ['If Powershell (alias) is cpi, copy, cp, what are all corresponding descriptions. ',
#    {'entities': [[25, 38, 'CONSTRAINT'], [67, 78, 'SELECT']]}],
#   ['When the cmd.exe / command.com is type, what are all associated values for powershell (cmdlet)?',
#    {'entities': [[34, 38, 'CONSTRAINT'], [75, 94, 'SELECT']]}],
#   ['How many values of powershell (cmdlet) are valid when unix shell is env, export, set, setenv?',
# ...
#    {'entities': [[6, 29, 'SELECT'], [89, 98, 'CONSTRAINT']]}],
#   ['Which administrative division had a 2011 population of 606,699 according to the siak database?',
#    {'entities': [[6, 29, 'SELECT'], [55, 62, 'CONSTRAINT']]}],
#   ['What was the installation date in El Paso, Texas? ',
#    {'entities': [[13, 30, 'SELECT'], [34, 48, 'CONSTRAINT']]}],
#   ['What is the chapter for Illinois Wesleyan? ',
#    {'entities': [[12, 19, 'SELECT'], [24, 41, 'CONSTRAINT']]}],
#   ['What does the inactive state for University of Texas, El Paso? ',
#    {'entities': [[14, 22, 'SELECT'], [33, 61, 'CONSTRAINT']]}],
#   ['What is the installation date for the Delta Chapter?',
#    {'entities': [[12, 29, 'SELECT'], [38, 43, 'CONSTRAINT']]}],
#   ['What is the lowest when pohang steelyard is the stadium?',
#    {'entities': [[12, 18, 'SELECT'], [24, 40, 'CONSTRAINT']]}],
#   ['How many match played have the highest as 32250?',
#    {'entities': [[9, 21, 'SELECT'], [42, 47, 'CONSTRAINT']]}],
#   ['Which team has a match played of 10 4?',
#    {'entities': [[6, 10, 'SELECT'], [33, 37, 'CONSTRAINT']]}],
#   ['What is the highest when pohang steelers is the team?',
#    {'entities': [[12, 19, 'SELECT'], [25, 40, 'CONSTRAINT']]}],
#   ['Which team has 7757 as the average?',
#    {'entities': [[6, 10, 'SELECT'], [15, 19, 'CONSTRAINT']]}],
#   ['Name the average grade for şımarık tarkan',
#    {'entities': [[9, 22, 'SELECT'], [27, 41, 'CONSTRAINT']]}],
#   ['What are the poles is #08 Miller racing?',
#    {'entities': [[13, 18, 'SELECT'], [22, 39, 'CONSTRAINT']]}],
#   ['What is the most recent year where the average start is 8.5?',
#    {'entities': [[24, 28, 'MAX SELECT'], [56, 59, 'CONSTRAINT']]}],
#   ['How many times was the opponent country India? ',
#    {'entities': [[32, 39, 'COUNT SELECT'], [40, 45, 'CONSTRAINT']]}],
#   ['What are the dates where the versus team is South Africa?',
#    {'entities': [[13, 17, 'SELECT'], [44, 56, 'CONSTRAINT']]}],
#   ['How many different outcomes did the final with Paul McNamee as a partner have?',
#    {'entities': [[19, 26, 'COUNT SELECT'], [47, 59, 'CONSTRAINT']]}],
#   ['How many different partners were played with during French Open (0/1)?',
#    {'entities': [[19, 26, 'COUNT SELECT'], [52, 69, 'CONSTRAINT']]}],
#   ['How many production codes are there for "the sub"?',
#    {'entities': [[9, 24, 'COUNT SELECT'], [40, 49, 'CONSTRAINT']]}],
#   ['What is the production code for episode 3 of the season?',
#    {'entities': [[12, 27, 'SELECT'], [40, 41, 'CONSTRAINT']]}],
#   ['Which orchestra has a recording year of 1951?',
#    {'entities': [[6, 15, 'SELECT'], [40, 44, 'CONSTRAINT']]}],
#   ['Where is the orchestra when the year of recording is 1934?',
#    {'entities': [[13, 22, 'SELECT'], [53, 57, 'CONSTRAINT']]}],
#   ['Name the former codes for  merged into panama ( pa , pan , 591 )',
#    {'entities': [[9, 21, 'SELECT'], [27, 64, 'CONSTRAINT']]}],
#   ['Name the total number for period of validity for upper volta',
#    {'entities': [[26, 44, 'COUNT SELECT'], [49, 60, 'CONSTRAINT']]}],
#   ['Who was the winner of seat no 4 for the election on January 25, 1967',
#    {'entities': [[22, 31, 'SELECT'], [52, 68, 'CONSTRAINT']]}],
#   ['Who is seat no 1 when the mayor was john j. seguier',
#    {'entities': [[7, 16, 'SELECT'], [36, 51, 'CONSTRAINT']]}],
#   ['Who was seat no 6 when seat no 1 and seat no 5 were jacques lachapelle and donald s. dutton',
#    {'entities': [[8, 17, 'SELECT'],
#      [52, 70, 'CONSTRAINT'],
#      [75, 91, 'CONSTRAINT']]}],
#   ['which election had seat no 1 filled by jacques lachapelle but seat no 5 was filled by g. sanscartier',
#    {'entities': [[6, 14, 'SELECT'],
#      [39, 57, 'CONSTRAINT'],
#      [86, 100, 'CONSTRAINT']]}],
#   ['How many season did the team lost in round 1 with a GP of 64?',
#    {'entities': [[9, 15, 'COUNT SELECT'],
#      [29, 44, 'CONSTRAINT'],
#      [58, 60, 'CONSTRAINT']]}],
#   ['What was the season where the team reached a GP of 244?',
#    {'entities': [[13, 19, 'SELECT'], [51, 54, 'CONSTRAINT']]}],
#   ['What was the maximum OTL if L is 28?',
#    {'entities': [[21, 24, 'MAX SELECT'], [33, 35, 'CONSTRAINT']]}],
#   ['What was the highest SOL where the team lost in round 3?',
#    {'entities': [[21, 24, 'MAX SELECT'], [40, 55, 'CONSTRAINT']]}],
#   ['What was the minimum L if the GA is 272?',
#    {'entities': [[21, 22, 'MIN SELECT'], [36, 39, 'CONSTRAINT']]}],
#   ['Who has the fastest lap where Benoît Tréluyer got the pole position?',
#    {'entities': [[12, 23, 'SELECT'], [30, 45, 'CONSTRAINT']]}],
#   ['What was the earlier round where Takashi Kogure got the fastest lap?',
#    {'entities': [[21, 26, 'MIN SELECT'], [33, 47, 'CONSTRAINT']]}],
#   ['What was the margin of the match on 19 Jan 2002?',
#    {'entities': [[13, 19, 'SELECT'], [36, 47, 'CONSTRAINT']]}],
#   ['How many vacators were in the Pennsylvania 33rd district?',
#    {'entities': [[9, 16, 'COUNT SELECT'], [30, 47, 'CONSTRAINT']]}],
#   ['Who was the successor for the Kentucky 2nd district?',
#    {'entities': [[12, 21, 'SELECT'], [30, 42, 'CONSTRAINT']]}],
#   ['Name the date successor seated for contested election; served until february 14, 1794',
#    {'entities': [[9, 30, 'SELECT'], [35, 85, 'CONSTRAINT']]}],
#   ['Name the date successor seated for delegate seat established',
#    {'entities': [[9, 30, 'SELECT'], [35, 60, 'CONSTRAINT']]}],
#   ['Name the date successor seated is south carolina 3rd',
#    {'entities': [[9, 30, 'SELECT'], [34, 52, 'CONSTRAINT']]}],
#   ['What is the number of vacators when the successor was William H. Wells ( F )?',
#    {'entities': [[22, 29, 'COUNT SELECT'], [54, 76, 'CONSTRAINT']]}],
#   ['What is the total number of successors when the vacator was William North ( F )',
#    {'entities': [[28, 37, 'COUNT SELECT'], [60, 79, 'CONSTRAINT']]}],
#   ['How many vacators have October 22, 1808 as date successor seated?',
#    {'entities': [[9, 16, 'COUNT SELECT'], [23, 39, 'CONSTRAINT']]}],
#   ['What is the date successor seated where Massachusetts 2nd is the district?',
#    {'entities': [[12, 33, 'SELECT'], [40, 57, 'CONSTRAINT']]}],
#   ['Who is the successor when the reason for change is seat declared vacant January 2, 1808',
#    {'entities': [[11, 20, 'SELECT'], [51, 87, 'CONSTRAINT']]}],
#   ['Which district has John Culpepper (f) as the vacator?',
#    {'entities': [[6, 14, 'SELECT'], [19, 37, 'CONSTRAINT']]}],
#   ['What is the reason for change when maryland 6th is the district? ',
#    {'entities': [[12, 29, 'SELECT'], [35, 47, 'CONSTRAINT']]}],
#   ['Who is the vacator when south carolina 4th is the district?',
#    {'entities': [[11, 18, 'SELECT'], [24, 42, 'CONSTRAINT']]}],
#   ['Who is the successor when florida territory at-large is the district?',
#    {'entities': [[11, 20, 'SELECT'], [26, 52, 'CONSTRAINT']]}],
#   ['Name the vacator for reason for change died january 12, 1826',
#    {'entities': [[9, 16, 'SELECT'], [39, 60, 'CONSTRAINT']]}],
#   ['Name the reason for change pennsylvania 13th',
#    {'entities': [[9, 26, 'SELECT'], [27, 44, 'CONSTRAINT']]}],
#   ['Name the vacator for died august 13, 1826',
#    {'entities': [[9, 16, 'SELECT'], [21, 41, 'CONSTRAINT']]}],
#   ['Name the successor for elected january 26, 1837',
#    {'entities': [[9, 18, 'COUNT SELECT'], [23, 47, 'CONSTRAINT']]}],
#   ['Name the successor for north carolina 13th',
#    {'entities': [[9, 18, 'SELECT'], [23, 42, 'CONSTRAINT']]}],
#   ['Name the date successor seated for pennsylvania 17th',
#    {'entities': [[9, 30, 'SELECT'], [35, 52, 'CONSTRAINT']]}],
#   ['which is the biggest production code?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [21, 36, 'MAX SELECT']]}],
#   ["What is the least year when men's singles is Raju Rai?",
#    {'entities': [[18, 22, 'MIN SELECT'], [45, 53, 'CONSTRAINT']]}],
#   ['How many outcomes are listed when the final opponent was Johan Kriek? ',
#    {'entities': [[9, 16, 'COUNT SELECT'], [57, 68, 'CONSTRAINT']]}],
#   ['What date was the race in 1968 run on?',
#    {'entities': [[5, 9, 'SELECT'], [26, 30, 'CONSTRAINT']]}],
#   ['What year had a race with 301* laps?',
#    {'entities': [[5, 9, 'SELECT'], [26, 30, 'CONSTRAINT']]}],
#   ['Name the most pos for west bromwich albion club',
#    {'entities': [[14, 17, 'MAX SELECT'], [22, 42, 'CONSTRAINT']]}],
#   ['Name the points for 212 respect toward opponents',
#    {'entities': [[9, 15, 'SELECT'], [20, 23, 'CONSTRAINT']]}],
#   ['Name the pos for west ham united',
#    {'entities': [[9, 12, 'MIN SELECT'], [17, 32, 'CONSTRAINT']]}],
#   ['Name the most red/yellow cards for positive play being 255',
#    {'entities': [[14, 30, 'MAX SELECT'], [55, 58, 'CONSTRAINT']]}],
#   ['Name the date of birth for 27/07/86',
#    {'entities': [[0, 4, 'SELECT'], [27, 35, 'CONSTRAINT']]}],
#   ['Name the least number',
#    {'entities': [[0, 0, 'CONSTRAINT'], [15, 21, 'MIN SELECT']]}],
#   ['Name the nationality for francesco guglielmi',
#    {'entities': [[9, 20, 'SELECT'], [25, 44, 'CONSTRAINT']]}],
#   ['How many points did player 7 score in the challenge cup?',
#    {'entities': [[27, 28, 'CONSTRAINT'], [42, 55, 'COUNT SELECT']]}],
#   ["What is Kris doolan's league number?",
#    {'entities': [[8, 19, 'CONSTRAINT'], [22, 28, 'COUNT SELECT']]}],
#   ["What is bryan hodge's player number",
#    {'entities': [[8, 19, 'CONSTRAINT'], [22, 23, 'COUNT SELECT']]}],
#   ['What was the lowest number of points scored in the league cup?',
#    {'entities': [[0, 0, 'CONSTRAINT'], [51, 61, 'MIN SELECT']]}],
#   ["What was the Cowboys' record for Nov. 5, 1966?",
#    {'entities': [[22, 28, 'SELECT'], [33, 39, 'CONSTRAINT']]}],
#   ['What was the conference when Arizona State won the regular season?',
#    {'entities': [[13, 23, 'SELECT'], [29, 42, 'CONSTRAINT']]}],
#   ['Who is the tournament winner in the Atlantic Coast Conference?',
#    {'entities': [[11, 28, 'SELECT'], [36, 61, 'CONSTRAINT']]}],
#   ['Which county had a 3.6% unemployment rate?',
#    {'entities': [[6, 12, 'SELECT'], [19, 23, 'CONSTRAINT']]}],
#   ['What is the status of the county that has a 17.3% poverty rate?',
#    {'entities': [[12, 18, 'SELECT'], [44, 49, 'CONSTRAINT']]}],
#   ['What is the market income per capita of the county with the 9.4% poverty rate?',
#    {'entities': [[12, 36, 'SELECT'], [60, 64, 'CONSTRAINT']]}],
#   ["How many status' are there with a population of 90565?",
#    {'entities': [[9, 15, 'COUNT SELECT'], [48, 53, 'CONSTRAINT']]}],
#   ['What is the status of the county with per capita market income of $24,326?',
#    {'entities': [[12, 18, 'SELECT'], [66, 73, 'CONSTRAINT']]}],
#   ['What is the unemployment rate for the county with a market income per capita of $20,958?',
#    {'entities': [[12, 29, 'COUNT SELECT'], [80, 87, 'CONSTRAINT']]}],
#   ['What is the original air date for production code 1ark79?',
#    {'entities': [[12, 29, 'SELECT'], [50, 56, 'CONSTRAINT']]}],
#   ['How many rounds were there in the 2006 davis cup europe/africa group I?',
#    {'entities': [[9, 14, 'COUNT SELECT'], [34, 70, 'CONSTRAINT']]}],
#   ['Where does the team play May 3?',
#    {'entities': [[15, 19, 'SELECT'], [25, 30, 'CONSTRAINT']]}],
#   ['What team was the game on February 27 played against?',
#    {'entities': [[5, 9, 'SELECT'], [26, 37, 'CONSTRAINT']]}],
#   ['What was the score of the game in which Brook Lopez (8) did the high rebounds?',
#    {'entities': [[13, 18, 'SELECT'], [40, 55, 'CONSTRAINT']]}],
#   ['Who did the high assists in the game played on February 9?',
#    {'entities': [[12, 24, 'SELECT'], [47, 57, 'CONSTRAINT']]}],
#   ['What was the record in the game against Memphis?',
#    {'entities': [[13, 19, 'SELECT'], [40, 47, 'CONSTRAINT']]}],
#   ["What's the highest game number for a game in which Kris Humphries (8) did the high rebounds?",
#    {'entities': [[19, 23, 'MAX SELECT'], [51, 69, 'CONSTRAINT']]}],
#   ['When 1-1 is the series who is the team?',
#    {'entities': [[5, 8, 'CONSTRAINT'], [34, 38, 'SELECT']]}],
#   ['When george hill (29) has the highest amount of points what is the date?',
#    {'entities': [[5, 21, 'CONSTRAINT'], [67, 71, 'SELECT']]}],
#   ['Name the audition city for hyatt regency chicago',
#    {'entities': [[9, 22, 'SELECT'], [27, 48, 'CONSTRAINT']]}],
#   ['Name the callback date for amway arena',
#    {'entities': [[9, 22, 'SELECT'], [27, 38, 'CONSTRAINT']]}],
#   ['Name the guest judge for first audition date being july 9, 2009',
#    {'entities': [[9, 20, 'COUNT SELECT'], [51, 63, 'CONSTRAINT']]}],
#   ['Name the total number of golden tickets being rosen shingle creek resort',
#    {'entities': [[25, 39, 'COUNT SELECT'], [46, 72, 'CONSTRAINT']]}],
#   ['Name the production code for number in season being 21',
#    {'entities': [[9, 24, 'SELECT'], [52, 54, 'CONSTRAINT']]}],
#   ['Name the production code by paul lieberstein',
#    {'entities': [[9, 24, 'SELECT'], [28, 44, 'CONSTRAINT']]}],
#   ['How much time, in minutes, did Chanel Chisholm play?',
#    {'entities': [[18, 25, 'COUNT SELECT'], [31, 46, 'CONSTRAINT']]}],
#   ['What is the lowest number of games played by the player with 50 steals?',
#    {'entities': [[29, 41, 'MIN SELECT'], [61, 63, 'CONSTRAINT']]}],
#   ['Name the original air date for " don\'t look a smith horse in the mouth "',
#    {'entities': [[9, 26, 'SELECT'], [33, 70, 'CONSTRAINT']]}],
#   ['Name the number of year for 6–3, 6–2 hard surface',
#    {'entities': [[19, 23, 'COUNT SELECT'],
#      [28, 36, 'CONSTRAINT'],
#      [37, 41, 'CONSTRAINT']]}],
#   ['Name the surface for philadelphia',
#    {'entities': [[9, 16, 'SELECT'], [21, 33, 'CONSTRAINT']]}],
#   ['Name the championship for clay and corrado barazzutti',
#    {'entities': [[9, 21, 'SELECT'],
#      [26, 30, 'CONSTRAINT'],
#      [35, 53, 'CONSTRAINT']]}],
#   ['Name the year for clay for boston and guillermo vilas',
#    {'entities': [[9, 13, 'SELECT'],
#      [18, 22, 'CONSTRAINT'],
#      [27, 33, 'CONSTRAINT'],
#      [38, 53, 'CONSTRAINT']]}],
#   ['Name the total number of opponent in the final for 6–2, 6–1, 6–3',
#    {'entities': [[25, 46, 'COUNT SELECT'], [51, 64, 'CONSTRAINT']]}],
#   ['What is every year where opponent in the final is John Mcenroe at Wimbledon?',
#    {'entities': [[14, 18, 'SELECT'],
#      [50, 62, 'CONSTRAINT'],
#      [66, 75, 'CONSTRAINT']]}],
#   ['What is every score in the final for opponent in final John Mcenroe at US Open?',
#    {'entities': [[14, 32, 'SELECT'],
#      [55, 67, 'CONSTRAINT'],
#      [71, 78, 'CONSTRAINT']]}],
#   ['What is every surface with a score in the final of 6–4, 6–7 (1–7) , 6–7 (4–7) , 4–6?',
#    {'entities': [[14, 21, 'SELECT'], [51, 83, 'CONSTRAINT']]}],
#   ['What was the score in game 6?',
#    {'entities': [[13, 18, 'SELECT'], [27, 28, 'CONSTRAINT']]}],
#   ['On what date was the attendance at TD Garden 18,624?',
#    {'entities': [[8, 12, 'SELECT'], [35, 51, 'CONSTRAINT']]}],
#   ['How many people got high points in game 35?',
#    {'entities': [[20, 31, 'COUNT SELECT'], [40, 42, 'CONSTRAINT']]}],
#   ['Who did the high rebounds in the game where Carl Landry (23) did the most high points?',
#    {'entities': [[12, 25, 'SELECT'], [44, 60, 'CONSTRAINT']]}],
#   ["What's the end score of the game where Shane Battier (8) did the high rebounds?",
#    {'entities': [[15, 20, 'SELECT'], [39, 56, 'CONSTRAINT']]}],
#   ['Who had the most high assists with a record of 32-19?',
#    {'entities': [[17, 29, 'SELECT'], [47, 52, 'CONSTRAINT']]}],
#   ['How many games had been played when the Mavericks had a 46-22 record?',
#    {'entities': [[9, 13, 'MAX SELECT'], [56, 61, 'CONSTRAINT']]}],
#   ['Name the date for score w 109–95 (ot)',
#    {'entities': [[9, 13, 'SELECT'], [24, 37, 'CONSTRAINT']]}],
#   ['Name the high points for pepsi center 19,155',
#    {'entities': [[9, 20, 'SELECT'], [25, 44, 'CONSTRAINT']]}],
#   ['If the record is 5-8, what is the team name?',
#    {'entities': [[17, 20, 'CONSTRAINT'], [34, 38, 'SELECT']]}],
#   ['If the record is 5-5, what is the game maximum?',
#    {'entities': [[17, 20, 'CONSTRAINT'], [34, 38, 'MAX SELECT']]}],
#   ['If the record is 6-8, what was the score?',
#    {'entities': [[17, 20, 'CONSTRAINT'], [35, 40, 'SELECT']]}],
#   ['What was the record in the game in which Jeff Green (14) did the most high rebounds?',
#    {'entities': [[13, 19, 'SELECT'], [41, 56, 'CONSTRAINT']]}],
#   ['Name the team for january 4',
#    {'entities': [[9, 13, 'SELECT'], [18, 27, 'CONSTRAINT']]}],
#   ...]}

# %% [markdown]
# The cells below convert the training and validation data into a .spacy object.

# %%
for text, annot in tqdm(TRAIN_DATA['annotations']):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents
    db.add(doc)

db.to_disk("/content/drive/MyDrive/train_spacy/training_data.spacy") # save the docbin object

# %%
for text, annot in tqdm(VALIDATION_DATA['annotations']):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents
    db.add(doc)

db.to_disk("/content/drive/MyDrive/train_spacy/validation_data.spacy") # save the docbin object

# %% [markdown]
# The spacy-transfomers library is installed to train the transformer based roBERTa model for custom NER.

# %%
# !pip install spacy-transformers
# Out:
# Installing collected packages: spacy-alignments, spacy-transformers
# Successfully installed spacy-alignments-0.9.1 spacy-transformers-1.3.3

# %% [markdown]
# The base_config.cfg file contains important specifications for the model like the initial learning rate, batch size, optimizer, and more. Many of these values are set by default in the spaCy documentation and are recommended for training. We created a base_config file to optimize for accuracy using [this](https://spacy.io/usage/training) link.

# %%
# !python -m spacy init fill-config '/content/drive/MyDrive/train_spacy/base_config.cfg' '/content/drive/MyDrive/train_spacy/config.cfg'
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/drive/MyDrive/train_spacy/config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %% [markdown]
# Below are logs from training our custom NER model. Training partially stopped automatically due to lack of memory in our Colab environment. However, we tried to train for as many epochs as possible to minimize loss.

# %%
! python -m spacy train '/content/drive/MyDrive/train_spacy/config.cfg' --output '/content/drive/MyDrive/train_spacy' --paths.train '/content/drive/MyDrive/train_spacy/training_data.spacy' --paths.dev '/content/drive/MyDrive/train_spacy/validation_data.spacy' --gpu-id 0
# Out:
# ℹ Saving to output directory: /content/drive/MyDrive/train_spacy
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# config.json: 100% 481/481 [00:00<00:00, 2.07MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 15.7MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 19.2MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 27.8MB/s]
# model.safetensors: 100% 499M/499M [00:03<00:00, 153MB/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0         598.41    503.67    0.10    0.07    0.19    0.00
#   0     200       63143.67  63328.46   83.22   81.55   84.96    0.83
#   0     400       10549.95  12257.28   89.38   89.97   88.81    0.89
#   1     600        7383.50   9204.58   90.66   89.80   91.53    0.91
#   1     800        6140.97   7854.69   91.84   91.97   91.71    0.92
#   1    1000        6132.84   7714.92   92.81   92.79   92.83    0.93
#   2    1200        4941.20   6416.94   93.25   93.04   93.46    0.93
#   2    1400        4727.20   6116.29   93.38   93.32   93.44    0.93
#   3    1600        4539.19   6016.72   93.37   93.43   93.31    0.93
#   3    1800        3742.67   5145.83   94.15   94.02   94.27    0.94
#   3    2000        3905.32   5193.21   94.35   94.42   94.28    0.94
#   4    2200        3492.34   4703.00   94.83   94.77   94.89    0.95
#   4    2400        3292.49   4439.58   94.69   94.55   94.82    0.95
#   4    2600        3589.49   4768.54   95.23   95.21   95.26    0.95
#   5    2800        2987.64   3964.67   95.17   95.08   95.27    0.95
#   5    3000        2895.53   3953.56   95.29   95.19   95.39    0.95
#   6    3200        2847.57   3873.81   95.20   95.32   95.07    0.95
#   6    3400        2669.01   3605.68   95.40   95.52   95.29    0.95
#   6    3600        2546.75   3544.07   95.74   95.79   95.69    0.96
#   7    3800        2437.88   3313.52   95.85   95.87   95.83    0.96
#   7    4000        2529.87   3317.36   95.93   95.97   95.89    0.96
#   8    4200        2601.89   3253.67   95.90   95.92   95.88    0.96
#   8    4400        2039.72   2923.57   96.05   96.22   95.89    0.96
#   8    4600        2143.42   2931.60   96.16   96.13   96.20    0.96
#   9    4800        2073.43   2867.37   96.34   96.31   96.38    0.96
#   9    5000        2121.24   2798.62   96.27   96.20   96.35    0.96
#   9    5200        2227.03   2949.77   96.50   96.51   96.49    0.97
#  10    5400        1838.16   2561.38   96.47   96.53   96.41    0.96
#  10    5600        1811.90   2506.44   96.52   96.53   96.52    0.97
#  11    5800        1835.23   2463.58   96.65   96.68   96.63    0.97
#  11    6000        1820.39   2363.14   96.81   96.85   96.77    0.97
#  11    6200        1846.69   2388.86   97.02   97.00   97.03    0.97
#  12    6400        1587.07   2222.22   96.83   96.77   96.89    0.97
#  12    6600        1637.29   2193.79   96.83   96.82   96.83    0.97
#  13    6800        1683.63   2286.76   97.23   97.17   97.29    0.97
#  13    7000        1510.99   1959.40   97.07   97.04   97.10    0.97
#  13    7200        1451.72   1993.39   97.43   97.43   97.43    0.97
#  14    7400        1418.56   1988.79   97.34   97.36   97.32    0.97
#  14    7600        1168.91   1739.78   97.42   97.36   97.47    0.97
#  14    7800        1249.66   1855.84   97.61   97.61   97.60    0.98
#  15    8000        1175.10   1671.43   97.50   97.50   97.51    0.98
#  15    8200        1249.95   1736.94   97.69   97.70   97.68    0.98
#  16    8400        1216.39   1635.15   97.77   97.77   97.78    0.98
#  16    8600        1184.72   1539.24   97.79   97.79   97.79    0.98
#  16    8800        1099.96   1493.63   97.82   97.79   97.85    0.98
#  17    9000        1012.65   1491.43   97.97   97.97   97.97    0.98
#  17    9200        1022.86   1357.15   97.89   97.87   97.90    0.98
#  17    9400         961.50   1398.12   98.13   98.12   98.15    0.98
#  18    9600         902.53   1205.37   98.06   98.05   98.07    0.98
#  18    9800         982.72   1296.04   98.13   98.14   98.12    0.98
#  19   10000         898.38   1205.46   98.09   98.10   98.09    0.98
#  19   10200         883.83   1188.42   98.26   98.22   98.31    0.98
#  19   10400         855.92   1096.81   98.22   98.24   98.19    0.98
#  20   10600         739.27   1048.40   98.29   98.27   98.30    0.98
#  20   10800         817.02   1058.93   98.37   98.38   98.36    0.98
#  21   11000         726.58   1016.23   98.45   98.43   98.47    0.98
#  21   11200         637.09    890.45   98.50   98.48   98.51    0.98
#  21   11400         655.43    899.35   98.53   98.52   98.54    0.99
#  22   11600         720.31    883.00   98.48   98.47   98.49    0.98
#  22   11800         669.15    846.07   98.57   98.53   98.60    0.99
#  22   12000         691.96    837.39   98.50   98.48   98.52    0.99
#  23   12200         580.07    756.03   98.57   98.54   98.60    0.99
#  23   12400         492.67    740.70   98.62   98.60   98.65    0.99
#  24   12600         496.99    706.97   98.60   98.59   98.61    0.99
#  24   12800         537.07    644.64   98.60   98.59   98.61    0.99
#  24   13000         498.62    721.50   98.63   98.60   98.67    0.99
#  25   13200         500.49    621.12   98.69   98.70   98.69    0.99
#  25   13400         400.54    579.33   98.68   98.67   98.68    0.99
#  26   13600         461.92    623.87   98.72   98.73   98.72    0.99
#  26   13800         418.45    533.91   98.74   98.74   98.74    0.99
#  26   14000         364.86    552.63   98.72   98.70   98.75    0.99
# ^C

# %% [markdown]
# Test the model after training.

# %%
import spacy_transformers
nlp_ner = spacy.load("/content/drive/MyDrive/train_spacy/model-best")

# %%
doc = nlp_ner('''What is the maximum capacity of the Otkrytie Arena stadium?''') # input sample text

# %%
spacy.displacy.render(doc, style="ent", jupyter=True) # display in Colab
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">What is the maximum
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     capacity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MAX SELECT</span>
# </mark>
#  of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Otkrytie Arena
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CONSTRAINT</span>
# </mark>
#  stadium?</div></span>

# %% [markdown]
# The cells below can be used to download the model from Google Drive for external use.

# %%
# !zip -r /content/file.zip '/content/drive/MyDrive/train_spacy/model-best'
# Out:
#   adding: content/drive/MyDrive/train_spacy/model-best/ (stored 0%)
#   adding: content/drive/MyDrive/train_spacy/model-best/tokenizer (deflated 81%)
#   adding: content/drive/MyDrive/train_spacy/model-best/meta.json (deflated 56%)
#   adding: content/drive/MyDrive/train_spacy/model-best/config.cfg (deflated 61%)
#   adding: content/drive/MyDrive/train_spacy/model-best/transformer/ (stored 0%)
#   adding: content/drive/MyDrive/train_spacy/model-best/transformer/cfg (stored 0%)
#   adding: content/drive/MyDrive/train_spacy/model-best/transformer/model (deflated 11%)
#   adding: content/drive/MyDrive/train_spacy/model-best/ner/ (stored 0%)
#   adding: content/drive/MyDrive/train_spacy/model-best/ner/model (deflated 8%)
#   adding: content/drive/MyDrive/train_spacy/model-best/ner/moves (deflated 48%)
#   adding: content/drive/MyDrive/train_spacy/model-best/ner/cfg (deflated 33%)
#   adding: content/drive/MyDrive/train_spacy/model-best/vocab/ (stored 0%)
#   adding: content/drive/MyDrive/train_spacy/model-best/vocab/strings.json (deflated 73%)
#   adding: content/drive/MyDrive/train_spacy/model-best/vocab/vectors (deflated 45%)
#   adding: content/drive/MyDrive/train_spacy/model-best/vocab/key2row (stored 0%)
#   adding: content/drive/MyDrive/train_spacy/model-best/vocab/vectors.cfg (stored 0%)
#   adding: content/drive/MyDrive/train_spacy/model-best/vocab/lookups.bin (stored 0%)

# %%
from google.colab import files
files.download("/content/file.zip")
